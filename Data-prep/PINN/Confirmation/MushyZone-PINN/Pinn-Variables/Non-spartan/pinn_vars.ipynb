# %% [markdown]
# # Import Libaries

# %%
import sys
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler, SubsetRandomSampler, random_split

from pinn_loss import loss_fn_data, l1_regularization, pde_loss, boundary_loss, ic_loss, accuracy
from Input_vec_gen import input_gen, temp_data_gen, st_gen, meshgen, input_3gen
from Datagen import sim1d
from sampler import g_sampler, strat_sampler

# %% [markdown]
# # Generate Data

# %%
## Load Data

# %%
L1 = sim1d(rho_l=2460.0, rho_s=2710.0, k_l=104.0, k_s= 96.2, cp_l=1245.3, cp_s=963.0, \
            t_surr=298.0, L_fusion=389000, temp_init=913.0, htc_l=10.0,htc_r= 12.0, length =15.0e-3)
                
L2 = sim1d(rho_l=2460.0, rho_s=2710.0, k_l=104.0, k_s= 96.2, cp_l=1245.3, cp_s=963.0, \
            t_surr=298.0, L_fusion=389000, temp_init=913.0, htc_l=12.0,htc_r= 12.0, length =15.0e-3)
L3 = sim1d(rho_l=2460.0, rho_s=2710.0, k_l=104.0, k_s= 96.2, cp_l=1245.3, cp_s=963.0, 
               t_surr=298.0, L_fusion=389000, temp_init=913.0, htc_l=15.0,htc_r= 12.0, length =15.0e-3)
# Out:
# Stable
# Stable
# Stable

# %% [markdown]
# ## Prepare the input and output vectors

# %%
length = 15.0e-3 # length of the rod
time_end =40 # end time of the simulation
htc_l_1,htc_l_2,htc_l_3 = 10.0,12.0,15.0 # htc values for the 3 simulations

# Extract the temperature, space and time vectors from the simulation data
T1,space_1,time_1 = L1[0],L1[1],L1[2] # 1st element is the temperature matrix, 2nd is the space vector, 3rd is the time vector
T2,space_2,time_2 = L2[0],L2[1],L2[2]
T3,space_3,time_3 = L3[0],L3[1],L3[2]

Temp_1,space_a1, time_a1 = np.array(T1),np.array(space_1),np.array(time_1)
Temp_2,space_a2, time_a2 = np.array(T2),np.array(space_2),np.array(time_2)
Temp_3,space_a3, time_a3 = np.array(T3),np.array(space_3),np.array(time_3)

# generate htc_l values

# %%
scaler = StandardScaler()

# Normalize the data

Temp_1n,Temp_2n, Temp_3n = scaler.fit_transform(Temp_1),scaler.fit_transform(Temp_2),scaler.fit_transform(Temp_3)
Space_1n,Space_2n, Space_3n = scaler.fit_transform(space_a1.reshape(-1,1)),scaler.fit_transform(space_a2.reshape(-1,1)),scaler.fit_transform(space_a3.reshape(-1,1))
Time_1n,Time_2n, Time_3n = scaler.fit_transform(time_a1.reshape(-1,1)),scaler.fit_transform(time_a2.reshape(-1,1)),scaler.fit_transform(time_a3.reshape(-1,1))

print(Temp_1n.shape,Space_1n.shape,Time_1n.shape)
# Out:
# (31470, 50) (50, 1) (31470, 1)

# %% [markdown]
# ## standardize outputs

# %%
Temp_1_pde,Temp_1_ic,Temp_1_bc_l,Temp_1_bc_r = temp_data_gen(Temp_1n,Space_1n,Time_1n)
Temp_2_pde,Temp_2_ic,Temp_2_bc_l,Temp_2_bc_r = temp_data_gen(Temp_2n,Space_2n,Time_2n)
Temp_3_pde,Temp_3_ic,Temp_3_bc_l,Temp_3_bc_r = temp_data_gen(Temp_3n,Space_3n,Time_3n)



Temp_1n_tr,Temp_2n_tr,Temp_3n_tr = Temp_1n.flatten(),Temp_2n.flatten(),Temp_3n.flatten()
Temp_all = np.concatenate((Temp_1n_tr,Temp_2n_tr,Temp_3n_tr))
print(Temp_all.shape)
Temp_1pde_tr,Temp_2pde_tr,Temp_3pde_tr = Temp_1_pde.flatten(),Temp_2_pde.flatten(),Temp_3_pde.flatten()
Temp_pde_all = np.concatenate((Temp_1pde_tr,Temp_2pde_tr,Temp_3pde_tr))


Temp_1ic_tr,Temp_2ic_tr,Temp_3ic_tr = Temp_1_ic.flatten(),Temp_2_ic.flatten(),Temp_3_ic.flatten()
Temp_ic_all = np.concatenate((Temp_1ic_tr,Temp_2ic_tr,Temp_3ic_tr))


Temp_1bcl_tr,Temp_2bcl_tr,Temp_3bcl_tr = Temp_1_bc_l.flatten(),Temp_2_bc_l.flatten(),Temp_3_bc_l.flatten()
Temp_bcl_all = np.concatenate((Temp_1bcl_tr,Temp_2bcl_tr,Temp_3bcl_tr))


Temp_1bcr_tr,Temp_2bcr_tr,Temp_3bcr_tr = Temp_1_bc_r.flatten(),Temp_2_bc_r.flatten(),Temp_3_bc_r.flatten()
Temp_bcr_all = np.concatenate((Temp_1bcr_tr,Temp_2bcr_tr,Temp_3bcr_tr))
# Out:
# (4720500,)

# %% [markdown]
# Generate input vector

# %% [markdown]
# ## Generate htc inputs

# %%
sp_pde_1,sp_ic_1,sp_bc_l_1,sp_bc_r_1 = st_gen(Space_1n,Time_1n)[0],st_gen(Space_1n,Time_1n)[1],\
                                        st_gen(Space_1n,Time_1n)[2],st_gen(Space_1n,Time_1n)[3]
t_pde_1,t_ic_1,t_bc_l_1,t_bc_r_1 = st_gen(Space_1n,Time_1n)[4],st_gen(Space_1n,Time_1n)[5],\
                                    st_gen(Space_1n,Time_1n)[6],st_gen(Space_1n,Time_1n)[7]

print(sp_pde_1.shape,sp_ic_1.shape,sp_bc_l_1.shape,sp_bc_r_1.shape)
print(t_pde_1.shape,t_ic_1.shape,t_bc_l_1.shape,t_bc_r_1.shape)
# Out:
# (31469, 48) (50,) (31470,) (31470,)
# (31469, 48) (50,) (31470,) (31470,)

# %% [markdown]
# ## Region 1

# %%
sp_pdtr_1 ,t_pdtr_1 = meshgen(sp_pde_1,t_pde_1)
htc_lpde_1 = np.ones(sp_pdtr_1.shape)* htc_l_1
inp_pde_1 = input_3gen(sp_pdtr_1,t_pdtr_1,htc_lpde_1)

sp_ic_1,t_ic_1 = meshgen(sp_ic_1,t_ic_1)
htc_ic_l_1 = np.ones(sp_ic_1.shape)*htc_l_1
inp_ic_1 = input_3gen(sp_ic_1,t_ic_1,htc_ic_l_1)

sp_bc_l_1,t_bc_l_1 = meshgen(sp_bc_l_1,t_bc_l_1)
htc_bc_l_1 = np.ones(sp_bc_l_1.shape)*htc_l_1
inp_bc_l_1 = input_3gen(sp_bc_l_1,t_bc_l_1,htc_bc_l_1)

sp_bc_r_1,t_bc_r_1 = meshgen(sp_bc_r_1,t_bc_r_1)
htc_bc_r_1 = np.ones(sp_bc_r_1.shape)*htc_l_1
inp_bc_r_1 = input_3gen(sp_bc_r_1,t_bc_r_1,htc_bc_r_1) 

Space_1n_tr,Time_1n_tr = np.meshgrid(Space_1n,Time_1n)
Space_tr_1,Time_tr_1 = meshgen(Space_1n_tr,Time_1n_tr)
htc_tr_1 = np.ones(Space_tr_1.shape)*htc_l_1
inp_tr_1 = input_3gen(Space_tr_1,Time_tr_1,htc_tr_1)

# %% [markdown]
# ## Region 2

# %%
sp_pdtr_2 ,t_pdtr_2 = meshgen(sp_pde_1,t_pde_1)
htc_lpde_2 = np.ones(sp_pdtr_2.shape)* htc_l_2
inp_pde_2 = input_3gen(sp_pdtr_2,t_pdtr_2,htc_lpde_2)

sp_ic_2,t_ic_2 = meshgen(sp_ic_1,t_ic_1)
htc_ic_l_2 = np.ones(sp_ic_2.shape)*htc_l_2
inp_ic_2 = input_3gen(sp_ic_2,t_ic_2,htc_ic_l_2)

sp_bc_l_2,t_bc_l_2 = meshgen(sp_bc_l_1,t_bc_l_1)
htc_bc_l_2 = np.ones(sp_bc_l_2.shape)*htc_l_2
inp_bc_l_2 = input_3gen(sp_bc_l_2,t_bc_l_2,htc_bc_l_2)

sp_bc_r_2,t_bc_r_2 = meshgen(sp_bc_r_1,t_bc_r_1)
htc_bc_r_2 = np.ones(sp_bc_r_2.shape)*htc_l_2
inp_bc_r_2 = input_3gen(sp_bc_r_2,t_bc_r_2,htc_bc_r_2)

Space_2n_tr,Time_2n_tr = np.meshgrid(Space_2n,Time_2n)
Space_tr_2,Time_tr_2 = meshgen(Space_2n_tr,Time_2n_tr)
htc_tr_2 = np.ones(Space_tr_2.shape)*htc_l_2
inp_tr_2 = input_3gen(Space_tr_2,Time_tr_2,htc_tr_2)

# %% [markdown]
# ## Region 3

# %%
sp_pdtr_3 ,t_pdtr_3 = meshgen(sp_pde_1,t_pde_1)
htc_lpde_3 = np.ones(sp_pdtr_3.shape)* htc_l_3
inp_pde_3 = input_3gen(sp_pdtr_3,t_pdtr_3,htc_lpde_3)

sp_ic_3,t_ic_3 = meshgen(sp_ic_1,t_ic_1)
htc_ic_l_3 = np.ones(sp_ic_3.shape)*htc_l_3
inp_ic_3 = input_3gen(sp_ic_3,t_ic_3,htc_ic_l_3)

sp_bc_l_3,t_bc_l_3 = meshgen(sp_bc_l_1,t_bc_l_1)
htc_bc_l_3 = np.ones(sp_bc_l_3.shape)*htc_l_3
inp_bc_l_3 = input_3gen(sp_bc_l_3,t_bc_l_3,htc_bc_l_3)

sp_bc_r_3,t_bc_r_3 = meshgen(sp_bc_r_1,t_bc_r_1)
htc_bc_r_3 = np.ones(sp_bc_r_3.shape)*htc_l_3
inp_bc_r_3 = input_3gen(sp_bc_r_3,t_bc_r_3,htc_bc_r_3)

Space_3n_tr,Time_3n_tr = np.meshgrid(Space_3n,Time_3n)
Space_tr_3,Time_tr_3 = meshgen(Space_3n_tr,Time_3n_tr)
htc_tr_3 = np.ones(Space_tr_3.shape)*htc_l_3
inp_tr_3 = input_3gen(Space_tr_3,Time_tr_3,htc_tr_3)

print(inp_pde_1.shape,inp_ic_1.shape,inp_bc_l_1.shape,inp_bc_r_1.shape,inp_tr_1.shape)
# Out:
# (1510512, 3) (50, 3) (31470, 3) (31470, 3) (1573500, 3)

# %% [markdown]
# ## Combining all data

# %%
sp_pdtr_all = np.concatenate((sp_pdtr_1,sp_pdtr_2,sp_pdtr_3),axis=0)
t_pdtr_all = np.concatenate((t_pdtr_1,t_pdtr_2,t_pdtr_3),axis=0)
htc_lpde_all = np.concatenate((htc_lpde_1,htc_lpde_2,htc_lpde_3),axis=0)
inp_pde_all = np.concatenate((inp_pde_1,inp_pde_2,inp_pde_3),axis=0)
print(inp_pde_all.shape)
sp_ic_all = np.concatenate((sp_ic_1,sp_ic_2,sp_ic_3),axis=0)
t_ic_all = np.concatenate((t_ic_1,t_ic_2,t_ic_3),axis=0)
htc_ic_l_all = np.concatenate((htc_ic_l_1,htc_ic_l_2,htc_ic_l_3),axis=0)
inp_ic_all = np.concatenate((inp_ic_1,inp_ic_2,inp_ic_3),axis=0)

print(inp_ic_all.shape)
sp_bc_l_all = np.concatenate((sp_bc_l_1,sp_bc_l_2,sp_bc_l_3),axis=0)
t_bc_l_all = np.concatenate((t_bc_l_1,t_bc_l_2,t_bc_l_3),axis=0)
htc_bc_l_all = np.concatenate((htc_bc_l_1,htc_bc_l_2,htc_bc_l_3),axis=0)
inp_bc_l_all = np.concatenate((inp_bc_l_1,inp_bc_l_2,inp_bc_l_3),axis=0)
print(inp_bc_l_all.shape)
sp_bc_r_all = np.concatenate((sp_bc_r_1,sp_bc_r_2,sp_bc_r_3),axis=0)
t_bc_r_all = np.concatenate((t_bc_r_1,t_bc_r_2,t_bc_r_3),axis=0)
htc_bc_r_all = np.concatenate((htc_bc_r_1,htc_bc_r_2,htc_bc_r_3),axis=0)
inp_bc_r_all = np.concatenate((inp_bc_r_1,inp_bc_r_2,inp_bc_r_3),axis=0)
print(inp_bc_r_all.shape)
Space_all_tr = np.concatenate((Space_tr_1,Space_tr_2,Space_tr_3),axis=0)
Time_all_tr = np.concatenate((Time_tr_1,Time_tr_2,Time_tr_3),axis=0)
htc_tr_all = np.concatenate((htc_tr_1,htc_tr_2,htc_tr_3),axis=0)
inp_tr_all = np.concatenate((inp_tr_1,inp_tr_2,inp_tr_3),axis=0)
print(inp_tr_all.shape)
# Out:
# (4531536, 3)
# (150, 3)
# (94410, 3)
# (94410, 3)
# (4720500, 3)

# %% [markdown]
# # Plot the Analytical Data

# %%
# plt a subplot of the three plots
space_cord, time_cord = np.meshgrid(np.arange(T1.shape[1]), np.arange(T1.shape[0]))
fig, axs = plt.subplots(1, 3, figsize=(20, 8))
axs[0].pcolormesh(space_cord, time_cord, T1, cmap='coolwarm', shading='auto')
axs[0].set_title('htc_l = 10.0')
axs[0].set_xlabel('Space')
axs[0].set_ylabel('Time')
axs[1].pcolormesh(space_cord, time_cord, T2, cmap='coolwarm', shading='auto')
axs[1].set_title('htc_l = 12.0')
axs[1].set_xlabel('Space')
axs[1].set_ylabel('Time')
axs[2].pcolormesh(space_cord, time_cord, T3, cmap='coolwarm', shading='auto')
axs[2].set_title('htc_l = 15.0')
axs[2].set_xlabel('Space')
axs[2].set_ylabel('Time')
plt.show()

# %%
# check for gpu
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device2 = torch.device('cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Sampler Preparation

# %%
t_surr = 298.0 # Surrounding temperature
t_init = 913.0 # Initial temperature
inputs_sam, T_sam = strat_sampler(inp_tr_all,Temp_all,0.01) # Sample the input and output data
inputs_pde_sam, T_pde_sam = strat_sampler(inp_pde_all,Temp_pde_all,0.01) # Sample the input and output data for pde 
inputs_i_sam,T_ic_sam = strat_sampler(inp_ic_all,Temp_ic_all,1) # Sample the input and output data for initial condition
inputs_b_l_sam,T_bcl_sam = strat_sampler(inp_bc_l_all,Temp_bcl_all,0.2) # Sample the input and output data for boundary condition left
inputs_b_r_sam, T_bcr_sam = strat_sampler(inp_bc_r_all, Temp_bcr_all, 0.2) # Sample the input and output data for boundary condition right

print(inputs_sam.shape,T_sam.shape)
print(inputs_pde_sam.shape,T_pde_sam.shape)
print(inputs_i_sam.shape,T_ic_sam.shape)
print(inputs_b_l_sam.shape,T_bcl_sam.shape)
print(inputs_b_r_sam.shape,T_bcr_sam.shape)
# Out:
# (47205, 3) (47205,)
# (45315, 3) (45315,)
# (150, 3) (150,)
# (18882, 3) (18882,)
# (18882, 3) (18882,)

# %% [markdown]
# ## Tensor the Sample Dataset

# %%
inp_sam, T_sam = torch.tensor(inputs_sam).float(), torch.tensor(T_sam).float()
inp_pde_sam, T_pde_sam = torch.tensor(inputs_pde_sam).float(), torch.tensor(T_pde_sam).float()
inp_i_sam, T_ic_sam = torch.tensor(inputs_i_sam).float(), torch.tensor(T_ic_sam).float()
inp_b_l_sam, T_bcl_sam = torch.tensor(inputs_b_l_sam).float(), torch.tensor(T_bcl_sam).float()
inp_b_r_sam, T_bcr_sam = torch.tensor(inputs_b_r_sam).float(), torch.tensor(T_bcr_sam).float()

# %% [markdown]
# ## Data splitting

# %%
train_inp_sam,test_inp_sam,train_T_sam,test_T_sam = train_test_split(inp_sam,T_sam,\
                                                                     test_size=0.2,random_state=42)
train_inp_pde_sam,test_inp_pde_sam,train_T_pde_sam,test_T_pde_sam = train_test_split(inp_pde_sam,T_pde_sam,\
                                                                                     test_size=0.2,random_state=42)
train_inp_i_sam,test_inp_i_sam,train_T_i_sam,test_T_i_sam = train_test_split(inp_i_sam,T_ic_sam,\
                                                                             test_size=0.2,random_state=42)
train_inp_b_l_sam,test_inp_b_l_sam,train_T_b_l_sam,test_T_b_l_sam = train_test_split(inp_b_l_sam,T_bcl_sam, \
                                                                                     test_size=0.2,random_state=42)
train_inp_b_r_sam,test_inp_b_r_sam,train_T_b_r_sam,test_T_b_r_sam = train_test_split(inp_b_r_sam,T_bcr_sam,\
                                                                                     test_size=0.2,random_state=42)

# %% [markdown]
# ## Dataloader

# %%
class PinnDataset(torch.utils.data.Dataset):
    def __init__(self, inputs, targets):
        self.inputs = inputs
        self.targets = targets

    def __len__(self):
        return len(self.targets)

    def __getitem__(self, idx):
        return self.inputs[idx], self.targets[idx]

# %% [markdown]
# ## Dataset Prep

# %%
train_dataset = PinnDataset(train_inp_sam, train_T_sam)
test_dataset = PinnDataset(test_inp_sam, test_T_sam)

train_pde_dataset = PinnDataset(train_inp_pde_sam, train_T_pde_sam)
test_pde_dataset = PinnDataset(test_inp_pde_sam, test_T_pde_sam)

train_ic_dataset = PinnDataset(train_inp_i_sam, train_T_i_sam)
test_ic_dataset = PinnDataset(test_inp_i_sam, test_T_i_sam)

train_b_l_dataset = PinnDataset(train_inp_b_l_sam, train_T_b_l_sam)
test_b_l_dataset = PinnDataset(test_inp_b_l_sam, test_T_b_l_sam)

train_b_r_dataset = PinnDataset(train_inp_b_r_sam, train_T_b_r_sam)
test_b_r_dataset = PinnDataset(test_inp_b_r_sam, test_T_b_r_sam)

# %%
#try random sampler if it doesnt work

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=True)

train_pde_loader = DataLoader(train_pde_dataset, batch_size=64, shuffle=True)
test_pde_loader = DataLoader(test_pde_dataset, batch_size=64, shuffle=True)

train_ic_loader = DataLoader(train_ic_dataset, batch_size=64, shuffle=True)
test_ic_loader = DataLoader(test_ic_dataset, batch_size=64, shuffle=True)

train_b_l_loader = DataLoader(train_b_l_dataset, batch_size=64, shuffle=True)
test_b_l_loader = DataLoader(test_b_l_dataset, batch_size=64, shuffle=True)

train_b_r_loader = DataLoader(train_b_r_dataset, batch_size=64, shuffle=True)
test_b_r_loader = DataLoader(test_b_r_dataset, batch_size=64, shuffle=True)

# %% [markdown]
# # Model Development

# %%
# prepare data into interior , boundary and initial condition
class Pinn_Var(nn.Module):
    def __init__(self, input_size, hidden_size, output_size): # This is the constructor
        super(Pinn_Var, self).__init__()
        self.base = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            # nn.BatchNorm1d(hidden_size),
            nn.Sigmoid(),
            nn.Linear(hidden_size, hidden_size),
            # nn.BatchNorm1d(hidden_size),
            nn.Sigmoid(),
            nn.Linear(hidden_size, hidden_size),
            # nn.BatchNorm1d(hidden_size),
            nn.Sigmoid(),
            nn.Linear(hidden_size, output_size)
        )
        
    def forward(self, x, t, h):                               # This is the forward pass
        input_features = torch.cat([x, t, h], dim=1)          # Concatenate the input features
        m = self.base(input_features)                                 # Pass through the third layer
        return m                    # Return the output of the network

# %%
# Hyperparameters
hidden_size = 20
learning_rate = 0.003
epochs = 30000
# alpha = 0.01  # Adjust this value based on your problem
# boundary_value = 313.0
# initial_value = init_temp
# Initialize the model
model = Pinn_Var(input_size=3, hidden_size=hidden_size,output_size=1).to(device)
lambd = 0.1

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# # Training & Testing Loop

# %%
train_losses = []
val_losses = []
test_losses = []

# %%
def training_loop(epochs, model, loss_fn_data, optimizer, train_loader,test_dataloader,\
                  train_pde_loader,train_loader_init,\
                    train_loader_bc_l,train_loader_bc_r):
    train_losses = []  # Initialize the list to store the training losses
    # val_losses = []    # Initialize the list to store the validation losses
    test_losses = []   # Initialize the list to store the test losses
    data_losses = []   # Initialize the list to store the data losses
    pde_losses = []   # Initialize the list to store the PDE losses
    ic_losses = []   # Initialize the list to store the initial condition losses
    bc_losses = []   # Initialize the list to store the boundary condition losses

    for epoch in range(epochs):
        model.train()                                                                           # Set the model to training mode
        train_loss = 0                                                                              # Initialize the training loss
        train_accuracy = 0
        for (batch,batch_pde,batch_init,batch_left,batch_right) in \
             zip (train_loader,train_pde_loader,train_loader_init,train_loader_bc_l,train_loader_bc_r):                                                          # Loop through the training dataloader
            
            train_inputs_sample, train_temp_inp_sample= batch                                                             # Get the inputs and the true values
            
            train_pde_sample, train_temp_inp_pde_sample= batch_pde                                                             # Get the inputs and the true values
            
            train_inputs_i_sample, train_temp_inp_i_sample= batch_init                                                             # Get the inputs and the true values 
            
            train_inputs_bc_l_sample, train_temp_inp_bc_l_sample= batch_left                                                             # Get the inputs and the true values
            train_inputs_bc_r_sample, train_temp_inp_bc_r_sample= batch_right                                                             # Get the inputs and the true values

            train_inputs_sample, train_temp_inp_sample= train_inputs_sample.to(device), train_temp_inp_sample.to(device)                                                             # Get the inputs and the true values
            
            train_pde_sample, train_temp_inp_pde_sample= train_pde_sample.to(device), train_temp_inp_pde_sample.to(device)                                                             # Get the inputs and the true values
            
            train_inputs_i_sample, train_temp_inp_i_sample= train_inputs_i_sample.to(device), train_temp_inp_i_sample.to(device)                                                            # Get the inputs and the true values 
            
            train_inputs_bc_l_sample, train_temp_inp_bc_l_sample=  train_inputs_bc_l_sample.to(device), train_temp_inp_bc_l_sample.to(device)                                                            # Get the inputs and the true values
            train_inputs_bc_r_sample, train_temp_inp_bc_r_sample= train_inputs_bc_r_sample.to(device), train_temp_inp_bc_r_sample.to(device)
            
            
            # print(inputs.shape)
            # print(inputs_init.shape)
            # print(inputs_left.shape)
            # print(inputs_right.shape)

            optimizer.zero_grad()                                                                    # Zero the gradients
            
            # Forward pass
            u_pred = model(train_inputs_sample[:,0].unsqueeze(1), train_inputs_sample[:,1].unsqueeze(1),\
                           train_inputs_sample[:,2].unsqueeze(1))                       # Get the predictions
            u_initl = model(train_inputs_i_sample[:,0].unsqueeze(1), train_inputs_i_sample[:,1].unsqueeze(1),\
                            train_inputs_i_sample[:,2].unsqueeze(1))                       # Get the predictions
            u_left = model(train_inputs_bc_l_sample[:,0].unsqueeze(1), train_inputs_bc_l_sample[:,1].unsqueeze(1),\
                           train_inputs_bc_l_sample[:,2].unsqueeze(1))               # Left boundary of the temperature
            u_right = model(train_inputs_bc_r_sample[:,0].unsqueeze(1), train_inputs_bc_r_sample[:,1].unsqueeze(1),\
                            train_inputs_bc_r_sample[:,2].unsqueeze(1))             # Right boundary of the temperature

            # Loss calculation
            data_loss = loss_fn_data(u_pred, train_temp_inp_sample)                                              # Calculate the data loss
            
            pd_loss = pde_loss(model,train_pde_sample[:,0].unsqueeze(1),train_pde_sample[:,1].unsqueeze(1),\
                               train_pde_sample[:,2].unsqueeze(1))             # Calculate the PDE loss
            # pd_loss = 0
            
            initc_loss = ic_loss(u_initl) 
            # initc_loss =0                                                      # Calculate initial condition loss
            
            bc_loss_left = boundary_loss(model,train_inputs_bc_l_sample[:,0].unsqueeze(1),\
                                         train_inputs_bc_l_sample[:,1].unsqueeze(1),\
                                            train_inputs_bc_l_sample[:,2].unsqueeze(1),\
                                            t_surr) # Calculate the left boundary condition loss
            bc_loss_right = boundary_loss(model,train_inputs_bc_r_sample[:,0].unsqueeze(1),
                                          train_inputs_bc_r_sample[:,1].unsqueeze(1),\
                                            train_inputs_bc_r_sample[:,2].unsqueeze(1),\
                                            t_surr) # Calculate the right boundary condition loss
            bc_loss = bc_loss_left + bc_loss_right
            # l1_regularization_loss = l1_regularization(model, lambda_l1)                      # Calculate the L1 regularization loss
            # loss = data_loss  + pd_loss + initc_loss + bc_loss                                              # Calculate the total loss
            w1 = 1
            w2 = 1e4
            w3 = 1e2
            loss = data_loss + w1* pd_loss + w2 *initc_loss + w3* bc_loss
            train_accuracy += accuracy(u_pred, train_temp_inp_sample)                                                              # Calculate the total loss
            # Backpropagation
            loss.backward(retain_graph=True)                                                        # Backpropagate the gradients
            
            optimizer.step()                                                                           # Update the weights
            
            train_loss += loss.item()                                                           # Add the loss to the training set loss  
            data_loss += data_loss.item()
            pd_loss += pd_loss.item()
            initc_loss += initc_loss.item()
            bc_loss += bc_loss.item()
        
        train_losses.append(train_loss)
        data_losses.append(data_loss)
        pde_losses.append(pd_loss)
        ic_losses.append(initc_loss)
        bc_losses.append(bc_loss)


        model.eval()
        test_loss = 0
        test_accuracy = 0
        # with torch.no_grad(): 
        for batch in test_dataloader:
            test_inputs_sample, test_temp_inp_sample= batch
            test_inputs_sample, test_temp_inp_sample= test_inputs_sample.to(device), test_temp_inp_sample.to(device)
            u_pred = model(test_inputs_sample[:,0].unsqueeze(1), test_inputs_sample[:,1].unsqueeze(1),\
                           test_inputs_sample[:,2].unsqueeze(1))
            data_loss_t = loss_fn_data(u_pred, test_temp_inp_sample)
            # l1_regularization_loss = l1_regularization(model, lambd)
            # loss = data_loss  + l1_regularization_loss
            
            loss = data_loss_t
            test_accuracy = accuracy(u_pred, test_temp_inp_sample)
            test_loss += loss.item()
        test_losses.append(test_loss)

                                                           # Append the training loss to the list of training losses
        
        


        if epoch % 10 == 0:
            print(f"Epoch {epoch},| Training-Loss {train_loss:.4e},| Data-loss {data_loss:.4e},"
                f"pde-loss {pd_loss:.4e}, initc-loss {initc_loss:.4e}|,"
                f"|bc_loss {bc_loss:.4e}, test-loss {test_loss:.4e}") 

    return train_losses, test_losses , pde_losses , bc_losses , ic_losses, data_losses                                                      # Return the training and validation losses

# %%
def test_loop(epochs, model, loss_fn_data, optimizer, train_dataloader, test_dataloader):
    for epoch in range(epochs):
        model.eval()
        test_loss = 0
        test_accuracy = 0
        with torch.no_grad():   
            for batch in test_dataloader:
                test_inputs_sample, test_temp_inp_sample= batch
                test_inputs_sample, test_temp_inp_sample= test_inputs_sample.to(device), test_temp_inp_sample.to(device)
                u_pred = model(test_inputs_sample[:,0].unsqueeze(1), test_inputs_sample[:,1].unsqueeze(1))
                data_loss = loss_fn_data(u_pred, test_temp_inp_sample)
                # l1_regularization_loss = l1_regularization(model, lambd)
                # loss = data_loss  + l1_regularization_loss
                
                loss = data_loss
                test_accuracy = accuracy(u_pred, test_temp_inp_sample)
                test_loss += loss.item()
        test_losses.append(test_loss)
        if epochs % 10 == 0:
            print(f"Epoch {epoch}, Test-Loss {test_loss:.4e}, Test-Accuracy {test_accuracy:.4e}")      
    return test_losses

# %% [markdown]
# # Model Run

# %%
train_losses, test_losses, pde_losses, bc_losses,ic_losses, data_losses = training_loop(epochs, model, \
                                        loss_fn_data, optimizer,train_loader,test_loader,\
                                            train_pde_loader, train_ic_loader,\
                                            train_b_l_loader,train_b_r_loader )  # Train the model
 
# test_losses = test_loop(epochs, model, loss_fn_data, optimizer, train_loader, test_loader)  # Test the model
# Out:
# /home/student.unimelb.edu.au/rrammohan/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /home/student.unimelb.edu.au/rrammohan/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([33])) that is different to the input size (torch.Size([33, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 0,| Training-Loss 2.0468e+10,| Data-loss 2.2796e+00,pde-loss 2.6986e-06, initc-loss 1.6905e+06|,|bc_loss 3.5611e+07, test-loss 1.6479e+02
# Epoch 10,| Training-Loss 2.0410e+10,| Data-loss 2.7108e+00,pde-loss 6.6294e-07, initc-loss 1.6870e+06|,|bc_loss 3.5383e+07, test-loss 2.0867e+02
# Epoch 20,| Training-Loss 2.0353e+10,| Data-loss 6.2816e+00,pde-loss 8.6484e-07, initc-loss 1.6836e+06|,|bc_loss 3.5162e+07, test-loss 5.1263e+02
# Epoch 30,| Training-Loss 2.0287e+10,| Data-loss 1.6892e+01,pde-loss 9.8355e-08, initc-loss 1.6795e+06|,|bc_loss 3.4899e+07, test-loss 1.2202e+03
# Epoch 40,| Training-Loss 2.0211e+10,| Data-loss 3.7817e+01,pde-loss 4.3286e-07, initc-loss 1.6749e+06|,|bc_loss 3.4602e+07, test-loss 2.4564e+03
# Epoch 50,| Training-Loss 2.0135e+10,| Data-loss 5.4409e+01,pde-loss 4.7770e-07, initc-loss 1.6703e+06|,|bc_loss 3.4307e+07, test-loss 4.1611e+03
# Epoch 60,| Training-Loss 2.0055e+10,| Data-loss 8.6005e+01,pde-loss 4.8867e-07, initc-loss 1.6654e+06|,|bc_loss 3.3994e+07, test-loss 6.4954e+03
# Epoch 70,| Training-Loss 1.9977e+10,| Data-loss 1.2267e+02,pde-loss 1.7724e-07, initc-loss 1.6606e+06|,|bc_loss 3.3690e+07, test-loss 9.2742e+03
# Epoch 80,| Training-Loss 1.9903e+10,| Data-loss 1.6572e+02,pde-loss 1.0733e-07, initc-loss 1.6561e+06|,|bc_loss 3.3402e+07, test-loss 1.2388e+04
# Epoch 90,| Training-Loss 1.9831e+10,| Data-loss 2.0801e+02,pde-loss 4.5977e-08, initc-loss 1.6517e+06|,|bc_loss 3.3125e+07, test-loss 1.5832e+04
# Epoch 100,| Training-Loss 1.9762e+10,| Data-loss 2.6688e+02,pde-loss 3.1648e-08, initc-loss 1.6475e+06|,|bc_loss 3.2855e+07, test-loss 1.9605e+04
# Epoch 110,| Training-Loss 1.9691e+10,| Data-loss 3.2058e+02,pde-loss 1.5061e-08, initc-loss 1.6431e+06|,|bc_loss 3.2581e+07, test-loss 2.3906e+04
# Epoch 120,| Training-Loss 1.9612e+10,| Data-loss 4.0309e+02,pde-loss 3.4109e-08, initc-loss 1.6383e+06|,|bc_loss 3.2276e+07, test-loss 2.9199e+04
# Epoch 130,| Training-Loss 1.9536e+10,| Data-loss 4.6928e+02,pde-loss 1.4709e-08, initc-loss 1.6336e+06|,|bc_loss 3.1985e+07, test-loss 3.4756e+04
# Epoch 140,| Training-Loss 1.9463e+10,| Data-loss 5.4641e+02,pde-loss 5.9645e-09, initc-loss 1.6291e+06|,|bc_loss 3.1703e+07, test-loss 4.0634e+04
# Epoch 150,| Training-Loss 1.9387e+10,| Data-loss 6.3358e+02,pde-loss 6.0391e-09, initc-loss 1.6244e+06|,|bc_loss 3.1409e+07, test-loss 4.7344e+04
# Epoch 160,| Training-Loss 1.9297e+10,| Data-loss 7.6055e+02,pde-loss 1.1746e-08, initc-loss 1.6188e+06|,|bc_loss 3.1064e+07, test-loss 5.5919e+04
# Epoch 170,| Training-Loss 1.9203e+10,| Data-loss 8.9817e+02,pde-loss 8.4680e-09, initc-loss 1.6130e+06|,|bc_loss 3.0705e+07, test-loss 6.5552e+04
# Epoch 180,| Training-Loss 1.9114e+10,| Data-loss 1.0170e+03,pde-loss 4.4220e-09, initc-loss 1.6075e+06|,|bc_loss 3.0365e+07, test-loss 7.5485e+04
# Epoch 190,| Training-Loss 1.9016e+10,| Data-loss 1.1728e+03,pde-loss 1.3660e-08, initc-loss 1.6015e+06|,|bc_loss 2.9994e+07, test-loss 8.7191e+04
# Epoch 200,| Training-Loss 1.8924e+10,| Data-loss 1.3274e+03,pde-loss 5.6194e-09, initc-loss 1.5958e+06|,|bc_loss 2.9646e+07, test-loss 9.8970e+04
# Epoch 210,| Training-Loss 1.8837e+10,| Data-loss 1.4890e+03,pde-loss 3.8688e-09, initc-loss 1.5903e+06|,|bc_loss 2.9315e+07, test-loss 1.1097e+05
# Epoch 220,| Training-Loss 1.8752e+10,| Data-loss 1.6405e+03,pde-loss 2.7459e-09, initc-loss 1.5850e+06|,|bc_loss 2.8996e+07, test-loss 1.2323e+05
# Epoch 230,| Training-Loss 1.8670e+10,| Data-loss 1.8386e+03,pde-loss 1.5602e-09, initc-loss 1.5799e+06|,|bc_loss 2.8685e+07, test-loss 1.3586e+05
# Epoch 240,| Training-Loss 1.8589e+10,| Data-loss 2.0079e+03,pde-loss 2.2546e-09, initc-loss 1.5749e+06|,|bc_loss 2.8382e+07, test-loss 1.4887e+05
# Epoch 250,| Training-Loss 1.8510e+10,| Data-loss 2.2141e+03,pde-loss 1.1923e-09, initc-loss 1.5699e+06|,|bc_loss 2.8085e+07, test-loss 1.6226e+05
# Epoch 260,| Training-Loss 1.8431e+10,| Data-loss 2.3272e+03,pde-loss 1.8593e-09, initc-loss 1.5650e+06|,|bc_loss 2.7793e+07, test-loss 1.7608e+05
# Epoch 270,| Training-Loss 1.8354e+10,| Data-loss 2.5701e+03,pde-loss 8.4194e-10, initc-loss 1.5602e+06|,|bc_loss 2.7505e+07, test-loss 1.9030e+05
# Epoch 280,| Training-Loss 1.8278e+10,| Data-loss 2.7552e+03,pde-loss 5.6674e-10, initc-loss 1.5554e+06|,|bc_loss 2.7222e+07, test-loss 2.0494e+05
# Epoch 290,| Training-Loss 1.8203e+10,| Data-loss 2.9641e+03,pde-loss 9.6680e-10, initc-loss 1.5507e+06|,|bc_loss 2.6942e+07, test-loss 2.2000e+05
# Epoch 300,| Training-Loss 1.8128e+10,| Data-loss 3.1556e+03,pde-loss 6.9309e-10, initc-loss 1.5460e+06|,|bc_loss 2.6666e+07, test-loss 2.3547e+05
# Epoch 310,| Training-Loss 1.8054e+10,| Data-loss 3.3751e+03,pde-loss 5.3447e-10, initc-loss 1.5413e+06|,|bc_loss 2.6393e+07, test-loss 2.5137e+05
# Epoch 320,| Training-Loss 1.7981e+10,| Data-loss 3.6068e+03,pde-loss 4.2817e-10, initc-loss 1.5367e+06|,|bc_loss 2.6123e+07, test-loss 2.6768e+05
# Epoch 330,| Training-Loss 1.7908e+10,| Data-loss 3.8624e+03,pde-loss 5.1983e-10, initc-loss 1.5321e+06|,|bc_loss 2.5856e+07, test-loss 2.8442e+05
# Epoch 340,| Training-Loss 1.7836e+10,| Data-loss 4.0845e+03,pde-loss 2.9458e-10, initc-loss 1.5275e+06|,|bc_loss 2.5591e+07, test-loss 3.0158e+05
# Epoch 350,| Training-Loss 1.7765e+10,| Data-loss 4.2989e+03,pde-loss 3.1241e-10, initc-loss 1.5230e+06|,|bc_loss 2.5329e+07, test-loss 3.1916e+05
# Epoch 360,| Training-Loss 1.7694e+10,| Data-loss 4.5124e+03,pde-loss 2.6961e-10, initc-loss 1.5185e+06|,|bc_loss 2.5070e+07, test-loss 3.3714e+05
# Epoch 370,| Training-Loss 1.7623e+10,| Data-loss 4.7535e+03,pde-loss 2.3184e-10, initc-loss 1.5140e+06|,|bc_loss 2.4813e+07, test-loss 3.5554e+05
# Epoch 380,| Training-Loss 1.7553e+10,| Data-loss 5.0098e+03,pde-loss 1.8723e-10, initc-loss 1.5096e+06|,|bc_loss 2.4559e+07, test-loss 3.7437e+05
# Epoch 390,| Training-Loss 1.7484e+10,| Data-loss 5.2791e+03,pde-loss 1.8264e-10, initc-loss 1.5051e+06|,|bc_loss 2.4306e+07, test-loss 3.9358e+05
# Epoch 400,| Training-Loss 1.7415e+10,| Data-loss 5.5820e+03,pde-loss 1.8101e-10, initc-loss 1.5007e+06|,|bc_loss 2.4056e+07, test-loss 4.1323e+05
# Epoch 410,| Training-Loss 1.7346e+10,| Data-loss 5.8846e+03,pde-loss 1.6402e-10, initc-loss 1.4963e+06|,|bc_loss 2.3808e+07, test-loss 4.3330e+05
# Epoch 420,| Training-Loss 1.7278e+10,| Data-loss 6.0933e+03,pde-loss 1.5499e-10, initc-loss 1.4920e+06|,|bc_loss 2.3562e+07, test-loss 4.5375e+05
# Epoch 430,| Training-Loss 1.7210e+10,| Data-loss 6.3702e+03,pde-loss 2.0268e-10, initc-loss 1.4876e+06|,|bc_loss 2.3318e+07, test-loss 4.7462e+05
# Epoch 440,| Training-Loss 1.7142e+10,| Data-loss 6.6470e+03,pde-loss 1.5950e-10, initc-loss 1.4833e+06|,|bc_loss 2.3076e+07, test-loss 4.9590e+05
# Epoch 450,| Training-Loss 1.7075e+10,| Data-loss 6.9939e+03,pde-loss 1.5940e-10, initc-loss 1.4790e+06|,|bc_loss 2.2836e+07, test-loss 5.1758e+05
# Epoch 460,| Training-Loss 1.7008e+10,| Data-loss 7.2072e+03,pde-loss 1.0060e-10, initc-loss 1.4747e+06|,|bc_loss 2.2598e+07, test-loss 5.3968e+05
# Epoch 470,| Training-Loss 1.6942e+10,| Data-loss 7.6302e+03,pde-loss 9.1093e-11, initc-loss 1.4704e+06|,|bc_loss 2.2362e+07, test-loss 5.6217e+05
# Epoch 480,| Training-Loss 1.6876e+10,| Data-loss 7.9166e+03,pde-loss 6.8391e-11, initc-loss 1.4662e+06|,|bc_loss 2.2128e+07, test-loss 5.8505e+05
# Epoch 490,| Training-Loss 1.6810e+10,| Data-loss 8.1975e+03,pde-loss 6.5033e-11, initc-loss 1.4619e+06|,|bc_loss 2.1895e+07, test-loss 6.0834e+05
# Epoch 500,| Training-Loss 1.6745e+10,| Data-loss 8.5235e+03,pde-loss 7.2242e-11, initc-loss 1.4577e+06|,|bc_loss 2.1664e+07, test-loss 6.3204e+05
# Epoch 510,| Training-Loss 1.6680e+10,| Data-loss 8.7992e+03,pde-loss 5.6301e-11, initc-loss 1.4535e+06|,|bc_loss 2.1435e+07, test-loss 6.5609e+05
# Epoch 520,| Training-Loss 1.6615e+10,| Data-loss 9.2070e+03,pde-loss 4.0142e-11, initc-loss 1.4493e+06|,|bc_loss 2.1208e+07, test-loss 6.8059e+05
# Epoch 530,| Training-Loss 1.6551e+10,| Data-loss 9.4840e+03,pde-loss 7.1883e-11, initc-loss 1.4451e+06|,|bc_loss 2.0982e+07, test-loss 7.0547e+05
# Epoch 540,| Training-Loss 1.6487e+10,| Data-loss 9.8987e+03,pde-loss 4.5290e-11, initc-loss 1.4409e+06|,|bc_loss 2.0758e+07, test-loss 7.3074e+05
# Epoch 550,| Training-Loss 1.6423e+10,| Data-loss 1.0212e+04,pde-loss 4.4304e-11, initc-loss 1.4368e+06|,|bc_loss 2.0536e+07, test-loss 7.5643e+05
# Epoch 560,| Training-Loss 1.6360e+10,| Data-loss 1.0569e+04,pde-loss 3.4133e-11, initc-loss 1.4327e+06|,|bc_loss 2.0315e+07, test-loss 7.8247e+05
# Epoch 570,| Training-Loss 1.6296e+10,| Data-loss 1.0955e+04,pde-loss 4.1480e-11, initc-loss 1.4285e+06|,|bc_loss 2.0096e+07, test-loss 8.0890e+05
# Epoch 580,| Training-Loss 1.6234e+10,| Data-loss 1.1283e+04,pde-loss 3.0836e-11, initc-loss 1.4244e+06|,|bc_loss 1.9878e+07, test-loss 8.3573e+05
# Epoch 590,| Training-Loss 1.6171e+10,| Data-loss 1.1667e+04,pde-loss 4.6359e-11, initc-loss 1.4203e+06|,|bc_loss 1.9662e+07, test-loss 8.6296e+05
# Epoch 600,| Training-Loss 1.6109e+10,| Data-loss 1.1915e+04,pde-loss 3.9453e-11, initc-loss 1.4162e+06|,|bc_loss 1.9448e+07, test-loss 8.9056e+05
# Epoch 610,| Training-Loss 1.6047e+10,| Data-loss 1.2341e+04,pde-loss 4.4216e-11, initc-loss 1.4122e+06|,|bc_loss 1.9235e+07, test-loss 9.1855e+05
# Epoch 620,| Training-Loss 1.5985e+10,| Data-loss 1.2741e+04,pde-loss 2.4180e-11, initc-loss 1.4081e+06|,|bc_loss 1.9024e+07, test-loss 9.4693e+05
# Epoch 630,| Training-Loss 1.5924e+10,| Data-loss 1.3154e+04,pde-loss 2.7851e-11, initc-loss 1.4041e+06|,|bc_loss 1.8814e+07, test-loss 9.7567e+05
# Epoch 640,| Training-Loss 1.5863e+10,| Data-loss 1.3640e+04,pde-loss 1.3234e-11, initc-loss 1.4000e+06|,|bc_loss 1.8606e+07, test-loss 1.0048e+06
# Epoch 650,| Training-Loss 1.5802e+10,| Data-loss 1.4002e+04,pde-loss 1.7669e-11, initc-loss 1.3960e+06|,|bc_loss 1.8399e+07, test-loss 1.0343e+06
# Epoch 660,| Training-Loss 1.5741e+10,| Data-loss 1.4378e+04,pde-loss 1.8899e-11, initc-loss 1.3920e+06|,|bc_loss 1.8194e+07, test-loss 1.0642e+06
# Epoch 670,| Training-Loss 1.5681e+10,| Data-loss 1.4780e+04,pde-loss 1.4162e-11, initc-loss 1.3880e+06|,|bc_loss 1.7990e+07, test-loss 1.0945e+06
# Epoch 680,| Training-Loss 1.5621e+10,| Data-loss 1.5190e+04,pde-loss 2.2163e-11, initc-loss 1.3840e+06|,|bc_loss 1.7788e+07, test-loss 1.1252e+06
# Epoch 690,| Training-Loss 1.5561e+10,| Data-loss 1.5659e+04,pde-loss 1.4565e-11, initc-loss 1.3801e+06|,|bc_loss 1.7587e+07, test-loss 1.1562e+06
# Epoch 700,| Training-Loss 1.5501e+10,| Data-loss 1.6083e+04,pde-loss 2.1686e-11, initc-loss 1.3761e+06|,|bc_loss 1.7387e+07, test-loss 1.1876e+06
# Epoch 710,| Training-Loss 1.5442e+10,| Data-loss 1.6412e+04,pde-loss 1.9575e-11, initc-loss 1.3722e+06|,|bc_loss 1.7189e+07, test-loss 1.2194e+06
# Epoch 720,| Training-Loss 1.5383e+10,| Data-loss 1.6934e+04,pde-loss 1.4330e-11, initc-loss 1.3682e+06|,|bc_loss 1.6992e+07, test-loss 1.2516e+06
# Epoch 730,| Training-Loss 1.5324e+10,| Data-loss 1.7348e+04,pde-loss 1.1116e-11, initc-loss 1.3643e+06|,|bc_loss 1.6797e+07, test-loss 1.2841e+06
# Epoch 740,| Training-Loss 1.5266e+10,| Data-loss 1.7814e+04,pde-loss 1.3131e-11, initc-loss 1.3604e+06|,|bc_loss 1.6603e+07, test-loss 1.3170e+06
# Epoch 750,| Training-Loss 1.5207e+10,| Data-loss 1.8175e+04,pde-loss 1.5813e-11, initc-loss 1.3565e+06|,|bc_loss 1.6411e+07, test-loss 1.3503e+06
# Epoch 760,| Training-Loss 1.5149e+10,| Data-loss 1.8719e+04,pde-loss 1.9252e-11, initc-loss 1.3526e+06|,|bc_loss 1.6220e+07, test-loss 1.3839e+06
# Epoch 770,| Training-Loss 1.5092e+10,| Data-loss 1.9143e+04,pde-loss 1.6440e-11, initc-loss 1.3487e+06|,|bc_loss 1.6030e+07, test-loss 1.4179e+06
# Epoch 780,| Training-Loss 1.5034e+10,| Data-loss 1.9636e+04,pde-loss 1.2046e-11, initc-loss 1.3448e+06|,|bc_loss 1.5842e+07, test-loss 1.4522e+06
# Epoch 790,| Training-Loss 1.4977e+10,| Data-loss 2.0058e+04,pde-loss 8.5786e-12, initc-loss 1.3410e+06|,|bc_loss 1.5655e+07, test-loss 1.4870e+06
# Epoch 800,| Training-Loss 1.4920e+10,| Data-loss 2.0498e+04,pde-loss 8.2942e-12, initc-loss 1.3371e+06|,|bc_loss 1.5469e+07, test-loss 1.5221e+06
# Epoch 810,| Training-Loss 1.4863e+10,| Data-loss 2.1025e+04,pde-loss 8.3148e-12, initc-loss 1.3333e+06|,|bc_loss 1.5285e+07, test-loss 1.5575e+06
# Epoch 820,| Training-Loss 1.4806e+10,| Data-loss 2.1512e+04,pde-loss 1.1139e-11, initc-loss 1.3295e+06|,|bc_loss 1.5102e+07, test-loss 1.5934e+06
# Epoch 830,| Training-Loss 1.4750e+10,| Data-loss 2.1970e+04,pde-loss 1.0731e-11, initc-loss 1.3256e+06|,|bc_loss 1.4920e+07, test-loss 1.6296e+06
# Epoch 840,| Training-Loss 1.4694e+10,| Data-loss 2.2525e+04,pde-loss 6.9093e-12, initc-loss 1.3218e+06|,|bc_loss 1.4740e+07, test-loss 1.6661e+06
# Epoch 850,| Training-Loss 1.4638e+10,| Data-loss 2.3024e+04,pde-loss 8.8793e-12, initc-loss 1.3180e+06|,|bc_loss 1.4561e+07, test-loss 1.7030e+06
# Epoch 860,| Training-Loss 1.4582e+10,| Data-loss 2.3553e+04,pde-loss 8.1916e-12, initc-loss 1.3142e+06|,|bc_loss 1.4384e+07, test-loss 1.7403e+06
# Epoch 870,| Training-Loss 1.4527e+10,| Data-loss 2.3909e+04,pde-loss 6.1157e-12, initc-loss 1.3105e+06|,|bc_loss 1.4207e+07, test-loss 1.7780e+06
# Epoch 880,| Training-Loss 1.4471e+10,| Data-loss 2.4544e+04,pde-loss 8.1267e-12, initc-loss 1.3067e+06|,|bc_loss 1.4032e+07, test-loss 1.8160e+06
# Epoch 890,| Training-Loss 1.4417e+10,| Data-loss 2.5003e+04,pde-loss 6.5740e-12, initc-loss 1.3029e+06|,|bc_loss 1.3858e+07, test-loss 1.8543e+06
# Epoch 900,| Training-Loss 1.4362e+10,| Data-loss 2.5543e+04,pde-loss 9.1119e-12, initc-loss 1.2992e+06|,|bc_loss 1.3686e+07, test-loss 1.8930e+06
# Epoch 910,| Training-Loss 1.4307e+10,| Data-loss 2.6155e+04,pde-loss 7.4118e-12, initc-loss 1.2954e+06|,|bc_loss 1.3515e+07, test-loss 1.9320e+06
# Epoch 920,| Training-Loss 1.4253e+10,| Data-loss 2.6603e+04,pde-loss 7.4760e-12, initc-loss 1.2917e+06|,|bc_loss 1.3345e+07, test-loss 1.9714e+06
# Epoch 930,| Training-Loss 1.4199e+10,| Data-loss 2.7153e+04,pde-loss 4.7895e-12, initc-loss 1.2880e+06|,|bc_loss 1.3176e+07, test-loss 2.0112e+06
# Epoch 940,| Training-Loss 1.4145e+10,| Data-loss 2.7676e+04,pde-loss 4.4808e-12, initc-loss 1.2843e+06|,|bc_loss 1.3008e+07, test-loss 2.0513e+06
# Epoch 950,| Training-Loss 1.4091e+10,| Data-loss 2.8185e+04,pde-loss 3.6401e-12, initc-loss 1.2806e+06|,|bc_loss 1.2842e+07, test-loss 2.0918e+06
# Epoch 960,| Training-Loss 1.4038e+10,| Data-loss 2.8823e+04,pde-loss 3.4028e-12, initc-loss 1.2769e+06|,|bc_loss 1.2677e+07, test-loss 2.1327e+06
# Epoch 970,| Training-Loss 1.3985e+10,| Data-loss 2.9338e+04,pde-loss 3.8227e-12, initc-loss 1.2732e+06|,|bc_loss 1.2514e+07, test-loss 2.1738e+06
# Epoch 980,| Training-Loss 1.3932e+10,| Data-loss 2.9902e+04,pde-loss 3.8067e-12, initc-loss 1.2695e+06|,|bc_loss 1.2351e+07, test-loss 2.2153e+06
# Epoch 990,| Training-Loss 1.3879e+10,| Data-loss 3.0475e+04,pde-loss 4.2205e-12, initc-loss 1.2659e+06|,|bc_loss 1.2190e+07, test-loss 2.2572e+06
# Epoch 1000,| Training-Loss 1.3826e+10,| Data-loss 3.1082e+04,pde-loss 4.9184e-12, initc-loss 1.2622e+06|,|bc_loss 1.2030e+07, test-loss 2.2994e+06
# Epoch 1010,| Training-Loss 1.3774e+10,| Data-loss 3.1482e+04,pde-loss 3.2832e-12, initc-loss 1.2586e+06|,|bc_loss 1.1871e+07, test-loss 2.3419e+06
# Epoch 1020,| Training-Loss 1.3722e+10,| Data-loss 3.2225e+04,pde-loss 3.2398e-12, initc-loss 1.2549e+06|,|bc_loss 1.1713e+07, test-loss 2.3848e+06
# Epoch 1030,| Training-Loss 1.3670e+10,| Data-loss 3.2743e+04,pde-loss 4.4806e-12, initc-loss 1.2513e+06|,|bc_loss 1.1557e+07, test-loss 2.4280e+06
# Epoch 1040,| Training-Loss 1.3618e+10,| Data-loss 3.3285e+04,pde-loss 2.6392e-12, initc-loss 1.2477e+06|,|bc_loss 1.1402e+07, test-loss 2.4717e+06
# Epoch 1050,| Training-Loss 1.3567e+10,| Data-loss 3.3922e+04,pde-loss 2.3179e-12, initc-loss 1.2441e+06|,|bc_loss 1.1248e+07, test-loss 2.5156e+06
# Epoch 1060,| Training-Loss 1.3515e+10,| Data-loss 3.4581e+04,pde-loss 3.4728e-12, initc-loss 1.2405e+06|,|bc_loss 1.1095e+07, test-loss 2.5599e+06
# Epoch 1070,| Training-Loss 1.3464e+10,| Data-loss 3.5147e+04,pde-loss 3.6076e-12, initc-loss 1.2369e+06|,|bc_loss 1.0944e+07, test-loss 2.6045e+06
# Epoch 1080,| Training-Loss 1.3414e+10,| Data-loss 3.5849e+04,pde-loss 2.4801e-12, initc-loss 1.2333e+06|,|bc_loss 1.0793e+07, test-loss 2.6495e+06
# Epoch 1090,| Training-Loss 1.3363e+10,| Data-loss 3.6447e+04,pde-loss 2.1763e-12, initc-loss 1.2297e+06|,|bc_loss 1.0644e+07, test-loss 2.6948e+06
# Epoch 1100,| Training-Loss 1.3312e+10,| Data-loss 3.6985e+04,pde-loss 2.4241e-12, initc-loss 1.2261e+06|,|bc_loss 1.0496e+07, test-loss 2.7404e+06
# Epoch 1110,| Training-Loss 1.3262e+10,| Data-loss 3.7652e+04,pde-loss 2.6933e-12, initc-loss 1.2226e+06|,|bc_loss 1.0349e+07, test-loss 2.7864e+06
# Epoch 1120,| Training-Loss 1.3212e+10,| Data-loss 3.8319e+04,pde-loss 2.5999e-12, initc-loss 1.2190e+06|,|bc_loss 1.0204e+07, test-loss 2.8327e+06
# Epoch 1130,| Training-Loss 1.3162e+10,| Data-loss 3.9014e+04,pde-loss 1.5781e-12, initc-loss 1.2155e+06|,|bc_loss 1.0059e+07, test-loss 2.8793e+06
# Epoch 1140,| Training-Loss 1.3113e+10,| Data-loss 3.9415e+04,pde-loss 2.6069e-12, initc-loss 1.2120e+06|,|bc_loss 9.9161e+06, test-loss 2.9263e+06
# Epoch 1150,| Training-Loss 1.3063e+10,| Data-loss 4.0166e+04,pde-loss 2.1099e-12, initc-loss 1.2084e+06|,|bc_loss 9.7740e+06, test-loss 2.9737e+06
# Epoch 1160,| Training-Loss 1.3014e+10,| Data-loss 4.0823e+04,pde-loss 3.0149e-12, initc-loss 1.2049e+06|,|bc_loss 9.6330e+06, test-loss 3.0213e+06
# Epoch 1170,| Training-Loss 1.2965e+10,| Data-loss 4.1392e+04,pde-loss 1.8159e-12, initc-loss 1.2014e+06|,|bc_loss 9.4932e+06, test-loss 3.0693e+06
# Epoch 1180,| Training-Loss 1.2916e+10,| Data-loss 4.2063e+04,pde-loss 2.2324e-12, initc-loss 1.1979e+06|,|bc_loss 9.3545e+06, test-loss 3.1176e+06
# Epoch 1190,| Training-Loss 1.2867e+10,| Data-loss 4.2802e+04,pde-loss 1.4196e-12, initc-loss 1.1944e+06|,|bc_loss 9.2170e+06, test-loss 3.1663e+06
# Epoch 1200,| Training-Loss 1.2819e+10,| Data-loss 4.3363e+04,pde-loss 1.5155e-12, initc-loss 1.1910e+06|,|bc_loss 9.0806e+06, test-loss 3.2152e+06
# Epoch 1210,| Training-Loss 1.2771e+10,| Data-loss 4.4030e+04,pde-loss 1.0964e-12, initc-loss 1.1875e+06|,|bc_loss 8.9454e+06, test-loss 3.2646e+06
# Epoch 1220,| Training-Loss 1.2722e+10,| Data-loss 4.4780e+04,pde-loss 2.1347e-12, initc-loss 1.1840e+06|,|bc_loss 8.8113e+06, test-loss 3.3142e+06
# Epoch 1230,| Training-Loss 1.2675e+10,| Data-loss 4.5518e+04,pde-loss 1.9116e-12, initc-loss 1.1806e+06|,|bc_loss 8.6783e+06, test-loss 3.3642e+06
# Epoch 1240,| Training-Loss 1.2627e+10,| Data-loss 4.6101e+04,pde-loss 1.2135e-12, initc-loss 1.1771e+06|,|bc_loss 8.5465e+06, test-loss 3.4145e+06
# Epoch 1250,| Training-Loss 1.2579e+10,| Data-loss 4.6629e+04,pde-loss 8.9000e-13, initc-loss 1.1737e+06|,|bc_loss 8.4158e+06, test-loss 3.4652e+06
# Epoch 1260,| Training-Loss 1.2532e+10,| Data-loss 4.7511e+04,pde-loss 1.1472e-12, initc-loss 1.1702e+06|,|bc_loss 8.2862e+06, test-loss 3.5161e+06
# Epoch 1270,| Training-Loss 1.2485e+10,| Data-loss 4.8014e+04,pde-loss 9.4651e-13, initc-loss 1.1668e+06|,|bc_loss 8.1577e+06, test-loss 3.5674e+06
# Epoch 1280,| Training-Loss 1.2438e+10,| Data-loss 4.9012e+04,pde-loss 1.2182e-12, initc-loss 1.1634e+06|,|bc_loss 8.0304e+06, test-loss 3.6190e+06
# Epoch 1290,| Training-Loss 1.2391e+10,| Data-loss 4.9602e+04,pde-loss 9.1894e-13, initc-loss 1.1600e+06|,|bc_loss 7.9041e+06, test-loss 3.6709e+06
# Epoch 1300,| Training-Loss 1.2345e+10,| Data-loss 5.0108e+04,pde-loss 9.0857e-13, initc-loss 1.1566e+06|,|bc_loss 7.7790e+06, test-loss 3.7232e+06
# Epoch 1310,| Training-Loss 1.2299e+10,| Data-loss 5.1005e+04,pde-loss 1.6510e-12, initc-loss 1.1532e+06|,|bc_loss 7.6550e+06, test-loss 3.7758e+06
# Epoch 1320,| Training-Loss 1.2252e+10,| Data-loss 5.1716e+04,pde-loss 1.1214e-12, initc-loss 1.1498e+06|,|bc_loss 7.5321e+06, test-loss 3.8287e+06
# Epoch 1330,| Training-Loss 1.2206e+10,| Data-loss 5.2230e+04,pde-loss 1.5752e-12, initc-loss 1.1464e+06|,|bc_loss 7.4102e+06, test-loss 3.8819e+06
# Epoch 1340,| Training-Loss 1.2161e+10,| Data-loss 5.3266e+04,pde-loss 7.8081e-13, initc-loss 1.1431e+06|,|bc_loss 7.2895e+06, test-loss 3.9354e+06
# Epoch 1350,| Training-Loss 1.2115e+10,| Data-loss 5.3897e+04,pde-loss 1.6826e-12, initc-loss 1.1397e+06|,|bc_loss 7.1699e+06, test-loss 3.9893e+06
# Epoch 1360,| Training-Loss 1.2070e+10,| Data-loss 5.4612e+04,pde-loss 1.3807e-12, initc-loss 1.1363e+06|,|bc_loss 7.0514e+06, test-loss 4.0435e+06
# Epoch 1370,| Training-Loss 1.2025e+10,| Data-loss 5.5107e+04,pde-loss 1.1095e-12, initc-loss 1.1330e+06|,|bc_loss 6.9339e+06, test-loss 4.0980e+06
# Epoch 1380,| Training-Loss 1.1980e+10,| Data-loss 5.5988e+04,pde-loss 9.9858e-13, initc-loss 1.1297e+06|,|bc_loss 6.8176e+06, test-loss 4.1528e+06
# Epoch 1390,| Training-Loss 1.1935e+10,| Data-loss 5.6759e+04,pde-loss 8.8515e-13, initc-loss 1.1263e+06|,|bc_loss 6.7023e+06, test-loss 4.2079e+06
# Epoch 1400,| Training-Loss 1.1890e+10,| Data-loss 5.7638e+04,pde-loss 1.0724e-12, initc-loss 1.1230e+06|,|bc_loss 6.5881e+06, test-loss 4.2634e+06
# Epoch 1410,| Training-Loss 1.1846e+10,| Data-loss 5.8261e+04,pde-loss 9.4412e-13, initc-loss 1.1197e+06|,|bc_loss 6.4750e+06, test-loss 4.3192e+06
# Epoch 1420,| Training-Loss 1.1801e+10,| Data-loss 5.9129e+04,pde-loss 8.6641e-13, initc-loss 1.1164e+06|,|bc_loss 6.3629e+06, test-loss 4.3752e+06
# Epoch 1430,| Training-Loss 1.1757e+10,| Data-loss 6.0116e+04,pde-loss 9.3298e-13, initc-loss 1.1131e+06|,|bc_loss 6.2519e+06, test-loss 4.4316e+06
# Epoch 1440,| Training-Loss 1.1713e+10,| Data-loss 6.0515e+04,pde-loss 9.1176e-13, initc-loss 1.1098e+06|,|bc_loss 6.1420e+06, test-loss 4.4884e+06
# Epoch 1450,| Training-Loss 1.1670e+10,| Data-loss 6.1403e+04,pde-loss 5.0859e-13, initc-loss 1.1065e+06|,|bc_loss 6.0332e+06, test-loss 4.5455e+06
# Epoch 1460,| Training-Loss 1.1626e+10,| Data-loss 6.2097e+04,pde-loss 5.2343e-13, initc-loss 1.1032e+06|,|bc_loss 5.9254e+06, test-loss 4.6028e+06
# Epoch 1470,| Training-Loss 1.1583e+10,| Data-loss 6.2860e+04,pde-loss 5.8543e-13, initc-loss 1.1000e+06|,|bc_loss 5.8187e+06, test-loss 4.6604e+06
# Epoch 1480,| Training-Loss 1.1540e+10,| Data-loss 6.3635e+04,pde-loss 1.0056e-12, initc-loss 1.0967e+06|,|bc_loss 5.7130e+06, test-loss 4.7184e+06
# Epoch 1490,| Training-Loss 1.1497e+10,| Data-loss 6.4579e+04,pde-loss 9.4838e-13, initc-loss 1.0935e+06|,|bc_loss 5.6084e+06, test-loss 4.7767e+06
# Epoch 1500,| Training-Loss 1.1454e+10,| Data-loss 6.5319e+04,pde-loss 3.9347e-13, initc-loss 1.0902e+06|,|bc_loss 5.5048e+06, test-loss 4.8352e+06
# Epoch 1510,| Training-Loss 1.1411e+10,| Data-loss 6.6102e+04,pde-loss 6.0478e-13, initc-loss 1.0870e+06|,|bc_loss 5.4023e+06, test-loss 4.8941e+06
# Epoch 1520,| Training-Loss 1.1369e+10,| Data-loss 6.6895e+04,pde-loss 6.6500e-13, initc-loss 1.0837e+06|,|bc_loss 5.3008e+06, test-loss 4.9534e+06
# Epoch 1530,| Training-Loss 1.1326e+10,| Data-loss 6.7547e+04,pde-loss 5.4187e-13, initc-loss 1.0805e+06|,|bc_loss 5.2004e+06, test-loss 5.0129e+06
# Epoch 1540,| Training-Loss 1.1284e+10,| Data-loss 6.8625e+04,pde-loss 6.4058e-13, initc-loss 1.0773e+06|,|bc_loss 5.1010e+06, test-loss 5.0726e+06
# Epoch 1550,| Training-Loss 1.1242e+10,| Data-loss 6.9361e+04,pde-loss 6.2783e-13, initc-loss 1.0741e+06|,|bc_loss 5.0027e+06, test-loss 5.1328e+06
# Epoch 1560,| Training-Loss 1.1201e+10,| Data-loss 7.0133e+04,pde-loss 4.2503e-13, initc-loss 1.0709e+06|,|bc_loss 4.9054e+06, test-loss 5.1932e+06
# Epoch 1570,| Training-Loss 1.1159e+10,| Data-loss 7.1129e+04,pde-loss 5.9069e-13, initc-loss 1.0677e+06|,|bc_loss 4.8091e+06, test-loss 5.2539e+06
# Epoch 1580,| Training-Loss 1.1118e+10,| Data-loss 7.1677e+04,pde-loss 4.3835e-13, initc-loss 1.0645e+06|,|bc_loss 4.7139e+06, test-loss 5.3149e+06
# Epoch 1590,| Training-Loss 1.1076e+10,| Data-loss 7.2506e+04,pde-loss 6.6271e-13, initc-loss 1.0613e+06|,|bc_loss 4.6197e+06, test-loss 5.3763e+06
# Epoch 1600,| Training-Loss 1.1035e+10,| Data-loss 7.3440e+04,pde-loss 3.8014e-13, initc-loss 1.0582e+06|,|bc_loss 4.5265e+06, test-loss 5.4379e+06
# Epoch 1610,| Training-Loss 1.0994e+10,| Data-loss 7.4162e+04,pde-loss 5.1993e-13, initc-loss 1.0550e+06|,|bc_loss 4.4343e+06, test-loss 5.4998e+06
# Epoch 1620,| Training-Loss 1.0954e+10,| Data-loss 7.5026e+04,pde-loss 7.5406e-13, initc-loss 1.0518e+06|,|bc_loss 4.3432e+06, test-loss 5.5620e+06
# Epoch 1630,| Training-Loss 1.0913e+10,| Data-loss 7.5932e+04,pde-loss 6.3095e-13, initc-loss 1.0487e+06|,|bc_loss 4.2531e+06, test-loss 5.6246e+06
# Epoch 1640,| Training-Loss 1.0873e+10,| Data-loss 7.6694e+04,pde-loss 3.4172e-13, initc-loss 1.0455e+06|,|bc_loss 4.1639e+06, test-loss 5.6874e+06
# Epoch 1650,| Training-Loss 1.0833e+10,| Data-loss 7.7645e+04,pde-loss 5.3852e-13, initc-loss 1.0424e+06|,|bc_loss 4.0759e+06, test-loss 5.7505e+06
# Epoch 1660,| Training-Loss 1.0793e+10,| Data-loss 7.8446e+04,pde-loss 2.9806e-13, initc-loss 1.0393e+06|,|bc_loss 3.9888e+06, test-loss 5.8140e+06
# Epoch 1670,| Training-Loss 1.0753e+10,| Data-loss 7.9380e+04,pde-loss 6.0052e-13, initc-loss 1.0362e+06|,|bc_loss 3.9027e+06, test-loss 5.8776e+06
# Epoch 1680,| Training-Loss 1.0713e+10,| Data-loss 8.0239e+04,pde-loss 5.6469e-13, initc-loss 1.0330e+06|,|bc_loss 3.8176e+06, test-loss 5.9417e+06
# Epoch 1690,| Training-Loss 1.0674e+10,| Data-loss 8.1204e+04,pde-loss 2.7657e-13, initc-loss 1.0299e+06|,|bc_loss 3.7336e+06, test-loss 6.0060e+06
# Epoch 1700,| Training-Loss 1.0634e+10,| Data-loss 8.1939e+04,pde-loss 3.5758e-13, initc-loss 1.0268e+06|,|bc_loss 3.6505e+06, test-loss 6.0707e+06
# Epoch 1710,| Training-Loss 1.0595e+10,| Data-loss 8.3081e+04,pde-loss 3.0154e-13, initc-loss 1.0237e+06|,|bc_loss 3.5684e+06, test-loss 6.1356e+06
# Epoch 1720,| Training-Loss 1.0556e+10,| Data-loss 8.3926e+04,pde-loss 4.6336e-13, initc-loss 1.0207e+06|,|bc_loss 3.4874e+06, test-loss 6.2007e+06
# Epoch 1730,| Training-Loss 1.0518e+10,| Data-loss 8.4680e+04,pde-loss 2.5988e-13, initc-loss 1.0176e+06|,|bc_loss 3.4073e+06, test-loss 6.2662e+06
# Epoch 1740,| Training-Loss 1.0479e+10,| Data-loss 8.5401e+04,pde-loss 4.1996e-13, initc-loss 1.0145e+06|,|bc_loss 3.3282e+06, test-loss 6.3320e+06
# Epoch 1750,| Training-Loss 1.0440e+10,| Data-loss 8.6417e+04,pde-loss 3.5025e-13, initc-loss 1.0114e+06|,|bc_loss 3.2502e+06, test-loss 6.3981e+06
# Epoch 1760,| Training-Loss 1.0402e+10,| Data-loss 8.7459e+04,pde-loss 5.2664e-13, initc-loss 1.0084e+06|,|bc_loss 3.1731e+06, test-loss 6.4645e+06
# Epoch 1770,| Training-Loss 1.0364e+10,| Data-loss 8.8302e+04,pde-loss 4.6289e-13, initc-loss 1.0053e+06|,|bc_loss 3.0969e+06, test-loss 6.5311e+06
# Epoch 1780,| Training-Loss 1.0326e+10,| Data-loss 8.9188e+04,pde-loss 1.9778e-13, initc-loss 1.0023e+06|,|bc_loss 3.0218e+06, test-loss 6.5980e+06
# Epoch 1790,| Training-Loss 1.0288e+10,| Data-loss 9.0129e+04,pde-loss 2.6974e-13, initc-loss 9.9926e+05|,|bc_loss 2.9477e+06, test-loss 6.6652e+06
# Epoch 1800,| Training-Loss 1.0251e+10,| Data-loss 9.0754e+04,pde-loss 3.1920e-13, initc-loss 9.9623e+05|,|bc_loss 2.8745e+06, test-loss 6.7327e+06
# Epoch 1810,| Training-Loss 1.0213e+10,| Data-loss 9.1831e+04,pde-loss 3.5083e-13, initc-loss 9.9321e+05|,|bc_loss 2.8023e+06, test-loss 6.8006e+06
# Epoch 1820,| Training-Loss 1.0176e+10,| Data-loss 9.2502e+04,pde-loss 3.5214e-13, initc-loss 9.9019e+05|,|bc_loss 2.7311e+06, test-loss 6.8686e+06
# Epoch 1830,| Training-Loss 1.0139e+10,| Data-loss 9.3678e+04,pde-loss 2.3204e-13, initc-loss 9.8718e+05|,|bc_loss 2.6608e+06, test-loss 6.9370e+06
# Epoch 1840,| Training-Loss 1.0102e+10,| Data-loss 9.4570e+04,pde-loss 2.3586e-13, initc-loss 9.8418e+05|,|bc_loss 2.5916e+06, test-loss 7.0057e+06
# Epoch 1850,| Training-Loss 1.0065e+10,| Data-loss 9.5545e+04,pde-loss 2.6285e-13, initc-loss 9.8119e+05|,|bc_loss 2.5233e+06, test-loss 7.0746e+06
# Epoch 1860,| Training-Loss 1.0029e+10,| Data-loss 9.6585e+04,pde-loss 2.5949e-13, initc-loss 9.7820e+05|,|bc_loss 2.4559e+06, test-loss 7.1439e+06
# Epoch 1870,| Training-Loss 9.9922e+09,| Data-loss 9.7521e+04,pde-loss 1.9629e-13, initc-loss 9.7522e+05|,|bc_loss 2.3896e+06, test-loss 7.2134e+06
# Epoch 1880,| Training-Loss 9.9559e+09,| Data-loss 9.8517e+04,pde-loss 2.0744e-13, initc-loss 9.7225e+05|,|bc_loss 2.3241e+06, test-loss 7.2831e+06
# Epoch 1890,| Training-Loss 9.9198e+09,| Data-loss 9.9115e+04,pde-loss 2.4987e-13, initc-loss 9.6928e+05|,|bc_loss 2.2597e+06, test-loss 7.3532e+06
# Epoch 1900,| Training-Loss 9.8838e+09,| Data-loss 1.0039e+05,pde-loss 2.1716e-13, initc-loss 9.6632e+05|,|bc_loss 2.1962e+06, test-loss 7.4235e+06
# Epoch 1910,| Training-Loss 9.8480e+09,| Data-loss 1.0118e+05,pde-loss 2.7970e-13, initc-loss 9.6337e+05|,|bc_loss 2.1336e+06, test-loss 7.4942e+06
# Epoch 1920,| Training-Loss 9.8124e+09,| Data-loss 1.0206e+05,pde-loss 2.0507e-13, initc-loss 9.6042e+05|,|bc_loss 2.0720e+06, test-loss 7.5651e+06
# Epoch 1930,| Training-Loss 9.7770e+09,| Data-loss 1.0318e+05,pde-loss 1.7854e-13, initc-loss 9.5748e+05|,|bc_loss 2.0114e+06, test-loss 7.6362e+06
# Epoch 1940,| Training-Loss 9.7417e+09,| Data-loss 1.0409e+05,pde-loss 2.3979e-13, initc-loss 9.5455e+05|,|bc_loss 1.9517e+06, test-loss 7.7076e+06
# Epoch 1950,| Training-Loss 9.7066e+09,| Data-loss 1.0500e+05,pde-loss 1.6998e-13, initc-loss 9.5163e+05|,|bc_loss 1.8930e+06, test-loss 7.7793e+06
# Epoch 1960,| Training-Loss 9.6716e+09,| Data-loss 1.0594e+05,pde-loss 2.1746e-13, initc-loss 9.4871e+05|,|bc_loss 1.8352e+06, test-loss 7.8513e+06
# Epoch 1970,| Training-Loss 9.6368e+09,| Data-loss 1.0711e+05,pde-loss 2.9034e-13, initc-loss 9.4580e+05|,|bc_loss 1.7783e+06, test-loss 7.9236e+06
# Epoch 1980,| Training-Loss 9.6021e+09,| Data-loss 1.0798e+05,pde-loss 1.6714e-13, initc-loss 9.4289e+05|,|bc_loss 1.7224e+06, test-loss 7.9961e+06
# Epoch 1990,| Training-Loss 9.5677e+09,| Data-loss 1.0902e+05,pde-loss 2.2347e-13, initc-loss 9.4000e+05|,|bc_loss 1.6674e+06, test-loss 8.0689e+06
# Epoch 2000,| Training-Loss 9.5333e+09,| Data-loss 1.0984e+05,pde-loss 1.3977e-13, initc-loss 9.3710e+05|,|bc_loss 1.6134e+06, test-loss 8.1421e+06
# Epoch 2010,| Training-Loss 9.4992e+09,| Data-loss 1.1119e+05,pde-loss 2.1367e-13, initc-loss 9.3422e+05|,|bc_loss 1.5602e+06, test-loss 8.2154e+06
# Epoch 2020,| Training-Loss 9.4652e+09,| Data-loss 1.1198e+05,pde-loss 1.4379e-13, initc-loss 9.3134e+05|,|bc_loss 1.5081e+06, test-loss 8.2889e+06
# Epoch 2030,| Training-Loss 9.4314e+09,| Data-loss 1.1294e+05,pde-loss 1.3997e-13, initc-loss 9.2847e+05|,|bc_loss 1.4568e+06, test-loss 8.3628e+06
# Epoch 2040,| Training-Loss 9.3977e+09,| Data-loss 1.1404e+05,pde-loss 1.5142e-13, initc-loss 9.2561e+05|,|bc_loss 1.4065e+06, test-loss 8.4370e+06
# Epoch 2050,| Training-Loss 9.3642e+09,| Data-loss 1.1498e+05,pde-loss 1.8050e-13, initc-loss 9.2275e+05|,|bc_loss 1.3571e+06, test-loss 8.5115e+06
# Epoch 2060,| Training-Loss 9.3308e+09,| Data-loss 1.1610e+05,pde-loss 2.0638e-13, initc-loss 9.1990e+05|,|bc_loss 1.3086e+06, test-loss 8.5861e+06
# Epoch 2070,| Training-Loss 9.2976e+09,| Data-loss 1.1701e+05,pde-loss 1.9838e-13, initc-loss 9.1706e+05|,|bc_loss 1.2610e+06, test-loss 8.6611e+06
# Epoch 2080,| Training-Loss 9.2646e+09,| Data-loss 1.1818e+05,pde-loss 1.9120e-13, initc-loss 9.1422e+05|,|bc_loss 1.2144e+06, test-loss 8.7364e+06
# Epoch 2090,| Training-Loss 9.2317e+09,| Data-loss 1.1907e+05,pde-loss 2.0529e-13, initc-loss 9.1139e+05|,|bc_loss 1.1687e+06, test-loss 8.8118e+06
# Epoch 2100,| Training-Loss 9.1990e+09,| Data-loss 1.2012e+05,pde-loss 1.6764e-13, initc-loss 9.0857e+05|,|bc_loss 1.1239e+06, test-loss 8.8876e+06
# Epoch 2110,| Training-Loss 9.1665e+09,| Data-loss 1.2132e+05,pde-loss 2.5127e-13, initc-loss 9.0575e+05|,|bc_loss 1.0800e+06, test-loss 8.9634e+06
# Epoch 2120,| Training-Loss 9.1341e+09,| Data-loss 1.2208e+05,pde-loss 1.4410e-13, initc-loss 9.0294e+05|,|bc_loss 1.0370e+06, test-loss 9.0397e+06
# Epoch 2130,| Training-Loss 9.1018e+09,| Data-loss 1.2273e+05,pde-loss 1.2505e-13, initc-loss 9.0014e+05|,|bc_loss 9.9490e+05, test-loss 9.1162e+06
# Epoch 2140,| Training-Loss 9.0697e+09,| Data-loss 1.2397e+05,pde-loss 7.5961e-14, initc-loss 8.9734e+05|,|bc_loss 9.5372e+05, test-loss 9.1929e+06
# Epoch 2150,| Training-Loss 9.0378e+09,| Data-loss 1.2521e+05,pde-loss 1.5127e-13, initc-loss 8.9455e+05|,|bc_loss 9.1345e+05, test-loss 9.2701e+06
# Epoch 2160,| Training-Loss 9.0060e+09,| Data-loss 1.2606e+05,pde-loss 1.7383e-13, initc-loss 8.9177e+05|,|bc_loss 8.7409e+05, test-loss 9.3472e+06
# Epoch 2170,| Training-Loss 8.9744e+09,| Data-loss 1.2743e+05,pde-loss 6.4156e-14, initc-loss 8.8899e+05|,|bc_loss 8.3562e+05, test-loss 9.4247e+06
# Epoch 2180,| Training-Loss 8.9430e+09,| Data-loss 1.2843e+05,pde-loss 1.2329e-13, initc-loss 8.8622e+05|,|bc_loss 7.9804e+05, test-loss 9.5026e+06
# Epoch 2190,| Training-Loss 8.9117e+09,| Data-loss 1.2932e+05,pde-loss 1.5473e-13, initc-loss 8.8346e+05|,|bc_loss 7.6137e+05, test-loss 9.5807e+06
# Epoch 2200,| Training-Loss 8.8805e+09,| Data-loss 1.3057e+05,pde-loss 1.0025e-13, initc-loss 8.8070e+05|,|bc_loss 7.2558e+05, test-loss 9.6590e+06
# Epoch 2210,| Training-Loss 8.8495e+09,| Data-loss 1.3157e+05,pde-loss 7.8241e-14, initc-loss 8.7796e+05|,|bc_loss 6.9069e+05, test-loss 9.7376e+06
# Epoch 2220,| Training-Loss 8.8187e+09,| Data-loss 1.3263e+05,pde-loss 8.7387e-14, initc-loss 8.7521e+05|,|bc_loss 6.5669e+05, test-loss 9.8163e+06
# Epoch 2230,| Training-Loss 8.7880e+09,| Data-loss 1.3382e+05,pde-loss 1.4439e-13, initc-loss 8.7248e+05|,|bc_loss 6.2357e+05, test-loss 9.8953e+06
# Epoch 2240,| Training-Loss 8.7575e+09,| Data-loss 1.3454e+05,pde-loss 1.0727e-13, initc-loss 8.6975e+05|,|bc_loss 5.9133e+05, test-loss 9.9747e+06
# Epoch 2250,| Training-Loss 8.7271e+09,| Data-loss 1.3562e+05,pde-loss 1.1417e-13, initc-loss 8.6702e+05|,|bc_loss 5.5998e+05, test-loss 1.0054e+07
# Epoch 2260,| Training-Loss 8.6969e+09,| Data-loss 1.3682e+05,pde-loss 1.1582e-13, initc-loss 8.6431e+05|,|bc_loss 5.2951e+05, test-loss 1.0134e+07
# Epoch 2270,| Training-Loss 8.6668e+09,| Data-loss 1.3788e+05,pde-loss 9.5450e-14, initc-loss 8.6160e+05|,|bc_loss 4.9992e+05, test-loss 1.0214e+07
# Epoch 2280,| Training-Loss 8.6369e+09,| Data-loss 1.3904e+05,pde-loss 1.4572e-13, initc-loss 8.5889e+05|,|bc_loss 4.7120e+05, test-loss 1.0294e+07
# Epoch 2290,| Training-Loss 8.6072e+09,| Data-loss 1.4006e+05,pde-loss 1.5420e-13, initc-loss 8.5620e+05|,|bc_loss 4.4336e+05, test-loss 1.0375e+07
# Epoch 2300,| Training-Loss 8.5776e+09,| Data-loss 1.4120e+05,pde-loss 8.9759e-14, initc-loss 8.5351e+05|,|bc_loss 4.1638e+05, test-loss 1.0456e+07
# Epoch 2310,| Training-Loss 8.5481e+09,| Data-loss 1.4272e+05,pde-loss 9.5840e-14, initc-loss 8.5082e+05|,|bc_loss 3.9028e+05, test-loss 1.0537e+07
# Epoch 2320,| Training-Loss 8.5189e+09,| Data-loss 1.4342e+05,pde-loss 7.8141e-14, initc-loss 8.4815e+05|,|bc_loss 3.6504e+05, test-loss 1.0618e+07
# Epoch 2330,| Training-Loss 8.4897e+09,| Data-loss 1.4453e+05,pde-loss 1.1350e-13, initc-loss 8.4548e+05|,|bc_loss 3.4067e+05, test-loss 1.0699e+07
# Epoch 2340,| Training-Loss 8.4607e+09,| Data-loss 1.4558e+05,pde-loss 1.0601e-13, initc-loss 8.4281e+05|,|bc_loss 3.1716e+05, test-loss 1.0781e+07
# Epoch 2350,| Training-Loss 8.4319e+09,| Data-loss 1.4650e+05,pde-loss 5.3335e-14, initc-loss 8.4016e+05|,|bc_loss 2.9451e+05, test-loss 1.0863e+07
# Epoch 2360,| Training-Loss 8.4032e+09,| Data-loss 1.4785e+05,pde-loss 6.8612e-14, initc-loss 8.3751e+05|,|bc_loss 2.7272e+05, test-loss 1.0945e+07
# Epoch 2370,| Training-Loss 8.3747e+09,| Data-loss 1.4902e+05,pde-loss 1.0874e-13, initc-loss 8.3486e+05|,|bc_loss 2.5179e+05, test-loss 1.1028e+07
# Epoch 2380,| Training-Loss 8.3463e+09,| Data-loss 1.4993e+05,pde-loss 4.9489e-14, initc-loss 8.3223e+05|,|bc_loss 2.3171e+05, test-loss 1.1110e+07
# Epoch 2390,| Training-Loss 8.3181e+09,| Data-loss 1.5105e+05,pde-loss 7.9221e-14, initc-loss 8.2959e+05|,|bc_loss 2.1248e+05, test-loss 1.1193e+07
# Epoch 2400,| Training-Loss 8.2900e+09,| Data-loss 1.5226e+05,pde-loss 6.9519e-14, initc-loss 8.2697e+05|,|bc_loss 1.9410e+05, test-loss 1.1276e+07
# Epoch 2410,| Training-Loss 8.2620e+09,| Data-loss 1.5337e+05,pde-loss 7.3428e-14, initc-loss 8.2435e+05|,|bc_loss 1.7657e+05, test-loss 1.1360e+07
# Epoch 2420,| Training-Loss 8.2343e+09,| Data-loss 1.5469e+05,pde-loss 1.1624e-13, initc-loss 8.2174e+05|,|bc_loss 1.5988e+05, test-loss 1.1443e+07
# Epoch 2430,| Training-Loss 8.2066e+09,| Data-loss 1.5576e+05,pde-loss 7.9516e-14, initc-loss 8.1914e+05|,|bc_loss 1.4403e+05, test-loss 1.1527e+07
# Epoch 2440,| Training-Loss 8.1791e+09,| Data-loss 1.5694e+05,pde-loss 5.7453e-14, initc-loss 8.1654e+05|,|bc_loss 1.2903e+05, test-loss 1.1611e+07
# Epoch 2450,| Training-Loss 8.1518e+09,| Data-loss 1.5790e+05,pde-loss 6.7295e-14, initc-loss 8.1395e+05|,|bc_loss 1.1486e+05, test-loss 1.1695e+07
# Epoch 2460,| Training-Loss 8.1246e+09,| Data-loss 1.5912e+05,pde-loss 5.1001e-14, initc-loss 8.1136e+05|,|bc_loss 1.0153e+05, test-loss 1.1780e+07
# Epoch 2470,| Training-Loss 8.0976e+09,| Data-loss 1.6016e+05,pde-loss 8.9140e-14, initc-loss 8.0879e+05|,|bc_loss 8.9034e+04, test-loss 1.1865e+07
# Epoch 2480,| Training-Loss 8.0707e+09,| Data-loss 1.6132e+05,pde-loss 7.7158e-14, initc-loss 8.0622e+05|,|bc_loss 7.7367e+04, test-loss 1.1950e+07
# Epoch 2490,| Training-Loss 8.0440e+09,| Data-loss 1.6262e+05,pde-loss 7.3349e-14, initc-loss 8.0365e+05|,|bc_loss 6.6530e+04, test-loss 1.2035e+07
# Epoch 2500,| Training-Loss 8.0174e+09,| Data-loss 1.6360e+05,pde-loss 7.3747e-14, initc-loss 8.0109e+05|,|bc_loss 5.6519e+04, test-loss 1.2120e+07
# Epoch 2510,| Training-Loss 7.9910e+09,| Data-loss 1.6485e+05,pde-loss 7.3774e-14, initc-loss 7.9854e+05|,|bc_loss 4.7333e+04, test-loss 1.2206e+07
# Epoch 2520,| Training-Loss 7.9647e+09,| Data-loss 1.6600e+05,pde-loss 4.1782e-14, initc-loss 7.9599e+05|,|bc_loss 3.8968e+04, test-loss 1.2292e+07
# Epoch 2530,| Training-Loss 7.9385e+09,| Data-loss 1.6731e+05,pde-loss 5.6934e-14, initc-loss 7.9346e+05|,|bc_loss 3.1423e+04, test-loss 1.2378e+07
# Epoch 2540,| Training-Loss 7.9125e+09,| Data-loss 1.6847e+05,pde-loss 7.4259e-14, initc-loss 7.9092e+05|,|bc_loss 2.4695e+04, test-loss 1.2464e+07
# Epoch 2550,| Training-Loss 7.8867e+09,| Data-loss 1.6969e+05,pde-loss 7.3887e-14, initc-loss 7.8840e+05|,|bc_loss 1.8783e+04, test-loss 1.2550e+07
# Epoch 2560,| Training-Loss 7.8610e+09,| Data-loss 1.7114e+05,pde-loss 8.5290e-14, initc-loss 7.8588e+05|,|bc_loss 1.3682e+04, test-loss 1.2637e+07
# Epoch 2570,| Training-Loss 7.8354e+09,| Data-loss 1.7165e+05,pde-loss 7.6986e-14, initc-loss 7.8337e+05|,|bc_loss 9.3923e+03, test-loss 1.2724e+07
# Epoch 2580,| Training-Loss 7.8100e+09,| Data-loss 1.7311e+05,pde-loss 3.0556e-14, initc-loss 7.8086e+05|,|bc_loss 5.9099e+03, test-loss 1.2811e+07
# Epoch 2590,| Training-Loss 7.7847e+09,| Data-loss 1.7396e+05,pde-loss 5.5967e-14, initc-loss 7.7836e+05|,|bc_loss 3.2329e+03, test-loss 1.2898e+07
# Epoch 2600,| Training-Loss 7.7596e+09,| Data-loss 1.7560e+05,pde-loss 5.8054e-14, initc-loss 7.7587e+05|,|bc_loss 1.3587e+03, test-loss 1.2986e+07
# Epoch 2610,| Training-Loss 7.7346e+09,| Data-loss 1.7639e+05,pde-loss 3.9360e-14, initc-loss 7.7338e+05|,|bc_loss 2.8505e+02, test-loss 1.3073e+07
# Epoch 2620,| Training-Loss 7.7098e+09,| Data-loss 1.7763e+05,pde-loss 5.5591e-14, initc-loss 7.7090e+05|,|bc_loss 9.4478e+00, test-loss 1.3161e+07
# Epoch 2630,| Training-Loss 7.6851e+09,| Data-loss 1.7915e+05,pde-loss 6.9597e-14, initc-loss 7.6843e+05|,|bc_loss 5.2947e+02, test-loss 1.3250e+07
# Epoch 2640,| Training-Loss 7.6606e+09,| Data-loss 1.8030e+05,pde-loss 7.4108e-14, initc-loss 7.6596e+05|,|bc_loss 1.8426e+03, test-loss 1.3338e+07
# Epoch 2650,| Training-Loss 7.6362e+09,| Data-loss 1.8130e+05,pde-loss 5.5648e-14, initc-loss 7.6350e+05|,|bc_loss 3.9465e+03, test-loss 1.3426e+07
# Epoch 2660,| Training-Loss 7.6119e+09,| Data-loss 1.8225e+05,pde-loss 5.5675e-14, initc-loss 7.6105e+05|,|bc_loss 6.8384e+03, test-loss 1.3515e+07
# Epoch 2670,| Training-Loss 7.5878e+09,| Data-loss 1.8368e+05,pde-loss 3.8795e-14, initc-loss 7.5860e+05|,|bc_loss 1.0516e+04, test-loss 1.3604e+07
# Epoch 2680,| Training-Loss 7.5639e+09,| Data-loss 1.8494e+05,pde-loss 6.9982e-14, initc-loss 7.5616e+05|,|bc_loss 1.4977e+04, test-loss 1.3693e+07
# Epoch 2690,| Training-Loss 7.5400e+09,| Data-loss 1.8570e+05,pde-loss 4.9503e-14, initc-loss 7.5372e+05|,|bc_loss 2.0219e+04, test-loss 1.3783e+07
# Epoch 2700,| Training-Loss 7.5164e+09,| Data-loss 1.8759e+05,pde-loss 3.4901e-14, initc-loss 7.5130e+05|,|bc_loss 2.6238e+04, test-loss 1.3872e+07
# Epoch 2710,| Training-Loss 7.4928e+09,| Data-loss 1.8867e+05,pde-loss 5.7180e-14, initc-loss 7.4887e+05|,|bc_loss 3.3033e+04, test-loss 1.3962e+07
# Epoch 2720,| Training-Loss 7.4694e+09,| Data-loss 1.8989e+05,pde-loss 4.6542e-14, initc-loss 7.4646e+05|,|bc_loss 4.0602e+04, test-loss 1.4052e+07
# Epoch 2730,| Training-Loss 7.4462e+09,| Data-loss 1.9094e+05,pde-loss 4.9811e-14, initc-loss 7.4405e+05|,|bc_loss 4.8940e+04, test-loss 1.4142e+07
# Epoch 2740,| Training-Loss 7.4231e+09,| Data-loss 1.9212e+05,pde-loss 4.0279e-14, initc-loss 7.4165e+05|,|bc_loss 5.8047e+04, test-loss 1.4232e+07
# Epoch 2750,| Training-Loss 7.4001e+09,| Data-loss 1.9349e+05,pde-loss 3.7076e-14, initc-loss 7.3925e+05|,|bc_loss 6.7919e+04, test-loss 1.4323e+07
# Epoch 2760,| Training-Loss 7.3773e+09,| Data-loss 1.9442e+05,pde-loss 4.8952e-14, initc-loss 7.3686e+05|,|bc_loss 7.8553e+04, test-loss 1.4413e+07
# Epoch 2770,| Training-Loss 7.3546e+09,| Data-loss 1.9592e+05,pde-loss 3.2821e-14, initc-loss 7.3448e+05|,|bc_loss 8.9948e+04, test-loss 1.4504e+07
# Epoch 2780,| Training-Loss 7.3320e+09,| Data-loss 1.9723e+05,pde-loss 5.0485e-14, initc-loss 7.3211e+05|,|bc_loss 1.0210e+05, test-loss 1.4595e+07
# Epoch 2790,| Training-Loss 7.3096e+09,| Data-loss 1.9822e+05,pde-loss 3.1864e-14, initc-loss 7.2974e+05|,|bc_loss 1.1501e+05, test-loss 1.4686e+07
# Epoch 2800,| Training-Loss 7.2874e+09,| Data-loss 1.9940e+05,pde-loss 5.2505e-14, initc-loss 7.2738e+05|,|bc_loss 1.2866e+05, test-loss 1.4778e+07
# Epoch 2810,| Training-Loss 7.2653e+09,| Data-loss 2.0097e+05,pde-loss 5.0913e-14, initc-loss 7.2502e+05|,|bc_loss 1.4307e+05, test-loss 1.4869e+07
# Epoch 2820,| Training-Loss 7.2433e+09,| Data-loss 2.0221e+05,pde-loss 3.5391e-14, initc-loss 7.2267e+05|,|bc_loss 1.5822e+05, test-loss 1.4961e+07
# Epoch 2830,| Training-Loss 7.2214e+09,| Data-loss 2.0330e+05,pde-loss 2.6439e-14, initc-loss 7.2033e+05|,|bc_loss 1.7412e+05, test-loss 1.5053e+07
# Epoch 2840,| Training-Loss 7.1997e+09,| Data-loss 2.0439e+05,pde-loss 3.6974e-14, initc-loss 7.1799e+05|,|bc_loss 1.9076e+05, test-loss 1.5145e+07
# Epoch 2850,| Training-Loss 7.1782e+09,| Data-loss 2.0556e+05,pde-loss 3.9620e-14, initc-loss 7.1566e+05|,|bc_loss 2.0814e+05, test-loss 1.5237e+07
# Epoch 2860,| Training-Loss 7.1567e+09,| Data-loss 2.0717e+05,pde-loss 2.1510e-14, initc-loss 7.1334e+05|,|bc_loss 2.2625e+05, test-loss 1.5330e+07
# Epoch 2870,| Training-Loss 7.1354e+09,| Data-loss 2.0838e+05,pde-loss 2.3825e-14, initc-loss 7.1102e+05|,|bc_loss 2.4510e+05, test-loss 1.5422e+07
# Epoch 2880,| Training-Loss 7.1143e+09,| Data-loss 2.0927e+05,pde-loss 3.7766e-14, initc-loss 7.0871e+05|,|bc_loss 2.6467e+05, test-loss 1.5515e+07
# Epoch 2890,| Training-Loss 7.0933e+09,| Data-loss 2.1092e+05,pde-loss 2.7426e-14, initc-loss 7.0641e+05|,|bc_loss 2.8497e+05, test-loss 1.5608e+07
# Epoch 2900,| Training-Loss 7.0724e+09,| Data-loss 2.1230e+05,pde-loss 3.9137e-14, initc-loss 7.0411e+05|,|bc_loss 3.0600e+05, test-loss 1.5701e+07
# Epoch 2910,| Training-Loss 7.0517e+09,| Data-loss 2.1330e+05,pde-loss 2.9930e-14, initc-loss 7.0182e+05|,|bc_loss 3.2775e+05, test-loss 1.5794e+07
# Epoch 2920,| Training-Loss 7.0311e+09,| Data-loss 2.1451e+05,pde-loss 2.8101e-14, initc-loss 6.9953e+05|,|bc_loss 3.5022e+05, test-loss 1.5888e+07
# Epoch 2930,| Training-Loss 7.0106e+09,| Data-loss 2.1583e+05,pde-loss 2.4002e-14, initc-loss 6.9726e+05|,|bc_loss 3.7340e+05, test-loss 1.5981e+07
# Epoch 2940,| Training-Loss 6.9903e+09,| Data-loss 2.1713e+05,pde-loss 3.1960e-14, initc-loss 6.9498e+05|,|bc_loss 3.9729e+05, test-loss 1.6075e+07
# Epoch 2950,| Training-Loss 6.9701e+09,| Data-loss 2.1855e+05,pde-loss 3.4280e-14, initc-loss 6.9272e+05|,|bc_loss 4.2190e+05, test-loss 1.6169e+07
# Epoch 2960,| Training-Loss 6.9501e+09,| Data-loss 2.2024e+05,pde-loss 2.8471e-14, initc-loss 6.9046e+05|,|bc_loss 4.4721e+05, test-loss 1.6263e+07
# Epoch 2970,| Training-Loss 6.9301e+09,| Data-loss 2.2104e+05,pde-loss 3.6894e-14, initc-loss 6.8821e+05|,|bc_loss 4.7322e+05, test-loss 1.6357e+07
# Epoch 2980,| Training-Loss 6.9104e+09,| Data-loss 2.2220e+05,pde-loss 1.8392e-14, initc-loss 6.8596e+05|,|bc_loss 4.9994e+05, test-loss 1.6452e+07
# Epoch 2990,| Training-Loss 6.8907e+09,| Data-loss 2.2376e+05,pde-loss 1.6651e-14, initc-loss 6.8373e+05|,|bc_loss 5.2735e+05, test-loss 1.6546e+07
# Epoch 3000,| Training-Loss 6.8712e+09,| Data-loss 2.2492e+05,pde-loss 2.8590e-14, initc-loss 6.8149e+05|,|bc_loss 5.5546e+05, test-loss 1.6641e+07
# Epoch 3010,| Training-Loss 6.8518e+09,| Data-loss 2.2625e+05,pde-loss 2.4276e-14, initc-loss 6.7927e+05|,|bc_loss 5.8426e+05, test-loss 1.6736e+07
# Epoch 3020,| Training-Loss 6.8326e+09,| Data-loss 2.2749e+05,pde-loss 3.5199e-14, initc-loss 6.7705e+05|,|bc_loss 6.1375e+05, test-loss 1.6830e+07
# Epoch 3030,| Training-Loss 6.8135e+09,| Data-loss 2.2852e+05,pde-loss 2.7824e-14, initc-loss 6.7484e+05|,|bc_loss 6.4392e+05, test-loss 1.6926e+07
# Epoch 3040,| Training-Loss 6.7945e+09,| Data-loss 2.2989e+05,pde-loss 2.3820e-14, initc-loss 6.7263e+05|,|bc_loss 6.7477e+05, test-loss 1.7021e+07
# Epoch 3050,| Training-Loss 6.7757e+09,| Data-loss 2.3130e+05,pde-loss 2.4591e-14, initc-loss 6.7043e+05|,|bc_loss 7.0631e+05, test-loss 1.7116e+07
# Epoch 3060,| Training-Loss 6.7570e+09,| Data-loss 2.3281e+05,pde-loss 4.7419e-14, initc-loss 6.6824e+05|,|bc_loss 7.3852e+05, test-loss 1.7212e+07
# Epoch 3070,| Training-Loss 6.7384e+09,| Data-loss 2.3387e+05,pde-loss 1.9037e-14, initc-loss 6.6605e+05|,|bc_loss 7.7140e+05, test-loss 1.7307e+07
# Epoch 3080,| Training-Loss 6.7199e+09,| Data-loss 2.3500e+05,pde-loss 1.7969e-14, initc-loss 6.6388e+05|,|bc_loss 8.0496e+05, test-loss 1.7403e+07
# Epoch 3090,| Training-Loss 6.7016e+09,| Data-loss 2.3671e+05,pde-loss 3.3073e-14, initc-loss 6.6170e+05|,|bc_loss 8.3918e+05, test-loss 1.7499e+07
# Epoch 3100,| Training-Loss 6.6835e+09,| Data-loss 2.3808e+05,pde-loss 1.5953e-14, initc-loss 6.5954e+05|,|bc_loss 8.7406e+05, test-loss 1.7595e+07
# Epoch 3110,| Training-Loss 6.6654e+09,| Data-loss 2.3902e+05,pde-loss 1.4708e-14, initc-loss 6.5738e+05|,|bc_loss 9.0960e+05, test-loss 1.7691e+07
# Epoch 3120,| Training-Loss 6.6475e+09,| Data-loss 2.4026e+05,pde-loss 1.7177e-14, initc-loss 6.5522e+05|,|bc_loss 9.4580e+05, test-loss 1.7788e+07
# Epoch 3130,| Training-Loss 6.6297e+09,| Data-loss 2.4152e+05,pde-loss 2.5498e-14, initc-loss 6.5308e+05|,|bc_loss 9.8265e+05, test-loss 1.7884e+07
# Epoch 3140,| Training-Loss 6.6121e+09,| Data-loss 2.4283e+05,pde-loss 1.9919e-14, initc-loss 6.5094e+05|,|bc_loss 1.0202e+06, test-loss 1.7980e+07
# Epoch 3150,| Training-Loss 6.5946e+09,| Data-loss 2.4415e+05,pde-loss 1.7033e-14, initc-loss 6.4880e+05|,|bc_loss 1.0583e+06, test-loss 1.8077e+07
# Epoch 3160,| Training-Loss 6.5772e+09,| Data-loss 2.4547e+05,pde-loss 1.5735e-14, initc-loss 6.4668e+05|,|bc_loss 1.0971e+06, test-loss 1.8174e+07
# Epoch 3170,| Training-Loss 6.5599e+09,| Data-loss 2.4667e+05,pde-loss 2.4028e-14, initc-loss 6.4456e+05|,|bc_loss 1.1365e+06, test-loss 1.8271e+07
# Epoch 3180,| Training-Loss 6.5428e+09,| Data-loss 2.4803e+05,pde-loss 1.4828e-14, initc-loss 6.4244e+05|,|bc_loss 1.1766e+06, test-loss 1.8368e+07
# Epoch 3190,| Training-Loss 6.5258e+09,| Data-loss 2.4918e+05,pde-loss 1.6702e-14, initc-loss 6.4034e+05|,|bc_loss 1.2173e+06, test-loss 1.8465e+07
# Epoch 3200,| Training-Loss 6.5089e+09,| Data-loss 2.5081e+05,pde-loss 1.8711e-14, initc-loss 6.3824e+05|,|bc_loss 1.2586e+06, test-loss 1.8562e+07
# ...
# Epoch 27030,| Training-Loss 1.6970e+07,| Data-loss 3.2302e+05,pde-loss 2.5333e+05, initc-loss 4.0519e+02|,|bc_loss 2.5094e+05, test-loss 2.6736e+07
# Epoch 27040,| Training-Loss 7.6765e+07,| Data-loss 3.3167e+05,pde-loss 9.7516e+05, initc-loss 1.6082e+02|,|bc_loss 2.4823e+02, test-loss 2.6244e+07
# Epoch 27050,| Training-Loss 7.4736e+07,| Data-loss 3.9840e+05,pde-loss 7.4722e+05, initc-loss 1.5630e+03|,|bc_loss 8.1592e+05, test-loss 2.6211e+07
# Epoch 27060,| Training-Loss 6.5320e+07,| Data-loss 3.8550e+05,pde-loss 6.0745e+04, initc-loss 1.3455e+03|,|bc_loss 7.0766e+05, test-loss 2.6122e+07
# Epoch 27070,| Training-Loss 4.3062e+06,| Data-loss 3.9867e+05,pde-loss 2.3910e+05, initc-loss 4.9237e+02|,|bc_loss 1.4478e+04, test-loss 2.6588e+07
# Epoch 27080,| Training-Loss 3.6388e+06,| Data-loss 3.6099e+05,pde-loss 4.9918e+05, initc-loss 4.4346e+02|,|bc_loss 7.2670e+02, test-loss 2.6481e+07
# Epoch 27090,| Training-Loss 4.4107e+07,| Data-loss 4.3317e+05,pde-loss 7.8405e+06, initc-loss 9.0466e+01|,|bc_loss 7.5429e+05, test-loss 2.6865e+07
# Epoch 27100,| Training-Loss 5.7839e+06,| Data-loss 3.7323e+05,pde-loss 2.8841e+05, initc-loss 8.5056e+02|,|bc_loss 9.3712e+02, test-loss 2.6224e+07
# Epoch 27110,| Training-Loss 1.2830e+07,| Data-loss 4.0047e+05,pde-loss 5.0708e+05, initc-loss 4.2079e+02|,|bc_loss 3.3564e+03, test-loss 2.6369e+07
# Epoch 27120,| Training-Loss 3.0893e+07,| Data-loss 3.6742e+05,pde-loss 4.5429e+05, initc-loss 1.0892e+03|,|bc_loss 1.5035e+04, test-loss 2.5962e+07
# Epoch 27130,| Training-Loss 1.3488e+07,| Data-loss 3.8993e+05,pde-loss 2.5705e+05, initc-loss 5.5846e+02|,|bc_loss 2.4117e+02, test-loss 2.6016e+07
# Epoch 27140,| Training-Loss 2.1856e+07,| Data-loss 3.9338e+05,pde-loss 1.2698e+06, initc-loss 2.3618e+03|,|bc_loss 1.1925e+02, test-loss 2.5853e+07
# Epoch 27150,| Training-Loss 4.7088e+06,| Data-loss 2.9711e+05,pde-loss 3.9811e+05, initc-loss 1.8460e+02|,|bc_loss 1.6274e+04, test-loss 2.6136e+07
# Epoch 27160,| Training-Loss 7.8800e+07,| Data-loss 2.5942e+05,pde-loss 5.6669e+05, initc-loss 6.0396e+03|,|bc_loss 6.4528e+05, test-loss 2.5498e+07
# Epoch 27170,| Training-Loss 7.3482e+07,| Data-loss 4.2344e+05,pde-loss 2.7332e+05, initc-loss 1.8848e+02|,|bc_loss 1.2838e+06, test-loss 2.5975e+07
# Epoch 27180,| Training-Loss 5.3734e+07,| Data-loss 2.7561e+05,pde-loss 7.9642e+06, initc-loss 3.4746e+03|,|bc_loss 1.6881e+04, test-loss 2.5904e+07
# Epoch 27190,| Training-Loss 1.0353e+08,| Data-loss 3.5095e+05,pde-loss 1.8061e+06, initc-loss 5.0963e+01|,|bc_loss 3.6924e+02, test-loss 2.6610e+07
# Epoch 27200,| Training-Loss 5.7656e+07,| Data-loss 4.5097e+05,pde-loss 2.2841e+06, initc-loss 2.2297e+02|,|bc_loss 6.3479e+02, test-loss 2.5898e+07
# Epoch 27210,| Training-Loss 5.9877e+07,| Data-loss 3.0910e+05,pde-loss 4.2162e+05, initc-loss 9.1117e+03|,|bc_loss 1.7198e+02, test-loss 2.5523e+07
# Epoch 27220,| Training-Loss 5.1305e+06,| Data-loss 3.7049e+05,pde-loss 4.8923e+05, initc-loss 3.6826e+02|,|bc_loss 1.0822e+03, test-loss 2.6499e+07
# Epoch 27230,| Training-Loss 2.9039e+07,| Data-loss 5.1950e+05,pde-loss 4.6979e+05, initc-loss 1.3684e+01|,|bc_loss 1.5942e+02, test-loss 2.6518e+07
# Epoch 27240,| Training-Loss 4.7154e+07,| Data-loss 3.4458e+05,pde-loss 7.9163e+05, initc-loss 2.5871e+03|,|bc_loss 4.2452e+03, test-loss 2.5674e+07
# Epoch 27250,| Training-Loss 2.7189e+07,| Data-loss 3.3191e+05,pde-loss 7.9286e+05, initc-loss 9.9214e+02|,|bc_loss 4.4728e+03, test-loss 2.6127e+07
# Epoch 27260,| Training-Loss 2.6862e+07,| Data-loss 4.2201e+05,pde-loss 4.5273e+05, initc-loss 3.2509e+02|,|bc_loss 2.8288e+05, test-loss 2.6289e+07
# Epoch 27270,| Training-Loss 5.0826e+07,| Data-loss 4.0332e+05,pde-loss 3.5887e+05, initc-loss 3.4146e+03|,|bc_loss 4.0125e+05, test-loss 2.6094e+07
# Epoch 27280,| Training-Loss 1.1265e+07,| Data-loss 3.3271e+05,pde-loss 8.8213e+04, initc-loss 1.3677e+03|,|bc_loss 5.7892e+02, test-loss 2.6225e+07
# Epoch 27290,| Training-Loss 6.5959e+06,| Data-loss 3.2675e+05,pde-loss 5.7530e+05, initc-loss 5.8759e+02|,|bc_loss 3.0605e+02, test-loss 2.6233e+07
# Epoch 27300,| Training-Loss 8.3504e+06,| Data-loss 3.5387e+05,pde-loss 5.2534e+05, initc-loss 3.4443e+02|,|bc_loss 1.0130e+05, test-loss 2.6678e+07
# Epoch 27310,| Training-Loss 6.7653e+07,| Data-loss 3.7634e+05,pde-loss 7.5979e+05, initc-loss 2.6925e+03|,|bc_loss 1.5488e+05, test-loss 2.6332e+07
# Epoch 27320,| Training-Loss 6.4237e+07,| Data-loss 4.5598e+05,pde-loss 1.0577e+06, initc-loss 9.1681e+03|,|bc_loss 1.5710e+03, test-loss 2.6547e+07
# Epoch 27330,| Training-Loss 5.7619e+07,| Data-loss 3.4409e+05,pde-loss 9.5900e+05, initc-loss 2.3110e+02|,|bc_loss 1.0548e+06, test-loss 2.6735e+07
# Epoch 27340,| Training-Loss 6.3554e+07,| Data-loss 3.1888e+05,pde-loss 2.2384e+06, initc-loss 3.9946e+02|,|bc_loss 1.3560e+05, test-loss 2.6321e+07
# Epoch 27350,| Training-Loss 1.2245e+07,| Data-loss 3.0767e+05,pde-loss 3.4617e+05, initc-loss 5.4209e+02|,|bc_loss 8.8465e+04, test-loss 2.6359e+07
# Epoch 27360,| Training-Loss 4.5680e+07,| Data-loss 4.4581e+05,pde-loss 7.9026e+05, initc-loss 6.9102e+02|,|bc_loss 6.7587e+05, test-loss 2.5999e+07
# Epoch 27370,| Training-Loss 1.2662e+07,| Data-loss 3.5018e+05,pde-loss 7.5713e+06, initc-loss 5.6782e+02|,|bc_loss 2.2568e+04, test-loss 2.6216e+07
# Epoch 27380,| Training-Loss 9.4081e+06,| Data-loss 2.9565e+05,pde-loss 3.3186e+06, initc-loss 3.9787e+02|,|bc_loss 1.8636e+02, test-loss 2.6381e+07
# Epoch 27390,| Training-Loss 1.0603e+07,| Data-loss 3.6977e+05,pde-loss 4.1169e+05, initc-loss 1.2024e+03|,|bc_loss 7.2142e+03, test-loss 2.6298e+07
# Epoch 27400,| Training-Loss 6.8182e+07,| Data-loss 3.9535e+05,pde-loss 1.6365e+06, initc-loss 3.9623e+01|,|bc_loss 1.3023e+06, test-loss 2.6660e+07
# Epoch 27410,| Training-Loss 8.5813e+06,| Data-loss 2.9516e+05,pde-loss 6.2998e+05, initc-loss 6.8674e+02|,|bc_loss 2.0536e+02, test-loss 2.6198e+07
# Epoch 27420,| Training-Loss 3.1511e+07,| Data-loss 2.7302e+05,pde-loss 5.6939e+05, initc-loss 7.4604e+01|,|bc_loss 4.5030e+03, test-loss 2.6326e+07
# Epoch 27430,| Training-Loss 2.0717e+07,| Data-loss 3.7186e+05,pde-loss 1.4397e+06, initc-loss 1.3575e+03|,|bc_loss 1.8637e+05, test-loss 2.6364e+07
# Epoch 27440,| Training-Loss 4.9150e+07,| Data-loss 3.3078e+05,pde-loss 4.3825e+05, initc-loss 2.5803e+03|,|bc_loss 6.2601e+05, test-loss 2.6148e+07
# Epoch 27450,| Training-Loss 1.4742e+08,| Data-loss 3.3062e+05,pde-loss 7.1961e+05, initc-loss 3.2096e+02|,|bc_loss 1.2476e+06, test-loss 2.6324e+07
# Epoch 27460,| Training-Loss 5.0418e+07,| Data-loss 4.2105e+05,pde-loss 1.1148e+06, initc-loss 1.3965e+03|,|bc_loss 4.4099e+04, test-loss 2.6040e+07
# Epoch 27470,| Training-Loss 1.0402e+07,| Data-loss 3.9949e+05,pde-loss 1.5507e+06, initc-loss 7.5463e+02|,|bc_loss 1.2146e+03, test-loss 2.6206e+07
# Epoch 27480,| Training-Loss 3.1413e+07,| Data-loss 3.2547e+05,pde-loss 2.5790e+05, initc-loss 2.6175e+02|,|bc_loss 1.0931e+04, test-loss 2.6337e+07
# Epoch 27490,| Training-Loss 1.0425e+07,| Data-loss 3.4352e+05,pde-loss 6.7153e+05, initc-loss 7.2257e+02|,|bc_loss 4.1305e+04, test-loss 2.6336e+07
# Epoch 27500,| Training-Loss 2.6912e+07,| Data-loss 3.8590e+05,pde-loss 6.6838e+05, initc-loss 3.4773e+03|,|bc_loss 5.6998e+03, test-loss 2.5966e+07
# Epoch 27510,| Training-Loss 4.3917e+07,| Data-loss 3.4382e+05,pde-loss 2.9207e+05, initc-loss 2.8532e+03|,|bc_loss 1.4603e+03, test-loss 2.5788e+07
# Epoch 27520,| Training-Loss 2.1791e+07,| Data-loss 3.5531e+05,pde-loss 3.1203e+05, initc-loss 2.2223e+03|,|bc_loss 8.1883e+03, test-loss 2.6037e+07
# Epoch 27530,| Training-Loss 9.0768e+07,| Data-loss 4.6244e+05,pde-loss 1.7793e+06, initc-loss 1.3291e+03|,|bc_loss 6.9056e+05, test-loss 2.5961e+07
# Epoch 27540,| Training-Loss 2.0990e+07,| Data-loss 3.0996e+05,pde-loss 3.2368e+06, initc-loss 4.0994e+02|,|bc_loss 1.5205e+02, test-loss 2.6293e+07
# Epoch 27550,| Training-Loss 1.2850e+08,| Data-loss 2.8750e+05,pde-loss 7.3412e+05, initc-loss 9.7757e+02|,|bc_loss 1.7471e+03, test-loss 2.5717e+07
# Epoch 27560,| Training-Loss 5.3209e+07,| Data-loss 3.2895e+05,pde-loss 6.2866e+05, initc-loss 5.9251e+02|,|bc_loss 9.0133e+05, test-loss 2.6208e+07
# Epoch 27570,| Training-Loss 4.7629e+07,| Data-loss 3.9122e+05,pde-loss 4.0946e+05, initc-loss 1.6074e+03|,|bc_loss 5.4589e+04, test-loss 2.6239e+07
# Epoch 27580,| Training-Loss 5.5490e+07,| Data-loss 4.2372e+05,pde-loss 6.9510e+05, initc-loss 2.6247e+02|,|bc_loss 1.4856e+04, test-loss 2.6524e+07
# Epoch 27590,| Training-Loss 6.4375e+06,| Data-loss 2.6631e+05,pde-loss 1.4637e+06, initc-loss 2.1248e+02|,|bc_loss 3.8962e+02, test-loss 2.6095e+07
# Epoch 27600,| Training-Loss 5.3174e+07,| Data-loss 3.1738e+05,pde-loss 1.6011e+05, initc-loss 6.0593e+03|,|bc_loss 2.6767e+02, test-loss 2.5691e+07
# Epoch 27610,| Training-Loss 9.8375e+06,| Data-loss 2.9821e+05,pde-loss 4.5357e+05, initc-loss 9.5436e+02|,|bc_loss 1.2481e+04, test-loss 2.6082e+07
# Epoch 27620,| Training-Loss 4.5482e+07,| Data-loss 3.8465e+05,pde-loss 1.7213e+06, initc-loss 3.0525e+03|,|bc_loss 4.4098e+05, test-loss 2.5863e+07
# Epoch 27630,| Training-Loss 5.5156e+07,| Data-loss 3.7100e+05,pde-loss 7.6086e+05, initc-loss 6.1935e+03|,|bc_loss 1.9283e+04, test-loss 2.5557e+07
# Epoch 27640,| Training-Loss 7.1758e+07,| Data-loss 3.5629e+05,pde-loss 7.0560e+05, initc-loss 6.9397e+01|,|bc_loss 2.6391e+05, test-loss 2.6427e+07
# Epoch 27650,| Training-Loss 4.7417e+07,| Data-loss 2.6379e+05,pde-loss 8.9543e+04, initc-loss 5.8459e+02|,|bc_loss 4.2661e+05, test-loss 2.5922e+07
# Epoch 27660,| Training-Loss 4.2319e+07,| Data-loss 3.8082e+05,pde-loss 1.7170e+06, initc-loss 2.8445e+02|,|bc_loss 4.2864e+05, test-loss 2.6295e+07
# Epoch 27670,| Training-Loss 1.3259e+08,| Data-loss 3.7150e+05,pde-loss 1.6756e+06, initc-loss 1.8069e+01|,|bc_loss 3.2836e+02, test-loss 2.6541e+07
# Epoch 27680,| Training-Loss 6.1981e+07,| Data-loss 2.7760e+05,pde-loss 9.9527e+05, initc-loss 5.1361e+03|,|bc_loss 3.0745e+02, test-loss 2.5664e+07
# Epoch 27690,| Training-Loss 3.1031e+07,| Data-loss 2.6944e+05,pde-loss 1.1889e+06, initc-loss 3.4224e+02|,|bc_loss 1.3664e+04, test-loss 2.6129e+07
# Epoch 27700,| Training-Loss 1.0420e+08,| Data-loss 4.4467e+05,pde-loss 5.6008e+05, initc-loss 9.7424e+01|,|bc_loss 6.8860e+05, test-loss 2.6120e+07
# Epoch 27710,| Training-Loss 6.2786e+07,| Data-loss 3.5663e+05,pde-loss 1.3469e+05, initc-loss 2.0407e+03|,|bc_loss 8.3023e+05, test-loss 2.5839e+07
# Epoch 27720,| Training-Loss 6.1754e+07,| Data-loss 4.0192e+05,pde-loss 3.7657e+04, initc-loss 1.1365e+03|,|bc_loss 2.1127e+05, test-loss 2.6116e+07
# Epoch 27730,| Training-Loss 8.8019e+07,| Data-loss 2.7002e+05,pde-loss 6.9744e+04, initc-loss 7.2232e+02|,|bc_loss 3.1843e+03, test-loss 2.6084e+07
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 train_losses, test_losses, pde_losses, bc_losses,ic_losses, data_losses = training_loop(epochs, model, \
#       2                                         loss_fn_data, optimizer,train_loader,test_loader,\
#       3                                             train_pde_loader, train_ic_loader,\
#       4                                             train_b_l_loader,train_b_r_loader )  # Train the model
#       6 # test_losses = test_loop(epochs, model, loss_fn_data, optimizer, train_loader, test_loader)  # Test the model
#
# Cell In[107], line 50, in training_loop(epochs, model, loss_fn_data, optimizer, train_loader, test_dataloader, train_pde_loader, train_loader_init, train_loader_bc_l, train_loader_bc_r)
#      46 u_pred = model(train_inputs_sample[:,0].unsqueeze(1), train_inputs_sample[:,1].unsqueeze(1),\
#      47                train_inputs_sample[:,2].unsqueeze(1))                       # Get the predictions
#      48 u_initl = model(train_inputs_i_sample[:,0].unsqueeze(1), train_inputs_i_sample[:,1].unsqueeze(1),\
#      49                 train_inputs_i_sample[:,2].unsqueeze(1))                       # Get the predictions
# ---> 50 u_left = model(train_inputs_bc_l_sample[:,0].unsqueeze(1), train_inputs_bc_l_sample[:,1].unsqueeze(1),\
#      51                train_inputs_bc_l_sample[:,2].unsqueeze(1))               # Left boundary of the temperature
#      52 u_right = model(train_inputs_bc_r_sample[:,0].unsqueeze(1), train_inputs_bc_r_sample[:,1].unsqueeze(1),\
#      53                 train_inputs_bc_r_sample[:,2].unsqueeze(1))             # Right boundary of the temperature
#      55 # Loss calculation
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[103], line 20, in Pinn_Var.forward(self, x, t, h)
#      18 def forward(self, x, t, h):                               # This is the forward pass
#      19     input_features = torch.cat([x, t, h], dim=1)          # Concatenate the input features
# ---> 20     m = self.base(input_features)                                 # Pass through the third layer
#      21     return m
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.00 MiB. GPU

# %% [markdown]
# # Plots

# %%
inputs = torch.tensor(inp_tr_1).float().to(device) # Convert the inputs to a tensor
temp_nn = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1),inputs[:,2].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model
num_points = space_a1.shape[0] # Number of points in the space vector
print(temp_nn.shape)
temp_nn = temp_nn.reshape(time_a1.shape, space_a1.shape) # Reshape the predictions to a 2D array
print(temp_nn.shape)
time_ss= np.linspace(0, time_end, time_a1.shape)
plt.figure
plt.plot(time_ss, temp_nn[:, num_points//2], label='Predicted Temperature')
plt.plot(time_ss, T1[:,num_points//2], label='Actual Temperature')
plt.xlabel('Time(s)')
plt.ylabel('Temperature (K)')
plt.title('Predicted vs Actual Temperature at x = 7.5mm')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(test_losses, label='test Loss')
# plt.xticks(np.arange(0, epochs, 10000))
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
pde_losses_n = [tensor.cpu().detach().numpy() for tensor in pde_losses]
data_losses_n = [tensor.cpu().detach().numpy() for tensor in data_losses]
ic_losses_n = [tensor.cpu().detach().numpy() for tensor in ic_losses]
bc_losses_n = [tensor.cpu().detach().numpy() for tensor in bc_losses]

plt.figure(figsize=(10, 6))
plt.plot(data_losses_n, label='Data Loss')
plt.plot(pde_losses_n, label='Pde Loss')
plt.plot(ic_losses_n, label='IC Loss')
plt.plot(bc_losses_n, label='BC Loss')
plt.yscale('log')
# plt.axhline(y=1e-6, color='red', linestyle='--', label='Near-Zero Line')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
space_coord, time_coord = np.meshgrid(np.arange(T1.shape[1]), np.arange(T1.shape[0]))

# time_coord = time_coord * dt 
# Create a figure with two subplots
print(space_coord.shape,time_coord.shape,T1.shape,temp_nn.shape)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))


# Plot the temperature history on the left subplot
im1 = ax1.pcolormesh(space_coord, time_coord, T1, cmap='viridis', shading='auto')
ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax1.set_title('Temperature Variation Over Time(Analytical Model)',fontname='Times New Roman', fontsize=20)
ax1.contour(space_coord, time_coord, T1, colors='red', linewidths=1.0, alpha=0.9)

ax1.grid(True)
cbar = fig.colorbar(im1, ax=ax1)
cbar.ax.invert_yaxis()
cbar.set_label('Temperature (K)', rotation=270, labelpad=20, fontname='Times New Roman', fontsize=16)

im2 = ax2.pcolormesh(space_coord, time_coord, temp_nn, cmap='viridis', shading='auto')
ax2.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax2.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax2.set_title('Temperature Variation Over Time(PINN Approach)',fontname='Times New Roman', fontsize=20)
ax2.contour(space_coord, time_coord, temp_nn, colors='red', linewidths=1.0, alpha=0.9)

ax2.grid(True)
cbar = fig.colorbar(im2, ax=ax2)
cbar.ax.invert_yaxis()
cbar.set_label('Temperature (K)', rotation=270, labelpad=20, fontname='Times New Roman', fontsize=16)


plt.tight_layout()
plt.show()
