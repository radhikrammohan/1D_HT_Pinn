# %% [markdown]
# # 1D Three Phase Simulation of Alloys and PINN model development

# %% [markdown]
# This notebook contains the simulation of 1D Phase change of aluminium alloy. There will be three phases (solid,liquid and mushy).
#
# The approach used is finite difference method and the physics involved in heat conduction.

# %% [markdown]
# ## Import Libraries

# %%
import sys
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler, SubsetRandomSampler, random_split

from pinn_loss import loss_fn_data, l1_regularization, pde_loss, boundary_loss, ic_loss, accuracy
from Input_vec_gen import input_gen

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Define the constants and inital geometric domain

# %%
# Geometry
length = 15.0e-3             # Length of the rod

# Material properties
rho = 2300.0                     # Density of AL380 (kg/m^3)
rho_l = 2460.0                   # Density of AL380 (kg/m^3)
rho_s = 2710.0                    # Density of AL380 (kg/m^3)
rho_m = (rho_l + rho_s )/2       # Desnity in mushy zone is taken as average of liquid and solid density

k = 104.0                       # W/m-K
k_l = k                       # W/m-K
k_s = 96.2                    # W/m-K
k_m =  (k_l+k_s)/2                     # W/m-K
k_mo = 41.5


cp = 1245.3                      # Specific heat of aluminum (J/kg-K)
cp_l = cp                      # Specific heat of aluminum (J/kg-K)
cp_s = 963.0                 # Specific heat of aluminum (J/kg-K)
cp_m =  (cp_l+cp_s)/2                 # Specific heat of mushy zone is taken as average of liquid and solid specific heat
# cp_m = cp
           # Thermal diffusivity
alpha_l = k_l / (rho_l * cp_l) 
alpha_s = k_s / (rho_s*cp_s)
alpha_m = k_m / (rho_m * cp_m)          #`Thermal diffusivity in mushy zone is taken as average of liquid and solid thermal diffusivity`


#L_fusion = 3.9e3                 # J/kg
L_fusion = 389.0e3               # J/kg  # Latent heat of fusion of aluminum
         # Thermal diffusivity


T_L = 574.4 +273.0                       #  K -Liquidus Temperature (615 c) AL 380
T_S = 497.3 +273.0                     # K- Solidus Temperature (550 C)
m_eff =(k_m/(rho_m*(cp_m + (L_fusion/(T_L-T_S)))))
print (f"alpha_l = {alpha_l}, alpha_s = {alpha_s}, m_eff = {m_eff}")

# htc = 10.0                   # W/m^2-K
# q = htc*(919.0-723.0)
# q = 10000.0


num_points = 50                        # Number of spatial points
dx = length / (num_points - 1)         # Distance between two spatial points
print('dx is',dx)

                                                              
# Time Discretization  
# 
time_end = 40        # seconds                         

maxi = max(alpha_s,alpha_l,alpha_m)
dt = abs(0.5*((dx**2) /maxi)) 

print('dt is ',dt)
num_steps = round(time_end/dt)
print('num_steps is',num_steps)
cfl = 0.5 *(dx**2/max(alpha_l,alpha_s,alpha_m))
print('cfl is',cfl)

time_steps = np.linspace(0, time_end, num_steps + 1)
step_coeff = dt / (dx ** 2)

if dt <= cfl:
    print('stability criteria satisfied')
else:
    print('stability criteria not satisfied')
    sys.exit()
# Out:
# alpha_l = 3.394878564540885e-05, alpha_s = 3.686205086349929e-05, m_eff = 6.296953764744878e-06
# dx is 0.0003061224489795918
# dt is  0.0012711033647622566
# num_steps is 31469
# cfl is 0.0012711033647622566
# stability criteria satisfied

# %% [markdown]
# ### Initial and Boundary Conditions

# %%
temp_init = 919.0
# Initial temperature and phase fields
temperature = np.full(num_points+2, 919.0)            # Initial temperature of the rod with ghost points at both ends
phase = np.zeros(num_points+2)*0.0                    # Initial phase of the rod with ghost points at both ends

# Set boundary conditions
# temperature[-1] = 919.0 
phase[-1] = 1.0

# temperature[0] = 919.0 #(40 C)
phase[0] = 1.0

# Store initial state in history
temperature_history = [temperature.copy()]    # List to store temperature at each time step
phi_history = [phase.copy()]                    # List to store phase at each time step
temp_init = temperature.copy()                 # Initial temperature of the rod
# print(temperature_history,phi_history)
# Array to store temperature at midpoint over time
midpoint_index = num_points // 2                          # Index of the midpoint

midpoint_temperature_history = [temperature[midpoint_index]]            # List to store temperature at midpoint over time
dm = 60.0e-3                                                            # die thickness in m

# r_m =  (k_mo / dm) + (1/htc)

t_surr = 500.0                                        # Surrounding temperature in K
# t_surr = h()

def kramp(temp,v1,v2,T_L,T_s):                                      # Function to calculate thermal conductivity in Mushy Zone
        slope = (v1-v2)/(T_L-T_S)
        if temp > T_L:
            k_m = k_l
        elif temp < T_S:
            k_m = k_s
        else:
            k_m = k_s + slope*(temp-T_S)
        return k_m

def cp_ramp(temp,v1,v2,T_L,T_s):                                    # Function to calculate specific heat capacity in Mushy Zone
    slope = (v1-v2)/(T_L-T_S)
    if temp > T_L:
        cp_m = cp_l
    elif temp < T_S:
        cp_m = cp_s
    else:
        cp_m = cp_s + slope*(temp-T_S)
    return cp_m

def rho_ramp(temp,v1,v2,T_L,T_s):                                       # Function to calculate density in Mushy Zone
    slope = (v1-v2)/(T_L-T_S)
    if temp > T_L:
        rho_m = rho_l
    elif temp < T_S:
        rho_m = rho_s
    else:
        rho_m = rho_s + slope*(temp-T_S)
    return rho_m

# %% [markdown]
# ### Solving the HT equation and phase change numerically

# %%
for m in range(1, num_steps+1):                                                                            # time loop
    htc = 10.0                   # htc of Still air in W/m^2-K
    q1 = htc*(temp_init[0]-t_surr)   # Heat flux at the left boundary
    
    # print(f"q1 is {q1}")
    temperature[0] = temp_init[0] + alpha_l * step_coeff * ((2.0*temp_init[1]) - (2.0 * temp_init[0])-(2.0*dx*(q1)))  # Update boundary condition temperature
    
    q2 = htc*(temp_init[-1]-t_surr)                   # Heat flux at the right boundary
    temperature[-1] = temp_init[-1] + alpha_l * step_coeff * ((2.0*temp_init[-2]) - (2.0 * temp_init[-1])-(2.0*dx*(q2)))  # Update boundary condition temperature
    
    for n in range(1,num_points+1):              # space loop, adjusted range
       
        if temperature[n] >= T_L:
            temperature[n] += ((alpha_l * step_coeff) * (temp_init[n+1] - (2.0 * temp_init[n]) + temp_init[n-1]))
            phase[n] = 0
            
            # print(f" Time-Step{m},Spatial point{n},Temperature{temperature[n]}")
        elif T_S < temperature[n] < T_L:
            
            k_m = kramp(temperature[n],k_l,k_s,T_L,T_S)
            cp_m = cp_ramp(temperature[n],cp_l,cp_s,T_L,T_S)
            rho_m = rho_ramp(temperature[n],rho_l,rho_s,T_L,T_S)
            m_eff =(k_m/(rho_m*(cp_m + (L_fusion/(T_L-T_S)))))
            
            temperature[n] += ((m_eff * step_coeff)* (temp_init[n+1] - (2.0 * temp_init[n]) + temp_init[n-1]))
            
            phase[n] = (T_L - temperature[n]) / (T_L - T_S)
            # print(m,n,temperature[n],phase[n])
         
        elif temperature[n]<T_S:
            temperature[n] += ((alpha_s * step_coeff) * (temp_init[n+1] - (2.0 * temp_init[n])+ temp_init[n-1]))
            phase[n] = 1
                     
        else:
            print("ERROR: should not be here")

     
          
    temperature = temperature.copy()                                                                # Update temperature
    phase = phase.copy()                                                                            # Update phase
    temp_init = temperature.copy()                                                                  # Update last time step temperature
    temperature_history.append(temperature.copy())                                                  # Append the temperature history to add ghost points
    phi_history.append(phase.copy())                                                                # Append the phase history to add ghost points
    midpoint_temperature_history.append(temperature[midpoint_index])                                # Store midpoint temperature
    
    
    # print(f"Step {m}, Temperature: {temperature}")
    


# print(midpoint_temperature_history)
#print(phi_history)

# %% [markdown]
# ### Plot the Results

# %%
# # Plot temperature history for debugging
# temperature_history_1 = np.array(temperature_history)
# print(temperature_history_1.shape)
# time_ss= np.linspace(0, time_end, num_steps+1)
# # print(time_ss.shape)
# plt.figure(figsize=(10, 6))
# plt.plot(time_ss, midpoint_temperature_history, label='Midpoint Temperature')
# plt.axhline(y=T_L, color='r', linestyle='--', label='Liquidus Temperature')
# plt.axhline(y=T_S, color='g', linestyle='--', label='Solidus Temperature')
# plt.xlabel('Time(s)')
# plt.ylabel('Temperature (K)')
# plt.title('Temperature Distribution Over Time at x = 7.5mm') 
# plt.legend()
# plt.show()

# %% [markdown]
# ### Data into Array

# %%
temperature_history = np.array(temperature_history)

phi_history = np.array(phi_history)

t_hist = np.array(temperature_history[:,1:-1]) # Remove ghost points
t_hist_2 = np.array(temperature_history[:,1:-1])
p_hist = np.array(phi_history[:,1:-1])

t_hist_pde = t_hist[1:,1:-1] # Remove initial condition and boudnary condition
t_hist_init = t_hist[0,:] # Initial condition
t_hist_bc_l = t_hist[:,0] # Left boundary condition
t_hist_bc_r = t_hist[:,-1] # Right boundary condition

# %%
# Assuming you have temperature_history and phi_history as lists of arrays


# # Check the new shape after transposing
# print("Transposed Temperature History Shape:", temperature_history.shape)
# print("Transposed Phi History Shape:", phi_history.shape)

# # Create a meshgrid for space and time coordinates
# space_coord, time_coord = np.meshgrid(np.arange(temperature_history.shape[1]), np.arange(temperature_history.shape[0]))

# time_coord = time_coord * dt 
# # Create a figure with two subplots
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# # Plot the temperature history on the left subplot
# im1 = ax1.pcolormesh(space_coord, time_coord, temperature_history, cmap='viridis')
# ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
# ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
# ax1.set_title('Temperature Variation Over Time',fontname='Times New Roman', fontsize=20)
# fig.colorbar(im1, ax=ax1, label='Temperature')

# # Plot the phase history on the right subplot
# im2 = ax2.pcolormesh(space_coord, time_coord, phi_history, cmap='viridis')
# ax2.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=18)
# ax2.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
# ax2.set_title('Phase Variation Over Time',fontname='Times New Roman', fontsize=20)
# fig.colorbar(im2, ax=ax2, label='Phase')
# plt.tight_layout()
# plt.show()

# #plot the main
# fig, ax = plt.subplots(figsize=(14, 6))
# im = ax.pcolormesh(space_coord, time_coord, Dim_ny, cmap='viridis')
# ax.set_xlabel('Space Coordinate')
# ax.set_ylabel('Time')
# ax.set_title('Niyama Variation Over Time')
# fig.colorbar(im, ax=ax, label='Main')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## ML training

# %% [markdown]
# ### GPU/CPU check

# %%
# check for gpu
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device2 = torch.device('cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Data preparation

# %% [markdown]
# ### Main Dataset

# %%
scaler = StandardScaler()


space = np.linspace(0, length, num_points) # Spatial points
time = np.linspace(0, time_end, num_steps+1) # Time points
space_tr = scaler.fit_transform(space.reshape(-1, 1)).flatten()
time_tr = scaler.fit_transform(time.reshape(-1, 1)).flatten()

space_pde = space[1:-1] # Remove boundary points
time_pde = time[1:-1] # Remove initial condition
space_pde_tr = space_tr[1:-1] # Remove boundary points
time_pde_tr = time_tr[1:] # Remove initial condition
print(space_pde.shape, time_pde.shape)
print(space_pde.shape, time_pde.shape)
print(space_tr.shape, time_tr.shape)
print(space.shape, time.shape)
# Out:
# (48,) (31468,)
# (48,) (31468,)
# (50,) (31470,)
# (50,) (31470,)

# %%
sp_i = np.linspace(0, length, num_points) # Spatial points for initial condition
time_i = np.zeros(num_points) # Time points for initial condition
sp_i_tr = scaler.fit_transform(sp_i.reshape(-1, 1)).flatten()
time_i_tr = scaler.fit_transform(time_i.reshape(-1, 1)).flatten()

sp_b_l = np.zeros(num_steps+1) # Spatial points for boundary condition left
time_b_l = np.linspace(0, time_end, num_steps+1) # Time points for boundary condition left
sp_b_l_tr = scaler.fit_transform(sp_b_l.reshape(-1, 1)).flatten()
time_b_l_tr = scaler.fit_transform(time_b_l.reshape(-1, 1)).flatten()

sp_b_r = np.ones(num_steps+1)*length # Spatial points for boundary condition right
time_b_r = np.linspace(0, time_end, num_steps+1) # Time points for boundary condition right
sp_b_r_tr = scaler.fit_transform(sp_b_r.reshape(-1, 1)).flatten()
time_b_r_tr = scaler.fit_transform(time_b_r.reshape(-1, 1)).flatten()

print(space_pde.shape, time_pde.shape)

print(sp_i.shape, time_i.shape)
print(sp_b_l.shape, time_b_l.shape)
print(sp_b_r.shape, time_b_r.shape)

# %%
inputs = input_gen(space_tr,time_tr,'mgrid') # Generate input for the model
inputs_pde = input_gen(space_pde_tr,time_pde_tr,'mgrid') # Generate input for the PDE
inputs_i = input_gen(sp_i_tr,time_i_tr,'scr') # Generate input for the initial condition
inputs_b_l = input_gen(sp_b_l_tr,time_b_l_tr,'scr') # Generate input for the boundary condition left
inputs_b_r = input_gen(sp_b_r_tr,time_b_r_tr,'scr') # Generate input for the boundary condition right

t_hist_tr = scaler.fit_transform(t_hist.reshape(-1,1))
t_hist_pde_tr = scaler.fit_transform(t_hist_pde.reshape(-1,1))
t_hist_init_tr = scaler.fit_transform(t_hist_init.reshape(-1,1))
t_hist_bc_l_tr = scaler.fit_transform(t_hist_bc_l.reshape(-1,1))
t_hist_bc_r_tr = scaler.fit_transform(t_hist_bc_r.reshape(-1,1))

# t_hist_tr = t_hist.reshape(-1,1)
# t_hist_pde_tr = t_hist_pde.reshape(-1,1)
# t_hist_init_tr = t_hist_init.reshape(-1,1)
# t_hist_bc_l_tr = t_hist_bc_l.reshape(-1,1)
# t_hist_bc_r_tr = t_hist_bc_r.reshape(-1,1)

# %%
print(inputs.shape,inputs_pde.shape,inputs_i.shape,inputs_b_l.shape,inputs_b_r.shape)
print(t_hist_tr.shape,t_hist_pde_tr.shape,t_hist_init_tr.shape,t_hist_bc_l_tr.shape,t_hist_bc_r_tr.shape)
# Out:
# torch.Size([1573500, 2]) (1510512, 2) (50, 2) (31470, 2) (31470, 2)
# (1573500, 1) (1510512, 1) (50, 1) (31470, 1) (31470, 1)

# %% [markdown]
# ## Sample from the Main dataset

# %%
def Sampler (x,t,samp_size):
    index = np.random.choice(x.shape[0],samp_size,replace=False)
    return x[index] , t[index]

inputs_sample, t_hist_sample = Sampler(inputs,t_hist_tr,10000) # Sample the input and output data
inputs_pde_sample, t_hist_pde_sample = Sampler(inputs_pde,t_hist_pde_tr,3000) # Sample the input and output data for pde 
inputs_i_sample,t_hist_i_sample = Sampler(inputs_i,t_hist_init_tr,50) # Sample the input and output data for initial condition
inputs_b_l_sample,t_hist_bc_l_sample = Sampler(inputs_b_l,t_hist_bc_l_tr,2000) # Sample the input and output data for boundary condition left
inputs_b_r_sample, t_hist_bc_r_sample = Sampler(inputs_b_r,t_hist_bc_r_tr, 2000) # Sample the input and output data for boundary condition right

print(inputs_sample.shape, t_hist_sample.shape)
print(inputs_pde_sample.shape, t_hist_pde_sample.shape)
print(inputs_i_sample.shape, t_hist_i_sample.shape)
print(inputs_b_l_sample.shape, t_hist_bc_l_sample.shape)
print(inputs_b_r_sample.shape, t_hist_bc_r_sample.shape)
# Out:
# (10000, 2) (10000, 1)
# (3000, 2) (3000, 1)
# (50, 2) (50, 1)
# (2000, 2) (2000, 1)
# (2000, 2) (2000, 1)

# %% [markdown]
# ### Tensor the sample dataset

# %%
inputs_sample = torch.tensor(inputs_sample).float().to(device) # Convert the inputs to a tensor
inputs_pde_sample = torch.tensor(inputs_pde_sample).float().to(device) # Convert the inputs to a tensor
inputs_i_sample = torch.tensor(inputs_i_sample).float().to(device) # Convert the inputs to a tensor
inputs_b_l_sample = torch.tensor(inputs_b_l_sample).float().to(device)# Convert the inputs to a tensor
inputs_b_r_sample = torch.tensor(inputs_b_r_sample).float().to(device)# Convert the inputs to a tensor

print(inputs_sample.shape)
# label/temp data
temp_inp_sample = torch.tensor(t_hist_sample).float().to(device) # Convert the temperature history to a tensor
temp_inp_pde_sample = torch.tensor(t_hist_pde_sample).float().to(device) # Convert the temperature history to a tensor
temp_inp_init_sample = torch.tensor(t_hist_i_sample).float().to(device) # Convert the temperature history to a tensor
temp_inp_bc_l_sample = torch.tensor(t_hist_bc_l_sample).float().to(device)# Convert the temperature history to a tensor
temp_inp_bc_r_sample = torch.tensor(t_hist_bc_r_sample).float().to(device)# Convert the temperature history to a tensor

print(temp_inp_sample.shape)
# Out:
# torch.Size([10000, 2])
# torch.Size([10000, 1])

# %%
#Data Splitting

# train_inputs, val_test_inputs, train_temp_inp, val_test_temp_inp = train_test_split(inputs, temp_inp, test_size=0.2, random_state=42)
# val_inputs, test_inputs, val_temp_inp, test_temp_inp = train_test_split(val_test_inputs, val_test_temp_inp, test_size=0.8, random_state=42)

train_inputs_sample, test_inputs_sample, \
    train_temp_inp_sample, test_temp_inp_sample = \
        train_test_split(inputs_sample, temp_inp_sample,\
                           test_size=0.2, random_state=42)
train_inputs_pde_sample, test_inputs_pde_sample, \
    train_temp_inp_pde_sample, test_temp_inp_pde_sample = \
        train_test_split(inputs_pde_sample, \
                            temp_inp_pde_sample, test_size=0.2, random_state=42)
train_inputs_i_sample, test_inputs_i_sample, \
    train_temp_inp_i_sample, test_temp_inp_i_sample = \
        train_test_split(inputs_i_sample, \
                         temp_inp_init_sample, test_size=0.2, random_state=42)
train_inputs_bc_l_sample, test_inputs_bc_l_sample, \
    train_temp_inp_bc_l_sample, test_temp_inp_bc_l_sample = \
        train_test_split(inputs_b_l_sample, \
                            temp_inp_bc_l_sample, test_size=0.2, random_state=42)
train_inputs_bc_r_sample, test_inputs_bc_r_sample, \
    train_temp_inp_bc_r_sample, test_temp_inp_bc_r_sample = \
        train_test_split(inputs_b_r_sample, temp_inp_bc_r_sample, \
                                    test_size=0.2, random_state=42)

# %% [markdown]
# ### Create Data loader

# %%
class TensorDataset(torch.utils.data.Dataset):
    def __init__(self, inputs,temp_inp,transform=None, target_transform =None):
        
        self.inputs = inputs
        self.temp_inp = temp_inp
               

    def __getitem__(self, index):
        return self.inputs[index], self.temp_inp[index]
    
    def __len__(self):
        return len(self.inputs)

# %%
  
train_dataset = TensorDataset(train_inputs_sample, train_temp_inp_sample) # Create the training dataset
# val_dataset = TensorDataset(val_inputs, val_temp_inp) # Create the validation dataset
test_dataset = TensorDataset(test_inputs_sample, test_temp_inp_sample) # Create the test dataset

train_pde_dataset = TensorDataset(train_inputs_pde_sample, train_temp_inp_pde_sample) # Create the training dataset
test_pde_dataset = TensorDataset(test_inputs_pde_sample, test_temp_inp_pde_sample) # Create the test dataset

train_dataset_i = TensorDataset(train_inputs_i_sample, train_temp_inp_i_sample) # Create the training dataset
test_dataset_i = TensorDataset(test_inputs_i_sample, test_temp_inp_i_sample) # Create the test dataset

train_dataset_bc_l = TensorDataset(train_inputs_bc_l_sample, train_temp_inp_bc_l_sample) # Create the training dataset
test_dataset_bc_l = TensorDataset(test_inputs_bc_l_sample, test_temp_inp_bc_l_sample) # Create the test dataset

train_dataset_bc_r = TensorDataset(train_inputs_bc_r_sample, train_temp_inp_bc_r_sample) # Create the training dataset
test_dataset_bc_r = TensorDataset(test_inputs_bc_r_sample, test_temp_inp_bc_r_sample) # Create the test dataset


batch_size = 64
batch_size_init_2 = 5

random_sampler_train = RandomSampler(train_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the training dataset
# # random_sampler_val = RandomSampler(val_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the validation dataset
random_sampler_test = RandomSampler(test_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset

random_sampler_train_pde = RandomSampler(train_pde_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the training dataset
random_sampler_test_pde = RandomSampler(test_pde_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset

random_sampler_train_i = RandomSampler(train_dataset_i, replacement=True, num_samples=batch_size_init_2) # Create a random sampler for the training dataset
random_sampler_test_i = RandomSampler(test_dataset_i, replacement=True, num_samples=batch_size_init_2) # Create a random sampler for the test dataset

random_sampler_train_bc_l = RandomSampler(train_dataset_bc_l, replacement=True, num_samples=batch_size) # Create a random sampler for the training dataset
random_sampler_test_bc_l = RandomSampler(test_dataset_bc_l, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset
random_sampler_train_bc_r = RandomSampler(train_dataset_bc_r, replacement=True, num_samples=batch_size) # Create a random sampler for the training dataset
random_sampler_test_bc_r = RandomSampler(test_dataset_bc_r, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset





train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=random_sampler_train) # Create the training dataloader



# val_loader = DataLoader(val_dataset, batch_size=batch_size, sampler=random_sampler_val) # Create the validation dataloader
test_loader = DataLoader(test_dataset, batch_size=batch_size, sampler= random_sampler_test) # Create the test dataloader

train_pde_loader = DataLoader(train_pde_dataset, batch_size=batch_size, \
                              sampler=random_sampler_train_pde) # Create the training dataloader
test_pde_loader = DataLoader(test_pde_dataset, batch_size=batch_size,\
                              sampler=random_sampler_test_pde) # Create the test dataloader


train_loader_init = DataLoader(train_dataset_i, batch_size=batch_size_init_2, \
                               sampler=random_sampler_train_i) # Create the training dataloader
test_loader_init = DataLoader(test_dataset_i, batch_size=batch_size_init_2, \
                              sampler=random_sampler_test_i) # Create the test dataloader

train_loader_bc_l = DataLoader(train_dataset_bc_l, batch_size=batch_size, \
                               sampler=random_sampler_train_bc_l) # Create the training dataloader
test_loader_bc_l = DataLoader(test_dataset_bc_l, batch_size=batch_size, \
                              sampler=random_sampler_test_bc_l) # Create the test dataloader
train_loader_bc_r = DataLoader(train_dataset_bc_r, batch_size=batch_size, \
                                sampler=random_sampler_train_bc_r) # Create the training dataloader
test_loader_bc_r = DataLoader(test_dataset_bc_r, batch_size=batch_size, \
                              sampler=random_sampler_test_bc_r) # Create the test dataloader

# %% [markdown]
# ### NN Architecture Definition

# %%
# Define the neural network architecture
class Mushydata(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_hidden_lyrs): # This is the constructor
        super(Mushydata, self).__init__()
        
        layers = []

        #input layer
        layers.append(nn.Linear(input_size, hidden_size))
        layers.append(nn.ReLU())

        #hidden layer
        for k in range(num_hidden_lyrs):
            layers.append(nn.Linear(hidden_size, hidden_size))
            layers.append(nn.ReLU())    

        #output layer
        layers.append(nn.Linear(hidden_size, output_size))

        # Cnvert the layers list into a pytorch sequential model
        self.base = nn.Sequential(*layers)

    def forward(self, x,t):
        #Concate the input and output to get the final output
        input_features = torch.cat([x,t], dim=1)
        # Pass through sequential layers
        output = self.base(input_features)
        return output
# features = torch.rand(1, 2)
# model = HeatPINN(2, 20, 1)
# output = model(features[:, 0:1], features[:, 1:2])
# print(output)


# Loss function for data

# %% [markdown]
# ### Hyperparamters Init

# %%
# Hyperparameters
hidden_size = 20
learning_rate = 0.005
num_hidden_lyrs = 3
epochs = 30000
# alpha = 0.01  # Adjust this value based on your problem
# boundary_value = 313.0
# initial_value = init_temp
# Initialize the model
model = Mushydata(input_size=2, hidden_size=hidden_size,output_size=1,num_hidden_lyrs=num_hidden_lyrs).to(device)
lambd = 0.1

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Loss List Init

# %%
train_losses = []
val_losses = []
test_losses = []

print(f"Datatype of train_loader is {type(train_loader)}")
# Out:
# Datatype of train_loader is <class 'torch.utils.data.dataloader.DataLoader'>

# %% [markdown]
# ### Loss functions

# %% [markdown]
# ### Training, Validation and Testing Module

# %%
def training_loop(epochs, model, loss_fn_data, optimizer, train_loader,test_dataloader,\
                  train_pde_loader,train_loader_init,\
                    train_loader_bc_l,train_loader_bc_r):
    train_losses = []  # Initialize the list to store the training losses
    # val_losses = []    # Initialize the list to store the validation losses
    test_losses = []   # Initialize the list to store the test losses
    data_losses = []   # Initialize the list to store the data losses
    pde_losses = []   # Initialize the list to store the PDE losses
    ic_losses = []   # Initialize the list to store the initial condition losses
    bc_losses = []   # Initialize the list to store the boundary condition losses

    for epoch in range(epochs):
        model.train()                                                                           # Set the model to training mode
        train_loss = 0                                                                              # Initialize the training loss
        train_accuracy = 0
        train_data_loss = 0
        train_pd_loss = 0
        train_initc_loss = 0
        train_bc_loss = 0

        
        for (batch,batch_pde,batch_init,batch_left,batch_right) in \
             zip (train_loader,train_pde_loader,train_loader_init,train_loader_bc_l,train_loader_bc_r):                                                          # Loop through the training dataloader
            
            train_inputs_sample, train_temp_inp_sample= batch                                                             # Get the inputs and the true values
            
            train_pde_sample, train_temp_inp_pde_sample= batch_pde                                                             # Get the inputs and the true values
            
            train_inputs_i_sample, train_temp_inp_i_sample= batch_init                                                             # Get the inputs and the true values 
            
            train_inputs_bc_l_sample, train_temp_inp_bc_l_sample= batch_left                                                             # Get the inputs and the true values
            train_inputs_bc_r_sample, train_temp_inp_bc_r_sample= batch_right                                                             # Get the inputs and the true values

            train_inputs_sample, train_temp_inp_sample= train_inputs_sample.to(device), train_temp_inp_sample.to(device)                                                             # Get the inputs and the true values
            
            train_pde_sample, train_temp_inp_pde_sample= train_pde_sample.to(device), train_temp_inp_pde_sample.to(device)                                                             # Get the inputs and the true values
            
            train_inputs_i_sample, train_temp_inp_i_sample= train_inputs_i_sample.to(device), train_temp_inp_i_sample.to(device)                                                            # Get the inputs and the true values 
            
            train_inputs_bc_l_sample, train_temp_inp_bc_l_sample=  train_inputs_bc_l_sample.to(device), train_temp_inp_bc_l_sample.to(device)                                                            # Get the inputs and the true values
            train_inputs_bc_r_sample, train_temp_inp_bc_r_sample= train_inputs_bc_r_sample.to(device), train_temp_inp_bc_r_sample.to(device)
            
            
            # print(inputs.shape)
            # print(inputs_init.shape)
            # print(inputs_left.shape)
            # print(inputs_right.shape)

            optimizer.zero_grad()                                                                    # Zero the gradients
            
            # Forward pass
            u_pred = model(train_inputs_sample[:,0].unsqueeze(1), train_inputs_sample[:,1].unsqueeze(1))                       # Get the predictions
            u_initl = model(train_inputs_i_sample[:,0].unsqueeze(1), train_inputs_i_sample[:,1].unsqueeze(1))                       # Get the predictions
            u_left = model(train_inputs_bc_l_sample[:,0].unsqueeze(1), train_inputs_bc_l_sample[:,1].unsqueeze(1))               # Left boundary of the temperature
            u_right = model(train_inputs_bc_r_sample[:,0].unsqueeze(1), train_inputs_bc_r_sample[:,1].unsqueeze(1))             # Right boundary of the temperature

            # Loss calculation
            data_loss = loss_fn_data(u_pred, train_temp_inp_sample)                                              # Calculate the data loss
            
            pd_loss = pde_loss(model,train_pde_sample[:,0].unsqueeze(1),train_pde_sample[:,1].unsqueeze(1))             # Calculate the PDE loss
            # pd_loss = 0
            
            initc_loss = ic_loss(u_initl) 
            # initc_loss =0                                                      # Calculate initial condition loss
            
            bc_loss_left = boundary_loss(model,train_inputs_bc_l_sample[:,0].unsqueeze(1),train_inputs_bc_l_sample[:,1].unsqueeze(1),t_surr) # Calculate the left boundary condition loss
            bc_loss_right = boundary_loss(model,train_inputs_bc_r_sample[:,0].unsqueeze(1),train_inputs_bc_r_sample[:,1].unsqueeze(1),t_surr) # Calculate the right boundary condition loss
            bc_loss = bc_loss_left + bc_loss_right
            # l1_regularization_loss = l1_regularization(model, lambda_l1)                      # Calculate the L1 regularization loss
            # loss = data_loss  + pd_loss + initc_loss + bc_loss                                              # Calculate the total loss
            w1 = 0.01
            w2 = 1000
            w3 = 10
            loss = data_loss + w1* pd_loss + w2 *initc_loss + w3* bc_loss
            train_accuracy += accuracy(u_pred, train_temp_inp_sample)                                                              # Calculate the total loss
            # Backpropagation
            loss.backward()                                                        # Backpropagate the gradients
            
            optimizer.step()                                                                           # Update the weights
            
            train_loss += loss.item()                                                           # Add the loss to the training set loss  
            train_data_loss += data_loss.item()
            train_pd_loss += pd_loss.item()
            train_initc_loss += initc_loss.item()
            train_bc_loss += bc_loss.item()
        
        train_losses.append(train_loss)
        data_losses.append(train_data_loss)
        pde_losses.append(train_pd_loss)
        ic_losses.append(train_initc_loss)
        bc_losses.append(train_bc_loss)


        model.eval()
        test_loss = 0
        test_accuracy = 0
        # with torch.no_grad(): 
        for batch in test_dataloader:
            test_inputs_sample, test_temp_inp_sample= batch
            test_inputs_sample, test_temp_inp_sample= test_inputs_sample.to(device), test_temp_inp_sample.to(device)
            u_pred = model(test_inputs_sample[:,0].unsqueeze(1), test_inputs_sample[:,1].unsqueeze(1))
            data_loss_t = loss_fn_data(u_pred, test_temp_inp_sample)
            # l1_regularization_loss = l1_regularization(model, lambd)
            # loss = data_loss  + l1_regularization_loss
            
            loss = data_loss_t
            test_accuracy = accuracy(u_pred, test_temp_inp_sample)
            test_loss += loss.item()
        test_losses.append(test_loss/len(test_dataloader))

                                                           # Append the training loss to the list of training losses
        
        

        torch.cuda.empty_cache()
        if epoch % 100 == 0:
            print(f"Epoch {epoch},| Training-Loss: {train_loss:.4e}| Test-loss: {test_loss:.4e}|")
            
            print(f"|Data-loss: {data_loss:.4e}|Pde-loss: {pd_loss:.4e}| Initc-loss: {initc_loss:.4e}"
                f"|Bc_loss: {bc_loss:.4e}|") 
            print()

    return train_losses, test_losses , pde_losses , bc_losses , ic_losses, data_losses                                                      # Return the training and validation losses

# %%
def test_loop(epochs, model, loss_fn_data, optimizer, train_dataloader, test_dataloader):
    for epoch in range(epochs):
        model.eval()
        test_loss = 0
        test_accuracy = 0
        with torch.no_grad():   
            for batch in test_dataloader:
                test_inputs_sample, test_temp_inp_sample= batch
                test_inputs_sample, test_temp_inp_sample= test_inputs_sample.to(device), test_temp_inp_sample.to(device)
                u_pred = model(test_inputs_sample[:,0].unsqueeze(1), test_inputs_sample[:,1].unsqueeze(1))
                data_loss = loss_fn_data(u_pred, test_temp_inp_sample)
                # l1_regularization_loss = l1_regularization(model, lambd)
                # loss = data_loss  + l1_regularization_loss
                
                loss = data_loss
                test_accuracy = accuracy(u_pred, test_temp_inp_sample)
                test_loss += loss.item()
        test_losses.append(test_loss)
        if epochs % 10 == 0:
            print(f"Epoch {epoch}, Test-Loss {test_loss:.4e}, Test-Accuracy {test_accuracy:.4e}")      
    return test_losses

# %% [markdown]
# ### Training Button

# %%
train_losses, test_losses, pde_losses, bc_losses,ic_losses, data_losses = training_loop(epochs, model, \
                                        loss_fn_data, optimizer,train_loader,test_loader,\
                                            train_pde_loader, train_loader_init,\
                                            train_loader_bc_l,train_loader_bc_r)  # Train the model
 
# test_losses = test_loop(epochs, model, loss_fn_data, optimizer, train_loader, test_loader)  # Test the model
# Out:
# Epoch 0,| Training-Loss: 1.3439e+09| Test-loss: 1.2149e+00|
# |Data-loss: 1.0757e+00|Pde-loss: 3.1134e-05| Initc-loss: 8.4425e+05|Bc_loss: 4.9967e+07|
#
# Epoch 100,| Training-Loss: 1.2659e+08| Test-loss: 5.6408e+05|
# |Data-loss: 5.2810e+05|Pde-loss: 2.1111e+04| Initc-loss: 9.3248e+04|Bc_loss: 3.2817e+06|
#
# Epoch 200,| Training-Loss: 5.3634e+07| Test-loss: 6.2125e+05|
# |Data-loss: 6.0131e+05|Pde-loss: 7.5787e+03| Initc-loss: 4.6924e+04|Bc_loss: 6.1083e+05|
#
# Epoch 300,| Training-Loss: 3.3931e+07| Test-loss: 6.2501e+05|
# |Data-loss: 5.6527e+05|Pde-loss: 1.3607e+04| Initc-loss: 2.5123e+04|Bc_loss: 8.2424e+05|
#
# Epoch 400,| Training-Loss: 2.0639e+07| Test-loss: 5.3646e+05|
# |Data-loss: 5.2129e+05|Pde-loss: 1.8311e+04| Initc-loss: 1.3493e+04|Bc_loss: 6.6252e+05|
#
# Epoch 500,| Training-Loss: 1.9778e+07| Test-loss: 5.6422e+05|
# |Data-loss: 5.0508e+05|Pde-loss: 1.9939e+04| Initc-loss: 1.0213e+04|Bc_loss: 9.0600e+05|
#
# Epoch 600,| Training-Loss: 1.7514e+07| Test-loss: 5.3766e+05|
# |Data-loss: 6.1111e+05|Pde-loss: 2.6221e+04| Initc-loss: 6.1088e+03|Bc_loss: 1.0794e+06|
#
# Epoch 700,| Training-Loss: 3.1322e+07| Test-loss: 5.7705e+05|
# |Data-loss: 5.0576e+05|Pde-loss: 3.0072e+04| Initc-loss: 2.1465e+04|Bc_loss: 9.3507e+05|
#
# Epoch 800,| Training-Loss: 2.3142e+07| Test-loss: 4.9277e+05|
# |Data-loss: 4.6104e+05|Pde-loss: 4.4815e+04| Initc-loss: 1.6171e+04|Bc_loss: 6.5096e+05|
#
# Epoch 900,| Training-Loss: 2.1935e+07| Test-loss: 5.0443e+05|
# |Data-loss: 4.8435e+05|Pde-loss: 3.9736e+04| Initc-loss: 1.2254e+04|Bc_loss: 9.1966e+05|
#
# Epoch 1000,| Training-Loss: 2.1400e+07| Test-loss: 5.0700e+05|
# |Data-loss: 4.4781e+05|Pde-loss: 8.5866e+04| Initc-loss: 1.5081e+04|Bc_loss: 5.8707e+05|
#
# Epoch 1100,| Training-Loss: 1.0246e+07| Test-loss: 4.5808e+05|
# |Data-loss: 5.1359e+05|Pde-loss: 1.0569e+05| Initc-loss: 6.4750e+03|Bc_loss: 3.2560e+05|
#
# Epoch 1200,| Training-Loss: 7.8180e+06| Test-loss: 5.1192e+05|
# |Data-loss: 4.9064e+05|Pde-loss: 9.9035e+04| Initc-loss: 3.6479e+03|Bc_loss: 3.6784e+05|
#
# Epoch 1300,| Training-Loss: 8.9180e+06| Test-loss: 4.5102e+05|
# |Data-loss: 5.2422e+05|Pde-loss: 2.5092e+05| Initc-loss: 5.4588e+03|Bc_loss: 2.9325e+05|
#
# Epoch 1400,| Training-Loss: 8.4473e+06| Test-loss: 5.0345e+05|
# |Data-loss: 5.3225e+05|Pde-loss: 1.7691e+05| Initc-loss: 6.1364e+03|Bc_loss: 1.7769e+05|
#
# Epoch 1500,| Training-Loss: 3.8378e+06| Test-loss: 5.0332e+05|
# |Data-loss: 5.4654e+05|Pde-loss: 1.5129e+05| Initc-loss: 2.3791e+02|Bc_loss: 3.0519e+05|
#
# Epoch 1600,| Training-Loss: 3.5211e+06| Test-loss: 5.0753e+05|
# |Data-loss: 5.3249e+05|Pde-loss: 2.5445e+05| Initc-loss: 1.0922e+03|Bc_loss: 1.8939e+05|
#
# Epoch 1700,| Training-Loss: 7.7029e+06| Test-loss: 5.1780e+05|
# |Data-loss: 5.5032e+05|Pde-loss: 2.1010e+05| Initc-loss: 1.1896e+02|Bc_loss: 7.0315e+05|
#
# Epoch 1800,| Training-Loss: 5.4037e+06| Test-loss: 5.3949e+05|
# |Data-loss: 5.6668e+05|Pde-loss: 3.6335e+05| Initc-loss: 9.5469e+01|Bc_loss: 4.7379e+05|
#
# Epoch 1900,| Training-Loss: 5.8380e+06| Test-loss: 5.4653e+05|
# |Data-loss: 5.2345e+05|Pde-loss: 8.4739e+05| Initc-loss: 3.3773e+03|Bc_loss: 1.9287e+05|
#
# Epoch 2000,| Training-Loss: 3.6443e+06| Test-loss: 5.5567e+05|
# |Data-loss: 5.6099e+05|Pde-loss: 4.1549e+05| Initc-loss: 3.4182e+02|Bc_loss: 2.7374e+05|
#
# Epoch 2100,| Training-Loss: 2.7377e+06| Test-loss: 5.0765e+05|
# |Data-loss: 5.6596e+05|Pde-loss: 3.0075e+05| Initc-loss: 4.0101e+01|Bc_loss: 2.1287e+05|
#
# Epoch 2200,| Training-Loss: 4.1526e+06| Test-loss: 6.3053e+05|
# |Data-loss: 5.9179e+05|Pde-loss: 3.1563e+05| Initc-loss: 1.3339e+03|Bc_loss: 2.2238e+05|
#
# Epoch 2300,| Training-Loss: 2.5348e+06| Test-loss: 5.8670e+05|
# |Data-loss: 5.7612e+05|Pde-loss: 1.5386e+05| Initc-loss: 2.2311e+02|Bc_loss: 1.7340e+05|
#
# Epoch 2400,| Training-Loss: 3.2911e+06| Test-loss: 6.1742e+05|
# |Data-loss: 6.0839e+05|Pde-loss: 1.4262e+06| Initc-loss: 9.0319e+01|Bc_loss: 2.5781e+05|
#
# Epoch 2500,| Training-Loss: 3.7670e+06| Test-loss: 5.5356e+05|
# |Data-loss: 5.8413e+05|Pde-loss: 1.2089e+06| Initc-loss: 1.2148e+02|Bc_loss: 3.0494e+05|
#
# Epoch 2600,| Training-Loss: 4.7138e+06| Test-loss: 5.1363e+05|
# |Data-loss: 5.0004e+05|Pde-loss: 1.0423e+06| Initc-loss: 3.6109e+03|Bc_loss: 5.9238e+04|
#
# Epoch 2700,| Training-Loss: 3.7219e+06| Test-loss: 5.3769e+05|
# |Data-loss: 5.7908e+05|Pde-loss: 8.3682e+04| Initc-loss: 9.9964e+01|Bc_loss: 3.0420e+05|
#
# Epoch 2800,| Training-Loss: 1.6923e+06| Test-loss: 4.4959e+05|
# |Data-loss: 5.4367e+05|Pde-loss: 1.0962e+06| Initc-loss: 1.5001e+02|Bc_loss: 9.8762e+04|
#
# Epoch 2900,| Training-Loss: 8.1654e+05| Test-loss: 4.7686e+05|
# |Data-loss: 5.1041e+05|Pde-loss: 3.8986e+05| Initc-loss: 2.1585e+00|Bc_loss: 3.0008e+04|
#
# Epoch 3000,| Training-Loss: 1.1106e+06| Test-loss: 5.2219e+05|
# |Data-loss: 4.6393e+05|Pde-loss: 1.8374e+05| Initc-loss: 1.7281e+02|Bc_loss: 4.7205e+04|
#
# Epoch 3100,| Training-Loss: 3.0481e+06| Test-loss: 4.8715e+05|
# |Data-loss: 4.6324e+05|Pde-loss: 1.0028e+06| Initc-loss: 6.2820e+02|Bc_loss: 1.9467e+05|
#
# Epoch 3200,| Training-Loss: 1.1695e+06| Test-loss: 4.8127e+05|
# |Data-loss: 4.2713e+05|Pde-loss: 2.7020e+05| Initc-loss: 2.4238e+02|Bc_loss: 4.9732e+04|
#
# Epoch 3300,| Training-Loss: 2.1533e+06| Test-loss: 4.3074e+05|
# |Data-loss: 4.1564e+05|Pde-loss: 4.0546e+05| Initc-loss: 1.0209e+03|Bc_loss: 7.1271e+04|
#
# Epoch 3400,| Training-Loss: 2.3679e+06| Test-loss: 3.7125e+05|
# |Data-loss: 4.1603e+05|Pde-loss: 1.3449e+06| Initc-loss: 7.3913e+01|Bc_loss: 1.8645e+05|
#
# Epoch 3500,| Training-Loss: 8.6873e+05| Test-loss: 3.6490e+05|
# |Data-loss: 4.3133e+05|Pde-loss: 2.2751e+05| Initc-loss: 6.7801e+01|Bc_loss: 3.6732e+04|
#
# Epoch 3600,| Training-Loss: 1.8119e+06| Test-loss: 3.7429e+05|
# |Data-loss: 4.5803e+05|Pde-loss: 6.7710e+05| Initc-loss: 3.4851e+02|Bc_loss: 9.9861e+04|
#
# Epoch 3700,| Training-Loss: 9.8861e+05| Test-loss: 4.1273e+05|
# |Data-loss: 3.6425e+05|Pde-loss: 2.9666e+06| Initc-loss: 8.2267e+01|Bc_loss: 5.1243e+04|
#
# Epoch 3800,| Training-Loss: 1.3156e+06| Test-loss: 3.9737e+05|
# |Data-loss: 3.8919e+05|Pde-loss: 1.1598e+06| Initc-loss: 6.7631e+01|Bc_loss: 8.4721e+04|
#
# Epoch 3900,| Training-Loss: 7.5423e+05| Test-loss: 3.5030e+05|
# |Data-loss: 3.5157e+05|Pde-loss: 3.5317e+05| Initc-loss: 1.6405e+02|Bc_loss: 2.3509e+04|
#
# Epoch 4000,| Training-Loss: 1.7734e+06| Test-loss: 3.4608e+05|
# |Data-loss: 3.5015e+05|Pde-loss: 4.4998e+05| Initc-loss: 2.6510e+02|Bc_loss: 1.1537e+05|
#
# Epoch 4100,| Training-Loss: 8.9800e+05| Test-loss: 3.3836e+05|
# |Data-loss: 3.8171e+05|Pde-loss: 6.4067e+05| Initc-loss: 2.6142e+02|Bc_loss: 2.4847e+04|
#
# Epoch 4200,| Training-Loss: 8.8677e+05| Test-loss: 3.3093e+05|
# |Data-loss: 3.0610e+05|Pde-loss: 2.3646e+06| Initc-loss: 4.0350e+01|Bc_loss: 5.1668e+04|
#
# Epoch 4300,| Training-Loss: 1.5914e+06| Test-loss: 3.2037e+05|
# |Data-loss: 3.8686e+05|Pde-loss: 5.0780e+04| Initc-loss: 1.6286e+02|Bc_loss: 1.0412e+05|
#
# Epoch 4400,| Training-Loss: 1.6865e+06| Test-loss: 2.5975e+05|
# |Data-loss: 3.6368e+05|Pde-loss: 3.7980e+05| Initc-loss: 4.7933e+02|Bc_loss: 8.3968e+04|
#
# Epoch 4500,| Training-Loss: 6.6407e+05| Test-loss: 2.8297e+05|
# |Data-loss: 3.0501e+05|Pde-loss: 1.9109e+06| Initc-loss: 2.4376e+01|Bc_loss: 3.1558e+04|
#
# Epoch 4600,| Training-Loss: 7.0710e+05| Test-loss: 2.8142e+05|
# |Data-loss: 3.3453e+05|Pde-loss: 6.5645e+05| Initc-loss: 6.6517e+01|Bc_loss: 2.9949e+04|
#
# Epoch 4700,| Training-Loss: 1.4001e+06| Test-loss: 3.0751e+05|
# |Data-loss: 2.6282e+05|Pde-loss: 1.0065e+06| Initc-loss: 6.2690e+02|Bc_loss: 5.0032e+04|
#
# Epoch 4800,| Training-Loss: 1.8493e+06| Test-loss: 2.8591e+05|
# |Data-loss: 3.1278e+05|Pde-loss: 3.5168e+06| Initc-loss: 2.7270e+02|Bc_loss: 1.2286e+05|
#
# Epoch 4900,| Training-Loss: 1.0572e+06| Test-loss: 2.7904e+05|
# |Data-loss: 2.8547e+05|Pde-loss: 6.9081e+04| Initc-loss: 2.0972e+02|Bc_loss: 5.6133e+04|
#
# Epoch 5000,| Training-Loss: 6.6526e+05| Test-loss: 2.7308e+05|
# |Data-loss: 2.5595e+05|Pde-loss: 1.5412e+06| Initc-loss: 8.5608e+00|Bc_loss: 3.8534e+04|
#
# Epoch 5100,| Training-Loss: 1.1282e+06| Test-loss: 2.0965e+05|
# |Data-loss: 2.5059e+05|Pde-loss: 1.4774e+06| Initc-loss: 1.2000e+02|Bc_loss: 7.4279e+04|
#
# Epoch 5200,| Training-Loss: 5.4240e+05| Test-loss: 2.6554e+05|
# |Data-loss: 2.2498e+05|Pde-loss: 6.8836e+05| Initc-loss: 7.9065e+01|Bc_loss: 2.3147e+04|
#
# Epoch 5300,| Training-Loss: 1.2526e+06| Test-loss: 2.7567e+05|
# |Data-loss: 2.9434e+05|Pde-loss: 3.4904e+06| Initc-loss: 4.0754e+02|Bc_loss: 5.1580e+04|
#
# Epoch 5400,| Training-Loss: 3.1491e+05| Test-loss: 2.3450e+05|
# |Data-loss: 2.3329e+05|Pde-loss: 1.5103e+06| Initc-loss: 5.3291e+01|Bc_loss: 1.3218e+03|
#
# Epoch 5500,| Training-Loss: 6.0722e+05| Test-loss: 2.5539e+05|
# |Data-loss: 2.4371e+05|Pde-loss: 1.6056e+06| Initc-loss: 4.6159e+01|Bc_loss: 3.0129e+04|
#
# Epoch 5600,| Training-Loss: 1.9762e+06| Test-loss: 2.3937e+05|
# |Data-loss: 2.3401e+05|Pde-loss: 2.0686e+06| Initc-loss: 3.8288e+02|Bc_loss: 1.3386e+05|
#
# Epoch 5700,| Training-Loss: 3.7107e+06| Test-loss: 2.7053e+05|
# |Data-loss: 2.2918e+05|Pde-loss: 1.6743e+06| Initc-loss: 2.4501e+03|Bc_loss: 1.0148e+05|
#
# Epoch 5800,| Training-Loss: 6.9946e+05| Test-loss: 2.2335e+05|
# |Data-loss: 2.2318e+05|Pde-loss: 9.5269e+05| Initc-loss: 2.0312e+02|Bc_loss: 2.6363e+04|
#
# Epoch 5900,| Training-Loss: 6.4447e+05| Test-loss: 2.0082e+05|
# |Data-loss: 2.3064e+05|Pde-loss: 1.5033e+06| Initc-loss: 1.9295e+01|Bc_loss: 3.7950e+04|
#
# Epoch 6000,| Training-Loss: 1.1889e+06| Test-loss: 2.1088e+05|
# |Data-loss: 2.6635e+05|Pde-loss: 2.7265e+06| Initc-loss: 5.9867e+02|Bc_loss: 2.9665e+04|
#
# Epoch 6100,| Training-Loss: 1.5660e+06| Test-loss: 2.0829e+05|
# |Data-loss: 2.1623e+05|Pde-loss: 2.8124e+06| Initc-loss: 6.8261e+02|Bc_loss: 6.3903e+04|
#
# Epoch 6200,| Training-Loss: 2.6143e+06| Test-loss: 2.1181e+05|
# |Data-loss: 2.3956e+05|Pde-loss: 2.6135e+06| Initc-loss: 2.9481e+02|Bc_loss: 2.0538e+05|
#
# Epoch 6300,| Training-Loss: 1.2068e+06| Test-loss: 2.3932e+05|
# |Data-loss: 2.0178e+05|Pde-loss: 2.3922e+06| Initc-loss: 2.8048e+02|Bc_loss: 7.0064e+04|
#
# Epoch 6400,| Training-Loss: 7.1597e+05| Test-loss: 2.0573e+05|
# |Data-loss: 2.1389e+05|Pde-loss: 8.9797e+05| Initc-loss: 2.2376e+02|Bc_loss: 2.6934e+04|
#
# Epoch 6500,| Training-Loss: 5.0591e+06| Test-loss: 2.1065e+05|
# |Data-loss: 1.9345e+05|Pde-loss: 9.1612e+05| Initc-loss: 3.8384e+03|Bc_loss: 1.0181e+05|
#
# Epoch 6600,| Training-Loss: 1.4516e+06| Test-loss: 1.9930e+05|
# |Data-loss: 1.9047e+05|Pde-loss: 1.0763e+05| Initc-loss: 3.6804e+01|Bc_loss: 1.2233e+05|
#
# Epoch 6700,| Training-Loss: 1.0809e+06| Test-loss: 2.2107e+05|
# |Data-loss: 1.9820e+05|Pde-loss: 1.1018e+06| Initc-loss: 9.6337e+01|Bc_loss: 7.7531e+04|
#
# Epoch 6800,| Training-Loss: 3.6593e+05| Test-loss: 2.1085e+05|
# |Data-loss: 1.8199e+05|Pde-loss: 1.6198e+05| Initc-loss: 6.1239e+01|Bc_loss: 1.2108e+04|
#
# Epoch 6900,| Training-Loss: 7.2730e+05| Test-loss: 2.0537e+05|
# |Data-loss: 1.9342e+05|Pde-loss: 8.5950e+06| Initc-loss: 2.3870e+02|Bc_loss: 2.0923e+04|
#
# Epoch 7000,| Training-Loss: 7.5621e+05| Test-loss: 2.1693e+05|
# |Data-loss: 1.8685e+05|Pde-loss: 1.8092e+06| Initc-loss: 3.2866e+02|Bc_loss: 2.2261e+04|
#
# Epoch 7100,| Training-Loss: 2.3330e+06| Test-loss: 1.7624e+05|
# |Data-loss: 1.8717e+05|Pde-loss: 1.1481e+06| Initc-loss: 1.4540e+03|Bc_loss: 6.8040e+04|
#
# Epoch 7200,| Training-Loss: 1.4561e+06| Test-loss: 2.1473e+05|
# |Data-loss: 1.9275e+05|Pde-loss: 9.8450e+04| Initc-loss: 3.7589e+02|Bc_loss: 8.8648e+04|
#
# Epoch 7300,| Training-Loss: 4.4647e+05| Test-loss: 2.0885e+05|
# |Data-loss: 1.8684e+05|Pde-loss: 1.7010e+06| Initc-loss: 5.5789e+00|Bc_loss: 2.3704e+04|
#
# Epoch 7400,| Training-Loss: 1.4796e+06| Test-loss: 1.9541e+05|
# |Data-loss: 1.9544e+05|Pde-loss: 5.9308e+04| Initc-loss: 2.4539e+02|Bc_loss: 1.0382e+05|
#
# Epoch 7500,| Training-Loss: 3.7577e+06| Test-loss: 1.4301e+05|
# |Data-loss: 1.4556e+05|Pde-loss: 8.8635e+05| Initc-loss: 2.6033e+03|Bc_loss: 1.0000e+05|
#
# Epoch 7600,| Training-Loss: 1.5736e+06| Test-loss: 1.6524e+05|
# |Data-loss: 1.6068e+05|Pde-loss: 2.7270e+06| Initc-loss: 1.0586e+03|Bc_loss: 3.2698e+04|
#
# Epoch 7700,| Training-Loss: 7.7892e+05| Test-loss: 1.4583e+05|
# |Data-loss: 1.7519e+05|Pde-loss: 8.7118e+04| Initc-loss: 5.5919e+01|Bc_loss: 5.4694e+04|
#
# Epoch 7800,| Training-Loss: 7.2278e+05| Test-loss: 1.6844e+05|
# |Data-loss: 1.7486e+05|Pde-loss: 1.1907e+06| Initc-loss: 1.4921e+02|Bc_loss: 3.8680e+04|
#
# Epoch 7900,| Training-Loss: 4.8856e+05| Test-loss: 1.8784e+05|
# |Data-loss: 1.4515e+05|Pde-loss: 1.2532e+05| Initc-loss: 4.5282e+01|Bc_loss: 2.9687e+04|
#
# Epoch 8000,| Training-Loss: 9.0162e+05| Test-loss: 1.5161e+05|
# |Data-loss: 1.4851e+05|Pde-loss: 4.2530e+06| Initc-loss: 4.4892e+02|Bc_loss: 2.6166e+04|
#
# Epoch 8100,| Training-Loss: 1.3762e+06| Test-loss: 1.6279e+05|
# |Data-loss: 1.8575e+05|Pde-loss: 1.9495e+06| Initc-loss: 2.6861e+01|Bc_loss: 1.1441e+05|
#
# Epoch 8200,| Training-Loss: 8.9903e+05| Test-loss: 2.0807e+05|
# |Data-loss: 1.8330e+05|Pde-loss: 3.1800e+06| Initc-loss: 1.7648e+02|Bc_loss: 5.0745e+04|
#
# Epoch 8300,| Training-Loss: 8.0082e+05| Test-loss: 1.8253e+05|
# |Data-loss: 1.7853e+05|Pde-loss: 2.0293e+06| Initc-loss: 1.1788e+01|Bc_loss: 5.9021e+04|
#
# Epoch 8400,| Training-Loss: 1.1023e+06| Test-loss: 1.8798e+05|
# |Data-loss: 1.8174e+05|Pde-loss: 1.9697e+05| Initc-loss: 7.5682e+01|Bc_loss: 8.4295e+04|
#
# Epoch 8500,| Training-Loss: 6.8315e+05| Test-loss: 2.1120e+05|
# |Data-loss: 1.6632e+05|Pde-loss: 1.0715e+05| Initc-loss: 2.3064e+02|Bc_loss: 2.8512e+04|
#
# Epoch 8600,| Training-Loss: 6.2233e+05| Test-loss: 1.6722e+05|
# |Data-loss: 1.9202e+05|Pde-loss: 7.2992e+05| Initc-loss: 1.0446e+01|Bc_loss: 4.1257e+04|
#
# Epoch 8700,| Training-Loss: 7.5710e+05| Test-loss: 1.8394e+05|
# |Data-loss: 1.7925e+05|Pde-loss: 3.7288e+06| Initc-loss: 1.4269e+02|Bc_loss: 3.9788e+04|
#
# Epoch 8800,| Training-Loss: 5.2959e+05| Test-loss: 1.8205e+05|
# |Data-loss: 1.6532e+05|Pde-loss: 3.2339e+06| Initc-loss: 3.4794e+01|Bc_loss: 2.9713e+04|
#
# Epoch 8900,| Training-Loss: 5.6887e+05| Test-loss: 2.1825e+05|
# |Data-loss: 1.8895e+05|Pde-loss: 1.3635e+05| Initc-loss: 1.0000e+02|Bc_loss: 2.7855e+04|
#
# Epoch 9000,| Training-Loss: 1.3418e+06| Test-loss: 1.5548e+05|
# |Data-loss: 1.7739e+05|Pde-loss: 1.3821e+05| Initc-loss: 2.1902e+02|Bc_loss: 9.4404e+04|
#
# Epoch 9100,| Training-Loss: 6.8056e+05| Test-loss: 2.0684e+05|
# |Data-loss: 1.8536e+05|Pde-loss: 8.1232e+05| Initc-loss: 9.8734e+01|Bc_loss: 3.8834e+04|
#
# Epoch 9200,| Training-Loss: 6.7397e+05| Test-loss: 1.6149e+05|
# |Data-loss: 1.5783e+05|Pde-loss: 1.9857e+05| Initc-loss: 1.8656e+02|Bc_loss: 3.2759e+04|
#
# Epoch 9300,| Training-Loss: 6.3853e+05| Test-loss: 1.5160e+05|
# |Data-loss: 1.5545e+05|Pde-loss: 1.0897e+06| Initc-loss: 1.7275e+02|Bc_loss: 2.9944e+04|
#
# Epoch 9400,| Training-Loss: 1.5026e+06| Test-loss: 1.2772e+05|
# |Data-loss: 1.5372e+05|Pde-loss: 2.3206e+05| Initc-loss: 9.8679e+02|Bc_loss: 3.5982e+04|
#
# Epoch 9500,| Training-Loss: 1.0673e+06| Test-loss: 1.7719e+05|
# |Data-loss: 1.4722e+05|Pde-loss: 3.2070e+06| Initc-loss: 3.6296e+02|Bc_loss: 5.2507e+04|
#
# Epoch 9600,| Training-Loss: 1.3110e+06| Test-loss: 1.4480e+05|
# |Data-loss: 1.6574e+05|Pde-loss: 5.8056e+06| Initc-loss: 5.1210e+02|Bc_loss: 5.7510e+04|
#
# Epoch 9700,| Training-Loss: 5.0091e+05| Test-loss: 1.5476e+05|
# |Data-loss: 1.1826e+05|Pde-loss: 3.8535e+06| Initc-loss: 1.1831e+02|Bc_loss: 2.2581e+04|
#
# Epoch 9800,| Training-Loss: 6.7588e+05| Test-loss: 1.5063e+05|
# |Data-loss: 1.3558e+05|Pde-loss: 7.0363e+05| Initc-loss: 3.0006e+02|Bc_loss: 2.3320e+04|
#
# Epoch 9900,| Training-Loss: 4.3247e+05| Test-loss: 1.3618e+05|
# |Data-loss: 1.7949e+05|Pde-loss: 4.6414e+06| Initc-loss: 2.7687e+01|Bc_loss: 1.7888e+04|
#
# Epoch 10000,| Training-Loss: 5.5576e+05| Test-loss: 1.6024e+05|
# |Data-loss: 1.7152e+05|Pde-loss: 1.5782e+06| Initc-loss: 7.6465e+01|Bc_loss: 2.9198e+04|
#
# Epoch 10100,| Training-Loss: 6.7864e+05| Test-loss: 1.3771e+05|
# |Data-loss: 1.5216e+05|Pde-loss: 6.8480e+06| Initc-loss: 2.5597e+02|Bc_loss: 2.0203e+04|
#
# Epoch 10200,| Training-Loss: 2.9487e+06| Test-loss: 1.7444e+05|
# |Data-loss: 1.4019e+05|Pde-loss: 3.0768e+06| Initc-loss: 9.6192e+02|Bc_loss: 1.8158e+05|
#
# Epoch 10300,| Training-Loss: 8.6063e+05| Test-loss: 1.3785e+05|
# |Data-loss: 1.3725e+05|Pde-loss: 1.1570e+06| Initc-loss: 4.3246e+00|Bc_loss: 7.0748e+04|
#
# Epoch 10400,| Training-Loss: 3.7165e+05| Test-loss: 1.4406e+05|
# |Data-loss: 1.7377e+05|Pde-loss: 2.0849e+06| Initc-loss: 9.4724e+00|Bc_loss: 1.6756e+04|
#
# Epoch 10500,| Training-Loss: 5.0048e+05| Test-loss: 1.5464e+05|
# |Data-loss: 1.5793e+05|Pde-loss: 3.1700e+06| Initc-loss: 1.2422e+02|Bc_loss: 1.8663e+04|
#
# Epoch 10600,| Training-Loss: 4.9022e+05| Test-loss: 1.4255e+05|
# |Data-loss: 1.4754e+05|Pde-loss: 3.7081e+06| Initc-loss: 1.8011e+01|Bc_loss: 2.8759e+04|
#
# Epoch 10700,| Training-Loss: 4.3559e+05| Test-loss: 1.4889e+05|
# |Data-loss: 1.2149e+05|Pde-loss: 1.6529e+05| Initc-loss: 8.2412e+01|Bc_loss: 2.3003e+04|
#
# Epoch 10800,| Training-Loss: 4.1625e+05| Test-loss: 1.4664e+05|
# |Data-loss: 1.2146e+05|Pde-loss: 1.7428e+06| Initc-loss: 8.8025e+01|Bc_loss: 1.8934e+04|
#
# Epoch 10900,| Training-Loss: 6.3406e+05| Test-loss: 1.1616e+05|
# |Data-loss: 1.2819e+05|Pde-loss: 3.6262e+06| Initc-loss: 6.2767e+01|Bc_loss: 4.0684e+04|
#
# Epoch 11000,| Training-Loss: 4.5359e+06| Test-loss: 1.4862e+05|
# |Data-loss: 1.9742e+05|Pde-loss: 9.7331e+05| Initc-loss: 2.6546e+03|Bc_loss: 1.6741e+05|
#
# Epoch 11100,| Training-Loss: 3.8434e+05| Test-loss: 1.3472e+05|
# |Data-loss: 1.3302e+05|Pde-loss: 3.5883e+06| Initc-loss: 5.7545e+00|Bc_loss: 2.0968e+04|
#
# Epoch 11200,| Training-Loss: 3.9734e+05| Test-loss: 1.3313e+05|
# |Data-loss: 1.4387e+05|Pde-loss: 1.3197e+06| Initc-loss: 5.9246e+01|Bc_loss: 1.8103e+04|
#
# Epoch 11300,| Training-Loss: 4.1529e+05| Test-loss: 1.5005e+05|
# |Data-loss: 1.4677e+05|Pde-loss: 1.0968e+06| Initc-loss: 8.9395e+01|Bc_loss: 1.6816e+04|
#
# Epoch 11400,| Training-Loss: 4.0286e+05| Test-loss: 1.3374e+05|
# |Data-loss: 1.7464e+05|Pde-loss: 1.2954e+05| Initc-loss: 3.5318e+01|Bc_loss: 1.9161e+04|
#
# Epoch 11500,| Training-Loss: 4.0231e+06| Test-loss: 1.3993e+05|
# |Data-loss: 1.4518e+05|Pde-loss: 3.2961e+06| Initc-loss: 2.8180e+03|Bc_loss: 1.0270e+05|
#
# Epoch 11600,| Training-Loss: 1.9556e+06| Test-loss: 1.3074e+05|
# |Data-loss: 1.5255e+05|Pde-loss: 7.6960e+05| Initc-loss: 7.2158e+02|Bc_loss: 1.0738e+05|
#
# Epoch 11700,| Training-Loss: 5.7280e+05| Test-loss: 1.1513e+05|
# |Data-loss: 1.1207e+05|Pde-loss: 1.8733e+06| Initc-loss: 1.4270e+01|Bc_loss: 4.2773e+04|
#
# Epoch 11800,| Training-Loss: 2.9091e+05| Test-loss: 1.2359e+05|
# |Data-loss: 1.1647e+05|Pde-loss: 8.2663e+04| Initc-loss: 4.7759e+00|Bc_loss: 1.6883e+04|
#
# Epoch 11900,| Training-Loss: 5.5059e+05| Test-loss: 1.3662e+05|
# |Data-loss: 9.5481e+04|Pde-loss: 6.1844e+05| Initc-loss: 1.0863e+02|Bc_loss: 3.4029e+04|
#
# Epoch 12000,| Training-Loss: 2.7654e+05| Test-loss: 1.1186e+05|
# |Data-loss: 1.2373e+05|Pde-loss: 7.4812e+05| Initc-loss: 1.3182e+01|Bc_loss: 1.3214e+04|
#
# Epoch 12100,| Training-Loss: 6.0763e+05| Test-loss: 1.1428e+05|
# |Data-loss: 1.3043e+05|Pde-loss: 4.1059e+06| Initc-loss: 5.0798e+01|Bc_loss: 3.8534e+04|
#
# Epoch 12200,| Training-Loss: 7.1256e+05| Test-loss: 1.5789e+05|
# |Data-loss: 1.1115e+05|Pde-loss: 8.9231e+05| Initc-loss: 3.2006e+02|Bc_loss: 2.7243e+04|
#
# Epoch 12300,| Training-Loss: 3.3601e+05| Test-loss: 1.5336e+05|
# |Data-loss: 1.4808e+05|Pde-loss: 2.1073e+05| Initc-loss: 2.5261e+01|Bc_loss: 1.6056e+04|
#
# Epoch 12400,| Training-Loss: 3.9474e+05| Test-loss: 1.3137e+05|
# |Data-loss: 1.1072e+05|Pde-loss: 3.6439e+06| Initc-loss: 3.0266e+01|Bc_loss: 2.1732e+04|
#
# Epoch 12500,| Training-Loss: 4.5826e+05| Test-loss: 1.3580e+05|
# |Data-loss: 1.3298e+05|Pde-loss: 4.5419e+06| Initc-loss: 3.5969e+01|Bc_loss: 2.4389e+04|
#
# Epoch 12600,| Training-Loss: 6.4267e+05| Test-loss: 1.4116e+05|
# |Data-loss: 1.1768e+05|Pde-loss: 1.7226e+06| Initc-loss: 1.3981e+02|Bc_loss: 3.6795e+04|
#
# Epoch 12700,| Training-Loss: 4.4156e+05| Test-loss: 8.8517e+04|
# |Data-loss: 1.3894e+05|Pde-loss: 2.9382e+06| Initc-loss: 7.5336e+01|Bc_loss: 1.9791e+04|
#
# Epoch 12800,| Training-Loss: 4.0199e+05| Test-loss: 1.1059e+05|
# |Data-loss: 1.3207e+05|Pde-loss: 6.6991e+06| Initc-loss: 9.3334e+00|Bc_loss: 1.9359e+04|
#
# Epoch 12900,| Training-Loss: 4.7863e+05| Test-loss: 1.2133e+05|
# |Data-loss: 9.5357e+04|Pde-loss: 8.3662e+05| Initc-loss: 1.9753e+02|Bc_loss: 1.7738e+04|
#
# Epoch 13000,| Training-Loss: 2.7825e+06| Test-loss: 1.0885e+05|
# |Data-loss: 1.1894e+05|Pde-loss: 3.0326e+06| Initc-loss: 1.2615e+03|Bc_loss: 1.3717e+05|
#
# Epoch 13100,| Training-Loss: 1.7397e+06| Test-loss: 1.1172e+05|
# |Data-loss: 1.0978e+05|Pde-loss: 9.1210e+05| Initc-loss: 9.9871e+02|Bc_loss: 6.2209e+04|
#
# Epoch 13200,| Training-Loss: 6.7186e+05| Test-loss: 1.1993e+05|
# |Data-loss: 1.3496e+05|Pde-loss: 7.0548e+05| Initc-loss: 7.7083e+01|Bc_loss: 4.5276e+04|
#
# Epoch 13300,| Training-Loss: 3.1359e+05| Test-loss: 1.1147e+05|
# |Data-loss: 1.3905e+05|Pde-loss: 1.2687e+05| Initc-loss: 2.5248e+01|Bc_loss: 1.4802e+04|
#
# Epoch 13400,| Training-Loss: 3.9753e+05| Test-loss: 1.3393e+05|
# |Data-loss: 1.2264e+05|Pde-loss: 5.9567e+05| Initc-loss: 2.1952e+00|Bc_loss: 2.6674e+04|
#
# Epoch 13500,| Training-Loss: 7.1998e+05| Test-loss: 1.4338e+05|
# |Data-loss: 1.2095e+05|Pde-loss: 1.2732e+06| Initc-loss: 8.4117e+01|Bc_loss: 5.0219e+04|
#
# Epoch 13600,| Training-Loss: 2.1893e+05| Test-loss: 1.4197e+05|
# |Data-loss: 1.1905e+05|Pde-loss: 1.7384e+06| Initc-loss: 3.0061e+00|Bc_loss: 7.9498e+03|
#
# Epoch 13700,| Training-Loss: 3.0650e+05| Test-loss: 1.3223e+05|
# |Data-loss: 1.2773e+05|Pde-loss: 2.9909e+05| Initc-loss: 4.2097e+01|Bc_loss: 1.3368e+04|
#
# Epoch 13800,| Training-Loss: 2.7315e+05| Test-loss: 1.2047e+05|
# |Data-loss: 8.6019e+04|Pde-loss: 6.6031e+06| Initc-loss: 7.0071e+00|Bc_loss: 1.1409e+04|
#
# Epoch 13900,| Training-Loss: 2.6614e+05| Test-loss: 8.9556e+04|
# |Data-loss: 1.0176e+05|Pde-loss: 3.3787e+05| Initc-loss: 5.9262e+01|Bc_loss: 1.0174e+04|
#
# Epoch 14000,| Training-Loss: 5.5322e+05| Test-loss: 1.1018e+05|
# |Data-loss: 9.7287e+04|Pde-loss: 6.0726e+05| Initc-loss: 1.9873e+02|Bc_loss: 2.5114e+04|
#
# Epoch 14100,| Training-Loss: 2.3605e+05| Test-loss: 1.1798e+05|
# |Data-loss: 1.0906e+05|Pde-loss: 1.4984e+05| Initc-loss: 5.9277e+00|Bc_loss: 1.1956e+04|
#
# Epoch 14200,| Training-Loss: 3.4474e+05| Test-loss: 1.2394e+05|
# |Data-loss: 1.2815e+05|Pde-loss: 1.0322e+06| Initc-loss: 1.8408e+01|Bc_loss: 1.8786e+04|
#
# Epoch 14300,| Training-Loss: 3.4320e+05| Test-loss: 8.2488e+04|
# |Data-loss: 1.2636e+05|Pde-loss: 4.8964e+06| Initc-loss: 6.7872e+00|Bc_loss: 1.6109e+04|
#
# Epoch 14400,| Training-Loss: 4.3037e+05| Test-loss: 9.0216e+04|
# |Data-loss: 9.6020e+04|Pde-loss: 3.7078e+05| Initc-loss: 8.4763e+01|Bc_loss: 2.4588e+04|
#
# Epoch 14500,| Training-Loss: 4.7480e+05| Test-loss: 1.7178e+05|
# |Data-loss: 1.0048e+05|Pde-loss: 3.5946e+06| Initc-loss: 1.9354e+02|Bc_loss: 1.4484e+04|
#
# Epoch 14600,| Training-Loss: 1.1048e+06| Test-loss: 8.5904e+04|
# |Data-loss: 1.2152e+05|Pde-loss: 3.8827e+06| Initc-loss: 6.0274e+02|Bc_loss: 3.4168e+04|
#
# Epoch 14700,| Training-Loss: 1.3617e+07| Test-loss: 8.7910e+04|
# |Data-loss: 1.2616e+05|Pde-loss: 1.9251e+06| Initc-loss: 1.2340e+04|Bc_loss: 1.1324e+05|
#
# Epoch 14800,| Training-Loss: 3.3902e+05| Test-loss: 1.3485e+05|
# |Data-loss: 1.3789e+05|Pde-loss: 9.4826e+05| Initc-loss: 4.8483e+00|Bc_loss: 1.8680e+04|
#
# Epoch 14900,| Training-Loss: 2.7993e+05| Test-loss: 1.0652e+05|
# |Data-loss: 1.2269e+05|Pde-loss: 6.9264e+05| Initc-loss: 1.9853e+01|Bc_loss: 1.3047e+04|
#
# Epoch 15000,| Training-Loss: 8.0039e+05| Test-loss: 9.8313e+04|
# |Data-loss: 9.7280e+04|Pde-loss: 3.2901e+06| Initc-loss: 7.5128e+00|Bc_loss: 6.6269e+04|
#
# Epoch 15100,| Training-Loss: 9.4329e+05| Test-loss: 1.1356e+05|
# |Data-loss: 1.0507e+05|Pde-loss: 1.8239e+06| Initc-loss: 2.9315e+01|Bc_loss: 7.9066e+04|
#
# Epoch 15200,| Training-Loss: 3.0053e+05| Test-loss: 1.0196e+05|
# |Data-loss: 1.0741e+05|Pde-loss: 3.9952e+05| Initc-loss: 8.3191e+00|Bc_loss: 1.8080e+04|
#
# Epoch 15300,| Training-Loss: 2.6271e+05| Test-loss: 1.2623e+05|
# |Data-loss: 9.1142e+04|Pde-loss: 5.0109e+06| Initc-loss: 1.8756e+01|Bc_loss: 1.0270e+04|
#
# Epoch 15400,| Training-Loss: 4.7130e+05| Test-loss: 8.9962e+04|
# |Data-loss: 1.0873e+05|Pde-loss: 2.9821e+06| Initc-loss: 6.5074e+00|Bc_loss: 3.2624e+04|
#
# Epoch 15500,| Training-Loss: 4.3399e+05| Test-loss: 1.0822e+05|
# |Data-loss: 1.1644e+05|Pde-loss: 8.8714e+06| Initc-loss: 5.4849e+01|Bc_loss: 1.7398e+04|
#
# Epoch 15600,| Training-Loss: 9.2699e+05| Test-loss: 9.4489e+04|
# |Data-loss: 1.1891e+05|Pde-loss: 4.3419e+05| Initc-loss: 5.5388e+02|Bc_loss: 2.4985e+04|
#
# Epoch 15700,| Training-Loss: 2.9264e+05| Test-loss: 1.3597e+05|
# |Data-loss: 1.3080e+05|Pde-loss: 7.0069e+05| Initc-loss: 1.7716e+01|Bc_loss: 1.3712e+04|
#
# Epoch 15800,| Training-Loss: 3.1234e+06| Test-loss: 1.4188e+05|
# |Data-loss: 9.9055e+04|Pde-loss: 7.8081e+06| Initc-loss: 2.3572e+03|Bc_loss: 5.8900e+04|
#
# Epoch 15900,| Training-Loss: 4.2160e+05| Test-loss: 8.6231e+04|
# |Data-loss: 1.2330e+05|Pde-loss: 9.6459e+05| Initc-loss: 1.8849e+01|Bc_loss: 2.6980e+04|
#
# Epoch 16000,| Training-Loss: 5.8765e+05| Test-loss: 9.3607e+04|
# |Data-loss: 1.1896e+05|Pde-loss: 2.3977e+05| Initc-loss: 4.6193e+01|Bc_loss: 4.2010e+04|
#
# Epoch 16100,| Training-Loss: 1.5142e+06| Test-loss: 1.1785e+05|
# |Data-loss: 1.0265e+05|Pde-loss: 1.3753e+05| Initc-loss: 1.2442e+03|Bc_loss: 1.6591e+04|
#
# Epoch 16200,| Training-Loss: 3.3464e+05| Test-loss: 1.0328e+05|
# |Data-loss: 9.5426e+04|Pde-loss: 3.4694e+05| Initc-loss: 1.0343e+01|Bc_loss: 2.2540e+04|
#
# Epoch 16300,| Training-Loss: 2.6785e+05| Test-loss: 1.0172e+05|
# |Data-loss: 1.0206e+05|Pde-loss: 1.0219e+06| Initc-loss: 1.4883e+01|Bc_loss: 1.4069e+04|
#
# Epoch 16400,| Training-Loss: 7.0245e+05| Test-loss: 1.2424e+05|
# |Data-loss: 1.5203e+05|Pde-loss: 1.0132e+06| Initc-loss: 1.2634e+01|Bc_loss: 5.2765e+04|
#
# Epoch 16500,| Training-Loss: 3.6595e+05| Test-loss: 1.2966e+05|
# |Data-loss: 9.4245e+04|Pde-loss: 2.7447e+06| Initc-loss: 1.2160e+02|Bc_loss: 1.2266e+04|
#
# Epoch 16600,| Training-Loss: 2.8002e+05| Test-loss: 7.7079e+04|
# |Data-loss: 1.2208e+05|Pde-loss: 1.7600e+05| Initc-loss: 1.9846e+01|Bc_loss: 1.3633e+04|
#
# Epoch 16700,| Training-Loss: 3.6010e+05| Test-loss: 1.0981e+05|
# |Data-loss: 1.2323e+05|Pde-loss: 2.9482e+05| Initc-loss: 6.6848e+00|Bc_loss: 2.2724e+04|
#
# Epoch 16800,| Training-Loss: 3.8227e+05| Test-loss: 1.0168e+05|
# |Data-loss: 8.9122e+04|Pde-loss: 4.1570e+06| Initc-loss: 4.0357e+01|Bc_loss: 2.1122e+04|
#
# Epoch 16900,| Training-Loss: 5.2198e+05| Test-loss: 8.2650e+04|
# |Data-loss: 1.0385e+05|Pde-loss: 7.6684e+06| Initc-loss: 4.6965e+01|Bc_loss: 2.9448e+04|
#
# Epoch 17000,| Training-Loss: 2.5303e+05| Test-loss: 8.9268e+04|
# |Data-loss: 1.3526e+05|Pde-loss: 1.9026e+06| Initc-loss: 1.1197e+01|Bc_loss: 8.7552e+03|
#
# Epoch 17100,| Training-Loss: 2.3909e+05| Test-loss: 1.0776e+05|
# |Data-loss: 8.2310e+04|Pde-loss: 7.3010e+05| Initc-loss: 1.6106e+00|Bc_loss: 1.4787e+04|
#
# Epoch 17200,| Training-Loss: 3.6990e+05| Test-loss: 1.2868e+05|
# |Data-loss: 1.1707e+05|Pde-loss: 2.7916e+05| Initc-loss: 9.1393e+01|Bc_loss: 1.5864e+04|
#
# Epoch 17300,| Training-Loss: 3.9428e+05| Test-loss: 9.7422e+04|
# |Data-loss: 1.0066e+05|Pde-loss: 3.2055e+06| Initc-loss: 5.3573e+01|Bc_loss: 2.0799e+04|
#
# Epoch 17400,| Training-Loss: 4.3855e+05| Test-loss: 8.2953e+04|
# |Data-loss: 1.0493e+05|Pde-loss: 1.9694e+06| Initc-loss: 1.3858e+01|Bc_loss: 3.0007e+04|
#
# Epoch 17500,| Training-Loss: 3.5859e+05| Test-loss: 1.0550e+05|
# |Data-loss: 9.9569e+04|Pde-loss: 4.3904e+06| Initc-loss: 6.1878e+01|Bc_loss: 1.5324e+04|
#
# Epoch 17600,| Training-Loss: 3.6484e+05| Test-loss: 9.7292e+04|
# |Data-loss: 9.2055e+04|Pde-loss: 1.1852e+06| Initc-loss: 8.0399e+01|Bc_loss: 1.8054e+04|
#
# Epoch 17700,| Training-Loss: 2.7472e+05| Test-loss: 1.1524e+05|
# |Data-loss: 1.3704e+05|Pde-loss: 1.7891e+06| Initc-loss: 5.3841e+00|Bc_loss: 1.1440e+04|
#
# Epoch 17800,| Training-Loss: 9.9536e+05| Test-loss: 8.8950e+04|
# |Data-loss: 7.7698e+04|Pde-loss: 2.6983e+06| Initc-loss: 7.6306e+02|Bc_loss: 1.2762e+04|
#
# Epoch 17900,| Training-Loss: 2.8609e+05| Test-loss: 1.0194e+05|
# |Data-loss: 1.2003e+05|Pde-loss: 3.5878e+06| Initc-loss: 2.2342e+01|Bc_loss: 1.0784e+04|
#
# Epoch 18000,| Training-Loss: 2.4920e+05| Test-loss: 7.8073e+04|
# |Data-loss: 7.5987e+04|Pde-loss: 1.3509e+06| Initc-loss: 3.7642e+01|Bc_loss: 1.2206e+04|
#
# Epoch 18100,| Training-Loss: 5.2664e+05| Test-loss: 1.1806e+05|
# |Data-loss: 1.2982e+05|Pde-loss: 2.8495e+06| Initc-loss: 6.2996e+00|Bc_loss: 3.6203e+04|
#
# Epoch 18200,| Training-Loss: 4.8689e+05| Test-loss: 9.2426e+04|
# |Data-loss: 8.3291e+04|Pde-loss: 2.5204e+06| Initc-loss: 1.4091e+02|Bc_loss: 2.3749e+04|
#
# Epoch 18300,| Training-Loss: 8.5483e+06| Test-loss: 1.1192e+05|
# |Data-loss: 8.5170e+04|Pde-loss: 3.0164e+06| Initc-loss: 6.2162e+03|Bc_loss: 2.2167e+05|
#
# Epoch 18400,| Training-Loss: 1.1089e+06| Test-loss: 1.0465e+05|
# |Data-loss: 1.4019e+05|Pde-loss: 1.3463e+06| Initc-loss: 3.5357e+02|Bc_loss: 6.0169e+04|
#
# Epoch 18500,| Training-Loss: 4.5234e+05| Test-loss: 9.1776e+04|
# |Data-loss: 1.1604e+05|Pde-loss: 1.0577e+06| Initc-loss: 6.5973e+01|Bc_loss: 2.5975e+04|
#
# Epoch 18600,| Training-Loss: 3.8327e+05| Test-loss: 9.0629e+04|
# |Data-loss: 1.2884e+05|Pde-loss: 2.3214e+06| Initc-loss: 4.8849e+01|Bc_loss: 1.8237e+04|
#
# Epoch 18700,| Training-Loss: 3.2201e+05| Test-loss: 1.1029e+05|
# |Data-loss: 8.3721e+04|Pde-loss: 1.5768e+05| Initc-loss: 3.9963e+00|Bc_loss: 2.3271e+04|
#
# Epoch 18800,| Training-Loss: 4.5033e+05| Test-loss: 1.0855e+05|
# |Data-loss: 1.0855e+05|Pde-loss: 2.6866e+05| Initc-loss: 3.7626e+01|Bc_loss: 3.0147e+04|
#
# Epoch 18900,| Training-Loss: 1.9469e+05| Test-loss: 1.1555e+05|
# |Data-loss: 9.3762e+04|Pde-loss: 8.1214e+05| Initc-loss: 5.9873e+00|Bc_loss: 8.6818e+03|
#
# Epoch 19000,| Training-Loss: 2.1052e+05| Test-loss: 1.0101e+05|
# |Data-loss: 7.7977e+04|Pde-loss: 2.4659e+05| Initc-loss: 9.8806e+00|Bc_loss: 1.2020e+04|
#
# Epoch 19100,| Training-Loss: 3.6584e+05| Test-loss: 8.8903e+04|
# |Data-loss: 1.2652e+05|Pde-loss: 2.2962e+06| Initc-loss: 4.7465e+01|Bc_loss: 1.6890e+04|
#
# Epoch 19200,| Training-Loss: 3.1282e+05| Test-loss: 1.2232e+05|
# |Data-loss: 1.2032e+05|Pde-loss: 5.4745e+05| Initc-loss: 1.1292e+01|Bc_loss: 1.7573e+04|
#
# Epoch 19300,| Training-Loss: 2.6341e+05| Test-loss: 1.0407e+05|
# |Data-loss: 1.1209e+05|Pde-loss: 5.7015e+05| Initc-loss: 1.0156e+01|Bc_loss: 1.3547e+04|
#
# Epoch 19400,| Training-Loss: 4.7952e+05| Test-loss: 8.2597e+04|
# |Data-loss: 1.1966e+05|Pde-loss: 1.4469e+06| Initc-loss: 1.0305e+02|Bc_loss: 2.4234e+04|
#
# Epoch 19500,| Training-Loss: 9.0554e+05| Test-loss: 1.0503e+05|
# |Data-loss: 1.0311e+05|Pde-loss: 7.0388e+06| Initc-loss: 1.3989e+02|Bc_loss: 5.9216e+04|
#
# Epoch 19600,| Training-Loss: 3.0576e+05| Test-loss: 1.0092e+05|
# |Data-loss: 1.1406e+05|Pde-loss: 4.3655e+06| Initc-loss: 5.4017e+01|Bc_loss: 9.4023e+03|
#
# Epoch 19700,| Training-Loss: 2.1581e+05| Test-loss: 1.1325e+05|
# |Data-loss: 7.3064e+04|Pde-loss: 1.2989e+06| Initc-loss: 2.5160e+01|Bc_loss: 1.0460e+04|
#
# Epoch 19800,| Training-Loss: 5.3543e+05| Test-loss: 1.3657e+05|
# |Data-loss: 1.0087e+05|Pde-loss: 4.0657e+06| Initc-loss: 1.2174e+01|Bc_loss: 3.8173e+04|
#
# Epoch 19900,| Training-Loss: 6.1419e+05| Test-loss: 9.9945e+04|
# |Data-loss: 1.1600e+05|Pde-loss: 1.7868e+06| Initc-loss: 9.9758e+01|Bc_loss: 3.8057e+04|
#
# Epoch 20000,| Training-Loss: 3.8809e+05| Test-loss: 9.4876e+04|
# |Data-loss: 9.5341e+04|Pde-loss: 7.1312e+05| Initc-loss: 1.0100e+00|Bc_loss: 2.8461e+04|
#
# Epoch 20100,| Training-Loss: 4.7340e+05| Test-loss: 8.3221e+04|
# |Data-loss: 8.4904e+04|Pde-loss: 5.1181e+05| Initc-loss: 1.0007e+02|Bc_loss: 2.8330e+04|
#
# Epoch 20200,| Training-Loss: 1.1075e+06| Test-loss: 8.7137e+04|
# |Data-loss: 1.1891e+05|Pde-loss: 1.8273e+06| Initc-loss: 6.5371e+02|Bc_loss: 3.1660e+04|
#
# Epoch 20300,| Training-Loss: 9.3245e+05| Test-loss: 9.5514e+04|
# |Data-loss: 7.4978e+04|Pde-loss: 3.6199e+05| Initc-loss: 3.7855e+02|Bc_loss: 4.7530e+04|
#
# Epoch 20400,| Training-Loss: 8.8800e+05| Test-loss: 1.0935e+05|
# |Data-loss: 1.2439e+05|Pde-loss: 1.2316e+06| Initc-loss: 4.5360e+02|Bc_loss: 2.9769e+04|
#
# Epoch 20500,| Training-Loss: 5.6984e+05| Test-loss: 1.1955e+05|
# |Data-loss: 1.3333e+05|Pde-loss: 8.2018e+05| Initc-loss: 3.9185e+01|Bc_loss: 3.8913e+04|
#
# Epoch 20600,| Training-Loss: 8.1030e+05| Test-loss: 1.1688e+05|
# |Data-loss: 1.1993e+05|Pde-loss: 1.4283e+06| Initc-loss: 4.6659e+01|Bc_loss: 6.2942e+04|
#
# Epoch 20700,| Training-Loss: 9.4325e+05| Test-loss: 1.2483e+05|
# |Data-loss: 1.1212e+05|Pde-loss: 8.8062e+05| Initc-loss: 2.5485e+02|Bc_loss: 5.6748e+04|
#
# Epoch 20800,| Training-Loss: 1.8083e+06| Test-loss: 1.1284e+05|
# |Data-loss: 1.0683e+05|Pde-loss: 2.5929e+06| Initc-loss: 9.5335e+02|Bc_loss: 7.2218e+04|
#
# Epoch 20900,| Training-Loss: 7.3736e+05| Test-loss: 9.1351e+04|
# |Data-loss: 1.1169e+05|Pde-loss: 1.6478e+06| Initc-loss: 3.8984e+01|Bc_loss: 5.7022e+04|
#
# Epoch 21000,| Training-Loss: 1.5843e+06| Test-loss: 9.5204e+04|
# |Data-loss: 1.2629e+05|Pde-loss: 1.3500e+06| Initc-loss: 5.0474e+02|Bc_loss: 9.3978e+04|
#
# Epoch 21100,| Training-Loss: 1.2231e+06| Test-loss: 1.2628e+05|
# |Data-loss: 1.0369e+05|Pde-loss: 1.7076e+06| Initc-loss: 1.2793e+02|Bc_loss: 9.7444e+04|
#
# Epoch 21200,| Training-Loss: 6.1339e+05| Test-loss: 1.8128e+05|
# |Data-loss: 1.4936e+05|Pde-loss: 1.0449e+06| Initc-loss: 1.6031e+02|Bc_loss: 2.9327e+04|
#
# Epoch 21300,| Training-Loss: 7.1119e+05| Test-loss: 1.2946e+05|
# |Data-loss: 1.5844e+05|Pde-loss: 9.4825e+05| Initc-loss: 2.0726e+02|Bc_loss: 3.3600e+04|
#
# Epoch 21400,| Training-Loss: 1.0444e+06| Test-loss: 1.6841e+05|
# |Data-loss: 1.6053e+05|Pde-loss: 1.8586e+06| Initc-loss: 2.4592e+02|Bc_loss: 6.1938e+04|
#
# Epoch 21500,| Training-Loss: 7.1269e+05| Test-loss: 1.3734e+05|
# |Data-loss: 1.4780e+05|Pde-loss: 1.3458e+06| Initc-loss: 3.6837e+01|Bc_loss: 5.1459e+04|
#
# Epoch 21600,| Training-Loss: 1.1692e+06| Test-loss: 1.5330e+05|
# |Data-loss: 1.8013e+05|Pde-loss: 9.6248e+05| Initc-loss: 5.2580e+02|Bc_loss: 4.5361e+04|
#
# Epoch 21700,| Training-Loss: 7.1283e+05| Test-loss: 1.3637e+05|
# |Data-loss: 1.7434e+05|Pde-loss: 1.7949e+06| Initc-loss: 1.2583e+02|Bc_loss: 3.9470e+04|
#
# Epoch 21800,| Training-Loss: 3.7087e+05| Test-loss: 1.3929e+05|
# |Data-loss: 1.8763e+05|Pde-loss: 7.8747e+05| Initc-loss: 5.7447e+01|Bc_loss: 1.1793e+04|
#
# Epoch 21900,| Training-Loss: 4.0705e+05| Test-loss: 1.5853e+05|
# |Data-loss: 1.5789e+05|Pde-loss: 7.8077e+05| Initc-loss: 7.7428e+00|Bc_loss: 2.3361e+04|
#
# Epoch 22000,| Training-Loss: 2.2560e+06| Test-loss: 1.4596e+05|
# |Data-loss: 1.2893e+05|Pde-loss: 1.4038e+06| Initc-loss: 1.5764e+03|Bc_loss: 5.3662e+04|
#
# Epoch 22100,| Training-Loss: 4.3862e+05| Test-loss: 1.0853e+05|
# |Data-loss: 1.5222e+05|Pde-loss: 1.8553e+06| Initc-loss: 1.5810e+00|Bc_loss: 2.6626e+04|
#
# Epoch 22200,| Training-Loss: 6.7264e+05| Test-loss: 1.6275e+05|
# |Data-loss: 1.1441e+05|Pde-loss: 1.9292e+05| Initc-loss: 1.1019e+02|Bc_loss: 4.4611e+04|
#
# Epoch 22300,| Training-Loss: 5.5270e+05| Test-loss: 1.3641e+05|
# |Data-loss: 1.3841e+05|Pde-loss: 2.8645e+05| Initc-loss: 3.6511e+01|Bc_loss: 3.7492e+04|
#
# Epoch 22400,| Training-Loss: 4.6392e+05| Test-loss: 1.5639e+05|
# |Data-loss: 1.1719e+05|Pde-loss: 2.5707e+05| Initc-loss: 2.9800e+01|Bc_loss: 3.1436e+04|
#
# Epoch 22500,| Training-Loss: 4.4733e+05| Test-loss: 1.3267e+05|
# |Data-loss: 1.4222e+05|Pde-loss: 3.9952e+05| Initc-loss: 3.6368e+01|Bc_loss: 2.6475e+04|
#
# Epoch 22600,| Training-Loss: 3.6046e+05| Test-loss: 1.3284e+05|
# |Data-loss: 1.4340e+05|Pde-loss: 1.2417e+06| Initc-loss: 8.0139e+00|Bc_loss: 1.9663e+04|
#
# Epoch 22700,| Training-Loss: 5.9013e+05| Test-loss: 1.3893e+05|
# |Data-loss: 1.4499e+05|Pde-loss: 4.9103e+06| Initc-loss: 1.0180e+02|Bc_loss: 2.9424e+04|
#
# Epoch 22800,| Training-Loss: 3.2577e+05| Test-loss: 1.5319e+05|
# |Data-loss: 1.1522e+05|Pde-loss: 9.1691e+05| Initc-loss: 5.3869e+01|Bc_loss: 1.4751e+04|
#
# Epoch 22900,| Training-Loss: 3.6925e+05| Test-loss: 1.1605e+05|
# |Data-loss: 1.3984e+05|Pde-loss: 4.2034e+05| Initc-loss: 1.1866e+02|Bc_loss: 1.0655e+04|
#
# Epoch 23000,| Training-Loss: 3.4040e+05| Test-loss: 1.1889e+05|
# |Data-loss: 1.2489e+05|Pde-loss: 4.9410e+05| Initc-loss: 5.3442e+00|Bc_loss: 2.0522e+04|
#
# Epoch 23100,| Training-Loss: 3.9272e+05| Test-loss: 1.4010e+05|
# |Data-loss: 1.0042e+05|Pde-loss: 1.9472e+06| Initc-loss: 2.9515e+01|Bc_loss: 2.4332e+04|
#
# Epoch 23200,| Training-Loss: 4.6388e+05| Test-loss: 1.0077e+05|
# |Data-loss: 1.2777e+05|Pde-loss: 7.1747e+05| Initc-loss: 2.6451e+01|Bc_loss: 3.0248e+04|
#
# Epoch 23300,| Training-Loss: 2.6305e+05| Test-loss: 1.3181e+05|
# |Data-loss: 1.0736e+05|Pde-loss: 1.5550e+06| Initc-loss: 1.3162e+01|Bc_loss: 1.2698e+04|
#
# Epoch 23400,| Training-Loss: 5.6152e+05| Test-loss: 9.6695e+04|
# |Data-loss: 1.2277e+05|Pde-loss: 9.9136e+05| Initc-loss: 9.2061e+01|Bc_loss: 3.3677e+04|
#
# Epoch 23500,| Training-Loss: 4.3980e+05| Test-loss: 1.1221e+05|
# |Data-loss: 1.1992e+05|Pde-loss: 1.5205e+06| Initc-loss: 1.4911e+02|Bc_loss: 1.5556e+04|
#
# Epoch 23600,| Training-Loss: 5.2818e+05| Test-loss: 1.0787e+05|
# |Data-loss: 1.1287e+05|Pde-loss: 2.1105e+06| Initc-loss: 2.4043e+01|Bc_loss: 3.7016e+04|
#
# Epoch 23700,| Training-Loss: 2.5821e+05| Test-loss: 2.0298e+05|
# |Data-loss: 1.1995e+05|Pde-loss: 1.1843e+06| Initc-loss: 8.0884e+00|Bc_loss: 1.1833e+04|
#
# Epoch 23800,| Training-Loss: 2.2022e+05| Test-loss: 7.2040e+04|
# |Data-loss: 1.1215e+05|Pde-loss: 1.9100e+06| Initc-loss: 5.8849e+00|Bc_loss: 8.3086e+03|
#
# Epoch 23900,| Training-Loss: 3.7501e+05| Test-loss: 9.3090e+04|
# |Data-loss: 1.0878e+05|Pde-loss: 2.1974e+06| Initc-loss: 1.4914e+01|Bc_loss: 2.2934e+04|
#
# Epoch 24000,| Training-Loss: 8.5385e+05| Test-loss: 1.0409e+05|
# |Data-loss: 1.3580e+05|Pde-loss: 2.1637e+06| Initc-loss: 3.5193e+02|Bc_loss: 3.4448e+04|
#
# Epoch 24100,| Training-Loss: 3.0975e+05| Test-loss: 9.7430e+04|
# |Data-loss: 1.0617e+05|Pde-loss: 1.4728e+06| Initc-loss: 2.7906e+01|Bc_loss: 1.6095e+04|
#
# Epoch 24200,| Training-Loss: 5.2630e+05| Test-loss: 8.5193e+04|
# |Data-loss: 1.2000e+05|Pde-loss: 9.0425e+05| Initc-loss: 2.2904e+01|Bc_loss: 3.7435e+04|
#
# Epoch 24300,| Training-Loss: 3.4318e+06| Test-loss: 1.2035e+05|
# |Data-loss: 1.0329e+05|Pde-loss: 1.6798e+06| Initc-loss: 1.4964e+03|Bc_loss: 1.8152e+05|
#
# Epoch 24400,| Training-Loss: 2.9652e+06| Test-loss: 1.0899e+05|
# |Data-loss: 1.0746e+05|Pde-loss: 2.3084e+06| Initc-loss: 1.3049e+02|Bc_loss: 2.7042e+05|
#
# Epoch 24500,| Training-Loss: 3.0194e+06| Test-loss: 1.5000e+05|
# |Data-loss: 1.3883e+05|Pde-loss: 2.8053e+06| Initc-loss: 1.3536e+03|Bc_loss: 1.4990e+05|
#
# Epoch 24600,| Training-Loss: 3.1392e+06| Test-loss: 1.4459e+05|
# |Data-loss: 1.0895e+05|Pde-loss: 1.4390e+06| Initc-loss: 1.5958e+03|Bc_loss: 1.4201e+05|
#
# Epoch 24700,| Training-Loss: 9.4848e+05| Test-loss: 1.6310e+05|
# |Data-loss: 1.3476e+05|Pde-loss: 2.4000e+06| Initc-loss: 3.8707e+02|Bc_loss: 4.0265e+04|
#
# Epoch 24800,| Training-Loss: 3.1429e+05| Test-loss: 1.3131e+05|
# |Data-loss: 8.0290e+04|Pde-loss: 1.1042e+06| Initc-loss: 4.4503e+01|Bc_loss: 1.7846e+04|
#
# Epoch 24900,| Training-Loss: 4.0549e+05| Test-loss: 1.2042e+05|
# |Data-loss: 1.0332e+05|Pde-loss: 1.8469e+05| Initc-loss: 2.4969e+01|Bc_loss: 2.7535e+04|
#
# Epoch 25000,| Training-Loss: 2.7798e+05| Test-loss: 1.3439e+05|
# |Data-loss: 1.2708e+05|Pde-loss: 1.8200e+06| Initc-loss: 7.8432e+00|Bc_loss: 1.2486e+04|
#
# Epoch 25100,| Training-Loss: 5.0026e+05| Test-loss: 1.3610e+05|
# |Data-loss: 1.0741e+05|Pde-loss: 3.5192e+05| Initc-loss: 1.0647e+02|Bc_loss: 2.8285e+04|
#
# Epoch 25200,| Training-Loss: 8.4076e+05| Test-loss: 1.2357e+05|
# |Data-loss: 1.2878e+05|Pde-loss: 9.3420e+05| Initc-loss: 1.0467e+01|Bc_loss: 6.9216e+04|
#
# Epoch 25300,| Training-Loss: 3.9011e+05| Test-loss: 1.0757e+05|
# |Data-loss: 8.8281e+04|Pde-loss: 3.0633e+06| Initc-loss: 4.1841e+01|Bc_loss: 2.2936e+04|
#
# Epoch 25400,| Training-Loss: 8.9192e+05| Test-loss: 1.3214e+05|
# |Data-loss: 1.3727e+05|Pde-loss: 9.7367e+05| Initc-loss: 1.7485e+02|Bc_loss: 5.7007e+04|
#
# Epoch 25500,| Training-Loss: 5.2749e+05| Test-loss: 9.1140e+04|
# |Data-loss: 1.2002e+05|Pde-loss: 1.7608e+06| Initc-loss: 1.0353e+02|Bc_loss: 2.8633e+04|
#
# Epoch 25600,| Training-Loss: 3.9812e+05| Test-loss: 1.2866e+05|
# |Data-loss: 1.2778e+05|Pde-loss: 4.4393e+06| Initc-loss: 3.0652e+01|Bc_loss: 1.9530e+04|
#
# Epoch 25700,| Training-Loss: 5.7868e+05| Test-loss: 1.3727e+05|
# |Data-loss: 1.0788e+05|Pde-loss: 2.2562e+06| Initc-loss: 2.2332e+02|Bc_loss: 2.2492e+04|
#
# Epoch 25800,| Training-Loss: 1.0329e+06| Test-loss: 9.7483e+04|
# |Data-loss: 1.2100e+05|Pde-loss: 2.5389e+06| Initc-loss: 1.1505e+01|Bc_loss: 8.7499e+04|
#
# Epoch 25900,| Training-Loss: 1.0984e+06| Test-loss: 9.3008e+04|
# |Data-loss: 1.1666e+05|Pde-loss: 1.6927e+06| Initc-loss: 9.3186e+01|Bc_loss: 8.7166e+04|
#
# Epoch 26000,| Training-Loss: 3.0341e+05| Test-loss: 1.1572e+05|
# |Data-loss: 8.4049e+04|Pde-loss: 2.0405e+06| Initc-loss: 2.6261e+01|Bc_loss: 1.7270e+04|
#
# Epoch 26100,| Training-Loss: 3.9532e+05| Test-loss: 8.6741e+04|
# |Data-loss: 9.2518e+04|Pde-loss: 3.1702e+06| Initc-loss: 1.0559e+02|Bc_loss: 1.6551e+04|
#
# Epoch 26200,| Training-Loss: 5.6538e+05| Test-loss: 9.3159e+04|
# |Data-loss: 1.1228e+05|Pde-loss: 2.0442e+06| Initc-loss: 2.3580e+02|Bc_loss: 1.9686e+04|
#
# Epoch 26300,| Training-Loss: 3.1753e+06| Test-loss: 9.9335e+04|
# |Data-loss: 9.2640e+04|Pde-loss: 1.4825e+06| Initc-loss: 2.1876e+03|Bc_loss: 8.8020e+04|
#
# Epoch 26400,| Training-Loss: 2.1655e+06| Test-loss: 1.3117e+05|
# |Data-loss: 1.2537e+05|Pde-loss: 7.0024e+05| Initc-loss: 6.1678e+02|Bc_loss: 1.4163e+05|
#
# Epoch 26500,| Training-Loss: 8.0977e+05| Test-loss: 1.4727e+05|
# |Data-loss: 1.3570e+05|Pde-loss: 3.1701e+06| Initc-loss: 3.9283e+02|Bc_loss: 2.4955e+04|
#
# Epoch 26600,| Training-Loss: 3.0066e+06| Test-loss: 1.1135e+05|
# |Data-loss: 1.0704e+05|Pde-loss: 1.6849e+06| Initc-loss: 1.7037e+03|Bc_loss: 1.1790e+05|
#
# Epoch 26700,| Training-Loss: 3.3369e+06| Test-loss: 1.2948e+05|
# |Data-loss: 1.3004e+05|Pde-loss: 9.2255e+05| Initc-loss: 1.2453e+03|Bc_loss: 1.9523e+05|
#
# Epoch 26800,| Training-Loss: 1.3308e+06| Test-loss: 1.1361e+05|
# |Data-loss: 1.2280e+05|Pde-loss: 2.7294e+06| Initc-loss: 3.0013e+02|Bc_loss: 8.8055e+04|
#
# Epoch 26900,| Training-Loss: 9.2736e+05| Test-loss: 1.2209e+05|
# |Data-loss: 9.8828e+04|Pde-loss: 1.8813e+06| Initc-loss: 5.8941e+02|Bc_loss: 2.2031e+04|
#
# Epoch 27000,| Training-Loss: 8.8415e+05| Test-loss: 1.2220e+05|
# |Data-loss: 1.3557e+05|Pde-loss: 5.3231e+05| Initc-loss: 2.4033e+02|Bc_loss: 5.0293e+04|
#
# Epoch 27100,| Training-Loss: 1.0120e+06| Test-loss: 1.2058e+05|
# |Data-loss: 8.2067e+04|Pde-loss: 6.4554e+05| Initc-loss: 4.7035e+02|Bc_loss: 4.5310e+04|
#
# Epoch 27200,| Training-Loss: 8.8995e+05| Test-loss: 1.4834e+05|
# |Data-loss: 1.2979e+05|Pde-loss: 9.1885e+05| Initc-loss: 3.8992e+02|Bc_loss: 3.6105e+04|
#
# Epoch 27300,| Training-Loss: 5.0870e+05| Test-loss: 1.1001e+05|
# |Data-loss: 8.3153e+04|Pde-loss: 7.7136e+05| Initc-loss: 3.5988e-01|Bc_loss: 4.1747e+04|
#
# Epoch 27400,| Training-Loss: 4.7077e+05| Test-loss: 1.1040e+05|
# |Data-loss: 1.3806e+05|Pde-loss: 2.0329e+05| Initc-loss: 8.1859e+01|Bc_loss: 2.4882e+04|
#
# Epoch 27500,| Training-Loss: 3.1506e+05| Test-loss: 8.6448e+04|
# |Data-loss: 8.4069e+04|Pde-loss: 9.1006e+05| Initc-loss: 1.3274e+02|Bc_loss: 8.9157e+03|
#
# Epoch 27600,| Training-Loss: 3.6826e+05| Test-loss: 1.0007e+05|
# |Data-loss: 6.9842e+04|Pde-loss: 2.4739e+06| Initc-loss: 6.3980e+01|Bc_loss: 2.0970e+04|
#
# Epoch 27700,| Training-Loss: 6.4631e+05| Test-loss: 9.0414e+04|
# |Data-loss: 8.6702e+04|Pde-loss: 1.8683e+06| Initc-loss: 2.5832e+01|Bc_loss: 5.1510e+04|
#
# Epoch 27800,| Training-Loss: 4.3768e+05| Test-loss: 9.6544e+04|
# |Data-loss: 1.2374e+05|Pde-loss: 1.7834e+06| Initc-loss: 1.1358e+02|Bc_loss: 1.8252e+04|
#
# Epoch 27900,| Training-Loss: 6.4974e+05| Test-loss: 8.2425e+04|
# |Data-loss: 7.4751e+04|Pde-loss: 2.9698e+06| Initc-loss: 2.2960e+02|Bc_loss: 3.1570e+04|
#
# Epoch 28000,| Training-Loss: 4.5038e+05| Test-loss: 9.1803e+04|
# |Data-loss: 8.2674e+04|Pde-loss: 3.7849e+06| Initc-loss: 6.2420e-01|Bc_loss: 3.2923e+04|
#
# Epoch 28100,| Training-Loss: 3.6218e+05| Test-loss: 6.8120e+04|
# |Data-loss: 7.8272e+04|Pde-loss: 9.9925e+05| Initc-loss: 8.8081e+01|Bc_loss: 1.8583e+04|
#
# Epoch 28200,| Training-Loss: 4.4586e+05| Test-loss: 8.5882e+04|
# |Data-loss: 1.0775e+05|Pde-loss: 4.2393e+05| Initc-loss: 8.7198e-01|Bc_loss: 3.3300e+04|
#
# Epoch 28300,| Training-Loss: 3.3609e+05| Test-loss: 8.7683e+04|
# |Data-loss: 1.0121e+05|Pde-loss: 2.8932e+06| Initc-loss: 1.4552e+01|Bc_loss: 1.9140e+04|
#
# Epoch 28400,| Training-Loss: 3.9786e+05| Test-loss: 9.8431e+04|
# |Data-loss: 8.3855e+04|Pde-loss: 2.1842e+06| Initc-loss: 4.8137e+01|Bc_loss: 2.4402e+04|
#
# Epoch 28500,| Training-Loss: 6.0817e+05| Test-loss: 6.4198e+04|
# |Data-loss: 1.1376e+05|Pde-loss: 4.9926e+06| Initc-loss: 3.8269e+02|Bc_loss: 6.1790e+03|
#
# Epoch 28600,| Training-Loss: 5.4749e+05| Test-loss: 1.3405e+05|
# |Data-loss: 7.1462e+04|Pde-loss: 7.1263e+06| Initc-loss: 1.2632e+02|Bc_loss: 2.7845e+04|
#
# Epoch 28700,| Training-Loss: 1.1625e+06| Test-loss: 1.0329e+05|
# |Data-loss: 8.3607e+04|Pde-loss: 6.8594e+05| Initc-loss: 5.5169e+01|Bc_loss: 1.0169e+05|
#
# Epoch 28800,| Training-Loss: 3.0895e+05| Test-loss: 7.8156e+04|
# |Data-loss: 7.2190e+04|Pde-loss: 8.2667e+05| Initc-loss: 7.8989e+00|Bc_loss: 2.2060e+04|
#
# Epoch 28900,| Training-Loss: 7.3605e+05| Test-loss: 1.1029e+05|
# |Data-loss: 1.2246e+05|Pde-loss: 4.5151e+05| Initc-loss: 3.8496e+00|Bc_loss: 6.0523e+04|
#
# Epoch 29000,| Training-Loss: 2.4293e+05| Test-loss: 1.0720e+05|
# |Data-loss: 1.1291e+05|Pde-loss: 4.0117e+06| Initc-loss: 1.4560e+01|Bc_loss: 7.5346e+03|
#
# Epoch 29100,| Training-Loss: 5.4596e+05| Test-loss: 9.9185e+04|
# |Data-loss: 8.0523e+04|Pde-loss: 2.7107e+06| Initc-loss: 1.9534e+01|Bc_loss: 4.1880e+04|
#
# Epoch 29200,| Training-Loss: 1.0476e+06| Test-loss: 1.0894e+05|
# |Data-loss: 1.0152e+05|Pde-loss: 1.9982e+06| Initc-loss: 2.4062e+02|Bc_loss: 6.8549e+04|
#
# Epoch 29300,| Training-Loss: 2.1299e+05| Test-loss: 8.9051e+04|
# |Data-loss: 1.1837e+05|Pde-loss: 4.8708e+05| Initc-loss: 8.9098e+00|Bc_loss: 8.0833e+03|
#
# Epoch 29400,| Training-Loss: 3.5293e+05| Test-loss: 8.0972e+04|
# |Data-loss: 7.8502e+04|Pde-loss: 1.5325e+06| Initc-loss: 1.0746e+02|Bc_loss: 1.5165e+04|
#
# Epoch 29500,| Training-Loss: 5.4968e+05| Test-loss: 1.0788e+05|
# |Data-loss: 7.4740e+04|Pde-loss: 4.9607e+05| Initc-loss: 9.8284e+01|Bc_loss: 3.7170e+04|
#
# Epoch 29600,| Training-Loss: 4.3406e+05| Test-loss: 8.5912e+04|
# |Data-loss: 1.2012e+05|Pde-loss: 1.0371e+06| Initc-loss: 4.9122e+01|Bc_loss: 2.5445e+04|
#
# Epoch 29700,| Training-Loss: 3.1740e+05| Test-loss: 1.0470e+05|
# |Data-loss: 1.0160e+05|Pde-loss: 1.2611e+06| Initc-loss: 1.0466e+02|Bc_loss: 9.8520e+03|
#
# Epoch 29800,| Training-Loss: 3.6410e+05| Test-loss: 1.2032e+05|
# |Data-loss: 1.1034e+05|Pde-loss: 5.3194e+06| Initc-loss: 2.5961e+01|Bc_loss: 1.7460e+04|
#
# Epoch 29900,| Training-Loss: 5.7215e+05| Test-loss: 8.9637e+04|
# |Data-loss: 8.4339e+04|Pde-loss: 1.9300e+06| Initc-loss: 7.2586e+01|Bc_loss: 3.9592e+04|

# %%
inputs = torch.tensor(inputs).float().to(device) # Convert the inputs to a tensor
temp_nn = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model
# temp_nn = scaler.inverse_transform(temp_nn) # Inverse transform the predictions
temp_nn = temp_nn.reshape(num_steps+1, num_points) # Reshape the predictions to a 2D array
print(temp_nn.shape)
time_ss= np.linspace(0, time_end, num_steps+1 )
plt.figure
plt.plot(time_ss, temp_nn[:, num_points//2], label='Predicted Temperature')
plt.plot(time_ss, temperature_history[:,num_points//2], label='Actual Temperature')
plt.xlabel('Time(s)')
plt.ylabel('Temperature (K)')
plt.title('Predicted vs Actual Temperature at x = 7.5mm')
plt.legend()
plt.show()
# Out:
# (31470, 50)

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(test_losses, label='test Loss')
# plt.xticks(np.arange(0, epochs, 10000))
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# pde_losses_n = [tensor.cpu().detach().numpy() for tensor in pde_losses]
pde_losses_n = pde_losses 
# data_losses_n = [tensor.cpu().detach().numpy() for tensor in data_losses]
# ic_losses_n = [tensor.cpu().detach().numpy() for tensor in ic_losses]
# bc_losses_n = [tensor.cpu().detach().numpy() for tensor in bc_losses]
data_losses_n = data_losses
ic_losses_n = ic_losses
bc_losses_n = bc_losses


plt.figure(figsize=(10, 6))
plt.plot(data_losses_n, label='Data Loss')
plt.plot(pde_losses_n, label='Pde Loss')
plt.plot(ic_losses_n, label='IC Loss')
plt.plot(bc_losses_n, label='BC Loss')
plt.yscale('log')
# plt.axhline(y=1e-6, color='red', linestyle='--', label='Near-Zero Line')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
space_coord, time_coord = np.meshgrid(np.arange(t_hist_2.shape[1]), np.arange(t_hist_2.shape[0]))

time_coord = time_coord * dt 
# Create a figure with two subplots
print(space_coord.shape,time_coord.shape,t_hist.shape,temp_nn.shape)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))


# Plot the temperature history on the left subplot
im1 = ax1.pcolormesh(space_coord, time_coord, t_hist_2, cmap='viridis', shading='auto')
ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax1.set_title('Temperature Variation Over Time(Analytical Model)',fontname='Times New Roman', fontsize=20)
ax1.contour(space_coord, time_coord, t_hist_2, colors='red', linewidths=1.0, alpha=0.9)

ax1.grid(True)
cbar = fig.colorbar(im1, ax=ax1)
cbar.ax.invert_yaxis()
cbar.set_label('Temperature (K)', rotation=270, labelpad=20, fontname='Times New Roman', fontsize=16)

im2 = ax2.pcolormesh(space_coord, time_coord, temp_nn, cmap='viridis', shading='auto')
ax2.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax2.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax2.set_title('Temperature Variation Over Time(PINN Approach)',fontname='Times New Roman', fontsize=20)
ax2.contour(space_coord, time_coord, temp_nn, colors='red', linewidths=1.0, alpha=0.9)

ax2.grid(True)
cbar = fig.colorbar(im2, ax=ax2)
cbar.ax.invert_yaxis()
cbar.set_label('Temperature (K)', rotation=270, labelpad=20, fontname='Times New Roman', fontsize=16)


plt.tight_layout()
plt.show()
# Out:
# (31470, 50) (31470, 50) (31470, 50) (31470, 50)
