# %% [markdown]
# # 1D Three Phase Simulation of Alloys and PINN model development

# %% [markdown]
# This notebook contains the simulation of 1D Phase change of aluminium alloy. There will be three phases (solid,liquid and mushy).
#
# The approach used is finite difference method and the physics involved in heat conduction.

# %% [markdown]
# ## Import Libraries

# %%
import sys
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler, SubsetRandomSampler, random_split

from pinn_loss import loss_fn_data, l1_regularization, pde_loss, boundary_loss, ic_loss, accuracy
from Input_vec_gen import input_gen
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 18
#      15 import torch.nn as nn
#      16 from torch.utils.data import DataLoader, TensorDataset, RandomSampler, SubsetRandomSampler, random_split
# ---> 18 from pinn_loss import loss_fn_data, l1_regularization, pde_loss, boundary_loss, ic_loss, accuracy
#      19 from Input_vec_gen import input_gen
#
# ModuleNotFoundError: No module named 'pinn_loss'

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Define the constants and inital geometric domain

# %%
# Geometry
length = 15.0e-3             # Length of the rod

# Material properties
rho = 2300.0                     # Density of AL380 (kg/m^3)
rho_l = 2460.0                   # Density of AL380 (kg/m^3)
rho_s = 2710.0                    # Density of AL380 (kg/m^3)
rho_m = (rho_l + rho_s )/2       # Desnity in mushy zone is taken as average of liquid and solid density

k = 104.0                       # W/m-K
k_l = k                       # W/m-K
k_s = 96.2                    # W/m-K
k_m =  (k_l+k_s)/2                     # W/m-K
k_mo = 41.5


cp = 1245.3                      # Specific heat of aluminum (J/kg-K)
cp_l = cp                      # Specific heat of aluminum (J/kg-K)
cp_s = 963.0                 # Specific heat of aluminum (J/kg-K)
cp_m =  (cp_l+cp_s)/2                 # Specific heat of mushy zone is taken as average of liquid and solid specific heat
# cp_m = cp
           # Thermal diffusivity
alpha_l = k_l / (rho_l * cp_l) 
alpha_s = k_s / (rho_s*cp_s)
alpha_m = k_m / (rho_m * cp_m)          #`Thermal diffusivity in mushy zone is taken as average of liquid and solid thermal diffusivity`


#L_fusion = 3.9e3                 # J/kg
L_fusion = 389.0e3               # J/kg  # Latent heat of fusion of aluminum
         # Thermal diffusivity


T_L = 574.4 +273.0                       #  K -Liquidus Temperature (615 c) AL 380
T_S = 497.3 +273.0                     # K- Solidus Temperature (550 C)
m_eff =(k_m/(rho_m*(cp_m + (L_fusion/(T_L-T_S)))))
print (f"alpha_l = {alpha_l}, alpha_s = {alpha_s}, m_eff = {m_eff}")

# htc = 10.0                   # W/m^2-K
# q = htc*(919.0-723.0)
# q = 10000.0


num_points = 50                        # Number of spatial points
dx = length / (num_points - 1)         # Distance between two spatial points
print('dx is',dx)

                                                              
# Time Discretization  
# 
time_end = 40        # seconds                         

maxi = max(alpha_s,alpha_l,alpha_m)
dt = abs(0.5*((dx**2) /maxi)) 

print('dt is ',dt)
num_steps = round(time_end/dt)
print('num_steps is',num_steps)
cfl = 0.5 *(dx**2/max(alpha_l,alpha_s,alpha_m))
print('cfl is',cfl)

time_steps = np.linspace(0, time_end, num_steps + 1)
step_coeff = dt / (dx ** 2)

if dt <= cfl:
    print('stability criteria satisfied')
else:
    print('stability criteria not satisfied')
    sys.exit()
# Out:
# alpha_l = 3.394878564540885e-05, alpha_s = 3.686205086349929e-05, m_eff = 6.296953764744878e-06
# dx is 0.0003061224489795918
# dt is  0.0012711033647622566
# num_steps is 31469
# cfl is 0.0012711033647622566
# stability criteria satisfied

# %% [markdown]
# ### Initial and Boundary Conditions

# %%
temp_init = 919.0
# Initial temperature and phase fields
temperature = np.full(num_points+2, 919.0)            # Initial temperature of the rod with ghost points at both ends
phase = np.zeros(num_points+2)*0.0                    # Initial phase of the rod with ghost points at both ends

# Set boundary conditions
# temperature[-1] = 919.0 
phase[-1] = 1.0

# temperature[0] = 919.0 #(40 C)
phase[0] = 1.0

# Store initial state in history
temperature_history = [temperature.copy()]    # List to store temperature at each time step
phi_history = [phase.copy()]                    # List to store phase at each time step
temp_init = temperature.copy()                 # Initial temperature of the rod
# print(temperature_history,phi_history)
# Array to store temperature at midpoint over time
midpoint_index = num_points // 2                          # Index of the midpoint

midpoint_temperature_history = [temperature[midpoint_index]]            # List to store temperature at midpoint over time
dm = 60.0e-3                                                            # die thickness in m

# r_m =  (k_mo / dm) + (1/htc)

t_surr = 500.0                                        # Surrounding temperature in K
# t_surr = h()

def kramp(temp,v1,v2,T_L,T_s):                                      # Function to calculate thermal conductivity in Mushy Zone
        slope = (v1-v2)/(T_L-T_S)
        if temp > T_L:
            k_m = k_l
        elif temp < T_S:
            k_m = k_s
        else:
            k_m = k_s + slope*(temp-T_S)
        return k_m

def cp_ramp(temp,v1,v2,T_L,T_s):                                    # Function to calculate specific heat capacity in Mushy Zone
    slope = (v1-v2)/(T_L-T_S)
    if temp > T_L:
        cp_m = cp_l
    elif temp < T_S:
        cp_m = cp_s
    else:
        cp_m = cp_s + slope*(temp-T_S)
    return cp_m

def rho_ramp(temp,v1,v2,T_L,T_s):                                       # Function to calculate density in Mushy Zone
    slope = (v1-v2)/(T_L-T_S)
    if temp > T_L:
        rho_m = rho_l
    elif temp < T_S:
        rho_m = rho_s
    else:
        rho_m = rho_s + slope*(temp-T_S)
    return rho_m

# %% [markdown]
# ### Solving the HT equation and phase change numerically

# %%
for m in range(1, num_steps+1):                                                                            # time loop
    htc = 10.0                   # htc of Still air in W/m^2-K
    q1 = htc*(temp_init[0]-t_surr)   # Heat flux at the left boundary
    
    # print(f"q1 is {q1}")
    temperature[0] = temp_init[0] + alpha_l * step_coeff * ((2.0*temp_init[1]) - (2.0 * temp_init[0])-(2.0*dx*(q1)))  # Update boundary condition temperature
    
    q2 = htc*(temp_init[-1]-t_surr)                   # Heat flux at the right boundary
    temperature[-1] = temp_init[-1] + alpha_l * step_coeff * ((2.0*temp_init[-2]) - (2.0 * temp_init[-1])-(2.0*dx*(q2)))  # Update boundary condition temperature
    
    for n in range(1,num_points+1):              # space loop, adjusted range
       
        if temperature[n] >= T_L:
            temperature[n] += ((alpha_l * step_coeff) * (temp_init[n+1] - (2.0 * temp_init[n]) + temp_init[n-1]))
            phase[n] = 0
            
            # print(f" Time-Step{m},Spatial point{n},Temperature{temperature[n]}")
        elif T_S < temperature[n] < T_L:
            
            k_m = kramp(temperature[n],k_l,k_s,T_L,T_S)
            cp_m = cp_ramp(temperature[n],cp_l,cp_s,T_L,T_S)
            rho_m = rho_ramp(temperature[n],rho_l,rho_s,T_L,T_S)
            m_eff =(k_m/(rho_m*(cp_m + (L_fusion/(T_L-T_S)))))
            
            temperature[n] += ((m_eff * step_coeff)* (temp_init[n+1] - (2.0 * temp_init[n]) + temp_init[n-1]))
            
            phase[n] = (T_L - temperature[n]) / (T_L - T_S)
            # print(m,n,temperature[n],phase[n])
         
        elif temperature[n]<T_S:
            temperature[n] += ((alpha_s * step_coeff) * (temp_init[n+1] - (2.0 * temp_init[n])+ temp_init[n-1]))
            phase[n] = 1
                     
        else:
            print("ERROR: should not be here")

     
          
    temperature = temperature.copy()                                                                # Update temperature
    phase = phase.copy()                                                                            # Update phase
    temp_init = temperature.copy()                                                                  # Update last time step temperature
    temperature_history.append(temperature.copy())                                                  # Append the temperature history to add ghost points
    phi_history.append(phase.copy())                                                                # Append the phase history to add ghost points
    midpoint_temperature_history.append(temperature[midpoint_index])                                # Store midpoint temperature
    
    
    # print(f"Step {m}, Temperature: {temperature}")
    


# print(midpoint_temperature_history)
#print(phi_history)

# %% [markdown]
# ### Plot the Results

# %%
# # Plot temperature history for debugging
# temperature_history_1 = np.array(temperature_history)
# print(temperature_history_1.shape)
# time_ss= np.linspace(0, time_end, num_steps+1)
# # print(time_ss.shape)
# plt.figure(figsize=(10, 6))
# plt.plot(time_ss, midpoint_temperature_history, label='Midpoint Temperature')
# plt.axhline(y=T_L, color='r', linestyle='--', label='Liquidus Temperature')
# plt.axhline(y=T_S, color='g', linestyle='--', label='Solidus Temperature')
# plt.xlabel('Time(s)')
# plt.ylabel('Temperature (K)')
# plt.title('Temperature Distribution Over Time at x = 7.5mm') 
# plt.legend()
# plt.show()

# %% [markdown]
# ### Data into Array

# %%
temperature_history = np.array(temperature_history)

phi_history = np.array(phi_history)

t_hist = np.array(temperature_history[:,1:-1])
t_hist_2 = np.array(temperature_history[:,1:-1])
p_hist = np.array(phi_history[:,1:-1])

t_hist_pde = t_hist[1:,1:-1]
t_hist_init = t_hist[0,:]
t_hist_bc_l = t_hist[:,0]
t_hist_bc_r = t_hist[:,-1]

# %%
# Assuming you have temperature_history and phi_history as lists of arrays


# # Check the new shape after transposing
# print("Transposed Temperature History Shape:", temperature_history.shape)
# print("Transposed Phi History Shape:", phi_history.shape)

# # Create a meshgrid for space and time coordinates
# space_coord, time_coord = np.meshgrid(np.arange(temperature_history.shape[1]), np.arange(temperature_history.shape[0]))

# time_coord = time_coord * dt 
# # Create a figure with two subplots
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# # Plot the temperature history on the left subplot
# im1 = ax1.pcolormesh(space_coord, time_coord, temperature_history, cmap='viridis')
# ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
# ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
# ax1.set_title('Temperature Variation Over Time',fontname='Times New Roman', fontsize=20)
# fig.colorbar(im1, ax=ax1, label='Temperature')

# # Plot the phase history on the right subplot
# im2 = ax2.pcolormesh(space_coord, time_coord, phi_history, cmap='viridis')
# ax2.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=18)
# ax2.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
# ax2.set_title('Phase Variation Over Time',fontname='Times New Roman', fontsize=20)
# fig.colorbar(im2, ax=ax2, label='Phase')
# plt.tight_layout()
# plt.show()

# #plot the main
# fig, ax = plt.subplots(figsize=(14, 6))
# im = ax.pcolormesh(space_coord, time_coord, Dim_ny, cmap='viridis')
# ax.set_xlabel('Space Coordinate')
# ax.set_ylabel('Time')
# ax.set_title('Niyama Variation Over Time')
# fig.colorbar(im, ax=ax, label='Main')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## ML training

# %% [markdown]
# ### GPU/CPU check

# %%
# check for gpu
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device2 = torch.device('cpu')
print('Using device:', device)
# Out:
# Using device: cpu

# %% [markdown]
# ### Data preparation

# %% [markdown]
# ### Main Dataset

# %%
space = np.linspace(0, length, num_points) # Spatial points
time = np.linspace(0, time_end, num_steps+1) # Time points


space_pde = space[1:-1] # Remove boundary points
time_pde = time[1:] # Remove initial condition

sp_i = np.linspace(0, length, num_points) # Spatial points for initial condition
time_i = np.zeros(num_points) # Time points for initial condition

sp_b_l = np.zeros(num_steps+1) # Spatial points for boundary condition left
time_b_l = np.linspace(0, time_end, num_steps+1) # Time points for boundary condition left

sp_b_r = np.ones(num_steps+1)*length # Spatial points for boundary condition right
time_b_r = np.linspace(0, time_end, num_steps+1) # Time points for boundary condition right

# %%
inputs = input_gen(space,time,'mgrid') # Generate input for the model
inputs_pde = input_gen(space_pde,time_pde,'mgrid') # Generate input for the PDE
inputs_i = input_gen(sp_i,time_i,'scr') # Generate input for the initial condition
inputs_b_l = input_gen(sp_b_l,time_b_l,'scr') # Generate input for the boundary condition left
inputs_b_r = input_gen(sp_b_r,time_b_r,'scr') # Generate input for the boundary condition right

t_hist = t_hist.reshape(-1,1)
t_hist_pde = t_hist_pde.reshape(-1,1)
t_hist_init = t_hist_init.reshape(-1,1)
t_hist_bc_l = t_hist_bc_l.reshape(-1,1)

# %%
print(inputs.shape,inputs_pde.shape,inputs_i.shape,inputs_b_l.shape,inputs_b_r.shape)
print(t_hist.shape,t_hist_pde.shape,t_hist_init.shape,t_hist_bc_l.shape,t_hist_bc_r.shape)
# Out:
# (1573500, 2) (1510512, 2) (50, 2) (31470, 2) (31470, 2)
# (1573500, 1) (1510512, 1) (50, 1) (31470, 1) (31470,)

# %% [markdown]
# ## Sample from the Main dataset

# %%
def Sampler (x,t,samp_size):
    index = np.random.choice(x.shape[0],samp_size,replace=False)
    return x[index] , t[index]

inputs_sample, t_hist_sample = Sampler(inputs,t_hist,3000) # Sample the input and output data
inputs_pde_sample, t_hist_pde_sample = Sampler(inputs_pde,t_hist_pde,3000) # Sample the input and output data for pde 
inputs_i_sample,t_hist_i_sample = Sampler(inputs_i,t_hist_init,50) # Sample the input and output data for initial condition
inputs_b_l_sample,t_hist_bc_l_sample = Sampler(inputs_b_l,t_hist_bc_l,2000) # Sample the input and output data for boundary condition left
inputs_b_r_sample, t_hist_bc_r_sample = Sampler(inputs_b_r,t_hist_bc_r, 2000) # Sample the input and output data for boundary condition right

print(inputs_sample[:5,:], t_hist_sample[:5,:])
print(inputs_pde_sample.shape, t_hist_pde_sample.shape)
print(inputs_i_sample.shape, t_hist_i_sample.shape)
print(inputs_b_l_sample.shape, t_hist_bc_l_sample.shape)
print(inputs_b_r_sample.shape, t_hist_bc_r_sample.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2     index = np.random.choice(x.shape[0],samp_size,replace=False)
#       3     return x[index] , t[index]
# ----> 5 inputs_sample, t_hist_sample = Sampler(inputs,t_hist,3000) # Sample the input and output data
#       6 inputs_pde_sample, t_hist_pde_sample = Sampler(inputs_pde,t_hist_pde,3000) # Sample the input and output data for pde
#       7 inputs_i_sample,t_hist_i_sample = Sampler(inputs_i,t_hist_init,50) # Sample the input and output data for initial condition
#
# NameError: name 'inputs' is not defined

# %% [markdown]
# ### Tensor the sample dataset

# %%
inputs_sample = torch.tensor(inputs_sample).float().to(device) # Convert the inputs to a tensor
inputs_pde_sample = torch.tensor(inputs_pde_sample).float().to(device) # Convert the inputs to a tensor
inputs_i_sample = torch.tensor(inputs_i_sample).float().to(device) # Convert the inputs to a tensor
inputs_b_l_sample = torch.tensor(inputs_b_l_sample).float().to(device)# Convert the inputs to a tensor
inputs_b_r_sample = torch.tensor(inputs_b_r_sample).float().to(device)# Convert the inputs to a tensor

print(inputs_sample.shape)
# label/temp data
temp_inp_sample = torch.tensor(t_hist_sample).float().to(device) # Convert the temperature history to a tensor
temp_inp_pde_sample = torch.tensor(t_hist_pde_sample).float().to(device) # Convert the temperature history to a tensor
temp_inp_init_sample = torch.tensor(t_hist_i_sample).float().to(device) # Convert the temperature history to a tensor
temp_inp_bc_l_sample = torch.tensor(t_hist_bc_l_sample).float().to(device)# Convert the temperature history to a tensor
temp_inp_bc_r_sample = torch.tensor(t_hist_bc_r_sample).float().to(device)# Convert the temperature history to a tensor
print(temp_inp_sample.shape)
# Out:
# torch.Size([3000, 2])
# torch.Size([3000, 1])

# %%
#Data Splitting

# train_inputs, val_test_inputs, train_temp_inp, val_test_temp_inp = train_test_split(inputs, temp_inp, test_size=0.2, random_state=42)
# val_inputs, test_inputs, val_temp_inp, test_temp_inp = train_test_split(val_test_inputs, val_test_temp_inp, test_size=0.8, random_state=42)

train_inputs_sample, test_inputs_sample, \
    train_temp_inp_sample, test_temp_inp_sample = \
        train_test_split(inputs_sample, temp_inp_sample,\
                           test_size=0.2, random_state=42)
train_inputs_pde_sample, test_inputs_pde_sample, \
    train_temp_inp_pde_sample, test_temp_inp_pde_sample = \
        train_test_split(inputs_pde_sample, \
                            temp_inp_pde_sample, test_size=0.2, random_state=42)
train_inputs_i_sample, test_inputs_i_sample, \
    train_temp_inp_i_sample, test_temp_inp_i_sample = \
        train_test_split(inputs_i_sample, \
                         temp_inp_init_sample, test_size=0.2, random_state=42)
train_inputs_bc_l_sample, test_inputs_bc_l_sample, \
    train_temp_inp_bc_l_sample, test_temp_inp_bc_l_sample = \
        train_test_split(inputs_b_l_sample, \
                            temp_inp_bc_l_sample, test_size=0.2, random_state=42)
train_inputs_bc_r_sample, test_inputs_bc_r_sample, \
    train_temp_inp_bc_r_sample, test_temp_inp_bc_r_sample = \
        train_test_split(inputs_b_r_sample, temp_inp_bc_r_sample, \
                                    test_size=0.2, random_state=42)

# %% [markdown]
# ### Create Data loader

# %%
class TensorDataset(torch.utils.data.Dataset):
    def __init__(self, inputs,temp_inp,transform=None, target_transform =None):
        
        self.inputs = inputs
        self.temp_inp = temp_inp
               

    def __getitem__(self, index):
        return self.inputs[index], self.temp_inp[index]
    
    def __len__(self):
        return len(self.inputs)

# %%
  
train_dataset = TensorDataset(train_inputs_sample, train_temp_inp_sample) # Create the training dataset
# val_dataset = TensorDataset(val_inputs, val_temp_inp) # Create the validation dataset
test_dataset = TensorDataset(test_inputs_sample, test_temp_inp_sample) # Create the test dataset

train_pde_dataset = TensorDataset(train_inputs_pde_sample, train_temp_inp_pde_sample) # Create the training dataset
test_pde_dataset = TensorDataset(test_inputs_pde_sample, test_temp_inp_pde_sample) # Create the test dataset

train_dataset_i = TensorDataset(train_inputs_i_sample, train_temp_inp_i_sample) # Create the training dataset
test_dataset_i = TensorDataset(test_inputs_i_sample, test_temp_inp_i_sample) # Create the test dataset

train_dataset_bc_l = TensorDataset(train_inputs_bc_l_sample, train_temp_inp_bc_l_sample) # Create the training dataset
test_dataset_bc_l = TensorDataset(test_inputs_bc_l_sample, test_temp_inp_bc_l_sample) # Create the test dataset

train_dataset_bc_r = TensorDataset(train_inputs_bc_r_sample, train_temp_inp_bc_r_sample) # Create the training dataset
test_dataset_bc_r = TensorDataset(test_inputs_bc_r_sample, test_temp_inp_bc_r_sample) # Create the test dataset


batch_size = 32
batch_size_init_2 = 5

random_sampler_train = RandomSampler(train_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the training dataset
# # random_sampler_val = RandomSampler(val_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the validation dataset
random_sampler_test = RandomSampler(test_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset

random_sampler_train_pde = RandomSampler(train_pde_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the training dataset
random_sampler_test_pde = RandomSampler(test_pde_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset

random_sampler_train_i = RandomSampler(train_dataset_i, replacement=True, num_samples=batch_size_init_2) # Create a random sampler for the training dataset
random_sampler_test_i = RandomSampler(test_dataset_i, replacement=True, num_samples=batch_size_init_2) # Create a random sampler for the test dataset

random_sampler_train_bc_l = RandomSampler(train_dataset_bc_l, replacement=True, num_samples=batch_size) # Create a random sampler for the training dataset
random_sampler_test_bc_l = RandomSampler(test_dataset_bc_l, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset
random_sampler_train_bc_r = RandomSampler(train_dataset_bc_r, replacement=True, num_samples=batch_size) # Create a random sampler for the training dataset
random_sampler_test_bc_r = RandomSampler(test_dataset_bc_r, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset





train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=random_sampler_train) # Create the training dataloader



# val_loader = DataLoader(val_dataset, batch_size=batch_size, sampler=random_sampler_val) # Create the validation dataloader
test_loader = DataLoader(test_dataset, batch_size=batch_size, sampler= random_sampler_test) # Create the test dataloader

train_pde_loader = DataLoader(train_pde_dataset, batch_size=batch_size, \
                              sampler=random_sampler_train_pde) # Create the training dataloader
test_pde_loader = DataLoader(test_pde_dataset, batch_size=batch_size,\
                              sampler=random_sampler_test_pde) # Create the test dataloader


train_loader_init = DataLoader(train_dataset_i, batch_size=batch_size_init_2, \
                               sampler=random_sampler_train_i) # Create the training dataloader
test_loader_init = DataLoader(test_dataset_i, batch_size=batch_size_init_2, \
                              sampler=random_sampler_test_i) # Create the test dataloader

train_loader_bc_l = DataLoader(train_dataset_bc_l, batch_size=batch_size, \
                               sampler=random_sampler_train_bc_l) # Create the training dataloader
test_loader_bc_l = DataLoader(test_dataset_bc_l, batch_size=batch_size, \
                              sampler=random_sampler_test_bc_l) # Create the test dataloader
train_loader_bc_r = DataLoader(train_dataset_bc_r, batch_size=batch_size, \
                                sampler=random_sampler_train_bc_r) # Create the training dataloader
test_loader_bc_r = DataLoader(test_dataset_bc_r, batch_size=batch_size, \
                              sampler=random_sampler_test_bc_r) # Create the test dataloader

# %% [markdown]
# ### NN Architecture Definition

# %%
# Define the neural network architecture
class Mushydata(nn.Module):
    def __init__(self, input_size, hidden_size, output_size): # This is the constructor
        super(Mushydata, self).__init__()
        self.base = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.BatchNorm1d(hidden_size),
            nn.Tanh(),
            nn.Linear(hidden_size, hidden_size),
            nn.BatchNorm1d(hidden_size),
            nn.Tanh(),
            nn.Linear(hidden_size, hidden_size),
            nn.BatchNorm1d(hidden_size),
            nn.Tanh(),
            nn.Linear(hidden_size, hidden_size),
            nn.BatchNorm1d(hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, output_size)
        )
        
    def forward(self, x, t):                               # This is the forward pass
        input_features = torch.cat([x, t], dim=1)          # Concatenate the input features
        m = self.base(input_features)                                 # Pass through the third layer
        return m                    # Return the output of the network


# features = torch.rand(1, 2)
# model = HeatPINN(2, 20, 1)
# output = model(features[:, 0:1], features[:, 1:2])
# print(output)


# Loss function for data

# %% [markdown]
# ### Hyperparamters Init

# %%
# Hyperparameters
hidden_size = 80
learning_rate = 0.003
epochs = 30000
# alpha = 0.01  # Adjust this value based on your problem
# boundary_value = 313.0
# initial_value = init_temp
# Initialize the model
model = Mushydata(input_size=2, hidden_size=hidden_size,output_size=1).to(device)
lambd = 0.1

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Loss List Init

# %%
train_losses = []
val_losses = []
test_losses = []

print(f"Datatype of train_loader is {type(train_loader)}")
# Out:
# Datatype of train_loader is <class 'torch.utils.data.dataloader.DataLoader'>

# %% [markdown]
# ### Loss functions

# %% [markdown]
# ### Training, Validation and Testing Module

# %%
def training_loop(epochs, model, loss_fn_data, optimizer, train_loader,test_dataloader,\
                  train_pde_loader,train_loader_init,\
                    train_loader_bc_l,train_loader_bc_r):
    train_losses = []  # Initialize the list to store the training losses
    # val_losses = []    # Initialize the list to store the validation losses
    test_losses = []   # Initialize the list to store the test losses
    data_losses = []   # Initialize the list to store the data losses
    pde_losses = []   # Initialize the list to store the PDE losses
    ic_losses = []   # Initialize the list to store the initial condition losses
    bc_losses = []   # Initialize the list to store the boundary condition losses

    for epoch in range(epochs):
        model.train()                                                                           # Set the model to training mode
        train_loss = 0                                                                              # Initialize the training loss
        train_accuracy = 0
        for (batch,batch_pde,batch_init,batch_left,batch_right) in \
             zip (train_loader,train_pde_loader,train_loader_init,train_loader_bc_l,train_loader_bc_r):                                                          # Loop through the training dataloader
            
            train_inputs_sample, train_temp_inp_sample= batch                                                             # Get the inputs and the true values
            
            train_pde_sample, train_temp_inp_pde_sample= batch_pde                                                             # Get the inputs and the true values
            
            train_inputs_i_sample, train_temp_inp_i_sample= batch_init                                                             # Get the inputs and the true values 
            
            train_inputs_bc_l_sample, train_temp_inp_bc_l_sample= batch_left                                                             # Get the inputs and the true values
            train_inputs_bc_r_sample, train_temp_inp_bc_r_sample= batch_right                                                             # Get the inputs and the true values

            train_inputs_sample, train_temp_inp_sample= train_inputs_sample.to(device), train_temp_inp_sample.to(device)                                                             # Get the inputs and the true values
            
            train_pde_sample, train_temp_inp_pde_sample= train_pde_sample.to(device), train_temp_inp_pde_sample.to(device)                                                             # Get the inputs and the true values
            
            train_inputs_i_sample, train_temp_inp_i_sample= train_inputs_i_sample.to(device), train_temp_inp_i_sample.to(device)                                                            # Get the inputs and the true values 
            
            train_inputs_bc_l_sample, train_temp_inp_bc_l_sample=  train_inputs_bc_l_sample.to(device), train_temp_inp_bc_l_sample.to(device)                                                            # Get the inputs and the true values
            train_inputs_bc_r_sample, train_temp_inp_bc_r_sample= train_inputs_bc_r_sample.to(device), train_temp_inp_bc_r_sample.to(device)
            
            
            # print(inputs.shape)
            # print(inputs_init.shape)
            # print(inputs_left.shape)
            # print(inputs_right.shape)

            optimizer.zero_grad()                                                                    # Zero the gradients
            
            # Forward pass
            u_pred = model(train_inputs_sample[:,0].unsqueeze(1), train_inputs_sample[:,1].unsqueeze(1))                       # Get the predictions
            u_initl = model(train_inputs_i_sample[:,0].unsqueeze(1), train_inputs_i_sample[:,1].unsqueeze(1))                       # Get the predictions
            u_left = model(train_inputs_bc_l_sample[:,0].unsqueeze(1), train_inputs_bc_l_sample[:,1].unsqueeze(1))               # Left boundary of the temperature
            u_right = model(train_inputs_bc_r_sample[:,0].unsqueeze(1), train_inputs_bc_r_sample[:,1].unsqueeze(1))             # Right boundary of the temperature

            # Loss calculation
            data_loss = loss_fn_data(u_pred, train_temp_inp_sample)                                              # Calculate the data loss
            
            pd_loss = pde_loss(model,train_pde_sample[:,0].unsqueeze(1),train_pde_sample[:,1].unsqueeze(1))             # Calculate the PDE loss
            # pd_loss = 0
            
            initc_loss = ic_loss(u_initl) 
            # initc_loss =0                                                      # Calculate initial condition loss
            
            bc_loss_left = boundary_loss(model,train_inputs_bc_l_sample[:,0].unsqueeze(1),train_inputs_bc_l_sample[:,1].unsqueeze(1),t_surr) # Calculate the left boundary condition loss
            bc_loss_right = boundary_loss(model,train_inputs_bc_r_sample[:,0].unsqueeze(1),\
                                          train_inputs_bc_r_sample[:,1].unsqueeze(1),t_surr) # Calculate the right boundary condition loss
            bc_loss = bc_loss_left + bc_loss_right
            # l1_regularization_loss = l1_regularization(model, lambda_l1)                      # Calculate the L1 regularization loss
            # loss = data_loss  + pd_loss + initc_loss + bc_loss                                              # Calculate the total loss
            w1 = 0.0001
            w2 = 0.0001
            w3 = 0.0001
            loss = data_loss + w1* pd_loss + w2 *initc_loss + w3* bc_loss
            train_accuracy += accuracy(u_pred, train_temp_inp_sample)                                                              # Calculate the total loss
            # Backpropagation
            loss.backward(retain_graph=True)                                                        # Backpropagate the gradients
            
            optimizer.step()                                                                           # Update the weights
            
            train_loss += loss.item()                                                           # Add the loss to the training set loss  
            data_loss += data_loss.item()
            pd_loss += pd_loss.item()
            initc_loss += initc_loss.item()
            bc_loss += bc_loss.item()
        
        train_losses.append(train_loss)
        data_losses.append(data_loss)
        pde_losses.append(pd_loss)
        ic_losses.append(initc_loss)
        bc_losses.append(bc_loss)


        model.eval()
        test_loss = 0
        test_accuracy = 0
        # with torch.no_grad(): 
        for batch in test_dataloader:
            test_inputs_sample, test_temp_inp_sample= batch
            test_inputs_sample, test_temp_inp_sample= test_inputs_sample.to(device), test_temp_inp_sample.to(device)
            u_pred = model(test_inputs_sample[:,0].unsqueeze(1), test_inputs_sample[:,1].unsqueeze(1))
            data_loss_t = loss_fn_data(u_pred, test_temp_inp_sample)
            # l1_regularization_loss = l1_regularization(model, lambd)
            # loss = data_loss  + l1_regularization_loss
            
            loss = data_loss_t
            test_accuracy = accuracy(u_pred, test_temp_inp_sample)
            test_loss += loss.item()
        test_losses.append(test_loss)

                                                           # Append the training loss to the list of training losses
        
        


        if epoch % 10 == 0:
            print(f"Epoch {epoch},| Training-Loss {train_loss:.4e},| Data-loss {data_loss:.4e},"
                f"pde-loss {pd_loss:.4e}, initc-loss {initc_loss:.4e}|,"
                f"|bc_loss {bc_loss:.4e}, test-loss {test_loss:.4e}") 

    return train_losses, test_losses , pde_losses , bc_losses , ic_losses, data_losses                                                      # Return the training and validation losses

# %%
def test_loop(epochs, model, loss_fn_data, optimizer, train_dataloader, test_dataloader):
    for epoch in range(epochs):
        model.eval()
        test_loss = 0
        test_accuracy = 0
        with torch.no_grad():   
            for batch in test_dataloader:
                test_inputs_sample, test_temp_inp_sample= batch
                test_inputs_sample, test_temp_inp_sample= test_inputs_sample.to(device), test_temp_inp_sample.to(device)
                u_pred = model(test_inputs_sample[:,0].unsqueeze(1), test_inputs_sample[:,1].unsqueeze(1))
                data_loss = loss_fn_data(u_pred, test_temp_inp_sample)
                # l1_regularization_loss = l1_regularization(model, lambd)
                # loss = data_loss  + l1_regularization_loss
                
                loss = data_loss
                test_accuracy = accuracy(u_pred, test_temp_inp_sample)
                test_loss += loss.item()
        test_losses.append(test_loss)
        if epochs % 10 == 0:
            print(f"Epoch {epoch}, Test-Loss {test_loss:.4e}, Test-Accuracy {test_accuracy:.4e}")      
    return test_losses

# %% [markdown]
# ### Training Button

# %%
train_losses, test_losses, pde_losses, bc_losses,ic_losses, data_losses = training_loop(epochs, model, \
                                        loss_fn_data, optimizer,train_loader,test_loader,\
                                            train_pde_loader, train_loader_init,\
                                            train_loader_bc_l,train_loader_bc_r)  # Train the model
 
# test_losses = test_loop(epochs, model, loss_fn_data, optimizer, train_loader, test_loader)  # Test the model
# Out:
# Epoch 0,| Training-Loss 6.5761e+05,| Data-loss 1.3050e+06,pde-loss 1.2908e-01, initc-loss 1.6898e+06|,|bc_loss 1.0012e+08, test-loss 6.6562e+05
# Epoch 10,| Training-Loss 6.5784e+05,| Data-loss 1.3055e+06,pde-loss 6.3022e-02, initc-loss 1.6850e+06|,|bc_loss 9.9804e+07, test-loss 6.4117e+05
# Epoch 20,| Training-Loss 6.3529e+05,| Data-loss 1.2605e+06,pde-loss 4.4403e-01, initc-loss 1.6803e+06|,|bc_loss 9.9008e+07, test-loss 6.6265e+05
# Epoch 30,| Training-Loss 6.6456e+05,| Data-loss 1.3191e+06,pde-loss 1.6080e+00, initc-loss 1.6748e+06|,|bc_loss 9.8477e+07, test-loss 6.5146e+05
# Epoch 40,| Training-Loss 6.4997e+05,| Data-loss 1.2900e+06,pde-loss 1.0218e+00, initc-loss 1.6702e+06|,|bc_loss 9.7901e+07, test-loss 6.5340e+05
# Epoch 50,| Training-Loss 6.4458e+05,| Data-loss 1.2793e+06,pde-loss 8.8587e-01, initc-loss 1.6633e+06|,|bc_loss 9.7148e+07, test-loss 6.4016e+05
# Epoch 60,| Training-Loss 6.5505e+05,| Data-loss 1.3003e+06,pde-loss 6.3404e+00, initc-loss 1.6544e+06|,|bc_loss 9.6243e+07, test-loss 6.2295e+05
# Epoch 70,| Training-Loss 6.4015e+05,| Data-loss 1.2706e+06,pde-loss 8.0794e+00, initc-loss 1.6452e+06|,|bc_loss 9.5292e+07, test-loss 6.3336e+05
# Epoch 80,| Training-Loss 6.4979e+05,| Data-loss 1.2900e+06,pde-loss 3.2616e+01, initc-loss 1.6369e+06|,|bc_loss 9.4294e+07, test-loss 6.1931e+05
# Epoch 410,| Training-Loss 2.3950e+05,| Data-loss 4.7745e+05,pde-loss 2.9285e+04, initc-loss 7.2942e+05|,|bc_loss 1.4691e+07, test-loss 2.4910e+05
# Epoch 420,| Training-Loss 2.2744e+05,| Data-loss 4.5352e+05,pde-loss 1.6013e+04, initc-loss 7.0490e+05|,|bc_loss 1.2841e+07, test-loss 2.2720e+05
# Epoch 430,| Training-Loss 2.0822e+05,| Data-loss 4.1521e+05,pde-loss 1.9906e+04, initc-loss 6.7132e+05|,|bc_loss 1.1617e+07, test-loss 2.1938e+05
# Epoch 440,| Training-Loss 2.0072e+05,| Data-loss 4.0040e+05,pde-loss 1.6428e+04, initc-loss 6.4356e+05|,|bc_loss 9.7110e+06, test-loss 2.0866e+05
# Epoch 450,| Training-Loss 2.0081e+05,| Data-loss 4.0072e+05,pde-loss 2.0317e+04, initc-loss 6.1473e+05|,|bc_loss 8.3186e+06, test-loss 2.0617e+05
# Epoch 460,| Training-Loss 1.6950e+05,| Data-loss 3.3825e+05,pde-loss 9.1328e+04, initc-loss 5.9775e+05|,|bc_loss 6.8551e+06, test-loss 1.8618e+05
# Epoch 470,| Training-Loss 1.6872e+05,| Data-loss 3.3679e+05,pde-loss 3.4585e+04, initc-loss 5.7347e+05|,|bc_loss 5.8690e+06, test-loss 1.6262e+05
# Epoch 480,| Training-Loss 1.5764e+05,| Data-loss 3.1474e+05,pde-loss 4.0659e+04, initc-loss 5.6093e+05|,|bc_loss 4.8618e+06, test-loss 1.6897e+05
# Epoch 490,| Training-Loss 1.4327e+05,| Data-loss 2.8610e+05,pde-loss 1.5422e+05, initc-loss 4.8084e+05|,|bc_loss 3.6911e+06, test-loss 1.4268e+05
# Epoch 500,| Training-Loss 1.4416e+05,| Data-loss 2.8802e+05,pde-loss 3.2732e+04, initc-loss 4.9242e+05|,|bc_loss 2.5786e+06, test-loss 1.2795e+05
# Epoch 510,| Training-Loss 1.3174e+05,| Data-loss 2.6315e+05,pde-loss 1.7088e+04, initc-loss 4.5810e+05|,|bc_loss 2.7602e+06, test-loss 1.1736e+05
# Epoch 520,| Training-Loss 1.2509e+05,| Data-loss 2.4980e+05,pde-loss 3.3100e+04, initc-loss 4.5508e+05|,|bc_loss 3.3837e+06, test-loss 1.2344e+05
# Epoch 530,| Training-Loss 1.0461e+05,| Data-loss 2.0892e+05,pde-loss 1.5268e+04, initc-loss 3.8731e+05|,|bc_loss 2.5968e+06, test-loss 1.1514e+05
# Epoch 540,| Training-Loss 9.7285e+04,| Data-loss 1.9418e+05,pde-loss 4.1786e+04, initc-loss 3.7444e+05|,|bc_loss 3.4785e+06, test-loss 1.1957e+05
# Epoch 550,| Training-Loss 9.1800e+04,| Data-loss 1.8321e+05,pde-loss 1.5478e+03, initc-loss 3.3642e+05|,|bc_loss 3.5648e+06, test-loss 1.0412e+05
# Epoch 560,| Training-Loss 8.7727e+04,| Data-loss 1.7506e+05,pde-loss 2.0900e+04, initc-loss 3.4820e+05|,|bc_loss 3.5515e+06, test-loss 8.0876e+04
# Epoch 1210,| Training-Loss 1.9083e+03,| Data-loss 5.0392e+02,pde-loss 4.8143e+04, initc-loss 5.3811e+04|,|bc_loss 3.3025e+07, test-loss 3.0050e+03
# Epoch 1220,| Training-Loss 2.2619e+03,| Data-loss 1.1412e+03,pde-loss 6.5601e+04, initc-loss 2.7014e+04|,|bc_loss 3.3733e+07, test-loss 2.3326e+03
# Epoch 1230,| Training-Loss 1.8797e+03,| Data-loss 3.8498e+02,pde-loss 3.2875e+04, initc-loss 4.0998e+04|,|bc_loss 3.3670e+07, test-loss 1.9499e+03
# Epoch 1240,| Training-Loss 1.9703e+03,| Data-loss 5.0161e+02,pde-loss 2.3787e+04, initc-loss 3.0848e+04|,|bc_loss 3.4336e+07, test-loss 1.8207e+03
# Epoch 1250,| Training-Loss 2.0332e+03,| Data-loss 6.8426e+02,pde-loss 4.5030e+04, initc-loss 4.4273e+04|,|bc_loss 3.3733e+07, test-loss 2.3447e+03
# Epoch 1260,| Training-Loss 2.2827e+03,| Data-loss 1.2248e+03,pde-loss 4.3333e+04, initc-loss 4.1142e+04|,|bc_loss 3.3323e+07, test-loss 1.6378e+03
# Epoch 1270,| Training-Loss 1.8824e+03,| Data-loss 3.3594e+02,pde-loss 5.0904e+04, initc-loss 4.0272e+04|,|bc_loss 3.4198e+07, test-loss 2.1397e+03
# Epoch 1280,| Training-Loss 2.5658e+03,| Data-loss 1.6926e+03,pde-loss 3.0286e+04, initc-loss 5.3726e+04|,|bc_loss 3.4306e+07, test-loss 1.6568e+03
# Epoch 1290,| Training-Loss 2.0267e+03,| Data-loss 8.3489e+02,pde-loss 5.6493e+04, initc-loss 3.9060e+04|,|bc_loss 3.2090e+07, test-loss 2.5011e+03
# Epoch 1300,| Training-Loss 2.4784e+03,| Data-loss 1.4687e+03,pde-loss 2.3950e+04, initc-loss 2.4659e+04|,|bc_loss 3.4832e+07, test-loss 2.9116e+03
# Epoch 1310,| Training-Loss 2.0883e+03,| Data-loss 7.8987e+02,pde-loss 1.0971e+04, initc-loss 2.5986e+04|,|bc_loss 3.3831e+07, test-loss 2.2958e+03
# Epoch 1320,| Training-Loss 1.9781e+03,| Data-loss 5.4221e+02,pde-loss 3.2750e+04, initc-loss 4.1862e+04|,|bc_loss 3.4066e+07, test-loss 2.2754e+03
# Epoch 1330,| Training-Loss 2.0792e+03,| Data-loss 6.3347e+02,pde-loss 3.0436e+04, initc-loss 2.3621e+04|,|bc_loss 3.5196e+07, test-loss 2.3346e+03
# Epoch 1340,| Training-Loss 2.2043e+03,| Data-loss 8.0969e+02,pde-loss 3.8606e+04, initc-loss 2.7328e+04|,|bc_loss 3.5923e+07, test-loss 2.6031e+03
# Epoch 1350,| Training-Loss 2.0487e+03,| Data-loss 7.3877e+02,pde-loss 1.1982e+05, initc-loss 2.6084e+04|,|bc_loss 3.3441e+07, test-loss 2.3362e+03
# Epoch 1360,| Training-Loss 2.0506e+03,| Data-loss 6.7969e+02,pde-loss 3.2915e+04, initc-loss 2.7841e+04|,|bc_loss 3.4154e+07, test-loss 2.5349e+03
# Epoch 1530,| Training-Loss 1.8442e+03,| Data-loss 3.6223e+02,pde-loss 3.0084e+04, initc-loss 3.1340e+04|,|bc_loss 3.3199e+07, test-loss 1.6078e+03
# Epoch 1540,| Training-Loss 1.8724e+03,| Data-loss 5.3340e+02,pde-loss 1.3052e+04, initc-loss 2.7323e+04|,|bc_loss 3.2073e+07, test-loss 3.7784e+03
# Epoch 1550,| Training-Loss 1.7480e+03,| Data-loss 2.9219e+02,pde-loss 1.0673e+04, initc-loss 3.4436e+04|,|bc_loss 3.1994e+07, test-loss 2.1972e+03
# Epoch 1560,| Training-Loss 2.1276e+03,| Data-loss 7.4952e+02,pde-loss 6.1692e+04, initc-loss 2.2602e+04|,|bc_loss 3.4972e+07, test-loss 2.0070e+03
# Epoch 1570,| Training-Loss 1.8088e+03,| Data-loss 3.1506e+02,pde-loss 2.3650e+04, initc-loss 3.0684e+04|,|bc_loss 3.2972e+07, test-loss 1.8623e+03
# Epoch 1580,| Training-Loss 1.7726e+03,| Data-loss 3.1182e+02,pde-loss 4.5226e+04, initc-loss 3.9736e+04|,|bc_loss 3.2249e+07, test-loss 4.2887e+03
# Epoch 1590,| Training-Loss 1.7934e+03,| Data-loss 4.2939e+02,pde-loss 2.1619e+04, initc-loss 3.8876e+04|,|bc_loss 3.1514e+07, test-loss 2.8901e+03
# Epoch 1600,| Training-Loss 1.8754e+03,| Data-loss 6.1594e+02,pde-loss 4.8546e+04, initc-loss 2.2376e+04|,|bc_loss 3.1278e+07, test-loss 2.0623e+03
# Epoch 1610,| Training-Loss 1.9070e+03,| Data-loss 5.1245e+02,pde-loss 4.7117e+04, initc-loss 2.3893e+04|,|bc_loss 3.2945e+07, test-loss 2.2654e+03
# Epoch 1620,| Training-Loss 1.9680e+03,| Data-loss 7.5291e+02,pde-loss 6.8482e+04, initc-loss 3.3045e+04|,|bc_loss 3.1729e+07, test-loss 3.8562e+03
# Epoch 1630,| Training-Loss 1.8968e+03,| Data-loss 5.7073e+02,pde-loss 3.1697e+04, initc-loss 2.6287e+04|,|bc_loss 3.2170e+07, test-loss 1.9632e+03
# Epoch 1640,| Training-Loss 1.7489e+03,| Data-loss 3.3408e+02,pde-loss 1.1279e+04, initc-loss 2.5856e+04|,|bc_loss 3.1600e+07, test-loss 1.6366e+03
# Epoch 1650,| Training-Loss 2.0473e+03,| Data-loss 7.9916e+02,pde-loss 3.8978e+04, initc-loss 3.6158e+04|,|bc_loss 3.2878e+07, test-loss 3.7066e+03
# Epoch 1660,| Training-Loss 1.7340e+03,| Data-loss 3.9299e+02,pde-loss 1.3879e+04, initc-loss 3.8189e+04|,|bc_loss 3.0698e+07, test-loss 2.3310e+03
# Epoch 1670,| Training-Loss 2.0589e+03,| Data-loss 9.1912e+02,pde-loss 6.7618e+04, initc-loss 4.0300e+04|,|bc_loss 3.1878e+07, test-loss 1.8504e+03
# Epoch 1680,| Training-Loss 1.9648e+03,| Data-loss 7.3874e+02,pde-loss 1.8765e+04, initc-loss 3.8250e+04|,|bc_loss 3.1852e+07, test-loss 2.5268e+03
# Epoch 2010,| Training-Loss 1.8925e+03,| Data-loss 1.3315e+03,pde-loss 1.4272e+04, initc-loss 3.1864e+04|,|bc_loss 2.4489e+07, test-loss 2.8686e+03
# Epoch 2020,| Training-Loss 1.6243e+03,| Data-loss 6.4281e+02,pde-loss 2.9277e+04, initc-loss 2.1448e+04|,|bc_loss 2.6006e+07, test-loss 3.2162e+03
# Epoch 2030,| Training-Loss 1.6124e+03,| Data-loss 4.6618e+02,pde-loss 1.8130e+04, initc-loss 2.6824e+04|,|bc_loss 2.7541e+07, test-loss 2.0013e+03
# Epoch 2040,| Training-Loss 1.4393e+03,| Data-loss 1.6298e+02,pde-loss 2.1366e+04, initc-loss 3.8699e+04|,|bc_loss 2.7096e+07, test-loss 3.9141e+03
# Epoch 2050,| Training-Loss 1.9698e+03,| Data-loss 1.3521e+03,pde-loss 1.9592e+04, initc-loss 2.8045e+04|,|bc_loss 2.5828e+07, test-loss 2.7007e+03
# Epoch 2060,| Training-Loss 1.4705e+03,| Data-loss 4.3542e+02,pde-loss 7.1543e+03, initc-loss 4.1761e+04|,|bc_loss 2.5007e+07, test-loss 4.2023e+03
# Epoch 2070,| Training-Loss 2.1963e+03,| Data-loss 1.9147e+03,pde-loss 2.5188e+04, initc-loss 3.5033e+04|,|bc_loss 2.4719e+07, test-loss 2.0870e+03
# Epoch 2080,| Training-Loss 1.4286e+03,| Data-loss 4.4227e+02,pde-loss 2.4413e+04, initc-loss 4.3729e+04|,|bc_loss 2.4082e+07, test-loss 3.7162e+03
# Epoch 2090,| Training-Loss 1.8010e+03,| Data-loss 1.1902e+03,pde-loss 1.7020e+04, initc-loss 3.8383e+04|,|bc_loss 2.4062e+07, test-loss 1.5736e+03
# Epoch 2100,| Training-Loss 1.7161e+03,| Data-loss 9.1752e+02,pde-loss 5.8001e+03, initc-loss 4.7798e+04|,|bc_loss 2.5092e+07, test-loss 3.1056e+03
# Epoch 2110,| Training-Loss 1.3339e+03,| Data-loss 2.5479e+02,pde-loss 1.2786e+04, initc-loss 3.2228e+04|,|bc_loss 2.4085e+07, test-loss 2.2301e+03
# Epoch 2120,| Training-Loss 1.4948e+03,| Data-loss 5.0056e+02,pde-loss 1.8305e+04, initc-loss 2.2749e+04|,|bc_loss 2.4850e+07, test-loss 3.1492e+03
# Epoch 2130,| Training-Loss 1.3355e+03,| Data-loss 2.6148e+02,pde-loss 3.0938e+04, initc-loss 3.0743e+04|,|bc_loss 2.4033e+07, test-loss 3.6241e+03
# Epoch 2140,| Training-Loss 1.4255e+03,| Data-loss 4.6333e+02,pde-loss 2.6831e+04, initc-loss 2.9666e+04|,|bc_loss 2.3820e+07, test-loss 1.9872e+03
# Epoch 2150,| Training-Loss 1.7003e+03,| Data-loss 1.0670e+03,pde-loss 4.6268e+04, initc-loss 3.0368e+04|,|bc_loss 2.3259e+07, test-loss 4.0985e+03
# Epoch 2160,| Training-Loss 1.3687e+03,| Data-loss 3.8934e+02,pde-loss 2.5830e+04, initc-loss 2.3060e+04|,|bc_loss 2.3432e+07, test-loss 1.4808e+03
# Epoch 2170,| Training-Loss 1.3427e+03,| Data-loss 2.5276e+02,pde-loss 3.5505e+04, initc-loss 2.8125e+04|,|bc_loss 2.4263e+07, test-loss 2.1631e+03
# Epoch 2180,| Training-Loss 1.2578e+03,| Data-loss 1.9722e+02,pde-loss 2.4937e+04, initc-loss 4.4562e+04|,|bc_loss 2.3114e+07, test-loss 5.1560e+03
# Epoch 2190,| Training-Loss 1.7558e+03,| Data-loss 1.0708e+03,pde-loss 3.3224e+04, initc-loss 3.9459e+04|,|bc_loss 2.4334e+07, test-loss 1.7801e+03
# Epoch 2200,| Training-Loss 1.5168e+03,| Data-loss 5.5842e+02,pde-loss 9.5572e+04, initc-loss 2.3239e+04|,|bc_loss 2.4633e+07, test-loss 3.4401e+03
# Epoch 2210,| Training-Loss 1.4220e+03,| Data-loss 3.8962e+02,pde-loss 3.1431e+04, initc-loss 4.2768e+04|,|bc_loss 2.4470e+07, test-loss 1.7922e+03
# Epoch 2220,| Training-Loss 1.4194e+03,| Data-loss 6.3085e+02,pde-loss 1.2333e+04, initc-loss 2.4526e+04|,|bc_loss 2.2042e+07, test-loss 3.3434e+03
# Epoch 2230,| Training-Loss 1.2728e+03,| Data-loss 2.9253e+02,pde-loss 3.3114e+04, initc-loss 4.3538e+04|,|bc_loss 2.2454e+07, test-loss 3.5842e+03
# Epoch 2240,| Training-Loss 1.2545e+03,| Data-loss 2.3504e+02,pde-loss 2.9454e+04, initc-loss 4.1218e+04|,|bc_loss 2.2668e+07, test-loss 2.8827e+03
# Epoch 2250,| Training-Loss 1.2444e+03,| Data-loss 3.5784e+02,pde-loss 2.4992e+04, initc-loss 5.0925e+04|,|bc_loss 2.1233e+07, test-loss 1.5744e+03
# Epoch 2260,| Training-Loss 1.6093e+03,| Data-loss 1.0532e+03,pde-loss 1.6814e+04, initc-loss 2.5225e+04|,|bc_loss 2.1612e+07, test-loss 1.9583e+03
# Epoch 2270,| Training-Loss 1.4551e+03,| Data-loss 6.7503e+02,pde-loss 2.3884e+04, initc-loss 3.6286e+04|,|bc_loss 2.2291e+07, test-loss 3.0995e+03
# Epoch 2280,| Training-Loss 1.3099e+03,| Data-loss 3.9091e+02,pde-loss 5.7148e+04, initc-loss 3.3369e+04|,|bc_loss 2.2198e+07, test-loss 2.2353e+03
# Epoch 2290,| Training-Loss 1.4698e+03,| Data-loss 7.3260e+02,pde-loss 3.0725e+04, initc-loss 2.2970e+04|,|bc_loss 2.2016e+07, test-loss 1.8306e+03
# Epoch 2300,| Training-Loss 1.3399e+03,| Data-loss 5.5159e+02,pde-loss 1.4890e+04, initc-loss 5.0648e+04|,|bc_loss 2.1217e+07, test-loss 3.3213e+03
# Epoch 2310,| Training-Loss 1.5255e+03,| Data-loss 9.0519e+02,pde-loss 2.5137e+04, initc-loss 2.6745e+04|,|bc_loss 2.1406e+07, test-loss 2.9163e+03
# Epoch 2320,| Training-Loss 1.7817e+03,| Data-loss 1.2808e+03,pde-loss 2.4906e+04, initc-loss 2.4901e+04|,|bc_loss 2.2776e+07, test-loss 1.8195e+03
# Epoch 3120,| Training-Loss 6.4071e+02,| Data-loss 2.8024e+02,pde-loss 1.3687e+04, initc-loss 3.1724e+04|,|bc_loss 9.9664e+06, test-loss 3.5744e+03
# Epoch 3130,| Training-Loss 8.7189e+02,| Data-loss 7.3777e+02,pde-loss 9.0992e+03, initc-loss 5.1604e+04|,|bc_loss 9.9993e+06, test-loss 1.9149e+03
# Epoch 3140,| Training-Loss 5.8109e+02,| Data-loss 1.0547e+02,pde-loss 4.6587e+04, initc-loss 3.7958e+04|,|bc_loss 1.0483e+07, test-loss 5.3368e+03
# Epoch 3150,| Training-Loss 6.5758e+02,| Data-loss 3.2466e+02,pde-loss 3.8955e+04, initc-loss 2.2783e+04|,|bc_loss 9.8434e+06, test-loss 1.6144e+03
# Epoch 3160,| Training-Loss 7.0742e+02,| Data-loss 4.1220e+02,pde-loss 5.6944e+03, initc-loss 3.2237e+04|,|bc_loss 9.9886e+06, test-loss 2.1980e+03
# Epoch 3170,| Training-Loss 9.2448e+02,| Data-loss 8.4492e+02,pde-loss 1.4157e+04, initc-loss 2.5755e+04|,|bc_loss 1.0001e+07, test-loss 1.8895e+03
# Epoch 3180,| Training-Loss 1.6798e+03,| Data-loss 2.3075e+03,pde-loss 4.3503e+04, initc-loss 2.2464e+04|,|bc_loss 1.0455e+07, test-loss 2.4849e+03
# Epoch 3190,| Training-Loss 8.8153e+02,| Data-loss 7.7293e+02,pde-loss 2.6394e+04, initc-loss 2.8770e+04|,|bc_loss 9.8461e+06, test-loss 1.0974e+03
# Epoch 3200,| Training-Loss 7.9067e+02,| Data-loss 5.5376e+02,pde-loss 1.2333e+04, initc-loss 2.0139e+04|,|bc_loss 1.0243e+07, test-loss 4.2247e+03
# Epoch 3210,| Training-Loss 7.4103e+02,| Data-loss 4.4497e+02,pde-loss 1.4427e+04, initc-loss 3.6978e+04|,|bc_loss 1.0320e+07, test-loss 2.4257e+03
# Epoch 3220,| Training-Loss 8.9019e+02,| Data-loss 7.8327e+02,pde-loss 2.4499e+04, initc-loss 3.0053e+04|,|bc_loss 9.9165e+06, test-loss 2.7706e+03
# Epoch 3230,| Training-Loss 7.8137e+02,| Data-loss 5.5428e+02,pde-loss 2.2846e+04, initc-loss 3.0596e+04|,|bc_loss 1.0031e+07, test-loss 2.5562e+03
# Epoch 3240,| Training-Loss 7.0215e+02,| Data-loss 4.0007e+02,pde-loss 2.5581e+04, initc-loss 2.4497e+04|,|bc_loss 9.9922e+06, test-loss 3.5164e+03
# Epoch 3250,| Training-Loss 8.0663e+02,| Data-loss 6.2492e+02,pde-loss 4.8229e+04, initc-loss 4.9996e+04|,|bc_loss 9.7851e+06, test-loss 1.2666e+03
# Epoch 3260,| Training-Loss 1.0548e+03,| Data-loss 1.1150e+03,pde-loss 1.0003e+04, initc-loss 2.2127e+04|,|bc_loss 9.9128e+06, test-loss 2.8945e+03
# ...
# Epoch 16700,| Training-Loss 2.5094e+02,| Data-loss 1.0112e+02,pde-loss 4.3950e+04, initc-loss 2.2178e+04|,|bc_loss 3.9416e+06, test-loss 4.0375e+03
# Epoch 16710,| Training-Loss 2.2669e+02,| Data-loss 1.4606e+02,pde-loss 1.3293e+04, initc-loss 3.5469e+04|,|bc_loss 3.0245e+06, test-loss 2.7151e+03
# Epoch 16720,| Training-Loss 3.3069e+02,| Data-loss 3.8675e+02,pde-loss 8.9885e+03, initc-loss 3.5562e+04|,|bc_loss 2.7017e+06, test-loss 3.3354e+03
# Epoch 16730,| Training-Loss 2.4154e+02,| Data-loss 2.1540e+02,pde-loss 8.0415e+03, initc-loss 3.5547e+04|,|bc_loss 2.6332e+06, test-loss 3.2235e+03
# Epoch 16740,| Training-Loss 1.7339e+02,| Data-loss 5.3233e+01,pde-loss 4.4261e+04, initc-loss 2.5940e+04|,|bc_loss 2.8652e+06, test-loss 4.5782e+03
# Epoch 16750,| Training-Loss 5.0405e+02,| Data-loss 7.3733e+02,pde-loss 2.0597e+03, initc-loss 2.3195e+04|,|bc_loss 2.6825e+06, test-loss 4.4486e+03
# Epoch 16760,| Training-Loss 3.0615e+02,| Data-loss 3.6853e+02,pde-loss 1.9329e+04, initc-loss 2.7732e+04|,|bc_loss 2.3906e+06, test-loss 3.9811e+03
# Epoch 16770,| Training-Loss 1.5775e+02,| Data-loss 2.9496e+01,pde-loss 4.1893e+04, initc-loss 3.3884e+04|,|bc_loss 2.7843e+06, test-loss 3.2149e+03
# Epoch 16780,| Training-Loss 3.3201e+02,| Data-loss 3.7239e+02,pde-loss 3.3213e+04, initc-loss 2.9301e+04|,|bc_loss 2.8538e+06, test-loss 4.2280e+03
# Epoch 16790,| Training-Loss 2.9290e+02,| Data-loss 3.5198e+02,pde-loss 2.7018e+03, initc-loss 3.2733e+04|,|bc_loss 2.3028e+06, test-loss 2.8563e+03
# Epoch 16800,| Training-Loss 2.2408e+02,| Data-loss 1.2793e+02,pde-loss 1.8115e+04, initc-loss 3.6188e+04|,|bc_loss 3.1479e+06, test-loss 2.9279e+03
# Epoch 16810,| Training-Loss 1.9059e+02,| Data-loss 9.2101e+01,pde-loss 1.5270e+04, initc-loss 3.1611e+04|,|bc_loss 2.8438e+06, test-loss 4.4197e+03
# Epoch 16820,| Training-Loss 1.9275e+02,| Data-loss 1.3801e+02,pde-loss 1.8557e+04, initc-loss 4.1206e+04|,|bc_loss 2.4152e+06, test-loss 3.0103e+03
# Epoch 16830,| Training-Loss 2.9644e+02,| Data-loss 3.4037e+02,pde-loss 1.0028e+04, initc-loss 2.6233e+04|,|bc_loss 2.4888e+06, test-loss 2.0614e+03
# Epoch 16840,| Training-Loss 2.3057e+02,| Data-loss 2.2381e+02,pde-loss 3.6863e+04, initc-loss 2.9241e+04|,|bc_loss 2.3072e+06, test-loss 2.2729e+03
# Epoch 16850,| Training-Loss 4.2806e+02,| Data-loss 6.1383e+02,pde-loss 5.1495e+04, initc-loss 3.0806e+04|,|bc_loss 2.3407e+06, test-loss 2.1689e+03
# Epoch 16860,| Training-Loss 2.7559e+02,| Data-loss 2.3838e+02,pde-loss 6.9233e+04, initc-loss 2.6200e+04|,|bc_loss 3.0326e+06, test-loss 2.3767e+03
# Epoch 16870,| Training-Loss 2.3239e+02,| Data-loss 1.7537e+02,pde-loss 3.1327e+04, initc-loss 2.4236e+04|,|bc_loss 2.8385e+06, test-loss 3.1229e+03
# Epoch 16880,| Training-Loss 2.9085e+02,| Data-loss 3.3257e+02,pde-loss 2.6756e+03, initc-loss 3.0686e+04|,|bc_loss 2.4579e+06, test-loss 3.5711e+03
# Epoch 16890,| Training-Loss 2.1231e+02,| Data-loss 1.1903e+02,pde-loss 1.9981e+04, initc-loss 2.9404e+04|,|bc_loss 3.0065e+06, test-loss 3.0986e+03
# Epoch 16900,| Training-Loss 1.3873e+02,| Data-loss 5.4474e+01,pde-loss 2.7642e+04, initc-loss 3.7666e+04|,|bc_loss 2.1646e+06, test-loss 2.5015e+03
# Epoch 16910,| Training-Loss 1.2955e+02,| Data-loss 5.3424e+01,pde-loss 6.2659e+03, initc-loss 2.9883e+04|,|bc_loss 2.0207e+06, test-loss 1.4762e+03
# Epoch 16920,| Training-Loss 1.5395e+02,| Data-loss 4.5214e+01,pde-loss 8.4129e+04, initc-loss 2.6870e+04|,|bc_loss 2.5159e+06, test-loss 3.0681e+03
# Epoch 16930,| Training-Loss 3.0160e+02,| Data-loss 2.8594e+02,pde-loss 6.8306e+03, initc-loss 3.3355e+04|,|bc_loss 3.1325e+06, test-loss 2.5691e+03
# Epoch 16940,| Training-Loss 1.6218e+02,| Data-loss 3.6628e+01,pde-loss 3.7043e+04, initc-loss 3.4502e+04|,|bc_loss 2.8058e+06, test-loss 2.8276e+03
# Epoch 16950,| Training-Loss 2.8813e+02,| Data-loss 3.1621e+02,pde-loss 9.9805e+03, initc-loss 2.5848e+04|,|bc_loss 2.5646e+06, test-loss 1.5771e+03
# Epoch 16960,| Training-Loss 2.0022e+02,| Data-loss 1.6654e+02,pde-loss 2.7510e+03, initc-loss 2.9896e+04|,|bc_loss 2.3064e+06, test-loss 2.6640e+03
# Epoch 16970,| Training-Loss 3.7890e+02,| Data-loss 5.5317e+02,pde-loss 2.5110e+03, initc-loss 3.5369e+04|,|bc_loss 2.0084e+06, test-loss 3.2439e+03
# Epoch 16980,| Training-Loss 3.0185e+02,| Data-loss 2.3684e+02,pde-loss 4.8315e+03, initc-loss 2.3638e+04|,|bc_loss 3.6402e+06, test-loss 4.9262e+03
# Epoch 16990,| Training-Loss 2.7008e+02,| Data-loss 2.7056e+02,pde-loss 3.3534e+03, initc-loss 2.2497e+04|,|bc_loss 2.6701e+06, test-loss 3.7623e+03
# Epoch 17000,| Training-Loss 4.1227e+02,| Data-loss 5.6247e+02,pde-loss 1.4143e+04, initc-loss 2.9732e+04|,|bc_loss 2.5769e+06, test-loss 2.8359e+03
# Epoch 17010,| Training-Loss 2.0673e+02,| Data-loss 1.4837e+02,pde-loss 1.9011e+04, initc-loss 2.8885e+04|,|bc_loss 2.6030e+06, test-loss 2.4957e+03
# Epoch 17020,| Training-Loss 1.7230e+02,| Data-loss 9.9586e+01,pde-loss 2.1852e+04, initc-loss 4.2116e+04|,|bc_loss 2.3862e+06, test-loss 3.0278e+03
# Epoch 17030,| Training-Loss 1.8590e+02,| Data-loss 1.4139e+02,pde-loss 1.0663e+04, initc-loss 3.1158e+04|,|bc_loss 2.2623e+06, test-loss 3.2395e+03
# Epoch 17040,| Training-Loss 3.4257e+02,| Data-loss 4.6743e+02,pde-loss 7.9525e+04, initc-loss 3.3879e+04|,|bc_loss 2.0637e+06, test-loss 3.5929e+03
# Epoch 17050,| Training-Loss 2.7479e+02,| Data-loss 2.8733e+02,pde-loss 1.1917e+04, initc-loss 2.5908e+04|,|bc_loss 2.5848e+06, test-loss 2.7455e+03
# Epoch 17060,| Training-Loss 1.7229e+02,| Data-loss 8.0746e+01,pde-loss 1.5722e+03, initc-loss 2.9932e+04|,|bc_loss 2.6069e+06, test-loss 2.2911e+03
# Epoch 17070,| Training-Loss 3.2616e+02,| Data-loss 3.7974e+02,pde-loss 3.8303e+04, initc-loss 2.8724e+04|,|bc_loss 2.6589e+06, test-loss 2.5444e+03
# Epoch 17080,| Training-Loss 3.9525e+02,| Data-loss 4.6173e+02,pde-loss 6.5187e+04, initc-loss 3.3118e+04|,|bc_loss 3.1894e+06, test-loss 3.0742e+03
# Epoch 17090,| Training-Loss 1.7102e+02,| Data-loss 9.5510e+01,pde-loss 8.4810e+03, initc-loss 3.1457e+04|,|bc_loss 2.4254e+06, test-loss 3.3319e+03
# Epoch 17100,| Training-Loss 1.5417e+02,| Data-loss 5.1715e+01,pde-loss 1.0299e+04, initc-loss 2.6289e+04|,|bc_loss 2.5297e+06, test-loss 3.4695e+03
# Epoch 17110,| Training-Loss 2.1649e+02,| Data-loss 1.4806e+02,pde-loss 1.6823e+03, initc-loss 8.8895e+04|,|bc_loss 2.7587e+06, test-loss 1.7378e+03
# Epoch 17120,| Training-Loss 3.3235e+02,| Data-loss 4.3123e+02,pde-loss 3.5251e+04, initc-loss 2.7237e+04|,|bc_loss 2.2721e+06, test-loss 2.4332e+03
# Epoch 17130,| Training-Loss 3.7060e+02,| Data-loss 4.4301e+02,pde-loss 3.0346e+05, initc-loss 4.0962e+04|,|bc_loss 2.6376e+06, test-loss 2.5807e+03
# Epoch 17140,| Training-Loss 2.3654e+02,| Data-loss 1.8311e+02,pde-loss 8.0048e+03, initc-loss 2.7410e+04|,|bc_loss 2.8642e+06, test-loss 3.1351e+03
# Epoch 17150,| Training-Loss 2.0766e+02,| Data-loss 1.6627e+02,pde-loss 3.6696e+03, initc-loss 4.9406e+04|,|bc_loss 2.4375e+06, test-loss 2.5650e+03
# Epoch 17160,| Training-Loss 1.7786e+02,| Data-loss 6.1178e+01,pde-loss 7.8691e+02, initc-loss 3.3037e+04|,|bc_loss 2.9116e+06, test-loss 1.1450e+03
# Epoch 17170,| Training-Loss 2.8181e+02,| Data-loss 2.7236e+02,pde-loss 2.4425e+03, initc-loss 4.0369e+04|,|bc_loss 2.8699e+06, test-loss 3.9070e+03
# Epoch 17180,| Training-Loss 6.8640e+02,| Data-loss 1.0007e+03,pde-loss 2.5119e+04, initc-loss 2.8720e+04|,|bc_loss 3.6673e+06, test-loss 1.7154e+03
# Epoch 17190,| Training-Loss 3.8123e+02,| Data-loss 4.5088e+02,pde-loss 3.0993e+04, initc-loss 3.6985e+04|,|bc_loss 3.0479e+06, test-loss 1.9588e+03
# Epoch 17200,| Training-Loss 1.9341e+02,| Data-loss 1.0983e+02,pde-loss 2.5427e+03, initc-loss 3.3460e+04|,|bc_loss 2.7339e+06, test-loss 2.7791e+03
# Epoch 17210,| Training-Loss 4.6696e+02,| Data-loss 6.4199e+02,pde-loss 1.1293e+04, initc-loss 2.6744e+04|,|bc_loss 2.8812e+06, test-loss 3.0285e+03
# Epoch 17220,| Training-Loss 3.8553e+02,| Data-loss 4.8150e+02,pde-loss 1.0017e+04, initc-loss 2.6822e+04|,|bc_loss 2.8588e+06, test-loss 2.8946e+03
# Epoch 17230,| Training-Loss 6.3731e+02,| Data-loss 1.0714e+03,pde-loss 9.8853e+03, initc-loss 3.7558e+04|,|bc_loss 1.9848e+06, test-loss 2.1674e+03
# Epoch 17240,| Training-Loss 4.3022e+02,| Data-loss 5.9410e+02,pde-loss 1.7130e+04, initc-loss 2.5344e+04|,|bc_loss 2.6209e+06, test-loss 4.5545e+03
# Epoch 17250,| Training-Loss 1.4635e+02,| Data-loss 3.4326e+01,pde-loss 4.2533e+03, initc-loss 2.6697e+04|,|bc_loss 2.5527e+06, test-loss 3.9519e+03
# Epoch 17260,| Training-Loss 1.4498e+02,| Data-loss 5.6747e+01,pde-loss 7.4671e+03, initc-loss 2.3409e+04|,|bc_loss 2.3012e+06, test-loss 2.9524e+03
# Epoch 17270,| Training-Loss 1.4022e+02,| Data-loss 4.1383e+01,pde-loss 2.4691e+04, initc-loss 2.4834e+04|,|bc_loss 2.3411e+06, test-loss 3.5263e+03
# Epoch 17280,| Training-Loss 2.0393e+02,| Data-loss 1.2498e+02,pde-loss 4.4733e+04, initc-loss 3.3975e+04|,|bc_loss 2.7501e+06, test-loss 2.6895e+03
# Epoch 17290,| Training-Loss 2.8244e+02,| Data-loss 2.9044e+02,pde-loss 1.4794e+03, initc-loss 2.8109e+04|,|bc_loss 2.7147e+06, test-loss 4.3368e+03
# Epoch 17300,| Training-Loss 4.3845e+02,| Data-loss 5.5263e+02,pde-loss 2.2822e+04, initc-loss 3.0549e+04|,|bc_loss 3.1893e+06, test-loss 2.3853e+03
# Epoch 17310,| Training-Loss 1.9238e+02,| Data-loss 1.0160e+02,pde-loss 1.1197e+04, initc-loss 2.4614e+04|,|bc_loss 2.7958e+06, test-loss 3.0787e+03
# Epoch 17320,| Training-Loss 1.9462e+02,| Data-loss 1.5704e+02,pde-loss 4.7678e+03, initc-loss 3.3452e+04|,|bc_loss 2.2837e+06, test-loss 4.7655e+03
# Epoch 17330,| Training-Loss 1.5537e+02,| Data-loss 5.8342e+01,pde-loss 5.2437e+04, initc-loss 3.3479e+04|,|bc_loss 2.4380e+06, test-loss 3.4498e+03
# Epoch 17340,| Training-Loss 2.2193e+02,| Data-loss 1.0276e+02,pde-loss 1.4238e+04, initc-loss 3.1966e+04|,|bc_loss 3.3648e+06, test-loss 3.4007e+03
# Epoch 17350,| Training-Loss 1.5548e+02,| Data-loss 7.3488e+01,pde-loss 5.7049e+03, initc-loss 2.7778e+04|,|bc_loss 2.3412e+06, test-loss 4.1376e+03
# Epoch 17360,| Training-Loss 1.4013e+02,| Data-loss 3.0073e+01,pde-loss 2.8133e+04, initc-loss 2.7191e+04|,|bc_loss 2.4466e+06, test-loss 5.7498e+03
# Epoch 17370,| Training-Loss 1.6797e+02,| Data-loss 8.6131e+01,pde-loss 1.9669e+04, initc-loss 2.5553e+04|,|bc_loss 2.4528e+06, test-loss 2.7757e+03
# Epoch 17380,| Training-Loss 1.7116e+02,| Data-loss 8.7659e+01,pde-loss 5.8440e+03, initc-loss 2.9634e+04|,|bc_loss 2.5111e+06, test-loss 2.5973e+03
# Epoch 17390,| Training-Loss 2.0541e+02,| Data-loss 1.1882e+02,pde-loss 2.8320e+04, initc-loss 3.2608e+04|,|bc_loss 2.8589e+06, test-loss 3.6604e+03
# Epoch 17400,| Training-Loss 1.9808e+02,| Data-loss 1.0738e+02,pde-loss 2.1444e+04, initc-loss 2.6015e+04|,|bc_loss 2.8404e+06, test-loss 4.0179e+03
# Epoch 17410,| Training-Loss 2.3113e+02,| Data-loss 1.7537e+02,pde-loss 7.4343e+04, initc-loss 2.3896e+04|,|bc_loss 2.7707e+06, test-loss 3.1242e+03
# Epoch 17420,| Training-Loss 2.5804e+02,| Data-loss 2.9774e+02,pde-loss 9.6733e+04, initc-loss 3.0741e+04|,|bc_loss 2.0559e+06, test-loss 3.8565e+03
# Epoch 17430,| Training-Loss 3.5993e+02,| Data-loss 4.7834e+02,pde-loss 2.5882e+03, initc-loss 2.4344e+04|,|bc_loss 2.3883e+06, test-loss 2.7716e+03
# Epoch 17440,| Training-Loss 3.4623e+02,| Data-loss 4.5827e+02,pde-loss 3.2981e+03, initc-loss 3.3535e+04|,|bc_loss 2.3051e+06, test-loss 2.8901e+03
# Epoch 17450,| Training-Loss 3.6300e+02,| Data-loss 4.8595e+02,pde-loss 2.3428e+03, initc-loss 2.3822e+04|,|bc_loss 2.3743e+06, test-loss 3.8768e+03
# Epoch 17460,| Training-Loss 2.7037e+02,| Data-loss 2.7267e+02,pde-loss 2.4153e+04, initc-loss 2.8963e+04|,|bc_loss 2.6275e+06, test-loss 4.0353e+03
# Epoch 17470,| Training-Loss 2.0700e+02,| Data-loss 1.9108e+02,pde-loss 2.1825e+04, initc-loss 2.2908e+04|,|bc_loss 2.1845e+06, test-loss 3.7782e+03
# Epoch 17480,| Training-Loss 6.4868e+02,| Data-loss 1.0580e+03,pde-loss 2.4665e+04, initc-loss 2.3905e+04|,|bc_loss 2.3447e+06, test-loss 4.7597e+03
# Epoch 17490,| Training-Loss 1.4644e+02,| Data-loss 4.9691e+01,pde-loss 2.2006e+04, initc-loss 3.1420e+04|,|bc_loss 2.3784e+06, test-loss 3.4765e+03
# Epoch 17500,| Training-Loss 1.8903e+02,| Data-loss 1.0639e+02,pde-loss 2.4877e+04, initc-loss 2.4906e+04|,|bc_loss 2.6669e+06, test-loss 2.9721e+03
# Epoch 17510,| Training-Loss 2.8349e+02,| Data-loss 3.0990e+02,pde-loss 2.0577e+04, initc-loss 3.1920e+04|,|bc_loss 2.5183e+06, test-loss 2.1358e+03
# Epoch 17520,| Training-Loss 1.9929e+02,| Data-loss 1.8801e+02,pde-loss 1.5662e+04, initc-loss 3.2549e+04|,|bc_loss 2.0575e+06, test-loss 3.3201e+03
# Epoch 17530,| Training-Loss 2.0630e+02,| Data-loss 1.2557e+02,pde-loss 5.4639e+03, initc-loss 2.4719e+04|,|bc_loss 2.8400e+06, test-loss 3.7077e+03
# Epoch 17540,| Training-Loss 2.7809e+02,| Data-loss 2.5185e+02,pde-loss 2.3409e+03, initc-loss 2.3539e+04|,|bc_loss 3.0175e+06, test-loss 3.5022e+03
# Epoch 17550,| Training-Loss 3.2215e+02,| Data-loss 2.9781e+02,pde-loss 2.3781e+04, initc-loss 3.2558e+04|,|bc_loss 3.4085e+06, test-loss 3.8828e+03
# Epoch 17560,| Training-Loss 1.6018e+02,| Data-loss 5.4260e+01,pde-loss 4.3283e+03, initc-loss 2.9978e+04|,|bc_loss 2.6266e+06, test-loss 3.3310e+03
# Epoch 17570,| Training-Loss 2.7306e+02,| Data-loss 2.7196e+02,pde-loss 1.7135e+04, initc-loss 3.4149e+04|,|bc_loss 2.6903e+06, test-loss 4.0580e+03
# Epoch 17580,| Training-Loss 2.4673e+02,| Data-loss 2.1190e+02,pde-loss 7.0740e+04, initc-loss 2.6594e+04|,|bc_loss 2.7183e+06, test-loss 3.0793e+03
# Epoch 17590,| Training-Loss 2.9928e+02,| Data-loss 2.9083e+02,pde-loss 6.1370e+03, initc-loss 3.1400e+04|,|bc_loss 3.0397e+06, test-loss 5.2743e+03
# Epoch 17600,| Training-Loss 1.3662e+02,| Data-loss 5.5439e+01,pde-loss 4.1279e+03, initc-loss 2.9562e+04|,|bc_loss 2.1443e+06, test-loss 4.1277e+03
# Epoch 17610,| Training-Loss 2.9221e+02,| Data-loss 3.1112e+02,pde-loss 2.1785e+03, initc-loss 2.7548e+04|,|bc_loss 2.7032e+06, test-loss 3.1463e+03
# Epoch 17620,| Training-Loss 3.4493e+02,| Data-loss 4.5702e+02,pde-loss 4.0577e+04, initc-loss 2.3865e+04|,|bc_loss 2.2639e+06, test-loss 5.0317e+03
# Epoch 17630,| Training-Loss 1.8778e+02,| Data-loss 1.5095e+02,pde-loss 6.3763e+04, initc-loss 3.5663e+04|,|bc_loss 2.1467e+06, test-loss 4.3046e+03
# Epoch 17640,| Training-Loss 3.5196e+02,| Data-loss 4.3064e+02,pde-loss 1.9922e+03, initc-loss 3.3943e+04|,|bc_loss 2.6968e+06, test-loss 3.2288e+03
# Epoch 17650,| Training-Loss 2.3986e+02,| Data-loss 1.3237e+02,pde-loss 6.7130e+03, initc-loss 3.2101e+04|,|bc_loss 3.4348e+06, test-loss 3.1316e+03
# Epoch 17660,| Training-Loss 1.4646e+02,| Data-loss 5.9985e+01,pde-loss 3.0709e+04, initc-loss 3.3162e+04|,|bc_loss 2.2655e+06, test-loss 3.2654e+03
# Epoch 17670,| Training-Loss 1.5177e+02,| Data-loss 5.7945e+01,pde-loss 2.6408e+04, initc-loss 2.6635e+04|,|bc_loss 2.4028e+06, test-loss 3.5265e+03
# Epoch 17680,| Training-Loss 2.1811e+02,| Data-loss 1.5324e+02,pde-loss 1.0441e+05, initc-loss 2.9795e+04|,|bc_loss 2.6957e+06, test-loss 3.8868e+03
# Epoch 17690,| Training-Loss 6.1373e+02,| Data-loss 9.7417e+02,pde-loss 4.4421e+04, initc-loss 2.6477e+04|,|bc_loss 2.4620e+06, test-loss 5.5780e+03
# Epoch 17700,| Training-Loss 2.8712e+02,| Data-loss 2.5153e+02,pde-loss 8.7810e+03, initc-loss 2.4784e+04|,|bc_loss 3.1936e+06, test-loss 4.3986e+03
# Epoch 17710,| Training-Loss 2.3948e+02,| Data-loss 1.9941e+02,pde-loss 8.9028e+04, initc-loss 3.9595e+04|,|bc_loss 2.6669e+06, test-loss 5.5301e+03
# Epoch 17720,| Training-Loss 5.7842e+02,| Data-loss 8.0363e+02,pde-loss 8.2496e+03, initc-loss 3.2567e+04|,|bc_loss 3.4913e+06, test-loss 3.6203e+03
# Epoch 17730,| Training-Loss 1.8677e+02,| Data-loss 9.1330e+01,pde-loss 1.3347e+04, initc-loss 3.0582e+04|,|bc_loss 2.7781e+06, test-loss 5.6246e+03
# Epoch 17740,| Training-Loss 1.4907e+02,| Data-loss 4.9261e+01,pde-loss 6.3464e+03, initc-loss 2.4245e+04|,|bc_loss 2.4583e+06, test-loss 5.0648e+03
# Epoch 17750,| Training-Loss 2.4036e+02,| Data-loss 1.8369e+02,pde-loss 2.0735e+04, initc-loss 3.5535e+04|,|bc_loss 2.9141e+06, test-loss 3.8534e+03
# Epoch 17760,| Training-Loss 1.5394e+02,| Data-loss 8.9433e+01,pde-loss 3.0200e+04, initc-loss 3.3582e+04|,|bc_loss 2.1206e+06, test-loss 3.1297e+03
# Epoch 17770,| Training-Loss 1.5444e+02,| Data-loss 4.2066e+01,pde-loss 8.6046e+04, initc-loss 2.9250e+04|,|bc_loss 2.5528e+06, test-loss 3.9229e+03

# %%
inputs = torch.tensor(inputs).float().to(device) # Convert the inputs to a tensor
temp_nn = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

temp_nn = temp_nn.reshape(num_steps+1, num_points) # Reshape the predictions to a 2D array
print(temp_nn.shape)
time_ss= np.linspace(0, time_end, num_steps+1 )
plt.figure
plt.plot(time_ss, temp_nn[:, num_points//2], label='Predicted Temperature')
plt.plot(time_ss, temperature_history[:,num_points//2], label='Actual Temperature')
plt.xlabel('Time(s)')
plt.ylabel('Temperature (K)')
plt.title('Predicted vs Actual Temperature at x = 7.5mm')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 inputs = torch.tensor(inputs).float().to(device) # Convert the inputs to a tensor
#       2 temp_nn = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model
#       4 temp_nn = temp_nn.reshape(num_steps+1, num_points) # Reshape the predictions to a 2D array
#
# NameError: name 'torch' is not defined

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(test_losses, label='test Loss')
# plt.xticks(np.arange(0, epochs, 10000))
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
pde_losses_n = [tensor.cpu().detach().numpy() for tensor in pde_losses]
data_losses_n = [tensor.cpu().detach().numpy() for tensor in data_losses]
ic_losses_n = [tensor.cpu().detach().numpy() for tensor in ic_losses]
bc_losses_n = [tensor.cpu().detach().numpy() for tensor in bc_losses]

plt.figure(figsize=(10, 6))
plt.plot(data_losses_n, label='Data Loss')
plt.plot(pde_losses_n, label='Pde Loss')
plt.plot(ic_losses_n, label='IC Loss')
plt.plot(bc_losses_n, label='BC Loss')
plt.yscale('log')
# plt.axhline(y=1e-6, color='red', linestyle='--', label='Near-Zero Line')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
space_coord, time_coord = np.meshgrid(np.arange(t_hist_2.shape[1]), np.arange(t_hist_2.shape[0]))

time_coord = time_coord * dt 
# Create a figure with two subplots
print(space_coord.shape,time_coord.shape,t_hist.shape,temp_nn.shape)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))


# Plot the temperature history on the left subplot
im1 = ax1.pcolormesh(space_coord, time_coord, t_hist_2, cmap='viridis', shading='auto')
ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax1.set_title('Temperature Variation Over Time(Analytical Model)',fontname='Times New Roman', fontsize=20)
ax1.contour(space_coord, time_coord, t_hist, colors='red', linewidths=1.0, alpha=0.9)

ax1.grid(True)
cbar = fig.colorbar(im1, ax=ax1)
cbar.ax.invert_yaxis()
cbar.set_label('Temperature (K)', rotation=270, labelpad=20, fontname='Times New Roman', fontsize=16)

im2 = ax2.pcolormesh(space_coord, time_coord, temp_nn, cmap='viridis', shading='auto')
ax2.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax2.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax2.set_title('Temperature Variation Over Time(PINN Approach)',fontname='Times New Roman', fontsize=20)
ax2.contour(space_coord, time_coord, temp_nn, colors='red', linewidths=1.0, alpha=0.9)

ax2.grid(True)
cbar = fig.colorbar(im2, ax=ax2)
cbar.ax.invert_yaxis()
cbar.set_label('Temperature (K)', rotation=270, labelpad=20, fontname='Times New Roman', fontsize=16)


plt.tight_layout()
plt.show()
