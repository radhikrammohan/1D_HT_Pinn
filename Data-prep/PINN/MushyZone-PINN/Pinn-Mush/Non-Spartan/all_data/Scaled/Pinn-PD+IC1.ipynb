# %% [markdown]
# # 1D Three Phase Simulation of Alloys and PINN model development

# %% [markdown]
# This notebook contains the simulation of 1D Phase change of aluminium alloy. There will be three phases (solid,liquid and mushy).
#
# The approach used is finite difference method and the physics involved in heat conduction.

# %% [markdown]
# ## Import Libraries

# %%
import sys
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler
import torchjd
from torchjd.aggregation import UPGrad

from pinn_loss import loss_fn_data, l1_regularization, pde_loss, boundary_loss, ic_loss, accuracy
from Input_vec_gen import input_gen

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Define the constants and inital geometric domain

# %%
# Geometry
length = 15.0e-3             # Length of the rod

# Material properties
rho = 2300.0                     # Density of AL380 (kg/m^3)
rho_l = 2460.0                   # Density of AL380 (kg/m^3)
rho_s = 2710.0                    # Density of AL380 (kg/m^3)
rho_m = (rho_l + rho_s )/2       # Desnity in mushy zone is taken as average of liquid and solid density

k = 104.0                       # W/m-K
k_l = k                       # W/m-K
k_s = 96.2                    # W/m-K
k_m =  (k_l+k_s)/2                     # W/m-K
k_mo = 41.5


cp = 1245.3                      # Specific heat of aluminum (J/kg-K)
cp_l = cp                      # Specific heat of aluminum (J/kg-K)
cp_s = 963.0                 # Specific heat of aluminum (J/kg-K)
cp_m =  (cp_l+cp_s)/2                 # Specific heat of mushy zone is taken as average of liquid and solid specific heat
# cp_m = cp
           # Thermal diffusivity
alpha_l = k_l / (rho_l * cp_l) 
alpha_s = k_s / (rho_s*cp_s)
alpha_m = k_m / (rho_m * cp_m)          #`Thermal diffusivity in mushy zone is taken as average of liquid and solid thermal diffusivity`


#L_fusion = 3.9e3                 # J/kg
L_fusion = 389.0e3               # J/kg  # Latent heat of fusion of aluminum
         # Thermal diffusivity


T_L = 574.4 +273.0                       #  K -Liquidus Temperature (615 c) AL 380
T_S = 497.3 +273.0                     # K- Solidus Temperature (550 C)
m_eff =(k_m/(rho_m*(cp_m + (L_fusion/(T_L-T_S)))))
print (f"alpha_l = {alpha_l}, alpha_s = {alpha_s}, m_eff = {m_eff}")

# htc = 10.0                   # W/m^2-K
# q = htc*(919.0-723.0)
# q = 10000.0


num_points = 50                        # Number of spatial points
dx = length / (num_points - 1)         # Distance between two spatial points
print('dx is',dx)

                                                              
# Time Discretization  
# 
time_end = 40        # seconds                         

maxi = max(alpha_s,alpha_l,alpha_m)
dt = abs(0.5*((dx**2) /maxi)) 

print('dt is ',dt)
num_steps = round(time_end/dt)
print('num_steps is',num_steps)
cfl = 0.5 *(dx**2/max(alpha_l,alpha_s,alpha_m))
print('cfl is',cfl)

time_steps = np.linspace(0, time_end, num_steps + 1)
step_coeff = dt / (dx ** 2)

if dt <= cfl:
    print('stability criteria satisfied')
else:
    print('stability criteria not satisfied')
    sys.exit()
# Out:
# alpha_l = 3.394878564540885e-05, alpha_s = 3.686205086349929e-05, m_eff = 6.296953764744878e-06
# dx is 0.0003061224489795918
# dt is  0.0012711033647622566
# num_steps is 31469
# cfl is 0.0012711033647622566
# stability criteria satisfied

# %% [markdown]
# ### Initial and Boundary Conditions

# %%
temp_init = 919.0
# Initial temperature and phase fields
temperature = np.full(num_points+2, 919.0)            # Initial temperature of the rod with ghost points at both ends
phase = np.zeros(num_points+2)*0.0                    # Initial phase of the rod with ghost points at both ends

# Set boundary conditions
# temperature[-1] = 919.0 
phase[-1] = 1.0

# temperature[0] = 919.0 #(40 C)
phase[0] = 1.0

# Store initial state in history
temperature_history = [temperature.copy()]    # List to store temperature at each time step
phi_history = [phase.copy()]                    # List to store phase at each time step
temp_init = temperature.copy()                 # Initial temperature of the rod
# print(temperature_history,phi_history)
# Array to store temperature at midpoint over time
midpoint_index = num_points // 2                          # Index of the midpoint

midpoint_temperature_history = [temperature[midpoint_index]]            # List to store temperature at midpoint over time
dm = 60.0e-3                                                            # die thickness in m

# r_m =  (k_mo / dm) + (1/htc)

t_surr = 500.0                                        # Surrounding temperature in K
# t_surr = h()

def kramp(temp,v1,v2,T_L,T_s):                                      # Function to calculate thermal conductivity in Mushy Zone
        slope = (v1-v2)/(T_L-T_S)
        if temp > T_L:
            k_m = k_l
        elif temp < T_S:
            k_m = k_s
        else:
            k_m = k_s + slope*(temp-T_S)
        return k_m

def cp_ramp(temp,v1,v2,T_L,T_s):                                    # Function to calculate specific heat capacity in Mushy Zone
    slope = (v1-v2)/(T_L-T_S)
    if temp > T_L:
        cp_m = cp_l
    elif temp < T_S:
        cp_m = cp_s
    else:
        cp_m = cp_s + slope*(temp-T_S)
    return cp_m

def rho_ramp(temp,v1,v2,T_L,T_s):                                       # Function to calculate density in Mushy Zone
    slope = (v1-v2)/(T_L-T_S)
    if temp > T_L:
        rho_m = rho_l
    elif temp < T_S:
        rho_m = rho_s
    else:
        rho_m = rho_s + slope*(temp-T_S)
    return rho_m

# %% [markdown]
# ### Solving the HT equation and phase change numerically

# %%
for m in range(1, num_steps+1):                                                                            # time loop
    htc = 10.0                   # htc of Still air in W/m^2-K
    q1 = htc*(temp_init[0]-t_surr)   # Heat flux at the left boundary
    
    # print(f"q1 is {q1}")
    temperature[0] = temp_init[0] + alpha_l * step_coeff * ((2.0*temp_init[1]) - (2.0 * temp_init[0])-(2.0*dx*(q1)))  # Update boundary condition temperature
    
    q2 = htc*(temp_init[-1]-t_surr)                   # Heat flux at the right boundary
    temperature[-1] = temp_init[-1] + alpha_l * step_coeff * ((2.0*temp_init[-2]) - (2.0 * temp_init[-1])-(2.0*dx*(q2)))  # Update boundary condition temperature
    
    for n in range(1,num_points+1):              # space loop, adjusted range
       
        if temperature[n] >= T_L:
            temperature[n] += ((alpha_l * step_coeff) * (temp_init[n+1] - (2.0 * temp_init[n]) + temp_init[n-1]))
            phase[n] = 0
            
            # print(f" Time-Step{m},Spatial point{n},Temperature{temperature[n]}")
        elif T_S < temperature[n] < T_L:
            
            k_m = kramp(temperature[n],k_l,k_s,T_L,T_S)
            cp_m = cp_ramp(temperature[n],cp_l,cp_s,T_L,T_S)
            rho_m = rho_ramp(temperature[n],rho_l,rho_s,T_L,T_S)
            m_eff =(k_m/(rho_m*(cp_m + (L_fusion/(T_L-T_S)))))
            
            temperature[n] += ((m_eff * step_coeff)* (temp_init[n+1] - (2.0 * temp_init[n]) + temp_init[n-1]))
            
            phase[n] = (T_L - temperature[n]) / (T_L - T_S)
            # print(m,n,temperature[n],phase[n])
         
        elif temperature[n]<T_S:
            temperature[n] += ((alpha_s * step_coeff) * (temp_init[n+1] - (2.0 * temp_init[n])+ temp_init[n-1]))
            phase[n] = 1
                     
        else:
            print("ERROR: should not be here")

     
          
    temperature = temperature.copy()                                                                # Update temperature
    phase = phase.copy()                                                                            # Update phase
    temp_init = temperature.copy()                                                                  # Update last time step temperature
    temperature_history.append(temperature.copy())                                                  # Append the temperature history to add ghost points
    phi_history.append(phase.copy())                                                                # Append the phase history to add ghost points
    midpoint_temperature_history.append(temperature[midpoint_index])                                # Store midpoint temperature
    
    
    # print(f"Step {m}, Temperature: {temperature}")
    


# print(midpoint_temperature_history)
#print(phi_history)

# %% [markdown]
# ### Plot the Results

# %%
# # Plot temperature history for debugging
# temperature_history_1 = np.array(temperature_history)
# print(temperature_history_1.shape)
# time_ss= np.linspace(0, time_end, num_steps+1)
# # print(time_ss.shape)
# plt.figure(figsize=(10, 6))
# plt.plot(time_ss, midpoint_temperature_history, label='Midpoint Temperature')
# plt.axhline(y=T_L, color='r', linestyle='--', label='Liquidus Temperature')
# plt.axhline(y=T_S, color='g', linestyle='--', label='Solidus Temperature')
# plt.xlabel('Time(s)')
# plt.ylabel('Temperature (K)')
# plt.title('Temperature Distribution Over Time at x = 7.5mm') 
# plt.legend()
# plt.show()

# %% [markdown]
# ### Data into Array

# %%
temperature_history = np.array(temperature_history)

phi_history = np.array(phi_history)

t_hist = np.array(temperature_history[:,1:-1])  # Remove ghost points
p_hist = np.array(phi_history[:,1:-1])
t_pde = t_hist[1:,1:-1]                # Remove initial condition and boundary condition
# t_pde = t_pde.flatten()
t_hist_init = t_hist[0,:]
t_hist_bc_l = t_hist[:,0]
t_hist_bc_r = t_hist[:,-1]

print(t_hist_init.shape)

scaler1 = StandardScaler()
t_hist_tr= scaler1.fit_transform(t_hist.reshape(-1,1)) # Normalize temperature history
t_pde_tr = scaler1.fit_transform(t_pde.reshape(-1,1)) # Normalize temperature PDE
t_hist_init_tr = scaler1.fit_transform(t_hist_init.reshape(-1,1)) # Normalize initial condition
t_hist_bc_l_tr = scaler1.fit_transform(t_hist_bc_l.reshape(-1,1)) # Normalize left boundary condition
t_hist_bc_r_tr = scaler1.fit_transform(t_hist_bc_r.reshape(-1,1)) # Normalize right boundary condition

print(t_hist_tr.shape,t_pde_tr.shape,t_hist_init_tr.shape,t_hist_bc_l_tr.shape,t_hist_bc_r_tr.shape)
# Out:
# (50,)
# (1573500, 1) (1510512, 1) (50, 1) (31470, 1) (31470, 1)

# %%
# Assuming you have temperature_history and phi_history as lists of arrays


# # Check the new shape after transposing
# print("Transposed Temperature History Shape:", temperature_history.shape)
# print("Transposed Phi History Shape:", phi_history.shape)

# # Create a meshgrid for space and time coordinates
# space_coord, time_coord = np.meshgrid(np.arange(temperature_history.shape[1]), np.arange(temperature_history.shape[0]))

# time_coord = time_coord * dt 
# # Create a figure with two subplots
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# # Plot the temperature history on the left subplot
# im1 = ax1.pcolormesh(space_coord, time_coord, temperature_history, cmap='viridis')
# ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
# ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
# ax1.set_title('Temperature Variation Over Time',fontname='Times New Roman', fontsize=20)
# fig.colorbar(im1, ax=ax1, label='Temperature')

# # Plot the phase history on the right subplot
# im2 = ax2.pcolormesh(space_coord, time_coord, phi_history, cmap='viridis')
# ax2.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=18)
# ax2.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
# ax2.set_title('Phase Variation Over Time',fontname='Times New Roman', fontsize=20)
# fig.colorbar(im2, ax=ax2, label='Phase')
# plt.tight_layout()
# plt.show()

# #plot the main
# fig, ax = plt.subplots(figsize=(14, 6))
# im = ax.pcolormesh(space_coord, time_coord, Dim_ny, cmap='viridis')
# ax.set_xlabel('Space Coordinate')
# ax.set_ylabel('Time')
# ax.set_title('Niyama Variation Over Time')
# fig.colorbar(im, ax=ax, label='Main')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## ML training

# %% [markdown]
# ### GPU/CPU check

# %%
# check for gpu
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Data preparation

# %%
space = np.linspace(0, length, num_points) # Spatial points
time = np.linspace(0, time_end, num_steps+1) # Time points
print(space.shape,time.shape)

space_pde = space[1:-1] # Spatial points 
time_pde = time[1:] # Time points
print(space_pde.shape,time_pde.shape)

sp_i = np.linspace(0, length, num_points) # Spatial points
time_i = np.zeros(num_points) # Time points
print(sp_i.shape,time_i.shape)
sp_b_l = np.zeros(num_steps+1) # Spatial points
time_b_l = np.linspace(0, time_end, num_steps+1) # Time points
print(sp_b_l.shape,time_b_l.shape)
sp_b_r = np.ones(num_steps+1)*length # Spatial points
time_b_r = np.linspace(0, time_end, num_steps+1) # Time points
print(sp_b_r[:5],time_b_r[:5])
# Out:
# (50,) (31470,)
# (48,) (31469,)
# (50,) (50,)
# (31470,) (31470,)
# [0.015 0.015 0.015 0.015 0.015] [0.         0.00127109 0.00254218 0.00381328 0.00508437]

# %%
scaler2 = StandardScaler()
inputs = input_gen(space,time,'mgrid')
inputs_pde = input_gen(space_pde,time_pde,'mgrid')
inputs_i = input_gen(sp_i,time_i,'scr')
inputs_b_l = input_gen(sp_b_l,time_b_l,'scr')
inputs_b_r = input_gen(sp_b_r,time_b_r,'scr')

inputs = scaler2.fit_transform(inputs)
inputs_pde = scaler2.fit_transform(inputs_pde)
inputs_init = scaler2.fit_transform(inputs_i)
inputs_b_l = scaler2.fit_transform(inputs_b_l)
inputs_b_r = scaler2.fit_transform(inputs_b_r)

# %%
print(inputs.shape,inputs_pde.shape,inputs_i.shape,inputs_b_l.shape,inputs_b_r.shape)
# Out:
# (1573500, 2) (1510512, 2) (50, 2) (31470, 2) (31470, 2)

# %%
# Convert the inputs to a tensor



inputs = torch.tensor(inputs).float().to(device)
inputs_pde = torch.tensor(inputs_pde).float().to(device)
inputs_init = torch.tensor(inputs_i).float().to(device) 
inputs_b_l = torch.tensor(inputs_b_l).float().to(device)
inputs_b_r = torch.tensor(inputs_b_r).float().to(device)


# print(inputs_init[:5,:])
# label/temp data to tensor
temp_tr = torch.tensor(t_hist_tr).float().to(device) # Convert the temperature history to a tensor
temp_inp = temp_tr.reshape(-1,1).float().to(device) # Reshape the temperature tensor to a column vector
temp_pde = torch.tensor(t_pde_tr).float().to(device) # Convert the temperature history to a tensor
temp_inp_init = torch.tensor(t_hist_init_tr).float().to(device) # Convert the temperature history to a tensor
temp_inp_bc_l = torch.tensor(t_hist_bc_l_tr).float().to(device)# Convert the temperature history to a tensor
temp_inp_bc_r = torch.tensor(t_hist_bc_r_tr).float().to(device)# Convert the temperature history to a tensor




#Data Splitting

# train_inputs, val_test_inputs, train_temp_inp, val_test_temp_inp = train_test_split(inputs, temp_inp, test_size=0.2, random_state=42)
# val_inputs, test_inputs, val_temp_inp, test_temp_inp = train_test_split(val_test_inputs, val_test_temp_inp, test_size=0.8, random_state=42)

train_inputs, test_inputs, train_temp_inp, test_temp_inp = train_test_split(inputs, temp_inp,test_size=0.2, random_state=42)
train_inputs_pde, test_inputs_pde, train_temp_inp_pde, test_temp_inp_pde = train_test_split(inputs_pde, temp_pde,\
                                                                                             test_size=0.2, random_state=42)
train_inputs_init, test_inputs_init, train_temp_inp_init, test_temp_inp_init = train_test_split(inputs_init, temp_inp_init, \
                                                                                                test_size=0.2, random_state=42)
train_inputs_bc_l, test_inputs_bc_l, train_temp_inp_bc_l, test_temp_inp_bc_l = train_test_split(inputs_b_l, temp_inp_bc_l, \
                                                                                                 test_size=0.2, random_state=42)
train_inputs_bc_r, test_inputs_bc_r, train_temp_inp_bc_r, test_temp_inp_bc_r = train_test_split(inputs_b_r, temp_inp_bc_r, \
                                                                                                test_size=0.2, random_state=42)

# print(train_inputs.shape, test_inputs.shape, train_temp_inp.shape, test_temp_inp.shape)

# %% [markdown]
# ### Create Data loader

# %%
class TensorDataset(torch.utils.data.Dataset):
    def __init__(self, inputs, temp_inp,transform=None, target_transform =None):
        self.inputs = inputs
        self.temp_inp = temp_inp

    def __getitem__(self, index):
        return self.inputs[index], self.temp_inp[index]
    
    def __len__(self):
        return len(self.inputs)

  
train_dataset = TensorDataset(train_inputs, train_temp_inp) # Create the training dataset
# val_dataset = TensorDataset(val_inputs, val_temp_inp) # Create the validation dataset
test_dataset = TensorDataset(test_inputs, test_temp_inp) # Create the test dataset

train_dataset_pde = TensorDataset(train_inputs_pde, train_temp_inp_pde) # Create the training dataset
test_dataset_pde = TensorDataset(test_inputs_pde, test_temp_inp_pde) # Create the test dataset

train_dataset_init = TensorDataset(train_inputs_init, train_temp_inp_init) # Create the training dataset
test_dataset_init = TensorDataset(test_inputs_init, test_temp_inp_init) # Create the test dataset
train_dataset_bc_l = TensorDataset(train_inputs_bc_l, train_temp_inp_bc_l) # Create the training dataset
test_dataset_bc_l = TensorDataset(test_inputs_bc_l, test_temp_inp_bc_l) # Create the test dataset
train_dataset_bc_r = TensorDataset(train_inputs_bc_r, train_temp_inp_bc_r) # Create the training dataset
test_dataset_bc_r = TensorDataset(test_inputs_bc_r, test_temp_inp_bc_r) # Create the test dataset


batch_size = 64
batch_size_s =100

random_sampler_train = RandomSampler(train_dataset, replacement=True, num_samples=batch_size_s) # Create a random sampler for the training dataset
# random_sampler_val = RandomSampler(val_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the validation dataset
random_sampler_test = RandomSampler(test_dataset, replacement=True, num_samples=batch_size_s) # Create a random sampler for the test dataset

random_sampler_train_pde = RandomSampler(train_dataset_pde, replacement=True, num_samples=batch_size_s) # Create a random sampler for the training dataset
random_sampler_test_pde = RandomSampler(test_dataset_pde, replacement=True, num_samples=batch_size_s) # Create a random sampler for the test dataset


random_sampler_train_init = RandomSampler(train_dataset_init, replacement=True, num_samples=50) # Create a random sampler for the training dataset
random_sampler_test_init = RandomSampler(test_dataset_init, replacement=True, num_samples=50) # Create a random sampler for the test dataset
random_sampler_train_bc_l = RandomSampler(train_dataset_bc_l, replacement=True, num_samples=batch_size_s) # Create a random sampler for the training dataset
random_sampler_test_bc_l = RandomSampler(test_dataset_bc_l, replacement=True, num_samples=batch_size_s) # Create a random sampler for the test dataset
random_sampler_train_bc_r = RandomSampler(train_dataset_bc_r, replacement=True, num_samples=batch_size_s) # Create a random sampler for the training dataset
random_sampler_test_bc_r = RandomSampler(test_dataset_bc_r, replacement=True, num_samples=batch_size_s) # Create a random sampler for the test dataset





train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=random_sampler_train) # Create the training dataloader
# val_loader = DataLoader(val_dataset, batch_size=batch_size, sampler=random_sampler_val) # Create the validation dataloader
test_loader = DataLoader(test_dataset, batch_size=batch_size, sampler=random_sampler_test) # Create the test dataloader

train_loader_pde = DataLoader(train_dataset_pde, batch_size=batch_size, sampler=random_sampler_train_pde) # Create the training dataloader
test_loader_pde = DataLoader(test_dataset_pde, batch_size=batch_size, sampler=random_sampler_test_pde) # Create the test dataloader

train_loader_init = DataLoader(train_dataset_init, batch_size=5, sampler=random_sampler_train_init) # Create the training dataloader
test_loader_init = DataLoader(test_dataset_init, batch_size=5, sampler=random_sampler_test_init) # Create the test dataloader
train_loader_bc_l = DataLoader(train_dataset_bc_l, batch_size=batch_size, sampler=random_sampler_train_bc_l) # Create the training dataloader
test_loader_bc_l = DataLoader(test_dataset_bc_l, batch_size=batch_size, sampler=random_sampler_test_bc_l) # Create the test dataloader
train_loader_bc_r = DataLoader(train_dataset_bc_r, batch_size=batch_size, sampler=random_sampler_train_bc_r) # Create the training dataloader
test_loader_bc_r = DataLoader(test_dataset_bc_r, batch_size=batch_size, sampler=random_sampler_test_bc_r) # Create the test dataloader

# %% [markdown]
# ### NN Architecture Definition

# %%
# Define the neural network architecture
class Mushydata(nn.Module):
    def __init__(self, input_size, hidden_size, output_size,hidden_layers,hidden_layers_2): # This is the constructor
        super(Mushydata, self).__init__()
        layers =[]

        layers.append(nn.Linear(input_size, hidden_size)) # First layer
        layers.append(nn.Tanh()) # Activation function

        for _ in range(hidden_layers):
            layers.append(nn.Linear(hidden_size, hidden_size))
            layers.append(nn.Tanh())

        for _ in range(hidden_layers_2):
            layers.append(nn.Linear(hidden_size, hidden_size))
            layers.append(nn.Tanh())

        layers.append(nn.Linear(hidden_size, output_size)) # Output layer
        self.base = nn.Sequential(*layers)
        
    def forward(self, x, t):                               # This is the forward pass
        input_features = torch.cat([x, t], dim=1)          # Concatenate the input features
        m = self.base(input_features)                                 # Pass through the third layer
        return m                    # Return the output of the network


# features = torch.rand(1, 2)
# model = HeatPINN(2, 20, 1)
# output = model(features[:, 0:1], features[:, 1:2])
# print(output)


# Loss function for data

# %% [markdown]
# ### Hyperparamters Init

# %%
# Hyperparameters
hidden_size = 50
learning_rate = 0.01
epochs = 5000
# alpha = 0.01  # Adjust this value based on your problem
# boundary_value = 313.0
# initial_value = init_temp
# Initialize the model
model = Mushydata(input_size=2, hidden_size=hidden_size,output_size=1,hidden_layers=5,hidden_layers_2=5).to(device)
lambd = 0.1

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Loss List Init

# %%
train_losses = []
val_losses = []
test_losses = []

print(f"Datatype of train_loader is {type(train_loader)}")

A = UPGrad()
# Out:
# Datatype of train_loader is <class 'torch.utils.data.dataloader.DataLoader'>

# %% [markdown]
# ### Loss functions

# %% [markdown]
# ### Training, Validation and Testing Module

# %%
def training_loop(epochs, model, loss_fn_data, optimizer, train_dataloader,train_loader_pde,\
                  test_dataloader,train_loader_init,\
                  train_loader_bc_l,train_loader_bc_r):
    train_losses = []  # Initialize the list to store the training losses
    # val_losses = []    # Initialize the list to store the validation losses
    test_losses = []   # Initialize the list to store the test losses
    data_losses = []   # Initialize the list to store the data losses
    pde_losses = []   # Initialize the list to store the PDE losses
    ic_losses = []   # Initialize the list to store the initial condition losses
    bc_losses = []   # Initialize the list to store the boundary condition losses

    for epoch in range(epochs):
        model.train()                                                                           # Set the model to training mode
        train_loss = 0                                                                              # Initialize the training loss
        data_loss = 0
        data_loss_b = 0
        phy_loss = 0
        init_loss = 0
      
        for (batch,batch_pde,batch_init,batch_left,batch_right) in \
             zip (train_dataloader,train_loader_pde,train_loader_init,train_loader_bc_l,\
                  train_loader_bc_r):                                                          # Loop through the training dataloader
            inputs, temp_inp= batch                                                             # Get the inputs and the true values
            inputs_pde, temp_inp_pde= batch_pde                                                             # Get the inputs and the true values
            inputs_init, temp_inp_init= batch_init                                                             # Get the inputs and the true values 
            inputs_left, temp_inp_left= batch_left                                                             # Get the inputs and the true values
            inputs_right, temp_inp_right= batch_right                                                             # Get the inputs and the true values

            inputs, temp_inp= inputs.to(device), temp_inp.to(device)                             # Move the inputs and true values to the GPU
            inputs_pde, temp_inp_pde= inputs_pde.to(device), temp_inp_pde.to(device)                             # Move the inputs and true values to the GPU
            inputs_init, temp_inp_init= inputs_init.to(device), temp_inp_init.to(device)                             # Move the initial condition inputs and temperature to the GPU
            inputs_left, temp_inp_left= inputs_left.to(device), temp_inp_left.to(device)                             # Move the left boundary condition inputs and temperature values to the GPU
            inputs_right, temp_inp_right= inputs_right.to(device), temp_inp_right.to(device)                             # Move the right boundary condition inputs and temperature values to the GPU
           
            # print(inputs[:5,:],temp_inp[:5,:])
            # print(inputs_pde[:5,:],temp_inp_pde[:5,:])
            # print(inputs_init[:5,:],temp_inp_init[:5,:])
            # print(inputs_left[:5],temp_inp_left[:5])
            # print(inputs_right[:5],temp_inp_right[:5])
            
            optimizer.zero_grad()                                                                    # Zero the gradients
            
            # Forward pass
            u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).to(device)                       # Get the predictions
            u_initl = model(inputs_init[:,0].unsqueeze(1), inputs_init[:,1].unsqueeze(1)).to(device)                       # Get the predictions
            
            u_left = model(inputs_b_l[:,0].unsqueeze(1), inputs_b_l[:,1].unsqueeze(1)).to(device)               # Left boundary of the temperature
            u_right = model(inputs_b_r[:,0].unsqueeze(1), inputs_b_r[:,1].unsqueeze(1)).to(device)             # Right boundary of the temperature

            # Loss calculation
            data_loss = loss_fn_data(u_pred, temp_inp)                                              # Calculate the data loss
            
            phy_loss = pde_loss(model,inputs[:,0].unsqueeze(1),inputs[:,1].unsqueeze(1))             # Calculate the PDE loss
            # pd_loss = 0
           
            init_loss = ic_loss(u_initl,temp_init) 
                                                             # Calculate initial condition loss
            # initc_loss =0                                                      # Calculate initial condition loss
            
            # bc_loss_left = boundary_loss(model,inputs_b_l[:,0].unsqueeze(1),inputs_b_l[:,1].unsqueeze(1),t_surr) # Calculate the left boundary condition loss
            # bc_loss_right = boundary_loss(model,inputs_b_r[:,0].unsqueeze(1),inputs_b_r[:,1].unsqueeze(1),t_surr) # Calculate the right boundary condition loss
            # bc_loss = bc_loss_left + bc_loss_right
            bc_loss = 0
            # l1_regularization_loss = l1_regularization(model, lambda_l1)                      # Calculate the L1 regularization loss
            # loss = data_loss  + pd_loss + initc_loss + bc_loss                                              # Calculate the total loss
            w0 = 1
            w1 = 0
            w2 = 1
            w3 = 0
            loss = w0*data_loss + w1* phy_loss + w2 *init_loss + w3* bc_loss
            # print(loss)
                                                                         # Calculate the total loss
            # Backpropagation
            loss.backward(retain_graph=True)                                                       # Backpropagate the gradients
            
            # torchjd.backward([data_loss,pd_loss], model.parameters(), A)

            optimizer.step()                                                                           # Update the weights
            
            train_loss += loss.item()                                                           # Add the loss to the training set loss  
            data_loss_b += data_loss.item()              
            phy_loss += phy_loss.item()
            init_loss += init_loss.item()
            # bc_losses.append(bc_loss.item())
        

        # model.eval()
        # test_loss = 0
        # test_accuracy = 0
        # with torch.no_grad():   
        #     for batch in test_dataloader:
        #         inputs, temp_inp= batch
        #         inputs, temp_inp= inputs.to(device), temp_inp.to(device)
        #         u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1))
        #         data_loss = loss_fn_data(u_pred, temp_inp)
        #         # l1_regularization_loss = l1_regularization(model, lambd)
        #         # loss = data_loss  + l1_regularization_loss
        #         loss = data_loss
        #         test_accuracy = accuracy(u_pred, temp_inp)
        #         test_loss += loss.item()
        #     test_losses.append(test_loss)
        
        train_losses.append(train_loss /len(train_dataloader))                                                   # Append the training loss to the list of training losses
        
        data_losses.append(data_loss /len(train_dataloader))                                                   # Append the training loss to the list of training losses
        pde_losses.append(phy_loss /len(train_loader_pde))                                                   # Append the training loss to the list of training losses
        ic_losses.append(init_loss /len(train_loader_init))                                                   # Append the training loss to the list of training losses
        # if epoch % 10 == 0:
        #     print(f"Epoch {epoch}, Training-Loss {train_loss:.4e}")
        
        model.eval()
        test_loss = 0
        
        # with torch.no_grad():   
        for batch in test_dataloader:
            inputs, temp_inp= batch
            inputs, temp_inp= inputs.to(device), temp_inp.to(device)
            u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1))
            data_loss_t = loss_fn_data(u_pred, temp_inp)
            # l1_regularization_loss = l1_regularization(model, lambd)
            # loss = data_loss  + l1_regularization_loss
            loss = data_loss_t
            test_accuracy = accuracy(u_pred, temp_inp)
            test_loss += loss.item()
        test_losses.append(test_loss)
        
        torch.cuda.empty_cache()
        
        if epoch % 10 == 0:
            print(f"| Epoch {epoch},            | Training-Loss {train_loss:.4e},| Test-Loss {test_loss:.4e}   |")
            print(f"--"*40)
            print(f"| Data-loss {data_loss:.4e},| pde-loss {phy_loss:.4e},        | initc-loss {init_loss:.4e},|bc_loss {bc_loss:.4e}|") 
    

    return train_losses, test_losses , pde_losses , bc_losses , ic_losses, data_losses                                                      # Return the training and validation losses

# %%
def test_loop(epochs, model, loss_fn_data, optimizer, train_dataloader, test_dataloader):
      
    model.eval()
    test_loss = 0
    test_accuracy = 0
    with torch.no_grad():   
        for batch in test_dataloader:
            inputs, temp_inp= batch
            inputs, temp_inp= inputs.to(device), temp_inp.to(device)
            u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1))
            data_loss = loss_fn_data(u_pred, temp_inp)
            # l1_regularization_loss = l1_regularization(model, lambd)
            # loss = data_loss  + l1_regularization_loss
            loss = data_loss
            test_accuracy = accuracy(u_pred, temp_inp)
            test_loss += loss.item()
        test_losses.append(test_loss)
    if epochs % 10 == 0:
        print(f"Epoch {epochs}, Test-Loss {test_loss:.4e}, Test-Accuracy {test_accuracy:.4e}")      
    return test_losses

# %% [markdown]
# ### Training Button

# %%
train_losses, test_losses, pde_losses, bc_losses,ic_losses, data_losses = training_loop(epochs, model, loss_fn_data, optimizer,train_loader,train_loader_pde,\
                    test_loader,train_loader_init,\
                  train_loader_bc_l,train_loader_bc_r)  # Train the model
 
# test_losses = test_loop(epochs, model, loss_fn_data, optimizer, train_loader, test_loader)  # Test the model
# Out:
# /home/student.unimelb.edu.au/rrammohan/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/autograd/graph.py:744: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at ../aten/src/ATen/cuda/CublasHandlePool.cpp:135.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# | Epoch 0,            | Training-Loss 1.0489e+06,| Test-Loss 4.9663e+00   |
# --------------------------------------------------------------------------------
# | Data-loss 9.7839e-01,| pde-loss 3.9483e-06,        | initc-loss 1.0484e+06,|bc_loss 0.0000e+00|
# | Epoch 10,            | Training-Loss 1.0138e+06,| Test-Loss 3.6595e+02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.5912e+02,| pde-loss 5.8081e-25,        | initc-loss 1.0127e+06,|bc_loss 0.0000e+00|
# | Epoch 20,            | Training-Loss 9.8444e+05,| Test-Loss 1.1614e+03   |
# --------------------------------------------------------------------------------
# | Data-loss 5.6344e+02,| pde-loss 1.2915e-26,        | initc-loss 9.8260e+05,|bc_loss 0.0000e+00|
# | Epoch 30,            | Training-Loss 9.5665e+05,| Test-Loss 2.3906e+03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1586e+03,| pde-loss 1.1793e-26,        | initc-loss 9.5367e+05,|bc_loss 0.0000e+00|
# | Epoch 40,            | Training-Loss 9.3043e+05,| Test-Loss 4.0180e+03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.9424e+03,| pde-loss 1.1621e-26,        | initc-loss 9.2590e+05,|bc_loss 0.0000e+00|
# | Epoch 50,            | Training-Loss 9.0559e+05,| Test-Loss 5.9060e+03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.9169e+03,| pde-loss 9.3159e-27,        | initc-loss 8.9916e+05,|bc_loss 0.0000e+00|
# | Epoch 60,            | Training-Loss 8.8205e+05,| Test-Loss 8.2296e+03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.0612e+03,| pde-loss 5.9898e-27,        | initc-loss 8.7335e+05,|bc_loss 0.0000e+00|
# | Epoch 70,            | Training-Loss 8.5968e+05,| Test-Loss 1.0871e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 5.3794e+03,| pde-loss 4.7946e-27,        | initc-loss 8.4840e+05,|bc_loss 0.0000e+00|
# | Epoch 80,            | Training-Loss 8.3841e+05,| Test-Loss 1.3718e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 6.7887e+03,| pde-loss 2.5155e-27,        | initc-loss 8.2428e+05,|bc_loss 0.0000e+00|
# | Epoch 90,            | Training-Loss 8.1822e+05,| Test-Loss 1.7001e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 8.3705e+03,| pde-loss 1.3557e-27,        | initc-loss 8.0096e+05,|bc_loss 0.0000e+00|
# | Epoch 100,            | Training-Loss 7.9906e+05,| Test-Loss 2.0437e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0060e+04,| pde-loss 1.0471e-27,        | initc-loss 7.7840e+05,|bc_loss 0.0000e+00|
# | Epoch 110,            | Training-Loss 7.8099e+05,| Test-Loss 2.4125e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2007e+04,| pde-loss 9.2085e-28,        | initc-loss 7.5658e+05,|bc_loss 0.0000e+00|
# | Epoch 120,            | Training-Loss 7.6382e+05,| Test-Loss 2.8049e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3973e+04,| pde-loss 8.0551e-28,        | initc-loss 7.3549e+05,|bc_loss 0.0000e+00|
# | Epoch 130,            | Training-Loss 7.4752e+05,| Test-Loss 3.2141e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 1.6009e+04,| pde-loss 5.5335e-28,        | initc-loss 7.1510e+05,|bc_loss 0.0000e+00|
# | Epoch 140,            | Training-Loss 7.3200e+05,| Test-Loss 3.6505e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 1.8068e+04,| pde-loss 4.0491e-28,        | initc-loss 6.9539e+05,|bc_loss 0.0000e+00|
# | Epoch 150,            | Training-Loss 7.1764e+05,| Test-Loss 4.1052e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 2.0496e+04,| pde-loss 3.6840e-28,        | initc-loss 6.7636e+05,|bc_loss 0.0000e+00|
# | Epoch 160,            | Training-Loss 7.0380e+05,| Test-Loss 4.5759e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 2.2721e+04,| pde-loss 2.5524e-28,        | initc-loss 6.5797e+05,|bc_loss 0.0000e+00|
# | Epoch 170,            | Training-Loss 6.9091e+05,| Test-Loss 5.0504e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 2.5168e+04,| pde-loss 2.5143e-28,        | initc-loss 6.4023e+05,|bc_loss 0.0000e+00|
# | Epoch 180,            | Training-Loss 6.7875e+05,| Test-Loss 5.5633e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 2.7685e+04,| pde-loss 1.8817e-28,        | initc-loss 6.2310e+05,|bc_loss 0.0000e+00|
# | Epoch 190,            | Training-Loss 6.6725e+05,| Test-Loss 6.0663e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 3.0220e+04,| pde-loss 1.6542e-28,        | initc-loss 6.0658e+05,|bc_loss 0.0000e+00|
# | Epoch 200,            | Training-Loss 6.5632e+05,| Test-Loss 6.5989e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 3.2689e+04,| pde-loss 1.3151e-28,        | initc-loss 5.9066e+05,|bc_loss 0.0000e+00|
# | Epoch 210,            | Training-Loss 6.4633e+05,| Test-Loss 7.0912e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 3.5390e+04,| pde-loss 1.1555e-28,        | initc-loss 5.7530e+05,|bc_loss 0.0000e+00|
# | Epoch 220,            | Training-Loss 6.3686e+05,| Test-Loss 7.6458e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 3.8069e+04,| pde-loss 8.2378e-29,        | initc-loss 5.6051e+05,|bc_loss 0.0000e+00|
# | Epoch 230,            | Training-Loss 6.2786e+05,| Test-Loss 8.1651e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 4.0635e+04,| pde-loss 9.2886e-29,        | initc-loss 5.4627e+05,|bc_loss 0.0000e+00|
# | Epoch 240,            | Training-Loss 6.1961e+05,| Test-Loss 8.7189e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 4.3405e+04,| pde-loss 4.6314e-29,        | initc-loss 5.3256e+05,|bc_loss 0.0000e+00|
# | Epoch 250,            | Training-Loss 6.1186e+05,| Test-Loss 9.2592e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 4.6158e+04,| pde-loss 6.1038e-29,        | initc-loss 5.1938e+05,|bc_loss 0.0000e+00|
# | Epoch 260,            | Training-Loss 6.0459e+05,| Test-Loss 9.7979e+04   |
# --------------------------------------------------------------------------------
# | Data-loss 4.8895e+04,| pde-loss 5.9686e-29,        | initc-loss 5.0670e+05,|bc_loss 0.0000e+00|
# | Epoch 270,            | Training-Loss 5.9799e+05,| Test-Loss 1.0361e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 5.1620e+04,| pde-loss 5.2389e-29,        | initc-loss 4.9451e+05,|bc_loss 0.0000e+00|
# | Epoch 280,            | Training-Loss 5.9158e+05,| Test-Loss 1.0890e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 5.4315e+04,| pde-loss 5.0377e-29,        | initc-loss 4.8281e+05,|bc_loss 0.0000e+00|
# | Epoch 290,            | Training-Loss 5.8581e+05,| Test-Loss 1.1461e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 5.7085e+04,| pde-loss 3.9773e-29,        | initc-loss 4.7157e+05,|bc_loss 0.0000e+00|
# | Epoch 300,            | Training-Loss 5.8044e+05,| Test-Loss 1.1986e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 5.9809e+04,| pde-loss 3.6433e-29,        | initc-loss 4.6079e+05,|bc_loss 0.0000e+00|
# | Epoch 310,            | Training-Loss 5.7541e+05,| Test-Loss 1.2528e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 6.2412e+04,| pde-loss 2.5032e-29,        | initc-loss 4.5045e+05,|bc_loss 0.0000e+00|
# | Epoch 320,            | Training-Loss 5.7077e+05,| Test-Loss 1.3031e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 6.5010e+04,| pde-loss 3.3936e-29,        | initc-loss 4.4053e+05,|bc_loss 0.0000e+00|
# | Epoch 330,            | Training-Loss 5.6643e+05,| Test-Loss 1.3556e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 6.7629e+04,| pde-loss 3.0427e-29,        | initc-loss 4.3104e+05,|bc_loss 0.0000e+00|
# | Epoch 340,            | Training-Loss 5.6256e+05,| Test-Loss 1.4095e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 7.0168e+04,| pde-loss 2.2339e-29,        | initc-loss 4.2195e+05,|bc_loss 0.0000e+00|
# | Epoch 350,            | Training-Loss 5.5920e+05,| Test-Loss 1.4580e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 7.2950e+04,| pde-loss 3.1482e-29,        | initc-loss 4.1325e+05,|bc_loss 0.0000e+00|
# | Epoch 360,            | Training-Loss 5.5578e+05,| Test-Loss 1.5089e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 7.5390e+04,| pde-loss 3.1466e-29,        | initc-loss 4.0493e+05,|bc_loss 0.0000e+00|
# | Epoch 370,            | Training-Loss 5.5273e+05,| Test-Loss 1.5596e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 7.7789e+04,| pde-loss 2.2382e-29,        | initc-loss 3.9698e+05,|bc_loss 0.0000e+00|
# | Epoch 380,            | Training-Loss 5.4998e+05,| Test-Loss 1.6073e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 8.0275e+04,| pde-loss 2.1999e-29,        | initc-loss 3.8938e+05,|bc_loss 0.0000e+00|
# | Epoch 390,            | Training-Loss 5.4709e+05,| Test-Loss 1.6533e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 8.2409e+04,| pde-loss 1.4162e-29,        | initc-loss 3.8214e+05,|bc_loss 0.0000e+00|
# | Epoch 400,            | Training-Loss 5.4501e+05,| Test-Loss 1.6992e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 8.4835e+04,| pde-loss 1.9779e-29,        | initc-loss 3.7522e+05,|bc_loss 0.0000e+00|
# | Epoch 410,            | Training-Loss 5.4290e+05,| Test-Loss 1.7431e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 8.7115e+04,| pde-loss 1.7859e-29,        | initc-loss 3.6863e+05,|bc_loss 0.0000e+00|
# | Epoch 420,            | Training-Loss 5.4101e+05,| Test-Loss 1.7898e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 8.9177e+04,| pde-loss 1.4690e-29,        | initc-loss 3.6235e+05,|bc_loss 0.0000e+00|
# | Epoch 430,            | Training-Loss 5.3924e+05,| Test-Loss 1.8308e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 9.1434e+04,| pde-loss 1.6455e-29,        | initc-loss 3.5638e+05,|bc_loss 0.0000e+00|
# | Epoch 440,            | Training-Loss 5.3776e+05,| Test-Loss 1.8720e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 9.3580e+04,| pde-loss 1.8459e-29,        | initc-loss 3.5069e+05,|bc_loss 0.0000e+00|
# | Epoch 450,            | Training-Loss 5.3594e+05,| Test-Loss 1.9124e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 9.5215e+04,| pde-loss 1.5102e-29,        | initc-loss 3.4529e+05,|bc_loss 0.0000e+00|
# | Epoch 460,            | Training-Loss 5.3478e+05,| Test-Loss 1.9504e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 9.7243e+04,| pde-loss 1.5832e-29,        | initc-loss 3.4016e+05,|bc_loss 0.0000e+00|
# | Epoch 470,            | Training-Loss 5.3387e+05,| Test-Loss 1.9865e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 9.9383e+04,| pde-loss 1.5001e-29,        | initc-loss 3.3528e+05,|bc_loss 0.0000e+00|
# | Epoch 480,            | Training-Loss 5.3274e+05,| Test-Loss 2.0222e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0114e+05,| pde-loss 1.6348e-29,        | initc-loss 3.3066e+05,|bc_loss 0.0000e+00|
# | Epoch 490,            | Training-Loss 5.3159e+05,| Test-Loss 2.0560e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0269e+05,| pde-loss 1.5038e-29,        | initc-loss 3.2628e+05,|bc_loss 0.0000e+00|
# | Epoch 500,            | Training-Loss 5.3090e+05,| Test-Loss 2.0881e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0435e+05,| pde-loss 1.1809e-29,        | initc-loss 3.2213e+05,|bc_loss 0.0000e+00|
# | Epoch 510,            | Training-Loss 5.3015e+05,| Test-Loss 2.1239e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0597e+05,| pde-loss 9.7452e-30,        | initc-loss 3.1820e+05,|bc_loss 0.0000e+00|
# | Epoch 520,            | Training-Loss 5.2935e+05,| Test-Loss 2.1543e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0739e+05,| pde-loss 1.3044e-29,        | initc-loss 3.1449e+05,|bc_loss 0.0000e+00|
# | Epoch 530,            | Training-Loss 5.2916e+05,| Test-Loss 2.1815e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0903e+05,| pde-loss 1.4384e-29,        | initc-loss 3.1098e+05,|bc_loss 0.0000e+00|
# | Epoch 540,            | Training-Loss 5.2849e+05,| Test-Loss 2.2066e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1027e+05,| pde-loss 1.2334e-29,        | initc-loss 3.0767e+05,|bc_loss 0.0000e+00|
# | Epoch 550,            | Training-Loss 5.2790e+05,| Test-Loss 2.2386e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1162e+05,| pde-loss 8.1535e-30,        | initc-loss 3.0455e+05,|bc_loss 0.0000e+00|
# | Epoch 560,            | Training-Loss 5.2754e+05,| Test-Loss 2.2622e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1297e+05,| pde-loss 1.0970e-29,        | initc-loss 3.0160e+05,|bc_loss 0.0000e+00|
# | Epoch 570,            | Training-Loss 5.2697e+05,| Test-Loss 2.2852e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1413e+05,| pde-loss 8.7418e-30,        | initc-loss 2.9883e+05,|bc_loss 0.0000e+00|
# | Epoch 580,            | Training-Loss 5.2679e+05,| Test-Loss 2.3075e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1508e+05,| pde-loss 1.1812e-29,        | initc-loss 2.9623e+05,|bc_loss 0.0000e+00|
# | Epoch 590,            | Training-Loss 5.2651e+05,| Test-Loss 2.3279e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1638e+05,| pde-loss 9.9639e-30,        | initc-loss 2.9378e+05,|bc_loss 0.0000e+00|
# | Epoch 600,            | Training-Loss 5.2653e+05,| Test-Loss 2.3506e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1756e+05,| pde-loss 1.2570e-29,        | initc-loss 2.9147e+05,|bc_loss 0.0000e+00|
# | Epoch 610,            | Training-Loss 5.2621e+05,| Test-Loss 2.3700e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1838e+05,| pde-loss 1.0065e-29,        | initc-loss 2.8932e+05,|bc_loss 0.0000e+00|
# | Epoch 620,            | Training-Loss 5.2574e+05,| Test-Loss 2.3872e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1931e+05,| pde-loss 7.8331e-30,        | initc-loss 2.8729e+05,|bc_loss 0.0000e+00|
# | Epoch 630,            | Training-Loss 5.2586e+05,| Test-Loss 2.4056e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2022e+05,| pde-loss 1.2129e-29,        | initc-loss 2.8540e+05,|bc_loss 0.0000e+00|
# | Epoch 640,            | Training-Loss 5.2578e+05,| Test-Loss 2.4235e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2118e+05,| pde-loss 1.0835e-29,        | initc-loss 2.8363e+05,|bc_loss 0.0000e+00|
# | Epoch 650,            | Training-Loss 5.2555e+05,| Test-Loss 2.4374e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2178e+05,| pde-loss 1.1406e-29,        | initc-loss 2.8198e+05,|bc_loss 0.0000e+00|
# | Epoch 660,            | Training-Loss 5.2554e+05,| Test-Loss 2.4502e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2249e+05,| pde-loss 9.2763e-30,        | initc-loss 2.8043e+05,|bc_loss 0.0000e+00|
# | Epoch 670,            | Training-Loss 5.2511e+05,| Test-Loss 2.4642e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2290e+05,| pde-loss 9.2552e-30,        | initc-loss 2.7899e+05,|bc_loss 0.0000e+00|
# | Epoch 680,            | Training-Loss 5.2521e+05,| Test-Loss 2.4762e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2366e+05,| pde-loss 8.5223e-30,        | initc-loss 2.7765e+05,|bc_loss 0.0000e+00|
# | Epoch 690,            | Training-Loss 5.2526e+05,| Test-Loss 2.4886e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2443e+05,| pde-loss 1.2046e-29,        | initc-loss 2.7640e+05,|bc_loss 0.0000e+00|
# | Epoch 700,            | Training-Loss 5.2522e+05,| Test-Loss 2.5004e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2512e+05,| pde-loss 1.3223e-29,        | initc-loss 2.7525e+05,|bc_loss 0.0000e+00|
# | Epoch 710,            | Training-Loss 5.2513e+05,| Test-Loss 2.5080e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2554e+05,| pde-loss 1.1450e-29,        | initc-loss 2.7417e+05,|bc_loss 0.0000e+00|
# | Epoch 720,            | Training-Loss 5.2498e+05,| Test-Loss 2.5191e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2592e+05,| pde-loss 7.3351e-30,        | initc-loss 2.7317e+05,|bc_loss 0.0000e+00|
# | Epoch 730,            | Training-Loss 5.2473e+05,| Test-Loss 2.5280e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2608e+05,| pde-loss 1.0144e-29,        | initc-loss 2.7225e+05,|bc_loss 0.0000e+00|
# | Epoch 740,            | Training-Loss 5.2498e+05,| Test-Loss 2.5353e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2675e+05,| pde-loss 9.9382e-30,        | initc-loss 2.7139e+05,|bc_loss 0.0000e+00|
# | Epoch 750,            | Training-Loss 5.2503e+05,| Test-Loss 2.5444e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2725e+05,| pde-loss 9.5684e-30,        | initc-loss 2.7060e+05,|bc_loss 0.0000e+00|
# | Epoch 760,            | Training-Loss 5.2509e+05,| Test-Loss 2.5501e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2765e+05,| pde-loss 1.2231e-29,        | initc-loss 2.6987e+05,|bc_loss 0.0000e+00|
# | Epoch 770,            | Training-Loss 5.2488e+05,| Test-Loss 2.5572e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2789e+05,| pde-loss 1.0060e-29,        | initc-loss 2.6920e+05,|bc_loss 0.0000e+00|
# | Epoch 780,            | Training-Loss 5.2500e+05,| Test-Loss 2.5602e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2823e+05,| pde-loss 9.6319e-30,        | initc-loss 2.6858e+05,|bc_loss 0.0000e+00|
# | Epoch 790,            | Training-Loss 5.2470e+05,| Test-Loss 2.5686e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2835e+05,| pde-loss 9.5025e-30,        | initc-loss 2.6801e+05,|bc_loss 0.0000e+00|
# | Epoch 800,            | Training-Loss 5.2485e+05,| Test-Loss 2.5745e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2869e+05,| pde-loss 8.8863e-30,        | initc-loss 2.6749e+05,|bc_loss 0.0000e+00|
# | Epoch 810,            | Training-Loss 5.2480e+05,| Test-Loss 2.5816e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2886e+05,| pde-loss 8.7897e-30,        | initc-loss 2.6701e+05,|bc_loss 0.0000e+00|
# | Epoch 820,            | Training-Loss 5.2460e+05,| Test-Loss 2.5835e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2906e+05,| pde-loss 7.7556e-30,        | initc-loss 2.6657e+05,|bc_loss 0.0000e+00|
# | Epoch 830,            | Training-Loss 5.2470e+05,| Test-Loss 2.5864e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2924e+05,| pde-loss 1.1074e-29,        | initc-loss 2.6616e+05,|bc_loss 0.0000e+00|
# | Epoch 840,            | Training-Loss 5.2481e+05,| Test-Loss 2.5890e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2940e+05,| pde-loss 9.7893e-30,        | initc-loss 2.6580e+05,|bc_loss 0.0000e+00|
# | Epoch 850,            | Training-Loss 5.2478e+05,| Test-Loss 2.5932e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2965e+05,| pde-loss 9.3993e-30,        | initc-loss 2.6546e+05,|bc_loss 0.0000e+00|
# | Epoch 860,            | Training-Loss 5.2483e+05,| Test-Loss 2.5990e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2990e+05,| pde-loss 1.0118e-29,        | initc-loss 2.6516e+05,|bc_loss 0.0000e+00|
# | Epoch 870,            | Training-Loss 5.2494e+05,| Test-Loss 2.6009e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3001e+05,| pde-loss 8.7702e-30,        | initc-loss 2.6488e+05,|bc_loss 0.0000e+00|
# | Epoch 880,            | Training-Loss 5.2516e+05,| Test-Loss 2.5999e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3020e+05,| pde-loss 1.1712e-29,        | initc-loss 2.6462e+05,|bc_loss 0.0000e+00|
# | Epoch 890,            | Training-Loss 5.2489e+05,| Test-Loss 2.6041e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3026e+05,| pde-loss 1.1823e-29,        | initc-loss 2.6440e+05,|bc_loss 0.0000e+00|
# | Epoch 900,            | Training-Loss 5.2494e+05,| Test-Loss 2.6080e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3051e+05,| pde-loss 1.0359e-29,        | initc-loss 2.6419e+05,|bc_loss 0.0000e+00|
# | Epoch 910,            | Training-Loss 5.2460e+05,| Test-Loss 2.6097e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3021e+05,| pde-loss 6.2017e-30,        | initc-loss 2.6400e+05,|bc_loss 0.0000e+00|
# | Epoch 920,            | Training-Loss 5.2488e+05,| Test-Loss 2.6109e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3056e+05,| pde-loss 9.7071e-30,        | initc-loss 2.6383e+05,|bc_loss 0.0000e+00|
# | Epoch 930,            | Training-Loss 5.2465e+05,| Test-Loss 2.6110e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3053e+05,| pde-loss 8.4380e-30,        | initc-loss 2.6367e+05,|bc_loss 0.0000e+00|
# | Epoch 940,            | Training-Loss 5.2483e+05,| Test-Loss 2.6103e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3065e+05,| pde-loss 1.1448e-29,        | initc-loss 2.6352e+05,|bc_loss 0.0000e+00|
# | Epoch 950,            | Training-Loss 5.2488e+05,| Test-Loss 2.6142e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3073e+05,| pde-loss 1.0055e-29,        | initc-loss 2.6340e+05,|bc_loss 0.0000e+00|
# | Epoch 960,            | Training-Loss 5.2478e+05,| Test-Loss 2.6163e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3072e+05,| pde-loss 7.7336e-30,        | initc-loss 2.6328e+05,|bc_loss 0.0000e+00|
# | Epoch 970,            | Training-Loss 5.2484e+05,| Test-Loss 2.6169e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3080e+05,| pde-loss 8.2832e-30,        | initc-loss 2.6318e+05,|bc_loss 0.0000e+00|
# | Epoch 980,            | Training-Loss 5.2507e+05,| Test-Loss 2.6166e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3100e+05,| pde-loss 8.0249e-30,        | initc-loss 2.6309e+05,|bc_loss 0.0000e+00|
# | Epoch 990,            | Training-Loss 5.2495e+05,| Test-Loss 2.6187e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3116e+05,| pde-loss 1.2005e-29,        | initc-loss 2.6301e+05,|bc_loss 0.0000e+00|
# | Epoch 1000,            | Training-Loss 5.2479e+05,| Test-Loss 2.6152e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3083e+05,| pde-loss 7.6283e-30,        | initc-loss 2.6295e+05,|bc_loss 0.0000e+00|
# | Epoch 1010,            | Training-Loss 5.2486e+05,| Test-Loss 2.6179e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3096e+05,| pde-loss 9.8682e-30,        | initc-loss 2.6288e+05,|bc_loss 0.0000e+00|
# | Epoch 1020,            | Training-Loss 5.2465e+05,| Test-Loss 2.6184e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3082e+05,| pde-loss 8.2341e-30,        | initc-loss 2.6283e+05,|bc_loss 0.0000e+00|
# | Epoch 1030,            | Training-Loss 5.2468e+05,| Test-Loss 2.6217e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3088e+05,| pde-loss 7.4524e-30,        | initc-loss 2.6278e+05,|bc_loss 0.0000e+00|
# | Epoch 1040,            | Training-Loss 5.2456e+05,| Test-Loss 2.6218e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3082e+05,| pde-loss 6.7672e-30,        | initc-loss 2.6274e+05,|bc_loss 0.0000e+00|
# | Epoch 1050,            | Training-Loss 5.2471e+05,| Test-Loss 2.6207e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3099e+05,| pde-loss 8.5888e-30,        | initc-loss 2.6270e+05,|bc_loss 0.0000e+00|
# | Epoch 1060,            | Training-Loss 5.2515e+05,| Test-Loss 2.6224e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3113e+05,| pde-loss 9.3051e-30,        | initc-loss 2.6267e+05,|bc_loss 0.0000e+00|
# | Epoch 1070,            | Training-Loss 5.2492e+05,| Test-Loss 2.6234e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3112e+05,| pde-loss 9.1651e-30,        | initc-loss 2.6264e+05,|bc_loss 0.0000e+00|
# | Epoch 1080,            | Training-Loss 5.2480e+05,| Test-Loss 2.6245e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3100e+05,| pde-loss 6.6991e-30,        | initc-loss 2.6261e+05,|bc_loss 0.0000e+00|
# | Epoch 1090,            | Training-Loss 5.2491e+05,| Test-Loss 2.6247e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3112e+05,| pde-loss 8.2119e-30,        | initc-loss 2.6259e+05,|bc_loss 0.0000e+00|
# | Epoch 1100,            | Training-Loss 5.2487e+05,| Test-Loss 2.6239e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3112e+05,| pde-loss 7.6471e-30,        | initc-loss 2.6257e+05,|bc_loss 0.0000e+00|
# | Epoch 1110,            | Training-Loss 5.2492e+05,| Test-Loss 2.6229e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3121e+05,| pde-loss 1.1587e-29,        | initc-loss 2.6255e+05,|bc_loss 0.0000e+00|
# | Epoch 1120,            | Training-Loss 5.2485e+05,| Test-Loss 2.6227e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3124e+05,| pde-loss 1.1532e-29,        | initc-loss 2.6254e+05,|bc_loss 0.0000e+00|
# | Epoch 1130,            | Training-Loss 5.2494e+05,| Test-Loss 2.6247e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3121e+05,| pde-loss 9.3673e-30,        | initc-loss 2.6252e+05,|bc_loss 0.0000e+00|
# | Epoch 1140,            | Training-Loss 5.2483e+05,| Test-Loss 2.6224e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3122e+05,| pde-loss 8.3290e-30,        | initc-loss 2.6251e+05,|bc_loss 0.0000e+00|
# | Epoch 1150,            | Training-Loss 5.2478e+05,| Test-Loss 2.6230e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3114e+05,| pde-loss 1.0229e-29,        | initc-loss 2.6250e+05,|bc_loss 0.0000e+00|
# | Epoch 1160,            | Training-Loss 5.2496e+05,| Test-Loss 2.6219e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3120e+05,| pde-loss 7.6619e-30,        | initc-loss 2.6248e+05,|bc_loss 0.0000e+00|
# | Epoch 1170,            | Training-Loss 5.2479e+05,| Test-Loss 2.6230e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3111e+05,| pde-loss 1.1520e-29,        | initc-loss 2.6247e+05,|bc_loss 0.0000e+00|
# | Epoch 1180,            | Training-Loss 5.2470e+05,| Test-Loss 2.6243e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3120e+05,| pde-loss 1.1934e-29,        | initc-loss 2.6246e+05,|bc_loss 0.0000e+00|
# | Epoch 1190,            | Training-Loss 5.2484e+05,| Test-Loss 2.6276e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3116e+05,| pde-loss 1.0999e-29,        | initc-loss 2.6245e+05,|bc_loss 0.0000e+00|
# | Epoch 1200,            | Training-Loss 5.2496e+05,| Test-Loss 2.6235e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3118e+05,| pde-loss 1.0871e-29,        | initc-loss 2.6245e+05,|bc_loss 0.0000e+00|
# | Epoch 1210,            | Training-Loss 5.2512e+05,| Test-Loss 2.6245e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3138e+05,| pde-loss 1.0517e-29,        | initc-loss 2.6244e+05,|bc_loss 0.0000e+00|
# | Epoch 1220,            | Training-Loss 5.2499e+05,| Test-Loss 2.6253e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3134e+05,| pde-loss 9.9289e-30,        | initc-loss 2.6244e+05,|bc_loss 0.0000e+00|
# | Epoch 1230,            | Training-Loss 5.2465e+05,| Test-Loss 2.6259e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3115e+05,| pde-loss 8.8784e-30,        | initc-loss 2.6244e+05,|bc_loss 0.0000e+00|
# | Epoch 1240,            | Training-Loss 5.2475e+05,| Test-Loss 2.6263e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3123e+05,| pde-loss 8.8724e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1250,            | Training-Loss 5.2483e+05,| Test-Loss 2.6245e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3118e+05,| pde-loss 1.2169e-29,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1260,            | Training-Loss 5.2487e+05,| Test-Loss 2.6233e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3125e+05,| pde-loss 9.1680e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1270,            | Training-Loss 5.2490e+05,| Test-Loss 2.6236e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3130e+05,| pde-loss 9.9803e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1280,            | Training-Loss 5.2490e+05,| Test-Loss 2.6246e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3132e+05,| pde-loss 1.1154e-29,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1290,            | Training-Loss 5.2474e+05,| Test-Loss 2.6215e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3110e+05,| pde-loss 8.1987e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1300,            | Training-Loss 5.2500e+05,| Test-Loss 2.6231e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3122e+05,| pde-loss 8.7496e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1310,            | Training-Loss 5.2449e+05,| Test-Loss 2.6235e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3094e+05,| pde-loss 5.0047e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1320,            | Training-Loss 5.2511e+05,| Test-Loss 2.6241e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3141e+05,| pde-loss 1.0373e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1330,            | Training-Loss 5.2499e+05,| Test-Loss 2.6258e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3133e+05,| pde-loss 1.0538e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1340,            | Training-Loss 5.2470e+05,| Test-Loss 2.6205e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3109e+05,| pde-loss 9.5165e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1350,            | Training-Loss 5.2497e+05,| Test-Loss 2.6250e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3134e+05,| pde-loss 1.0798e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1360,            | Training-Loss 5.2494e+05,| Test-Loss 2.6211e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3131e+05,| pde-loss 9.5520e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1370,            | Training-Loss 5.2506e+05,| Test-Loss 2.6255e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3134e+05,| pde-loss 1.2408e-29,        | initc-loss 2.6241e+05,|bc_loss 0.0000e+00|
# | Epoch 1380,            | Training-Loss 5.2503e+05,| Test-Loss 2.6244e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3140e+05,| pde-loss 9.4945e-30,        | initc-loss 2.6241e+05,|bc_loss 0.0000e+00|
# | Epoch 1390,            | Training-Loss 5.2468e+05,| Test-Loss 2.6261e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3106e+05,| pde-loss 1.2031e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1400,            | Training-Loss 5.2497e+05,| Test-Loss 2.6264e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3146e+05,| pde-loss 1.3185e-29,        | initc-loss 2.6241e+05,|bc_loss 0.0000e+00|
# | Epoch 1410,            | Training-Loss 5.2444e+05,| Test-Loss 2.6260e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3087e+05,| pde-loss 9.5327e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1420,            | Training-Loss 5.2497e+05,| Test-Loss 2.6250e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3130e+05,| pde-loss 9.2554e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1430,            | Training-Loss 5.2470e+05,| Test-Loss 2.6265e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3111e+05,| pde-loss 1.0235e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1440,            | Training-Loss 5.2486e+05,| Test-Loss 2.6237e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3126e+05,| pde-loss 1.1445e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1450,            | Training-Loss 5.2469e+05,| Test-Loss 2.6252e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3112e+05,| pde-loss 8.9833e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1460,            | Training-Loss 5.2495e+05,| Test-Loss 2.6239e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3116e+05,| pde-loss 9.7069e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1470,            | Training-Loss 5.2490e+05,| Test-Loss 2.6220e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3129e+05,| pde-loss 9.3799e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1480,            | Training-Loss 5.2497e+05,| Test-Loss 2.6219e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3131e+05,| pde-loss 7.8750e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1490,            | Training-Loss 5.2468e+05,| Test-Loss 2.6253e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3104e+05,| pde-loss 8.3175e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1500,            | Training-Loss 5.2506e+05,| Test-Loss 2.6233e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3127e+05,| pde-loss 9.1105e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1510,            | Training-Loss 5.2463e+05,| Test-Loss 2.6265e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3106e+05,| pde-loss 8.6485e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1520,            | Training-Loss 5.2478e+05,| Test-Loss 2.6248e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3113e+05,| pde-loss 9.2311e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1530,            | Training-Loss 5.2473e+05,| Test-Loss 2.6213e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3124e+05,| pde-loss 7.7531e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1540,            | Training-Loss 5.2464e+05,| Test-Loss 2.6250e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3105e+05,| pde-loss 8.5728e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1550,            | Training-Loss 5.2470e+05,| Test-Loss 2.6244e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3113e+05,| pde-loss 1.0373e-29,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1560,            | Training-Loss 5.2472e+05,| Test-Loss 2.6246e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3113e+05,| pde-loss 9.3523e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1570,            | Training-Loss 5.2465e+05,| Test-Loss 2.6217e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3116e+05,| pde-loss 5.4929e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1580,            | Training-Loss 5.2472e+05,| Test-Loss 2.6230e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3120e+05,| pde-loss 8.9070e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1590,            | Training-Loss 5.2485e+05,| Test-Loss 2.6254e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3138e+05,| pde-loss 1.1627e-29,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1600,            | Training-Loss 5.2481e+05,| Test-Loss 2.6243e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3124e+05,| pde-loss 9.2016e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1610,            | Training-Loss 5.2486e+05,| Test-Loss 2.6196e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3137e+05,| pde-loss 9.4486e-30,        | initc-loss 2.6244e+05,|bc_loss 0.0000e+00|
# | Epoch 1620,            | Training-Loss 5.2488e+05,| Test-Loss 2.6229e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3129e+05,| pde-loss 1.1506e-29,        | initc-loss 2.6244e+05,|bc_loss 0.0000e+00|
# | Epoch 1630,            | Training-Loss 5.2476e+05,| Test-Loss 2.6247e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3116e+05,| pde-loss 1.0852e-29,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1640,            | Training-Loss 5.2458e+05,| Test-Loss 2.6229e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3108e+05,| pde-loss 8.6722e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1650,            | Training-Loss 5.2480e+05,| Test-Loss 2.6244e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3131e+05,| pde-loss 1.1168e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1660,            | Training-Loss 5.2501e+05,| Test-Loss 2.6241e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3133e+05,| pde-loss 1.1192e-29,        | initc-loss 2.6241e+05,|bc_loss 0.0000e+00|
# | Epoch 1670,            | Training-Loss 5.2483e+05,| Test-Loss 2.6233e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3121e+05,| pde-loss 9.0219e-30,        | initc-loss 2.6241e+05,|bc_loss 0.0000e+00|
# | Epoch 1680,            | Training-Loss 5.2482e+05,| Test-Loss 2.6258e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3116e+05,| pde-loss 6.6847e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1690,            | Training-Loss 5.2491e+05,| Test-Loss 2.6216e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3126e+05,| pde-loss 8.3163e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1700,            | Training-Loss 5.2480e+05,| Test-Loss 2.6227e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3124e+05,| pde-loss 8.0317e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1710,            | Training-Loss 5.2509e+05,| Test-Loss 2.6246e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3136e+05,| pde-loss 1.2344e-29,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1720,            | Training-Loss 5.2465e+05,| Test-Loss 2.6245e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3110e+05,| pde-loss 1.0995e-29,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1730,            | Training-Loss 5.2486e+05,| Test-Loss 2.6239e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3112e+05,| pde-loss 9.0612e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1740,            | Training-Loss 5.2495e+05,| Test-Loss 2.6260e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3128e+05,| pde-loss 1.1268e-29,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1750,            | Training-Loss 5.2464e+05,| Test-Loss 2.6234e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3115e+05,| pde-loss 1.0537e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1760,            | Training-Loss 5.2482e+05,| Test-Loss 2.6229e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3113e+05,| pde-loss 8.7523e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1770,            | Training-Loss 5.2462e+05,| Test-Loss 2.6250e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3104e+05,| pde-loss 7.4635e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1780,            | Training-Loss 5.2492e+05,| Test-Loss 2.6242e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3134e+05,| pde-loss 1.0023e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 1790,            | Training-Loss 5.2522e+05,| Test-Loss 2.6243e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3146e+05,| pde-loss 1.1172e-29,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1800,            | Training-Loss 5.2478e+05,| Test-Loss 2.6234e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3118e+05,| pde-loss 9.4908e-30,        | initc-loss 2.6244e+05,|bc_loss 0.0000e+00|
# | Epoch 1810,            | Training-Loss 5.2487e+05,| Test-Loss 2.6242e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3110e+05,| pde-loss 6.1552e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1820,            | Training-Loss 5.2505e+05,| Test-Loss 2.6270e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3131e+05,| pde-loss 1.1530e-29,        | initc-loss 2.6244e+05,|bc_loss 0.0000e+00|
# | Epoch 1830,            | Training-Loss 5.2505e+05,| Test-Loss 2.6247e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3128e+05,| pde-loss 7.3417e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 1840,            | Training-Loss 5.2505e+05,| Test-Loss 2.6251e+05   |
# --------------------------------------------------------------------------------
# ...
# | Epoch 4380,            | Training-Loss 5.2482e+05,| Test-Loss 2.6224e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3138e+05,| pde-loss 9.5121e-30,        | initc-loss 2.6247e+05,|bc_loss 0.0000e+00|
# | Epoch 4390,            | Training-Loss 5.2481e+05,| Test-Loss 2.6245e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3115e+05,| pde-loss 1.0837e-29,        | initc-loss 2.6238e+05,|bc_loss 0.0000e+00|
# | Epoch 4400,            | Training-Loss 5.2482e+05,| Test-Loss 2.6257e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3130e+05,| pde-loss 8.4503e-30,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 4410,            | Training-Loss 5.2494e+05,| Test-Loss 2.6236e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3132e+05,| pde-loss 1.2878e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 4420,            | Training-Loss 5.2498e+05,| Test-Loss 2.6261e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3130e+05,| pde-loss 8.6450e-30,        | initc-loss 2.6241e+05,|bc_loss 0.0000e+00|
# | Epoch 4430,            | Training-Loss 5.2512e+05,| Test-Loss 2.6232e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3144e+05,| pde-loss 1.1700e-29,        | initc-loss 2.6239e+05,|bc_loss 0.0000e+00|
# | Epoch 4440,            | Training-Loss 5.2466e+05,| Test-Loss 2.6246e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3111e+05,| pde-loss 6.2959e-30,        | initc-loss 2.6245e+05,|bc_loss 0.0000e+00|
# | Epoch 4450,            | Training-Loss 5.2485e+05,| Test-Loss 2.6250e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3127e+05,| pde-loss 9.7164e-30,        | initc-loss 2.6240e+05,|bc_loss 0.0000e+00|
# | Epoch 4460,            | Training-Loss 5.2480e+05,| Test-Loss 2.6237e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3120e+05,| pde-loss 9.6054e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 4470,            | Training-Loss 5.2483e+05,| Test-Loss 2.6228e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3124e+05,| pde-loss 8.9234e-30,        | initc-loss 2.6240e+05,|bc_loss 0.0000e+00|
# | Epoch 4480,            | Training-Loss 5.2498e+05,| Test-Loss 2.6247e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3114e+05,| pde-loss 9.5122e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 4490,            | Training-Loss 5.2489e+05,| Test-Loss 2.6263e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3123e+05,| pde-loss 1.0887e-29,        | initc-loss 2.6238e+05,|bc_loss 0.0000e+00|
# | Epoch 4500,            | Training-Loss 5.2474e+05,| Test-Loss 2.6228e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3115e+05,| pde-loss 7.6819e-30,        | initc-loss 2.6245e+05,|bc_loss 0.0000e+00|
# | Epoch 4510,            | Training-Loss 5.2524e+05,| Test-Loss 2.6249e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3150e+05,| pde-loss 8.7664e-30,        | initc-loss 2.6232e+05,|bc_loss 0.0000e+00|
# | Epoch 4520,            | Training-Loss 5.2495e+05,| Test-Loss 2.6237e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3128e+05,| pde-loss 1.1431e-29,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 4530,            | Training-Loss 5.2478e+05,| Test-Loss 2.6242e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3118e+05,| pde-loss 8.8101e-30,        | initc-loss 2.6238e+05,|bc_loss 0.0000e+00|
# | Epoch 4540,            | Training-Loss 5.2491e+05,| Test-Loss 2.6244e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3125e+05,| pde-loss 9.3686e-30,        | initc-loss 2.6245e+05,|bc_loss 0.0000e+00|
# | Epoch 4550,            | Training-Loss 5.2500e+05,| Test-Loss 2.6239e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3127e+05,| pde-loss 9.4422e-30,        | initc-loss 2.6239e+05,|bc_loss 0.0000e+00|
# | Epoch 4560,            | Training-Loss 5.2513e+05,| Test-Loss 2.6230e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3145e+05,| pde-loss 1.0669e-29,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 4570,            | Training-Loss 5.2495e+05,| Test-Loss 2.6253e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3126e+05,| pde-loss 9.0179e-30,        | initc-loss 2.6238e+05,|bc_loss 0.0000e+00|
# | Epoch 4580,            | Training-Loss 5.2480e+05,| Test-Loss 2.6226e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3123e+05,| pde-loss 1.2198e-29,        | initc-loss 2.6245e+05,|bc_loss 0.0000e+00|
# | Epoch 4590,            | Training-Loss 5.2462e+05,| Test-Loss 2.6258e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3113e+05,| pde-loss 7.2596e-30,        | initc-loss 2.6238e+05,|bc_loss 0.0000e+00|
# | Epoch 4600,            | Training-Loss 5.2479e+05,| Test-Loss 2.6242e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3117e+05,| pde-loss 1.0494e-29,        | initc-loss 2.6240e+05,|bc_loss 0.0000e+00|
# | Epoch 4610,            | Training-Loss 5.2481e+05,| Test-Loss 2.6247e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3125e+05,| pde-loss 9.2244e-30,        | initc-loss 2.6239e+05,|bc_loss 0.0000e+00|
# | Epoch 4620,            | Training-Loss 5.2492e+05,| Test-Loss 2.6253e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3122e+05,| pde-loss 8.2718e-30,        | initc-loss 2.6244e+05,|bc_loss 0.0000e+00|
# | Epoch 4630,            | Training-Loss 5.2459e+05,| Test-Loss 2.6224e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3098e+05,| pde-loss 7.9995e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 4640,            | Training-Loss 5.2496e+05,| Test-Loss 2.6253e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3133e+05,| pde-loss 1.0539e-29,        | initc-loss 2.6238e+05,|bc_loss 0.0000e+00|
# | Epoch 4650,            | Training-Loss 5.2495e+05,| Test-Loss 2.6229e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3116e+05,| pde-loss 8.9776e-30,        | initc-loss 2.6247e+05,|bc_loss 0.0000e+00|
# | Epoch 4660,            | Training-Loss 5.2491e+05,| Test-Loss 2.6245e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3138e+05,| pde-loss 1.0169e-29,        | initc-loss 2.6237e+05,|bc_loss 0.0000e+00|
# | Epoch 4670,            | Training-Loss 5.2504e+05,| Test-Loss 2.6216e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3134e+05,| pde-loss 1.0490e-29,        | initc-loss 2.6246e+05,|bc_loss 0.0000e+00|
# | Epoch 4680,            | Training-Loss 5.2486e+05,| Test-Loss 2.6280e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3127e+05,| pde-loss 9.0534e-30,        | initc-loss 2.6239e+05,|bc_loss 0.0000e+00|
# | Epoch 4690,            | Training-Loss 5.2489e+05,| Test-Loss 2.6224e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3113e+05,| pde-loss 9.9331e-30,        | initc-loss 2.6248e+05,|bc_loss 0.0000e+00|
# | Epoch 4700,            | Training-Loss 5.2481e+05,| Test-Loss 2.6282e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3130e+05,| pde-loss 9.2168e-30,        | initc-loss 2.6240e+05,|bc_loss 0.0000e+00|
# | Epoch 4710,            | Training-Loss 5.2491e+05,| Test-Loss 2.6243e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3127e+05,| pde-loss 1.0460e-29,        | initc-loss 2.6244e+05,|bc_loss 0.0000e+00|
# | Epoch 4720,            | Training-Loss 5.2466e+05,| Test-Loss 2.6273e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3120e+05,| pde-loss 6.2165e-30,        | initc-loss 2.6240e+05,|bc_loss 0.0000e+00|
# | Epoch 4730,            | Training-Loss 5.2481e+05,| Test-Loss 2.6238e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3120e+05,| pde-loss 6.4464e-30,        | initc-loss 2.6239e+05,|bc_loss 0.0000e+00|
# | Epoch 4740,            | Training-Loss 5.2457e+05,| Test-Loss 2.6273e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3111e+05,| pde-loss 1.0806e-29,        | initc-loss 2.6240e+05,|bc_loss 0.0000e+00|
# | Epoch 4750,            | Training-Loss 5.2491e+05,| Test-Loss 2.6234e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3111e+05,| pde-loss 8.3561e-30,        | initc-loss 2.6249e+05,|bc_loss 0.0000e+00|
# | Epoch 4760,            | Training-Loss 5.2481e+05,| Test-Loss 2.6243e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3122e+05,| pde-loss 8.5314e-30,        | initc-loss 2.6241e+05,|bc_loss 0.0000e+00|
# | Epoch 4770,            | Training-Loss 5.2474e+05,| Test-Loss 2.6253e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3126e+05,| pde-loss 1.0091e-29,        | initc-loss 2.6239e+05,|bc_loss 0.0000e+00|
# | Epoch 4780,            | Training-Loss 5.2514e+05,| Test-Loss 2.6256e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3136e+05,| pde-loss 9.7043e-30,        | initc-loss 2.6241e+05,|bc_loss 0.0000e+00|
# | Epoch 4790,            | Training-Loss 5.2511e+05,| Test-Loss 2.6230e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3155e+05,| pde-loss 1.2068e-29,        | initc-loss 2.6247e+05,|bc_loss 0.0000e+00|
# | Epoch 4800,            | Training-Loss 5.2475e+05,| Test-Loss 2.6223e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3117e+05,| pde-loss 9.2301e-30,        | initc-loss 2.6237e+05,|bc_loss 0.0000e+00|
# | Epoch 4810,            | Training-Loss 5.2500e+05,| Test-Loss 2.6231e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3137e+05,| pde-loss 8.4855e-30,        | initc-loss 2.6246e+05,|bc_loss 0.0000e+00|
# | Epoch 4820,            | Training-Loss 5.2450e+05,| Test-Loss 2.6247e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3108e+05,| pde-loss 7.0338e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 4830,            | Training-Loss 5.2496e+05,| Test-Loss 2.6247e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3127e+05,| pde-loss 1.0473e-29,        | initc-loss 2.6250e+05,|bc_loss 0.0000e+00|
# | Epoch 4840,            | Training-Loss 5.2480e+05,| Test-Loss 2.6245e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3119e+05,| pde-loss 7.9738e-30,        | initc-loss 2.6237e+05,|bc_loss 0.0000e+00|
# | Epoch 4850,            | Training-Loss 5.2480e+05,| Test-Loss 2.6227e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3126e+05,| pde-loss 1.2379e-29,        | initc-loss 2.6246e+05,|bc_loss 0.0000e+00|
# | Epoch 4860,            | Training-Loss 5.2463e+05,| Test-Loss 2.6258e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3116e+05,| pde-loss 8.8044e-30,        | initc-loss 2.6239e+05,|bc_loss 0.0000e+00|
# | Epoch 4870,            | Training-Loss 5.2481e+05,| Test-Loss 2.6246e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3127e+05,| pde-loss 8.3472e-30,        | initc-loss 2.6240e+05,|bc_loss 0.0000e+00|
# | Epoch 4880,            | Training-Loss 5.2501e+05,| Test-Loss 2.6254e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3134e+05,| pde-loss 1.0341e-29,        | initc-loss 2.6245e+05,|bc_loss 0.0000e+00|
# | Epoch 4890,            | Training-Loss 5.2443e+05,| Test-Loss 2.6249e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3105e+05,| pde-loss 7.1698e-30,        | initc-loss 2.6232e+05,|bc_loss 0.0000e+00|
# | Epoch 4900,            | Training-Loss 5.2499e+05,| Test-Loss 2.6254e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3129e+05,| pde-loss 1.1255e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 4910,            | Training-Loss 5.2490e+05,| Test-Loss 2.6275e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3131e+05,| pde-loss 1.0435e-29,        | initc-loss 2.6237e+05,|bc_loss 0.0000e+00|
# | Epoch 4920,            | Training-Loss 5.2489e+05,| Test-Loss 2.6236e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3118e+05,| pde-loss 7.7157e-30,        | initc-loss 2.6246e+05,|bc_loss 0.0000e+00|
# | Epoch 4930,            | Training-Loss 5.2489e+05,| Test-Loss 2.6229e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3124e+05,| pde-loss 1.0465e-29,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 4940,            | Training-Loss 5.2507e+05,| Test-Loss 2.6245e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3135e+05,| pde-loss 1.1779e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 4950,            | Training-Loss 5.2479e+05,| Test-Loss 2.6241e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3118e+05,| pde-loss 8.8521e-30,        | initc-loss 2.6243e+05,|bc_loss 0.0000e+00|
# | Epoch 4960,            | Training-Loss 5.2457e+05,| Test-Loss 2.6237e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3101e+05,| pde-loss 7.7460e-30,        | initc-loss 2.6245e+05,|bc_loss 0.0000e+00|
# | Epoch 4970,            | Training-Loss 5.2471e+05,| Test-Loss 2.6267e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3105e+05,| pde-loss 1.1573e-29,        | initc-loss 2.6242e+05,|bc_loss 0.0000e+00|
# | Epoch 4980,            | Training-Loss 5.2470e+05,| Test-Loss 2.6261e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3110e+05,| pde-loss 5.7588e-30,        | initc-loss 2.6239e+05,|bc_loss 0.0000e+00|
# | Epoch 4990,            | Training-Loss 5.2473e+05,| Test-Loss 2.6247e+05   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3117e+05,| pde-loss 7.8440e-30,        | initc-loss 2.6240e+05,|bc_loss 0.0000e+00|

# %% [markdown]
# ## Plots

# %%
temp_nn = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model
print(temp_nn.shape)
temp_nn = scaler1.inverse_transform(temp_nn) # Inverse transform the predictions
temp_nn = temp_nn.reshape(num_steps+1, num_points) # Reshape the predictions to a 2D array
time_ss= np.linspace(0, time_end, num_steps+1 )

plt.figure
plt.plot(time_ss, temp_nn[:, num_points//2], label='Predicted Temperature')
plt.plot(time_ss, temperature_history[:,num_points//2], label='Actual Temperature')
plt.xlabel('Time(s)')
plt.ylabel('Temperature (K)')
plt.yscale('linear')
plt.title('Predicted vs Actual Temperature at x = 7.5mm')
plt.legend()
plt.show()
# Out:
# (1573500, 1)

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(test_losses, label='test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data_losses, label='Data Loss')
plt.plot(pde_losses, label='Pde Loss')
plt.plot(ic_losses, label='IC Loss')
plt.plot(bc_losses, label='BC Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.plot(data_losses, label='Data Loss')
#       3 plt.plot(pde_losses, label='Pde Loss')
#       4 plt.plot(ic_losses, label='IC Loss')
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/matplotlib/axes/_base.py:491, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     489     y = _check_1d(xy[1])
#     490 else:
# --> 491     x, y = index_of(xy[-1])
#     493 if axes.xaxis is not None:
#     494     axes.xaxis.update_units(x)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/matplotlib/cbook.py:1666, in index_of(y)
#    1664     pass
#    1665 try:
# -> 1666     y = _check_1d(y)
#    1667 except (VisibleDeprecationWarning, ValueError):
#    1668     # NumPy 1.19 will warn on ragged input, and we can't actually use it.
#    1669     pass
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/matplotlib/cbook.py:1358, in _check_1d(x)
#    1352 # plot requires `shape` and `ndim`.  If passed an
#    1353 # object that doesn't provide them, then force to numpy array.
#    1354 # Note this will strip unit information.
#    1355 if (not hasattr(x, 'shape') or
#    1356         not hasattr(x, 'ndim') or
#    1357         len(x.shape) < 1):
# -> 1358     return np.atleast_1d(x)
#    1359 else:
#    1360     return x
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/numpy/core/shape_base.py:65, in atleast_1d(*arys)
#      63 res = []
#      64 for ary in arys:
# ---> 65     ary = asanyarray(ary)
#      66     if ary.ndim == 0:
#      67         result = ary.reshape(1)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/_tensor.py:1087, in Tensor.__array__(self, dtype)
#    1085     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1086 if dtype is None:
# -> 1087     return self.numpy()
#    1088 else:
#    1089     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
space_coord, time_coord = np.meshgrid(np.arange(t_hist.shape[1]), np.arange(t_hist.shape[0]))

time_coord = time_coord * dt 
# Create a figure with two subplots

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))


# Plot the temperature history on the left subplot
im1 = ax1.pcolormesh(space_coord, time_coord, t_hist, cmap='viridis', shading='auto')
ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax1.set_title('Temperature Variation Over Time(Analytical Model)',fontname='Times New Roman', fontsize=20)
ax1.contour(space_coord, time_coord, t_hist, colors='red', linewidths=1.0, alpha=0.9)

ax1.grid(True)
cbar = fig.colorbar(im1, ax=ax1)
cbar.ax.invert_yaxis()
cbar.set_label('Temperature (K)', rotation=270, labelpad=20, fontname='Times New Roman', fontsize=16)

im2 = ax2.pcolormesh(space_coord, time_coord, temp_nn, cmap='viridis', shading='auto')
ax2.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax2.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax2.set_title('Temperature Variation Over Time(PINN model)',fontname='Times New Roman', fontsize=20)
ax2.contour(space_coord, time_coord, temp_nn, colors='red', linewidths=1.0, alpha=0.9)

ax2.grid(True)
cbar = fig.colorbar(im2, ax=ax2)
cbar.ax.invert_yaxis()
cbar.set_label('Temperature (K)', rotation=270, labelpad=20, fontname='Times New Roman', fontsize=16)


plt.tight_layout()
plt.show()
