# %% [markdown]
# # 1D Three Phase Simulation of Alloys and PINN model development

# %% [markdown]
# This notebook contains the simulation of 1D Phase change of aluminium alloy. There will be three phases (solid,liquid and mushy).
#
# The approach used is finite difference method and the physics involved in heat conduction.

# %% [markdown]
# ## Import Libraries

# %%
import sys
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler
import torchjd
from torchjd.aggregation import UPGrad

from pinn_loss import loss_fn_data, l1_regularization, pde_loss, boundary_loss, ic_loss, accuracy
from Input_vec_gen import input_gen

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Define the constants and inital geometric domain

# %%
# Geometry
length = 15.0e-3             # Length of the rod

# Material properties
rho = 2300.0                     # Density of AL380 (kg/m^3)
rho_l = 2460.0                   # Density of AL380 (kg/m^3)
rho_s = 2710.0                    # Density of AL380 (kg/m^3)
rho_m = (rho_l + rho_s )/2       # Desnity in mushy zone is taken as average of liquid and solid density

k = 104.0                       # W/m-K
k_l = k                       # W/m-K
k_s = 96.2                    # W/m-K
k_m =  (k_l+k_s)/2                     # W/m-K
k_mo = 41.5


cp = 1245.3                      # Specific heat of aluminum (J/kg-K)
cp_l = cp                      # Specific heat of aluminum (J/kg-K)
cp_s = 963.0                 # Specific heat of aluminum (J/kg-K)
cp_m =  (cp_l+cp_s)/2                 # Specific heat of mushy zone is taken as average of liquid and solid specific heat
# cp_m = cp
           # Thermal diffusivity
alpha_l = k_l / (rho_l * cp_l) 
alpha_s = k_s / (rho_s*cp_s)
alpha_m = k_m / (rho_m * cp_m)          #`Thermal diffusivity in mushy zone is taken as average of liquid and solid thermal diffusivity`


#L_fusion = 3.9e3                 # J/kg
L_fusion = 389.0e3               # J/kg  # Latent heat of fusion of aluminum
         # Thermal diffusivity


T_L = 574.4 +273.0                       #  K -Liquidus Temperature (615 c) AL 380
T_S = 497.3 +273.0                     # K- Solidus Temperature (550 C)
m_eff =(k_m/(rho_m*(cp_m + (L_fusion/(T_L-T_S)))))
print (f"alpha_l = {alpha_l}, alpha_s = {alpha_s}, m_eff = {m_eff}")

# htc = 10.0                   # W/m^2-K
# q = htc*(919.0-723.0)
# q = 10000.0


num_points = 50                        # Number of spatial points
dx = length / (num_points - 1)         # Distance between two spatial points
print('dx is',dx)

                                                              
# Time Discretization  
# 
time_end = 40        # seconds                         

maxi = max(alpha_s,alpha_l,alpha_m)
dt = abs(0.5*((dx**2) /maxi)) 

print('dt is ',dt)
num_steps = round(time_end/dt)
print('num_steps is',num_steps)
cfl = 0.5 *(dx**2/max(alpha_l,alpha_s,alpha_m))
print('cfl is',cfl)

time_steps = np.linspace(0, time_end, num_steps + 1)
step_coeff = dt / (dx ** 2)

if dt <= cfl:
    print('stability criteria satisfied')
else:
    print('stability criteria not satisfied')
    sys.exit()
# Out:
# alpha_l = 3.394878564540885e-05, alpha_s = 3.686205086349929e-05, m_eff = 6.296953764744878e-06
# dx is 0.0003061224489795918
# dt is  0.0012711033647622566
# num_steps is 31469
# cfl is 0.0012711033647622566
# stability criteria satisfied

# %% [markdown]
# ### Initial and Boundary Conditions

# %%
temp_init = 919.0
# Initial temperature and phase fields
temperature = np.full(num_points+2, 919.0)            # Initial temperature of the rod with ghost points at both ends
phase = np.zeros(num_points+2)*0.0                    # Initial phase of the rod with ghost points at both ends

# Set boundary conditions
# temperature[-1] = 919.0 
phase[-1] = 1.0

# temperature[0] = 919.0 #(40 C)
phase[0] = 1.0

# Store initial state in history
temperature_history = [temperature.copy()]    # List to store temperature at each time step
phi_history = [phase.copy()]                    # List to store phase at each time step
temp_init = temperature.copy()                 # Initial temperature of the rod
# print(temperature_history,phi_history)
# Array to store temperature at midpoint over time
midpoint_index = num_points // 2                          # Index of the midpoint

midpoint_temperature_history = [temperature[midpoint_index]]            # List to store temperature at midpoint over time
dm = 60.0e-3                                                            # die thickness in m

# r_m =  (k_mo / dm) + (1/htc)

t_surr = 500.0                                        # Surrounding temperature in K
# t_surr = h()

def kramp(temp,v1,v2,T_L,T_s):                                      # Function to calculate thermal conductivity in Mushy Zone
        slope = (v1-v2)/(T_L-T_S)
        if temp > T_L:
            k_m = k_l
        elif temp < T_S:
            k_m = k_s
        else:
            k_m = k_s + slope*(temp-T_S)
        return k_m

def cp_ramp(temp,v1,v2,T_L,T_s):                                    # Function to calculate specific heat capacity in Mushy Zone
    slope = (v1-v2)/(T_L-T_S)
    if temp > T_L:
        cp_m = cp_l
    elif temp < T_S:
        cp_m = cp_s
    else:
        cp_m = cp_s + slope*(temp-T_S)
    return cp_m

def rho_ramp(temp,v1,v2,T_L,T_s):                                       # Function to calculate density in Mushy Zone
    slope = (v1-v2)/(T_L-T_S)
    if temp > T_L:
        rho_m = rho_l
    elif temp < T_S:
        rho_m = rho_s
    else:
        rho_m = rho_s + slope*(temp-T_S)
    return rho_m

# %% [markdown]
# ### Solving the HT equation and phase change numerically

# %%
for m in range(1, num_steps+1):                                                                            # time loop
    htc = 10.0                   # htc of Still air in W/m^2-K
    q1 = htc*(temp_init[0]-t_surr)   # Heat flux at the left boundary
    
    # print(f"q1 is {q1}")
    temperature[0] = temp_init[0] + alpha_l * step_coeff * ((2.0*temp_init[1]) - (2.0 * temp_init[0])-(2.0*dx*(q1)))  # Update boundary condition temperature
    
    q2 = htc*(temp_init[-1]-t_surr)                   # Heat flux at the right boundary
    temperature[-1] = temp_init[-1] + alpha_l * step_coeff * ((2.0*temp_init[-2]) - (2.0 * temp_init[-1])-(2.0*dx*(q2)))  # Update boundary condition temperature
    
    for n in range(1,num_points+1):              # space loop, adjusted range
       
        if temperature[n] >= T_L:
            temperature[n] += ((alpha_l * step_coeff) * (temp_init[n+1] - (2.0 * temp_init[n]) + temp_init[n-1]))
            phase[n] = 0
            
            # print(f" Time-Step{m},Spatial point{n},Temperature{temperature[n]}")
        elif T_S < temperature[n] < T_L:
            
            k_m = kramp(temperature[n],k_l,k_s,T_L,T_S)
            cp_m = cp_ramp(temperature[n],cp_l,cp_s,T_L,T_S)
            rho_m = rho_ramp(temperature[n],rho_l,rho_s,T_L,T_S)
            m_eff =(k_m/(rho_m*(cp_m + (L_fusion/(T_L-T_S)))))
            
            temperature[n] += ((m_eff * step_coeff)* (temp_init[n+1] - (2.0 * temp_init[n]) + temp_init[n-1]))
            
            phase[n] = (T_L - temperature[n]) / (T_L - T_S)
            # print(m,n,temperature[n],phase[n])
         
        elif temperature[n]<T_S:
            temperature[n] += ((alpha_s * step_coeff) * (temp_init[n+1] - (2.0 * temp_init[n])+ temp_init[n-1]))
            phase[n] = 1
                     
        else:
            print("ERROR: should not be here")

     
          
    temperature = temperature.copy()                                                                # Update temperature
    phase = phase.copy()                                                                            # Update phase
    temp_init = temperature.copy()                                                                  # Update last time step temperature
    temperature_history.append(temperature.copy())                                                  # Append the temperature history to add ghost points
    phi_history.append(phase.copy())                                                                # Append the phase history to add ghost points
    midpoint_temperature_history.append(temperature[midpoint_index])                                # Store midpoint temperature
    
    
    # print(f"Step {m}, Temperature: {temperature}")
    


# print(midpoint_temperature_history)
#print(phi_history)

# %% [markdown]
# ### Plot the Results

# %%
# # Plot temperature history for debugging
# temperature_history_1 = np.array(temperature_history)
# print(temperature_history_1.shape)
# time_ss= np.linspace(0, time_end, num_steps+1)
# # print(time_ss.shape)
# plt.figure(figsize=(10, 6))
# plt.plot(time_ss, midpoint_temperature_history, label='Midpoint Temperature')
# plt.axhline(y=T_L, color='r', linestyle='--', label='Liquidus Temperature')
# plt.axhline(y=T_S, color='g', linestyle='--', label='Solidus Temperature')
# plt.xlabel('Time(s)')
# plt.ylabel('Temperature (K)')
# plt.title('Temperature Distribution Over Time at x = 7.5mm') 
# plt.legend()
# plt.show()

# %% [markdown]
# ### Data into Array

# %%
temperature_history = np.array(temperature_history)

phi_history = np.array(phi_history)

t_hist = np.array(temperature_history)  # Remove ghost points
# p_hist = np.array(phi_history[:,1:-1])
# t_pde = t_hist[1:,1:-1]                # Remove initial condition and boundary condition
# # t_pde = t_pde.flatten()
# t_hist_init = t_hist[0,:]
# t_hist_bc_l = t_hist[:,0]
# t_hist_bc_r = t_hist[:,-1]

print(t_hist.shape)

scaler_temp = StandardScaler()
t_hist_tr= scaler_temp.fit_transform(t_hist.reshape(-1,1)) # Normalize temperature history
t_prep = t_hist_tr.reshape(num_steps+1,num_points+2)
print(t_prep.shape)
t_pde = t_prep[1:,2:-2]
t_init = t_prep[0,:]
t_bc_l = t_prep[:,0]
t_bc_r = t_prep[:,-1]

t_pde = t_pde.flatten() 
t_init = t_init.flatten()
t_bc_l = t_bc_l.flatten()
t_bc_r = t_bc_r.flatten()

print(t_pde.shape)
# t_pde_tr = scaler_temp.fit_transform(t_pde.reshape(-1,1)) # Normalize temperature PDE
# t_hist_init_tr = scaler_temp.fit_transform(t_hist_init.reshape(-1,1)) # Normalize initial condition
# t_hist_bc_l_tr = scaler_temp.fit_transform(t_hist_bc_l.reshape(-1,1)) # Normalize left boundary condition
# t_hist_bc_r_tr = scaler_temp.fit_transform(t_hist_bc_r.reshape(-1,1)) # Normalize right boundary condition

print(t_hist_tr.shape)
# Out:
# (31470, 52)
# (31470, 52)
# (1510512,)
# (1636440, 1)

# %%
# Assuming you have temperature_history and phi_history as lists of arrays


# # Check the new shape after transposing
# print("Transposed Temperature History Shape:", temperature_history.shape)
# print("Transposed Phi History Shape:", phi_history.shape)

# # Create a meshgrid for space and time coordinates
# space_coord, time_coord = np.meshgrid(np.arange(temperature_history.shape[1]), np.arange(temperature_history.shape[0]))

# time_coord = time_coord * dt 
# # Create a figure with two subplots
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# # Plot the temperature history on the left subplot
# im1 = ax1.pcolormesh(space_coord, time_coord, temperature_history, cmap='viridis')
# ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
# ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
# ax1.set_title('Temperature Variation Over Time',fontname='Times New Roman', fontsize=20)
# fig.colorbar(im1, ax=ax1, label='Temperature')

# # Plot the phase history on the right subplot
# im2 = ax2.pcolormesh(space_coord, time_coord, phi_history, cmap='viridis')
# ax2.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=18)
# ax2.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
# ax2.set_title('Phase Variation Over Time',fontname='Times New Roman', fontsize=20)
# fig.colorbar(im2, ax=ax2, label='Phase')
# plt.tight_layout()
# plt.show()

# #plot the main
# fig, ax = plt.subplots(figsize=(14, 6))
# im = ax.pcolormesh(space_coord, time_coord, Dim_ny, cmap='viridis')
# ax.set_xlabel('Space Coordinate')
# ax.set_ylabel('Time')
# ax.set_title('Niyama Variation Over Time')
# fig.colorbar(im, ax=ax, label='Main')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## ML training

# %% [markdown]
# ### GPU/CPU check

# %%
# check for gpu
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Data preparation

# %%
space = np.linspace(0, length, num_points+2) # Spatial points
time = np.linspace(0, time_end, num_steps+1) # Time points

space, time = np.meshgrid(space, time)

scaler1 = StandardScaler()
scaler2 = StandardScaler()

space = scaler1.fit_transform(space.reshape(-1,1)) # Normalize spatial points
time = scaler2.fit_transform(time.reshape(-1,1)) # Normalize time points

space = space.reshape(num_steps+1,num_points+2)
time = time.reshape(num_steps+1,num_points+2)

print(space.shape,time.shape)

sp_pde = space[1:,2:-2] # Spatial points
time_pde = time[1:,2:-2]
print(sp_pde.shape,time_pde.shape)

sp_i = space[0,:]   
time_i = time[0,:]

sp_b_l = space[:,0]
time_b_l = time[:,0]

sp_b_r = space[:,-1]
time_b_r = time[:,-1]


space = space.flatten()
time = time.flatten()

sp_pde = sp_pde.flatten()
time_pde = time_pde.flatten()

sp_i = sp_i.flatten()
time_i = time_i.flatten()

sp_b_l = sp_b_l.flatten()
time_b_l = time_b_l.flatten()

sp_b_r = sp_b_r.flatten()
time_b_r = time_b_r.flatten()



print(space.shape,time.shape)

# space_pde = space[1:-1] # Spatial points 
# time_pde = time[1:] # Time points
# print(space_pde.shape,time_pde.shape)

# sp_i = np.linspace(0, length, num_points) # Spatial points
# time_i = np.zeros(num_points) # Time points
# print(sp_i.shape,time_i.shape)
# sp_b_l = np.zeros(num_steps+1) # Spatial points
# time_b_l = np.linspace(0, time_end, num_steps+1) # Time points
# print(sp_b_l.shape,time_b_l.shape)
# sp_b_r = np.ones(num_steps+1)*length # Spatial points
# time_b_r = np.linspace(0, time_end, num_steps+1) # Time points
# print(sp_b_r.shape,time_b_r.shape)
# Out:
# (31470, 52) (31470, 52)
# (31469, 48) (31469, 48)
# (1636440,) (1636440,)

# %%
inputs = np.column_stack((space, time)) # Input vector
inputs_pde = np.column_stack((sp_pde, time_pde)) # Input vector for PDE
inputs_init = np.column_stack((sp_i, time_i)) # Input vector for initial condition
inputs_bc_l = np.column_stack((sp_b_l, time_b_l)) # Input vector for left boundary condition
inputs_bc_r = np.column_stack((sp_b_r, time_b_r)) # Input vector for right boundary condition

print(inputs.shape,inputs_pde.shape,inputs_init.shape,inputs_bc_l.shape,inputs_bc_r.shape)
# Out:
# (1636440, 2) (1510512, 2) (52, 2) (31470, 2) (31470, 2)

# %%
# Convert the inputs to a tensor



inputs = torch.tensor(inputs).float().to(device)
inputs_pde = torch.tensor(inputs_pde).float().to(device)
inputs_init = torch.tensor(inputs_init).float().to(device) 
inputs_b_l = torch.tensor(inputs_bc_l).float().to(device)
inputs_b_r = torch.tensor(inputs_bc_r).float().to(device)


# print(inputs_init[:5,:])
# label/temp data to tensor
temp_tr = torch.tensor(t_hist_tr).float().to(device) # Convert the temperature history to a tensor
temp_inp = temp_tr.reshape(-1,1).float().to(device) # Reshape the temperature tensor to a column vector
temp_pde = torch.tensor(t_pde).float().to(device) # Convert the temperature history to a tensor
temp_inp_init = torch.tensor(t_init).float().to(device) # Convert the temperature history to a tensor
temp_inp_bc_l = torch.tensor(t_bc_l).float().to(device)# Convert the temperature history to a tensor
temp_inp_bc_r = torch.tensor(t_bc_r).float().to(device)# Convert the temperature history to a tensor




#Data Splitting

# train_inputs, val_test_inputs, train_temp_inp, val_test_temp_inp = train_test_split(inputs, temp_inp, test_size=0.2, random_state=42)
# val_inputs, test_inputs, val_temp_inp, test_temp_inp = train_test_split(val_test_inputs, val_test_temp_inp, test_size=0.8, random_state=42)

train_inputs, test_inputs, train_temp_inp, test_temp_inp = train_test_split(inputs, temp_inp,test_size=0.2, random_state=42)
train_inputs_pde, test_inputs_pde, train_temp_inp_pde, test_temp_inp_pde = train_test_split(inputs_pde, temp_pde,\
                                                                                             test_size=0.2, random_state=42)
train_inputs_init, test_inputs_init, train_temp_inp_init, test_temp_inp_init = train_test_split(inputs_init, temp_inp_init, \
                                                                                                test_size=0.2, random_state=42)
train_inputs_bc_l, test_inputs_bc_l, train_temp_inp_bc_l, test_temp_inp_bc_l = train_test_split(inputs_b_l, temp_inp_bc_l, \
                                                                                                 test_size=0.2, random_state=42)
train_inputs_bc_r, test_inputs_bc_r, train_temp_inp_bc_r, test_temp_inp_bc_r = train_test_split(inputs_b_r, temp_inp_bc_r, \
                                                                                                test_size=0.2, random_state=42)

# print(train_inputs.shape, test_inputs.shape, train_temp_inp.shape, test_temp_inp.shape)

# %% [markdown]
# ### Create Data loader

# %%
class TensorDataset(torch.utils.data.Dataset):
    def __init__(self, inputs, temp_inp,transform=None, target_transform =None):
        self.inputs = inputs
        self.temp_inp = temp_inp

    def __getitem__(self, index):
        return self.inputs[index], self.temp_inp[index]
    
    def __len__(self):
        return len(self.inputs)

  
train_dataset = TensorDataset(train_inputs, train_temp_inp) # Create the training dataset
# val_dataset = TensorDataset(val_inputs, val_temp_inp) # Create the validation dataset
test_dataset = TensorDataset(test_inputs, test_temp_inp) # Create the test dataset

train_dataset_pde = TensorDataset(train_inputs_pde, train_temp_inp_pde) # Create the training dataset
test_dataset_pde = TensorDataset(test_inputs_pde, test_temp_inp_pde) # Create the test dataset

train_dataset_init = TensorDataset(train_inputs_init, train_temp_inp_init) # Create the training dataset
test_dataset_init = TensorDataset(test_inputs_init, test_temp_inp_init) # Create the test dataset
train_dataset_bc_l = TensorDataset(train_inputs_bc_l, train_temp_inp_bc_l) # Create the training dataset
test_dataset_bc_l = TensorDataset(test_inputs_bc_l, test_temp_inp_bc_l) # Create the test dataset
train_dataset_bc_r = TensorDataset(train_inputs_bc_r, train_temp_inp_bc_r) # Create the training dataset
test_dataset_bc_r = TensorDataset(test_inputs_bc_r, test_temp_inp_bc_r) # Create the test dataset


batch_size = 64
batch_size_s =1000

random_sampler_train = RandomSampler(train_dataset, replacement=True, num_samples=batch_size_s) # Create a random sampler for the training dataset
# random_sampler_val = RandomSampler(val_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the validation dataset
random_sampler_test = RandomSampler(test_dataset, replacement=True, num_samples=batch_size_s) # Create a random sampler for the test dataset

random_sampler_train_pde = RandomSampler(train_dataset_pde, replacement=True, num_samples=batch_size_s) # Create a random sampler for the training dataset
random_sampler_test_pde = RandomSampler(test_dataset_pde, replacement=True, num_samples=batch_size_s) # Create a random sampler for the test dataset


random_sampler_train_init = RandomSampler(train_dataset_init, replacement=True, num_samples=50) # Create a random sampler for the training dataset
random_sampler_test_init = RandomSampler(test_dataset_init, replacement=True, num_samples=50) # Create a random sampler for the test dataset
random_sampler_train_bc_l = RandomSampler(train_dataset_bc_l, replacement=True, num_samples=batch_size_s) # Create a random sampler for the training dataset
random_sampler_test_bc_l = RandomSampler(test_dataset_bc_l, replacement=True, num_samples=batch_size_s) # Create a random sampler for the test dataset
random_sampler_train_bc_r = RandomSampler(train_dataset_bc_r, replacement=True, num_samples=batch_size_s) # Create a random sampler for the training dataset
random_sampler_test_bc_r = RandomSampler(test_dataset_bc_r, replacement=True, num_samples=batch_size_s) # Create a random sampler for the test dataset





train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=random_sampler_train) # Create the training dataloader
# val_loader = DataLoader(val_dataset, batch_size=batch_size, sampler=random_sampler_val) # Create the validation dataloader
test_loader = DataLoader(test_dataset, batch_size=batch_size, sampler=random_sampler_test) # Create the test dataloader

train_loader_pde = DataLoader(train_dataset_pde, batch_size=batch_size, sampler=random_sampler_train_pde) # Create the training dataloader
test_loader_pde = DataLoader(test_dataset_pde, batch_size=batch_size, sampler=random_sampler_test_pde) # Create the test dataloader

train_loader_init = DataLoader(train_dataset_init, batch_size=5, sampler=random_sampler_train_init) # Create the training dataloader
test_loader_init = DataLoader(test_dataset_init, batch_size=5, sampler=random_sampler_test_init) # Create the test dataloader
train_loader_bc_l = DataLoader(train_dataset_bc_l, batch_size=batch_size, sampler=random_sampler_train_bc_l) # Create the training dataloader
test_loader_bc_l = DataLoader(test_dataset_bc_l, batch_size=batch_size, sampler=random_sampler_test_bc_l) # Create the test dataloader
train_loader_bc_r = DataLoader(train_dataset_bc_r, batch_size=batch_size, sampler=random_sampler_train_bc_r) # Create the training dataloader
test_loader_bc_r = DataLoader(test_dataset_bc_r, batch_size=batch_size, sampler=random_sampler_test_bc_r) # Create the test dataloader

# %% [markdown]
# ### NN Architecture Definition

# %%
# Define the neural network architecture
class Mushydata(nn.Module):
    def __init__(self, input_size, hidden_size, output_size,hidden_layers,hidden_layers_2): # This is the constructor
        super(Mushydata, self).__init__()
        layers =[]

        layers.append(nn.Linear(input_size, hidden_size)) # First layer
        layers.append(nn.ReLU()) # Activation function

        for _ in range(hidden_layers):
            layers.append(nn.Linear(hidden_size, hidden_size))
            layers.append(nn.ReLU())

        for _ in range(hidden_layers_2):
            layers.append(nn.Linear(hidden_size, hidden_size))
            layers.append(nn.ReLU())

        layers.append(nn.Linear(hidden_size, output_size)) # Output layer
        self.base = nn.Sequential(*layers)
        
    def forward(self, x, t):                               # This is the forward pass
        input_features = torch.cat([x, t], dim=1)          # Concatenate the input features
        m = self.base(input_features)                                 # Pass through the third layer
        return m                    # Return the output of the network


# features = torch.rand(1, 2)
# model = HeatPINN(2, 20, 1)
# output = model(features[:, 0:1], features[:, 1:2])
# print(output)


# Loss function for data

# %% [markdown]
# ### Hyperparamters Init

# %%
# Hyperparameters
hidden_size = 50
learning_rate = 0.01
epochs = 5000
# alpha = 0.01  # Adjust this value based on your problem
# boundary_value = 313.0
# initial_value = init_temp
# Initialize the model
model = Mushydata(input_size=2, hidden_size=hidden_size,output_size=1,hidden_layers=5,hidden_layers_2=5).to(device)
lambd = 0.1

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Loss List Init

# %%
train_losses = []
val_losses = []
test_losses = []

print(f"Datatype of train_loader is {type(train_loader)}")
# Out:
# Datatype of train_loader is <class 'torch.utils.data.dataloader.DataLoader'>

# %% [markdown]
# ### Loss functions

# %% [markdown]
# ### Training, Validation and Testing Module

# %%
def training_loop(epochs, model, loss_fn_data, optimizer, train_dataloader,train_loader_pde,\
                  test_dataloader,train_loader_init,\
                  train_loader_bc_l,train_loader_bc_r):
    train_losses = []  # Initialize the list to store the training losses
    # val_losses = []    # Initialize the list to store the validation losses
    test_losses = []   # Initialize the list to store the test losses
    data_losses = []   # Initialize the list to store the data losses
    pde_losses = []   # Initialize the list to store the PDE losses
    ic_losses = []   # Initialize the list to store the initial condition losses
    bc_losses = []   # Initialize the list to store the boundary condition losses

    for epoch in range(epochs):
        model.train()                                                                           # Set the model to training mode
        train_loss = 0                                                                              # Initialize the training loss
        data_loss = 0
        data_loss_b = 0
        phy_loss = 0
        init_loss = 0
      
        for (batch,batch_pde,batch_init,batch_left,batch_right) in \
             zip (train_dataloader,train_loader_pde,train_loader_init,train_loader_bc_l,\
                  train_loader_bc_r):                                                          # Loop through the training dataloader
            inputs, temp_inp= batch                                                             # Get the inputs and the true values
            inputs_pde, temp_inp_pde= batch_pde                                                             # Get the inputs and the true values
            inputs_init, temp_inp_init= batch_init                                                             # Get the inputs and the true values 
            inputs_left, temp_inp_left= batch_left                                                             # Get the inputs and the true values
            inputs_right, temp_inp_right= batch_right                                                             # Get the inputs and the true values

            inputs, temp_inp= inputs.to(device), temp_inp.to(device)                             # Move the inputs and true values to the GPU
            inputs_pde, temp_inp_pde= inputs_pde.to(device), temp_inp_pde.to(device)                             # Move the inputs and true values to the GPU
            inputs_init, temp_inp_init= inputs_init.to(device), temp_inp_init.to(device)                             # Move the initial condition inputs and temperature to the GPU
            inputs_left, temp_inp_left= inputs_left.to(device), temp_inp_left.to(device)                             # Move the left boundary condition inputs and temperature values to the GPU
            inputs_right, temp_inp_right= inputs_right.to(device), temp_inp_right.to(device)                             # Move the right boundary condition inputs and temperature values to the GPU
           
            # print(inputs[:5,:],temp_inp[:5,:])
            # print(inputs_pde[:5,:],temp_inp_pde[:5,:])
            # print(inputs_init[:5,:],temp_inp_init[:5,:])
            # print(inputs_left[:5],temp_inp_left[:5])
            # print(inputs_right[:5],temp_inp_right[:5])
            
            optimizer.zero_grad()                                                                    # Zero the gradients
            
            # Forward pass
            u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).to(device)                       # Get the predictions
            u_initl = model(inputs_init[:,0].unsqueeze(1), inputs_init[:,1].unsqueeze(1)).to(device)                       # Get the predictions
            
            u_left = model(inputs_b_l[:,0].unsqueeze(1), inputs_b_l[:,1].unsqueeze(1)).to(device)               # Left boundary of the temperature
            u_right = model(inputs_b_r[:,0].unsqueeze(1), inputs_b_r[:,1].unsqueeze(1)).to(device)             # Right boundary of the temperature

            # Loss calculation
            data_loss = loss_fn_data(u_pred, temp_inp)                                              # Calculate the data loss
            
            phy_loss = pde_loss(model,inputs[:,0].unsqueeze(1),inputs[:,1].unsqueeze(1))             # Calculate the PDE loss
            # pd_loss = 0
           
            init_loss = ic_loss(u_initl,temp_init) 
                                                             # Calculate initial condition loss
            # initc_loss =0                                                      # Calculate initial condition loss
            
            # bc_loss_left = boundary_loss(model,inputs_b_l[:,0].unsqueeze(1),inputs_b_l[:,1].unsqueeze(1),t_surr) # Calculate the left boundary condition loss
            # bc_loss_right = boundary_loss(model,inputs_b_r[:,0].unsqueeze(1),inputs_b_r[:,1].unsqueeze(1),t_surr) # Calculate the right boundary condition loss
            # bc_loss = bc_loss_left + bc_loss_right
            bc_loss = 0
            # l1_regularization_loss = l1_regularization(model, lambda_l1)                      # Calculate the L1 regularization loss
            # loss = data_loss  + pd_loss + initc_loss + bc_loss                                              # Calculate the total loss
            w0 = 1
            w1 = 0
            w2 = 1
            w3 = 0
            loss = data_loss 
            # print(loss)
                                                                         # Calculate the total loss
            # Backpropagation
            loss.backward(retain_graph=True)                                                       # Backpropagate the gradients
            
            # torchjd.backward([data_loss,pd_loss], model.parameters(), A)

            optimizer.step()                                                                           # Update the weights
            
            train_loss += loss.item()                                                           # Add the loss to the training set loss  
            data_loss_b += data_loss.item()              
            phy_loss += phy_loss.item()
            init_loss += init_loss.item()
            # bc_losses.append(bc_loss.item())
        

        # model.eval()
        # test_loss = 0
        # test_accuracy = 0
        # with torch.no_grad():   
        #     for batch in test_dataloader:
        #         inputs, temp_inp= batch
        #         inputs, temp_inp= inputs.to(device), temp_inp.to(device)
        #         u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1))
        #         data_loss = loss_fn_data(u_pred, temp_inp)
        #         # l1_regularization_loss = l1_regularization(model, lambd)
        #         # loss = data_loss  + l1_regularization_loss
        #         loss = data_loss
        #         test_accuracy = accuracy(u_pred, temp_inp)
        #         test_loss += loss.item()
        #     test_losses.append(test_loss)
        
        train_losses.append(train_loss /len(train_dataloader))                                                   # Append the training loss to the list of training losses
        
        data_losses.append(data_loss /len(train_dataloader))                                                   # Append the training loss to the list of training losses
        pde_losses.append(phy_loss /len(train_loader_pde))                                                   # Append the training loss to the list of training losses
        ic_losses.append(init_loss /len(train_loader_init))                                                   # Append the training loss to the list of training losses
        # if epoch % 10 == 0:
        #     print(f"Epoch {epoch}, Training-Loss {train_loss:.4e}")
        
        model.eval()
        test_loss = 0
        
        # with torch.no_grad():   
        for batch in test_dataloader:
            inputs, temp_inp= batch
            inputs, temp_inp= inputs.to(device), temp_inp.to(device)
            u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1))
            data_loss_t = loss_fn_data(u_pred, temp_inp)
            # l1_regularization_loss = l1_regularization(model, lambd)
            # loss = data_loss  + l1_regularization_loss
            loss = data_loss_t
            test_accuracy = accuracy(u_pred, temp_inp)
            test_loss += loss.item()
        test_losses.append(test_loss)
        
        torch.cuda.empty_cache()
        
        if epoch % 10 == 0:
            print(f"| Epoch {epoch},            | Training-Loss {train_loss:.4e},| Test-Loss {test_loss:.4e}   |")
            print(f"--"*40)
            print(f"| Data-loss {data_loss:.4e},| pde-loss {phy_loss:.4e},        | initc-loss {init_loss:.4e},|bc_loss {bc_loss:.4e}|") 
    

    return train_losses, test_losses , pde_losses , bc_losses , ic_losses, data_losses                                                      # Return the training and validation losses

# %%
def test_loop(epochs, model, loss_fn_data, optimizer, train_dataloader, test_dataloader):
      
    model.eval()
    test_loss = 0
    test_accuracy = 0
    with torch.no_grad():   
        for batch in test_dataloader:
            inputs, temp_inp= batch
            inputs, temp_inp= inputs.to(device), temp_inp.to(device)
            u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1))
            data_loss = loss_fn_data(u_pred, temp_inp)
            # l1_regularization_loss = l1_regularization(model, lambd)
            # loss = data_loss  + l1_regularization_loss
            loss = data_loss
            test_accuracy = accuracy(u_pred, temp_inp)
            test_loss += loss.item()
        test_losses.append(test_loss)
    if epochs % 10 == 0:
        print(f"Epoch {epochs}, Test-Loss {test_loss:.4e}, Test-Accuracy {test_accuracy:.4e}")      
    return test_losses

# %% [markdown]
# ### Training Button

# %%
train_losses, test_losses, pde_losses, bc_losses,ic_losses, data_losses = training_loop(epochs, model, loss_fn_data, optimizer,train_loader,train_loader_pde,\
                    test_loader,train_loader_init,\
                  train_loader_bc_l,train_loader_bc_r)  # Train the model
 
# test_losses = test_loop(epochs, model, loss_fn_data, optimizer, train_loader, test_loader)  # Test the model
# Out:
# | Epoch 0,            | Training-Loss 9.1681e+00,| Test-Loss 1.6906e+01   |
# --------------------------------------------------------------------------------
# | Data-loss 3.2627e-01,| pde-loss 2.6158e+00,        | initc-loss 1.0477e+06,|bc_loss 0.0000e+00|
# | Epoch 10,            | Training-Loss 3.3324e-01,| Test-Loss 2.6342e-01   |
# --------------------------------------------------------------------------------
# | Data-loss 3.7287e-02,| pde-loss 3.6903e+00,        | initc-loss 1.0433e+06,|bc_loss 0.0000e+00|
# | Epoch 20,            | Training-Loss 9.5776e-02,| Test-Loss 1.0963e-01   |
# --------------------------------------------------------------------------------
# | Data-loss 1.5599e-02,| pde-loss 8.0834e+00,        | initc-loss 1.0418e+06,|bc_loss 0.0000e+00|
# | Epoch 30,            | Training-Loss 5.4389e-02,| Test-Loss 9.8673e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.7605e-03,| pde-loss 1.0076e+01,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 40,            | Training-Loss 3.0415e-02,| Test-Loss 5.5672e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.9879e-03,| pde-loss 9.5529e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 50,            | Training-Loss 7.0939e-03,| Test-Loss 1.8817e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 2.5634e-04,| pde-loss 5.2304e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 60,            | Training-Loss 9.6491e-03,| Test-Loss 1.4017e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 8.1083e-04,| pde-loss 7.3290e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 70,            | Training-Loss 3.2331e-01,| Test-Loss 1.8083e+00   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0458e-02,| pde-loss 6.0280e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 80,            | Training-Loss 2.6695e-02,| Test-Loss 2.7374e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 3.2741e-03,| pde-loss 9.6567e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 90,            | Training-Loss 4.6344e-03,| Test-Loss 6.0572e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.3411e-04,| pde-loss 5.6640e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 100,            | Training-Loss 4.6258e-03,| Test-Loss 6.5972e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.7200e-04,| pde-loss 6.6125e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 110,            | Training-Loss 3.3993e-03,| Test-Loss 4.6556e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.6523e-04,| pde-loss 7.1351e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 120,            | Training-Loss 5.3946e-03,| Test-Loss 5.8429e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 7.1279e-04,| pde-loss 9.9534e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 130,            | Training-Loss 3.5958e-03,| Test-Loss 6.5696e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0151e-03,| pde-loss 1.0766e+01,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 140,            | Training-Loss 2.1411e-03,| Test-Loss 2.0909e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.0700e-04,| pde-loss 8.1830e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 150,            | Training-Loss 5.7505e-03,| Test-Loss 2.0688e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.5559e-04,| pde-loss 4.7220e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 160,            | Training-Loss 2.8238e-02,| Test-Loss 2.8895e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.9584e-03,| pde-loss 4.6766e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 170,            | Training-Loss 4.2683e-02,| Test-Loss 5.0676e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 5.5628e-03,| pde-loss 9.5273e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 180,            | Training-Loss 8.8421e-02,| Test-Loss 1.1705e-01   |
# --------------------------------------------------------------------------------
# | Data-loss 4.9122e-03,| pde-loss 5.5794e+00,        | initc-loss 1.0421e+06,|bc_loss 0.0000e+00|
# | Epoch 190,            | Training-Loss 9.8300e-03,| Test-Loss 1.4301e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0781e-03,| pde-loss 1.0047e+01,        | initc-loss 1.0410e+06,|bc_loss 0.0000e+00|
# | Epoch 200,            | Training-Loss 2.5539e-03,| Test-Loss 2.8201e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.0351e-04,| pde-loss 7.3939e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 210,            | Training-Loss 9.6907e-03,| Test-Loss 1.9311e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 5.5965e-04,| pde-loss 1.1668e+01,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 220,            | Training-Loss 7.2878e-03,| Test-Loss 3.2695e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.7952e-04,| pde-loss 1.0425e+01,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 230,            | Training-Loss 1.6183e-02,| Test-Loss 8.0771e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.7784e-03,| pde-loss 9.7238e+00,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 240,            | Training-Loss 9.9524e-03,| Test-Loss 2.7257e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 4.2770e-04,| pde-loss 9.7453e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 250,            | Training-Loss 5.4747e-02,| Test-Loss 6.2112e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 4.7880e-03,| pde-loss 7.1310e+00,        | initc-loss 1.0420e+06,|bc_loss 0.0000e+00|
# | Epoch 260,            | Training-Loss 2.0316e-02,| Test-Loss 1.6747e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.5639e-03,| pde-loss 4.3981e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 270,            | Training-Loss 5.1799e-03,| Test-Loss 5.1009e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 6.9651e-04,| pde-loss 8.1599e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 280,            | Training-Loss 6.7139e-03,| Test-Loss 1.4811e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 8.0022e-04,| pde-loss 6.8730e+00,        | initc-loss 1.0408e+06,|bc_loss 0.0000e+00|
# | Epoch 290,            | Training-Loss 4.2552e-03,| Test-Loss 5.5204e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.5339e-04,| pde-loss 6.4280e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 300,            | Training-Loss 1.1636e-02,| Test-Loss 1.5792e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2585e-03,| pde-loss 8.3711e+00,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 310,            | Training-Loss 3.9812e-02,| Test-Loss 1.8040e-01   |
# --------------------------------------------------------------------------------
# | Data-loss 2.4590e-03,| pde-loss 6.8756e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 320,            | Training-Loss 1.0530e-02,| Test-Loss 3.2144e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 5.8862e-04,| pde-loss 7.5827e+00,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 330,            | Training-Loss 2.3229e-03,| Test-Loss 3.9642e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 5.0509e-04,| pde-loss 1.1126e+01,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 340,            | Training-Loss 2.4722e-03,| Test-Loss 5.4079e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.7810e-04,| pde-loss 8.4291e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 350,            | Training-Loss 3.0443e-01,| Test-Loss 8.0191e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 5.1474e-02,| pde-loss 7.8957e+00,        | initc-loss 1.0406e+06,|bc_loss 0.0000e+00|
# | Epoch 360,            | Training-Loss 1.0586e-02,| Test-Loss 1.5649e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0874e-03,| pde-loss 7.6721e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 370,            | Training-Loss 2.0290e-03,| Test-Loss 2.8673e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.8429e-04,| pde-loss 9.5843e+00,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 380,            | Training-Loss 1.8666e-03,| Test-Loss 2.1647e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3838e-04,| pde-loss 7.7153e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 390,            | Training-Loss 1.2447e-03,| Test-Loss 2.2244e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.2965e-04,| pde-loss 8.6440e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 400,            | Training-Loss 1.1872e-02,| Test-Loss 2.0524e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1779e-03,| pde-loss 6.5836e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 410,            | Training-Loss 8.4197e-03,| Test-Loss 1.2786e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 3.3973e-04,| pde-loss 6.6182e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 420,            | Training-Loss 2.0481e-02,| Test-Loss 1.0595e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 3.2168e-03,| pde-loss 1.0097e+01,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 430,            | Training-Loss 1.4966e-02,| Test-Loss 1.2831e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 9.5163e-04,| pde-loss 6.2931e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 440,            | Training-Loss 3.8798e-03,| Test-Loss 3.0045e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.1127e-04,| pde-loss 1.0495e+01,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 450,            | Training-Loss 1.2716e-03,| Test-Loss 1.8953e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2723e-04,| pde-loss 1.0116e+01,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 460,            | Training-Loss 4.3370e-03,| Test-Loss 1.6393e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 3.1355e-04,| pde-loss 7.3276e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 470,            | Training-Loss 2.4565e-03,| Test-Loss 6.3475e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.5215e-04,| pde-loss 8.2663e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 480,            | Training-Loss 8.3037e-03,| Test-Loss 8.1176e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.8487e-04,| pde-loss 5.9314e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 490,            | Training-Loss 1.8496e-02,| Test-Loss 4.6955e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.5062e-03,| pde-loss 8.6139e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 500,            | Training-Loss 2.2742e-03,| Test-Loss 1.0983e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1260e-04,| pde-loss 9.7686e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 510,            | Training-Loss 2.9106e-02,| Test-Loss 1.0244e-01   |
# --------------------------------------------------------------------------------
# | Data-loss 3.6120e-03,| pde-loss 6.7742e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 520,            | Training-Loss 2.4256e-03,| Test-Loss 5.9075e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.4010e-04,| pde-loss 7.0390e+00,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 530,            | Training-Loss 1.1998e-01,| Test-Loss 1.3872e-01   |
# --------------------------------------------------------------------------------
# | Data-loss 9.7318e-03,| pde-loss 4.0175e+00,        | initc-loss 1.0418e+06,|bc_loss 0.0000e+00|
# | Epoch 540,            | Training-Loss 1.5003e-01,| Test-Loss 3.0626e-01   |
# --------------------------------------------------------------------------------
# | Data-loss 8.1387e-03,| pde-loss 8.1672e+00,        | initc-loss 1.0418e+06,|bc_loss 0.0000e+00|
# | Epoch 550,            | Training-Loss 9.2835e-03,| Test-Loss 8.7635e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.0664e-04,| pde-loss 7.9395e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 560,            | Training-Loss 1.8468e-03,| Test-Loss 2.5041e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.7728e-04,| pde-loss 9.6143e+00,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 570,            | Training-Loss 7.3624e-03,| Test-Loss 8.2160e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 7.0462e-04,| pde-loss 6.7483e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 580,            | Training-Loss 1.2524e-03,| Test-Loss 2.2529e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 5.3309e-05,| pde-loss 5.4291e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 590,            | Training-Loss 1.0284e-03,| Test-Loss 1.8552e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.6608e-04,| pde-loss 8.9677e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 600,            | Training-Loss 4.0496e-03,| Test-Loss 4.0110e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 5.1637e-04,| pde-loss 8.8897e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 610,            | Training-Loss 7.4059e-03,| Test-Loss 6.2676e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3288e-03,| pde-loss 9.4291e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 620,            | Training-Loss 3.6287e-03,| Test-Loss 6.2328e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.7661e-04,| pde-loss 8.6710e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 630,            | Training-Loss 1.8695e-03,| Test-Loss 2.1321e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 8.6600e-05,| pde-loss 7.7768e+00,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 640,            | Training-Loss 3.8321e-03,| Test-Loss 1.0637e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 3.3860e-04,| pde-loss 6.9645e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 650,            | Training-Loss 1.4679e-03,| Test-Loss 2.1645e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 9.5210e-05,| pde-loss 8.8320e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 660,            | Training-Loss 1.0460e-02,| Test-Loss 8.6784e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1858e-03,| pde-loss 8.4479e+00,        | initc-loss 1.0410e+06,|bc_loss 0.0000e+00|
# | Epoch 670,            | Training-Loss 4.5215e-03,| Test-Loss 3.9929e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 5.1537e-04,| pde-loss 9.2833e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 680,            | Training-Loss 3.1936e-03,| Test-Loss 2.0619e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.9302e-04,| pde-loss 7.1845e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 690,            | Training-Loss 9.0144e-02,| Test-Loss 7.7248e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 2.1639e-03,| pde-loss 6.7834e+00,        | initc-loss 1.0419e+06,|bc_loss 0.0000e+00|
# | Epoch 700,            | Training-Loss 8.6015e-03,| Test-Loss 5.6026e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 6.0904e-04,| pde-loss 9.3583e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 710,            | Training-Loss 1.6937e-02,| Test-Loss 1.6101e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 4.6196e-04,| pde-loss 1.1492e+01,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 720,            | Training-Loss 4.2510e-03,| Test-Loss 3.8800e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.3303e-04,| pde-loss 5.9128e+00,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 730,            | Training-Loss 7.1730e-03,| Test-Loss 1.4587e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 2.1246e-04,| pde-loss 7.7604e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 740,            | Training-Loss 3.4046e-03,| Test-Loss 5.8911e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.6534e-04,| pde-loss 9.0361e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 750,            | Training-Loss 4.5428e-03,| Test-Loss 3.8686e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.0903e-04,| pde-loss 8.0310e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 760,            | Training-Loss 1.7637e-02,| Test-Loss 7.7204e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.5927e-03,| pde-loss 6.9932e+00,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 770,            | Training-Loss 1.7213e-03,| Test-Loss 2.4264e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 9.4453e-05,| pde-loss 6.1004e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 780,            | Training-Loss 4.6835e-03,| Test-Loss 4.6611e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.3308e-04,| pde-loss 6.1814e+00,        | initc-loss 1.0417e+06,|bc_loss 0.0000e+00|
# | Epoch 790,            | Training-Loss 6.6295e-03,| Test-Loss 1.3047e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 2.8689e-04,| pde-loss 1.0201e+01,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 800,            | Training-Loss 2.1067e-03,| Test-Loss 3.4600e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.6287e-04,| pde-loss 1.3633e+01,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 810,            | Training-Loss 1.2156e-02,| Test-Loss 8.4369e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3073e-03,| pde-loss 6.5002e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 820,            | Training-Loss 9.3496e-02,| Test-Loss 1.6031e-01   |
# --------------------------------------------------------------------------------
# | Data-loss 7.3260e-03,| pde-loss 7.2281e+00,        | initc-loss 1.0424e+06,|bc_loss 0.0000e+00|
# | Epoch 830,            | Training-Loss 1.4779e-02,| Test-Loss 3.4994e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2231e-03,| pde-loss 5.0344e+00,        | initc-loss 1.0417e+06,|bc_loss 0.0000e+00|
# | Epoch 840,            | Training-Loss 1.7277e-03,| Test-Loss 1.9251e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.5105e-04,| pde-loss 9.2365e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 850,            | Training-Loss 2.5575e-03,| Test-Loss 1.6904e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.4050e-04,| pde-loss 6.3950e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 860,            | Training-Loss 4.6388e-03,| Test-Loss 3.3506e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 7.6853e-04,| pde-loss 1.2968e+01,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 870,            | Training-Loss 6.3275e-03,| Test-Loss 4.5883e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 5.4862e-04,| pde-loss 8.3695e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 880,            | Training-Loss 3.5704e-03,| Test-Loss 5.4745e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.8821e-04,| pde-loss 7.2942e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 890,            | Training-Loss 1.6439e-02,| Test-Loss 2.9863e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2496e-03,| pde-loss 5.9788e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 900,            | Training-Loss 3.9327e-03,| Test-Loss 7.7315e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.0986e-04,| pde-loss 5.7666e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 910,            | Training-Loss 4.2587e-03,| Test-Loss 2.9140e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 5.8921e-04,| pde-loss 1.1646e+01,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 920,            | Training-Loss 6.9051e-03,| Test-Loss 1.0313e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 5.5224e-04,| pde-loss 6.1659e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 930,            | Training-Loss 2.1987e-01,| Test-Loss 4.2948e-01   |
# --------------------------------------------------------------------------------
# | Data-loss 5.0674e-02,| pde-loss 1.1909e+01,        | initc-loss 1.0408e+06,|bc_loss 0.0000e+00|
# | Epoch 940,            | Training-Loss 7.7050e-03,| Test-Loss 6.9457e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.5390e-03,| pde-loss 1.0065e+01,        | initc-loss 1.0417e+06,|bc_loss 0.0000e+00|
# | Epoch 950,            | Training-Loss 2.1828e-03,| Test-Loss 2.1764e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1861e-04,| pde-loss 5.8213e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 960,            | Training-Loss 3.8557e-03,| Test-Loss 5.0422e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.6292e-04,| pde-loss 8.0042e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 970,            | Training-Loss 4.9415e-03,| Test-Loss 8.1091e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.0620e-04,| pde-loss 4.9992e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 980,            | Training-Loss 4.2523e-03,| Test-Loss 1.4145e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 5.1495e-04,| pde-loss 1.1198e+01,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 990,            | Training-Loss 1.2138e-02,| Test-Loss 2.0786e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 6.4463e-04,| pde-loss 1.0090e+01,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1000,            | Training-Loss 9.8892e-03,| Test-Loss 6.5148e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.8794e-03,| pde-loss 9.4463e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 1010,            | Training-Loss 1.8117e-02,| Test-Loss 1.3164e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 2.5056e-03,| pde-loss 7.9047e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1020,            | Training-Loss 3.3166e-03,| Test-Loss 9.6374e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.8574e-04,| pde-loss 9.1455e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1030,            | Training-Loss 1.3736e-03,| Test-Loss 3.2273e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 5.7177e-05,| pde-loss 8.9681e+00,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 1040,            | Training-Loss 1.9019e-02,| Test-Loss 3.3331e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 9.9867e-04,| pde-loss 7.2353e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 1050,            | Training-Loss 4.9404e-03,| Test-Loss 4.7805e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.4481e-04,| pde-loss 7.6137e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1060,            | Training-Loss 1.8034e-02,| Test-Loss 2.3771e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 9.7546e-04,| pde-loss 1.0060e+01,        | initc-loss 1.0408e+06,|bc_loss 0.0000e+00|
# | Epoch 1070,            | Training-Loss 1.5748e-02,| Test-Loss 3.3496e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3078e-03,| pde-loss 6.6115e+00,        | initc-loss 1.0419e+06,|bc_loss 0.0000e+00|
# | Epoch 1080,            | Training-Loss 1.9128e-02,| Test-Loss 2.0701e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.4390e-03,| pde-loss 3.8863e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 1090,            | Training-Loss 2.7733e-03,| Test-Loss 4.2843e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.4978e-04,| pde-loss 7.5746e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 1100,            | Training-Loss 6.1566e-03,| Test-Loss 8.0618e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.0706e-04,| pde-loss 2.3689e+01,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1110,            | Training-Loss 1.7277e-03,| Test-Loss 2.4801e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.5551e-04,| pde-loss 8.5400e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1120,            | Training-Loss 8.5391e-03,| Test-Loss 8.7819e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 7.6426e-04,| pde-loss 1.0415e+01,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 1130,            | Training-Loss 6.1217e-03,| Test-Loss 1.3736e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 3.5512e-04,| pde-loss 7.4072e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1140,            | Training-Loss 2.1868e-03,| Test-Loss 3.3615e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.8062e-04,| pde-loss 6.8694e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1150,            | Training-Loss 3.5025e-03,| Test-Loss 5.6398e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.8056e-04,| pde-loss 6.7404e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1160,            | Training-Loss 1.0082e-03,| Test-Loss 1.8476e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 6.3154e-05,| pde-loss 9.0394e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1170,            | Training-Loss 4.3090e-03,| Test-Loss 9.0465e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.7515e-04,| pde-loss 6.2042e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1180,            | Training-Loss 1.3332e-02,| Test-Loss 7.2663e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 3.0188e-03,| pde-loss 7.5173e+00,        | initc-loss 1.0417e+06,|bc_loss 0.0000e+00|
# | Epoch 1190,            | Training-Loss 2.9514e-02,| Test-Loss 4.5877e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.9260e-03,| pde-loss 1.1467e+01,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 1200,            | Training-Loss 1.6868e-03,| Test-Loss 3.9285e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.4943e-04,| pde-loss 2.0836e+01,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1210,            | Training-Loss 1.5718e-03,| Test-Loss 3.2461e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.7517e-04,| pde-loss 1.4085e+01,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1220,            | Training-Loss 2.2911e-03,| Test-Loss 5.8207e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.6929e-04,| pde-loss 4.1532e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1230,            | Training-Loss 1.9896e-03,| Test-Loss 7.4779e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.9883e-04,| pde-loss 1.0995e+01,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 1240,            | Training-Loss 1.0411e-02,| Test-Loss 5.9680e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.5535e-03,| pde-loss 5.9415e+00,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 1250,            | Training-Loss 2.5926e-03,| Test-Loss 2.2695e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.4617e-04,| pde-loss 8.2506e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1260,            | Training-Loss 1.7626e-03,| Test-Loss 1.5930e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.8451e-04,| pde-loss 8.7120e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1270,            | Training-Loss 3.5166e-02,| Test-Loss 7.4596e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 2.6249e-03,| pde-loss 6.9772e+00,        | initc-loss 1.0418e+06,|bc_loss 0.0000e+00|
# | Epoch 1280,            | Training-Loss 1.1739e-02,| Test-Loss 1.6766e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 5.9822e-04,| pde-loss 1.0968e+01,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1290,            | Training-Loss 3.2436e-03,| Test-Loss 6.1183e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.2547e-04,| pde-loss 1.2664e+01,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1300,            | Training-Loss 9.3025e-03,| Test-Loss 1.5255e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 3.1179e-03,| pde-loss 7.0769e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1310,            | Training-Loss 4.9971e-03,| Test-Loss 5.8071e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.2330e-04,| pde-loss 6.4924e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1320,            | Training-Loss 4.4603e-03,| Test-Loss 4.5822e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.7210e-04,| pde-loss 9.0993e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1330,            | Training-Loss 8.2866e-03,| Test-Loss 4.9806e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 6.0229e-04,| pde-loss 1.1353e+01,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1340,            | Training-Loss 6.5519e-03,| Test-Loss 5.9353e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 7.2195e-04,| pde-loss 8.5042e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1350,            | Training-Loss 2.1712e-03,| Test-Loss 2.6929e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 9.4307e-05,| pde-loss 8.0179e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1360,            | Training-Loss 5.6842e-03,| Test-Loss 5.9767e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 6.6789e-04,| pde-loss 6.9834e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1370,            | Training-Loss 2.7356e-03,| Test-Loss 6.7524e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.5659e-04,| pde-loss 9.2631e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1380,            | Training-Loss 1.8728e-02,| Test-Loss 5.4028e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 2.0042e-03,| pde-loss 7.8677e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1390,            | Training-Loss 2.3628e-02,| Test-Loss 5.2085e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 2.3379e-03,| pde-loss 6.5902e+00,        | initc-loss 1.0418e+06,|bc_loss 0.0000e+00|
# | Epoch 1400,            | Training-Loss 1.1846e-02,| Test-Loss 1.7616e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2093e-03,| pde-loss 9.0493e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1410,            | Training-Loss 2.1417e-03,| Test-Loss 2.4215e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.2939e-04,| pde-loss 1.1914e+01,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1420,            | Training-Loss 1.7719e-03,| Test-Loss 2.8063e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2686e-04,| pde-loss 1.3430e+01,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1430,            | Training-Loss 1.9025e-03,| Test-Loss 9.0234e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.5461e-04,| pde-loss 7.3969e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1440,            | Training-Loss 9.7469e-03,| Test-Loss 1.3793e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2020e-03,| pde-loss 8.0137e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1450,            | Training-Loss 1.7244e-02,| Test-Loss 4.3545e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 9.0884e-04,| pde-loss 6.9590e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1460,            | Training-Loss 5.9456e-03,| Test-Loss 4.2533e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.4921e-04,| pde-loss 5.4154e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1470,            | Training-Loss 1.4728e-03,| Test-Loss 3.5812e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 7.3432e-05,| pde-loss 5.4962e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1480,            | Training-Loss 1.6104e-03,| Test-Loss 1.8748e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0781e-04,| pde-loss 1.0171e+01,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1490,            | Training-Loss 1.2581e-02,| Test-Loss 2.3025e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 2.3351e-03,| pde-loss 7.3799e+00,        | initc-loss 1.0417e+06,|bc_loss 0.0000e+00|
# | Epoch 1500,            | Training-Loss 2.5685e-03,| Test-Loss 5.3653e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.1674e-04,| pde-loss 4.9238e+00,        | initc-loss 1.0417e+06,|bc_loss 0.0000e+00|
# | Epoch 1510,            | Training-Loss 1.9789e-02,| Test-Loss 4.5034e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 3.4107e-03,| pde-loss 6.4442e+00,        | initc-loss 1.0411e+06,|bc_loss 0.0000e+00|
# | Epoch 1520,            | Training-Loss 7.1423e-03,| Test-Loss 9.8459e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 8.3467e-04,| pde-loss 6.1033e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1530,            | Training-Loss 6.0377e-03,| Test-Loss 9.9687e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.6769e-04,| pde-loss 1.2108e+01,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1540,            | Training-Loss 5.8091e-03,| Test-Loss 4.4057e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 9.0984e-04,| pde-loss 6.1694e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1550,            | Training-Loss 1.5302e-02,| Test-Loss 1.0626e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 5.8761e-04,| pde-loss 6.7255e+00,        | initc-loss 1.0418e+06,|bc_loss 0.0000e+00|
# | Epoch 1560,            | Training-Loss 2.3567e-03,| Test-Loss 1.7502e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.5287e-04,| pde-loss 7.3535e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1570,            | Training-Loss 2.4850e-03,| Test-Loss 3.9109e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.8753e-04,| pde-loss 1.1788e+01,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1580,            | Training-Loss 3.3176e-03,| Test-Loss 8.2333e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 8.2147e-05,| pde-loss 6.7465e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1590,            | Training-Loss 1.0543e-02,| Test-Loss 2.7430e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 8.1884e-04,| pde-loss 7.5666e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 1600,            | Training-Loss 1.2645e-02,| Test-Loss 2.8810e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.8664e-03,| pde-loss 6.8601e+00,        | initc-loss 1.0417e+06,|bc_loss 0.0000e+00|
# | Epoch 1610,            | Training-Loss 1.5600e-03,| Test-Loss 1.6231e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.4445e-04,| pde-loss 9.1575e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1620,            | Training-Loss 1.8853e-03,| Test-Loss 3.5507e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.4424e-04,| pde-loss 1.2296e+01,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 1630,            | Training-Loss 2.1427e-03,| Test-Loss 6.2161e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.5479e-04,| pde-loss 1.1102e+01,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1640,            | Training-Loss 4.8071e-03,| Test-Loss 6.8646e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.3857e-04,| pde-loss 8.5517e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1650,            | Training-Loss 2.1940e-03,| Test-Loss 7.8326e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.0416e-04,| pde-loss 4.9133e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1660,            | Training-Loss 5.7869e-03,| Test-Loss 1.1239e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 2.1758e-04,| pde-loss 8.7744e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1670,            | Training-Loss 1.7637e-03,| Test-Loss 2.8960e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.9070e-04,| pde-loss 7.9104e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1680,            | Training-Loss 1.5952e-03,| Test-Loss 1.3420e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.0287e-04,| pde-loss 7.3468e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1690,            | Training-Loss 4.7966e-03,| Test-Loss 4.3386e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.6385e-04,| pde-loss 4.3174e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1700,            | Training-Loss 8.1423e-03,| Test-Loss 7.9636e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.5123e-03,| pde-loss 8.8634e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1710,            | Training-Loss 4.3017e-03,| Test-Loss 4.8398e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.6408e-04,| pde-loss 5.3738e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 1720,            | Training-Loss 8.2447e-03,| Test-Loss 7.6911e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 6.9737e-04,| pde-loss 8.3035e+00,        | initc-loss 1.0417e+06,|bc_loss 0.0000e+00|
# | Epoch 1730,            | Training-Loss 2.2218e-02,| Test-Loss 5.0307e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 5.9463e-04,| pde-loss 4.7720e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1740,            | Training-Loss 2.1575e-02,| Test-Loss 1.4988e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.9098e-03,| pde-loss 8.8316e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1750,            | Training-Loss 1.7486e-03,| Test-Loss 2.1274e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0680e-04,| pde-loss 6.0964e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 1760,            | Training-Loss 3.1275e-03,| Test-Loss 3.7144e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.4898e-04,| pde-loss 1.2600e+01,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1770,            | Training-Loss 2.1843e-02,| Test-Loss 3.0895e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0952e-03,| pde-loss 7.0519e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 1780,            | Training-Loss 2.3381e-02,| Test-Loss 9.3171e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.4069e-03,| pde-loss 2.7650e+01,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1790,            | Training-Loss 2.5057e-03,| Test-Loss 3.5350e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0105e-04,| pde-loss 5.3073e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1800,            | Training-Loss 4.5848e-03,| Test-Loss 6.1898e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 9.8070e-05,| pde-loss 6.4125e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1810,            | Training-Loss 2.0794e-03,| Test-Loss 2.2745e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.1500e-04,| pde-loss 8.4941e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 1820,            | Training-Loss 5.7802e-03,| Test-Loss 4.4643e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.8584e-04,| pde-loss 5.9807e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 1830,            | Training-Loss 2.5493e-03,| Test-Loss 2.5550e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.5988e-04,| pde-loss 1.0999e+01,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1840,            | Training-Loss 4.1616e-03,| Test-Loss 8.8143e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.5311e-04,| pde-loss 6.5763e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1850,            | Training-Loss 2.5099e-03,| Test-Loss 4.3468e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.5532e-04,| pde-loss 8.1094e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 1860,            | Training-Loss 6.9587e-03,| Test-Loss 2.6804e-02   |
# ...
# | Epoch 4380,            | Training-Loss 3.0703e-03,| Test-Loss 4.3379e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.9731e-04,| pde-loss 1.1881e+01,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 4390,            | Training-Loss 1.2122e-03,| Test-Loss 1.7034e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.3759e-04,| pde-loss 1.0632e+01,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4400,            | Training-Loss 1.1354e-03,| Test-Loss 1.4813e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 8.0404e-05,| pde-loss 9.4358e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4410,            | Training-Loss 6.1963e-03,| Test-Loss 1.0389e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 5.4969e-04,| pde-loss 1.1387e+01,        | initc-loss 1.0417e+06,|bc_loss 0.0000e+00|
# | Epoch 4420,            | Training-Loss 2.5642e-03,| Test-Loss 5.8118e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2387e-04,| pde-loss 4.8968e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4430,            | Training-Loss 1.3096e-02,| Test-Loss 6.0564e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.8426e-03,| pde-loss 7.7998e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4440,            | Training-Loss 1.6932e-03,| Test-Loss 2.1034e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.5221e-04,| pde-loss 7.1751e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4450,            | Training-Loss 8.8033e-03,| Test-Loss 1.1271e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 4.9064e-04,| pde-loss 5.6817e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4460,            | Training-Loss 2.5824e-03,| Test-Loss 2.4641e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.3915e-04,| pde-loss 9.4082e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4470,            | Training-Loss 1.5425e-03,| Test-Loss 1.8314e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 8.7314e-05,| pde-loss 9.0604e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 4480,            | Training-Loss 1.1103e-03,| Test-Loss 1.9477e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 9.1103e-05,| pde-loss 6.8294e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4490,            | Training-Loss 5.9137e-04,| Test-Loss 1.7470e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 7.1457e-05,| pde-loss 9.5980e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4500,            | Training-Loss 8.0083e-03,| Test-Loss 2.3052e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 3.7256e-04,| pde-loss 7.3246e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4510,            | Training-Loss 4.8062e-03,| Test-Loss 8.5028e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.6676e-04,| pde-loss 6.9957e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4520,            | Training-Loss 1.8640e-03,| Test-Loss 3.8300e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.2906e-04,| pde-loss 9.5407e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 4530,            | Training-Loss 5.4638e-03,| Test-Loss 3.3804e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.9515e-04,| pde-loss 6.9302e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4540,            | Training-Loss 4.0099e-03,| Test-Loss 7.6331e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.6760e-04,| pde-loss 5.9807e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4550,            | Training-Loss 8.4378e-04,| Test-Loss 2.5649e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 6.7600e-05,| pde-loss 9.2398e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4560,            | Training-Loss 7.1447e-04,| Test-Loss 1.3910e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.2633e-05,| pde-loss 8.9565e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4570,            | Training-Loss 6.0520e-03,| Test-Loss 7.9605e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 6.6638e-04,| pde-loss 5.2030e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 4580,            | Training-Loss 5.8039e-03,| Test-Loss 1.5547e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 9.0861e-04,| pde-loss 6.2964e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4590,            | Training-Loss 2.7859e-03,| Test-Loss 3.4775e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0217e-04,| pde-loss 4.8522e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4600,            | Training-Loss 1.4400e-03,| Test-Loss 5.1472e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 6.6227e-05,| pde-loss 8.3828e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4610,            | Training-Loss 2.5352e-03,| Test-Loss 3.5050e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.6794e-04,| pde-loss 7.2950e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4620,            | Training-Loss 9.5187e-04,| Test-Loss 3.9187e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.6116e-04,| pde-loss 8.7852e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4630,            | Training-Loss 1.8492e-03,| Test-Loss 4.2134e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 5.7698e-05,| pde-loss 5.7869e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4640,            | Training-Loss 1.7960e-03,| Test-Loss 4.8047e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 9.4176e-05,| pde-loss 5.5333e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 4650,            | Training-Loss 2.7351e-03,| Test-Loss 2.7801e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.3746e-04,| pde-loss 7.2451e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4660,            | Training-Loss 2.2339e-03,| Test-Loss 2.1589e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.3033e-04,| pde-loss 1.0794e+01,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 4670,            | Training-Loss 2.3301e-03,| Test-Loss 4.5453e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.8201e-04,| pde-loss 8.8859e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4680,            | Training-Loss 1.2020e-02,| Test-Loss 1.2361e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 4.5469e-04,| pde-loss 9.3713e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4690,            | Training-Loss 1.0542e-03,| Test-Loss 1.4864e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 6.8002e-05,| pde-loss 9.6137e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4700,            | Training-Loss 7.8308e-04,| Test-Loss 1.2061e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 7.7038e-05,| pde-loss 8.4174e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4710,            | Training-Loss 1.3283e-03,| Test-Loss 3.1464e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 5.4632e-05,| pde-loss 6.0729e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4720,            | Training-Loss 5.7785e-03,| Test-Loss 5.3114e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.9431e-03,| pde-loss 7.6978e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 4730,            | Training-Loss 9.7256e-03,| Test-Loss 1.8446e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 4.7759e-04,| pde-loss 7.7098e+00,        | initc-loss 1.0417e+06,|bc_loss 0.0000e+00|
# | Epoch 4740,            | Training-Loss 1.5022e-03,| Test-Loss 2.2623e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1085e-04,| pde-loss 9.7950e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4750,            | Training-Loss 6.5259e-04,| Test-Loss 1.5195e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.9175e-05,| pde-loss 8.6773e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4760,            | Training-Loss 2.7404e-03,| Test-Loss 1.9475e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.2943e-04,| pde-loss 1.0038e+01,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 4770,            | Training-Loss 1.1955e-03,| Test-Loss 2.0948e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.8933e-04,| pde-loss 1.0912e+01,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4780,            | Training-Loss 3.0516e-03,| Test-Loss 5.4162e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 8.7881e-05,| pde-loss 7.2636e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 4790,            | Training-Loss 1.1091e-03,| Test-Loss 1.9073e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0277e-04,| pde-loss 9.6635e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4800,            | Training-Loss 1.4418e-03,| Test-Loss 1.8070e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 7.9819e-05,| pde-loss 6.8132e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 4810,            | Training-Loss 1.9101e-03,| Test-Loss 4.4432e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.3776e-04,| pde-loss 8.9844e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4820,            | Training-Loss 4.3135e-03,| Test-Loss 4.3404e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.2749e-03,| pde-loss 5.8218e+00,        | initc-loss 1.0417e+06,|bc_loss 0.0000e+00|
# | Epoch 4830,            | Training-Loss 7.1245e-03,| Test-Loss 8.2653e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.3427e-04,| pde-loss 7.1119e+00,        | initc-loss 1.0415e+06,|bc_loss 0.0000e+00|
# | Epoch 4840,            | Training-Loss 1.7789e-03,| Test-Loss 2.5069e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 9.5138e-05,| pde-loss 8.5738e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4850,            | Training-Loss 2.6065e-03,| Test-Loss 2.6334e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 3.3954e-04,| pde-loss 5.6082e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4860,            | Training-Loss 2.4870e-03,| Test-Loss 1.9779e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 4.7002e-04,| pde-loss 8.9113e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4870,            | Training-Loss 1.3241e-03,| Test-Loss 2.1760e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.0008e-04,| pde-loss 7.8943e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4880,            | Training-Loss 6.0223e-03,| Test-Loss 1.3981e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 7.8761e-04,| pde-loss 9.7684e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4890,            | Training-Loss 1.7478e-03,| Test-Loss 2.6851e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.6597e-04,| pde-loss 9.4542e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 4900,            | Training-Loss 2.4529e-02,| Test-Loss 1.5314e-02   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1863e-03,| pde-loss 6.9173e+00,        | initc-loss 1.0417e+06,|bc_loss 0.0000e+00|
# | Epoch 4910,            | Training-Loss 2.8064e-03,| Test-Loss 3.8157e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 2.5980e-04,| pde-loss 8.4516e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4920,            | Training-Loss 2.1043e-03,| Test-Loss 3.5686e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.6242e-04,| pde-loss 9.0351e+00,        | initc-loss 1.0412e+06,|bc_loss 0.0000e+00|
# | Epoch 4930,            | Training-Loss 8.5890e-04,| Test-Loss 1.5683e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 8.7184e-05,| pde-loss 7.8363e+00,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4940,            | Training-Loss 1.5786e-03,| Test-Loss 4.2758e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.4887e-04,| pde-loss 1.1912e+01,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4950,            | Training-Loss 1.1266e-03,| Test-Loss 3.0209e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 1.1078e-04,| pde-loss 6.9510e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4960,            | Training-Loss 4.0965e-03,| Test-Loss 2.6583e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 7.2344e-04,| pde-loss 1.1255e+01,        | initc-loss 1.0414e+06,|bc_loss 0.0000e+00|
# | Epoch 4970,            | Training-Loss 2.5148e-03,| Test-Loss 5.8179e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 6.7526e-05,| pde-loss 9.9658e+00,        | initc-loss 1.0413e+06,|bc_loss 0.0000e+00|
# | Epoch 4980,            | Training-Loss 4.4932e-03,| Test-Loss 5.2997e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 5.1368e-04,| pde-loss 8.4356e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|
# | Epoch 4990,            | Training-Loss 5.0344e-03,| Test-Loss 2.8441e-03   |
# --------------------------------------------------------------------------------
# | Data-loss 5.9836e-04,| pde-loss 9.5930e+00,        | initc-loss 1.0416e+06,|bc_loss 0.0000e+00|

# %% [markdown]
# ## Plots

# %%
temp_nn = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model
print(temp_nn.shape)
temp_nn = scaler1.inverse_transform(temp_nn) # Inverse transform the predictions
temp_nn = temp_nn.reshape(num_steps+1, num_points) # Reshape the predictions to a 2D array
time_ss= np.linspace(0, time_end, num_steps+1 )

plt.figure
plt.plot(time_ss, temp_nn[:, num_points//2], label='Predicted Temperature')
plt.plot(time_ss, temperature_history[:,num_points//2], label='Actual Temperature')
plt.xlabel('Time(s)')
plt.ylabel('Temperature (K)')
plt.yscale('linear')
plt.title('Predicted vs Actual Temperature at x = 7.5mm')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 temp_nn = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model
#       2 print(temp_nn.shape)
#       3 temp_nn = scaler1.inverse_transform(temp_nn) # Inverse transform the predictions
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[86], line 23, in Mushydata.forward(self, x, t)
#      21 def forward(self, x, t):                               # This is the forward pass
#      22     input_features = torch.cat([x, t], dim=1)          # Concatenate the input features
# ---> 23     m = self.base(input_features)                                 # Pass through the third layer
#      24     return m
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/modules/activation.py:103, in ReLU.forward(self, input)
#     102 def forward(self, input: Tensor) -> Tensor:
# --> 103     return F.relu(input, inplace=self.inplace)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/functional.py:1500, in relu(input, inplace)
#    1498     result = torch.relu_(input)
#    1499 else:
# -> 1500     result = torch.relu(input)
#    1501 return result
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 314.00 MiB. GPU

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(test_losses, label='test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data_losses, label='Data Loss')
plt.plot(pde_losses, label='Pde Loss')
plt.plot(ic_losses, label='IC Loss')
plt.plot(bc_losses, label='BC Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.plot(data_losses, label='Data Loss')
#       3 plt.plot(pde_losses, label='Pde Loss')
#       4 plt.plot(ic_losses, label='IC Loss')
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/matplotlib/pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/matplotlib/axes/_base.py:491, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     489     y = _check_1d(xy[1])
#     490 else:
# --> 491     x, y = index_of(xy[-1])
#     493 if axes.xaxis is not None:
#     494     axes.xaxis.update_units(x)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/matplotlib/cbook.py:1666, in index_of(y)
#    1664     pass
#    1665 try:
# -> 1666     y = _check_1d(y)
#    1667 except (VisibleDeprecationWarning, ValueError):
#    1668     # NumPy 1.19 will warn on ragged input, and we can't actually use it.
#    1669     pass
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/matplotlib/cbook.py:1358, in _check_1d(x)
#    1352 # plot requires `shape` and `ndim`.  If passed an
#    1353 # object that doesn't provide them, then force to numpy array.
#    1354 # Note this will strip unit information.
#    1355 if (not hasattr(x, 'shape') or
#    1356         not hasattr(x, 'ndim') or
#    1357         len(x.shape) < 1):
# -> 1358     return np.atleast_1d(x)
#    1359 else:
#    1360     return x
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/numpy/core/shape_base.py:65, in atleast_1d(*arys)
#      63 res = []
#      64 for ary in arys:
# ---> 65     ary = asanyarray(ary)
#      66     if ary.ndim == 0:
#      67         result = ary.reshape(1)
#
# File ~/anaconda3/envs/pytorch-env/lib/python3.11/site-packages/torch/_tensor.py:1087, in Tensor.__array__(self, dtype)
#    1085     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1086 if dtype is None:
# -> 1087     return self.numpy()
#    1088 else:
#    1089     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
space_coord, time_coord = np.meshgrid(np.arange(t_hist.shape[1]), np.arange(t_hist.shape[0]))

time_coord = time_coord * dt 
# Create a figure with two subplots

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))


# Plot the temperature history on the left subplot
im1 = ax1.pcolormesh(space_coord, time_coord, t_hist, cmap='viridis', shading='auto')
ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax1.set_title('Temperature Variation Over Time(Analytical Model)',fontname='Times New Roman', fontsize=20)
ax1.contour(space_coord, time_coord, t_hist, colors='red', linewidths=1.0, alpha=0.9)

ax1.grid(True)
cbar = fig.colorbar(im1, ax=ax1)
cbar.ax.invert_yaxis()
cbar.set_label('Temperature (K)', rotation=270, labelpad=20, fontname='Times New Roman', fontsize=16)

im2 = ax2.pcolormesh(space_coord, time_coord, temp_nn, cmap='viridis', shading='auto')
ax2.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax2.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax2.set_title('Temperature Variation Over Time(PINN model)',fontname='Times New Roman', fontsize=20)
ax2.contour(space_coord, time_coord, temp_nn, colors='red', linewidths=1.0, alpha=0.9)

ax2.grid(True)
cbar = fig.colorbar(im2, ax=ax2)
cbar.ax.invert_yaxis()
cbar.set_label('Temperature (K)', rotation=270, labelpad=20, fontname='Times New Roman', fontsize=16)


plt.tight_layout()
plt.show()
