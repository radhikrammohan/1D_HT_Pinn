# %% [markdown]
# # 1D Three Phase Simulation of Alloys and PINN model development

# %% [markdown]
# This notebook contains the simulation of 1D Phase change of aluminium alloy. There will be three phases (solid,liquid and mushy).
#
# The approach used is finite difference method and the physics involved in heat conduction.

# %% [markdown]
# ## Import Libraries

# %%
import sys
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import csv
from sklearn import svm
import pandas as pd
import itertools
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, RandomSampler

from pinn_loss import loss_fn_data, l1_regularization, pde_loss, boundary_loss, ic_loss, accuracy
from Input_vec_gen import input_gen

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Define the constants and inital geometric domain

# %%
# Geometry
length = 15.0e-3             # Length of the rod

# Material properties
rho = 2300.0                     # Density of AL380 (kg/m^3)
rho_l = 2460.0                   # Density of AL380 (kg/m^3)
rho_s = 2710.0                    # Density of AL380 (kg/m^3)
rho_m = (rho_l + rho_s )/2       # Desnity in mushy zone is taken as average of liquid and solid density

k = 104.0                       # W/m-K
k_l = k                       # W/m-K
k_s = 96.2                    # W/m-K
k_m =  (k_l+k_s)/2                     # W/m-K
k_mo = 41.5


cp = 1245.3                      # Specific heat of aluminum (J/kg-K)
cp_l = cp                      # Specific heat of aluminum (J/kg-K)
cp_s = 963.0                 # Specific heat of aluminum (J/kg-K)
cp_m =  (cp_l+cp_s)/2                 # Specific heat of mushy zone is taken as average of liquid and solid specific heat
# cp_m = cp
           # Thermal diffusivity
alpha_l = k_l / (rho_l * cp_l) 
alpha_s = k_s / (rho_s*cp_s)
alpha_m = k_m / (rho_m * cp_m)          #`Thermal diffusivity in mushy zone is taken as average of liquid and solid thermal diffusivity`


#L_fusion = 3.9e3                 # J/kg
L_fusion = 389.0e3               # J/kg  # Latent heat of fusion of aluminum
         # Thermal diffusivity


T_L = 574.4 +273.0                       #  K -Liquidus Temperature (615 c) AL 380
T_S = 497.3 +273.0                     # K- Solidus Temperature (550 C)
m_eff =(k_m/(rho_m*(cp_m + (L_fusion/(T_L-T_S)))))
print (f"alpha_l = {alpha_l}, alpha_s = {alpha_s}, m_eff = {m_eff}")

# htc = 10.0                   # W/m^2-K
# q = htc*(919.0-723.0)
# q = 10000.0


num_points = 50                        # Number of spatial points
dx = length / (num_points - 1)         # Distance between two spatial points
print('dx is',dx)

                                                              
# Time Discretization  
# 
time_end = 40        # seconds                         

maxi = max(alpha_s,alpha_l,alpha_m)
dt = abs(0.5*((dx**2) /maxi)) 

print('dt is ',dt)
num_steps = round(time_end/dt)
print('num_steps is',num_steps)
cfl = 0.5 *(dx**2/max(alpha_l,alpha_s,alpha_m))
print('cfl is',cfl)

time_steps = np.linspace(0, time_end, num_steps + 1)
step_coeff = dt / (dx ** 2)

if dt <= cfl:
    print('stability criteria satisfied')
else:
    print('stability criteria not satisfied')
    sys.exit()
# Out:
# alpha_l = 3.394878564540885e-05, alpha_s = 3.686205086349929e-05, m_eff = 6.296953764744878e-06
# dx is 0.0003061224489795918
# dt is  0.0012711033647622566
# num_steps is 31469
# cfl is 0.0012711033647622566
# stability criteria satisfied

# %% [markdown]
# ### Initial and Boundary Conditions

# %%
temp_init = 919.0
# Initial temperature and phase fields
temperature = np.full(num_points+2, 919.0)            # Initial temperature of the rod with ghost points at both ends
phase = np.zeros(num_points+2)*0.0                    # Initial phase of the rod with ghost points at both ends

# Set boundary conditions
# temperature[-1] = 919.0 
phase[-1] = 1.0

# temperature[0] = 919.0 #(40 C)
phase[0] = 1.0

# Store initial state in history
temperature_history = [temperature.copy()]    # List to store temperature at each time step
phi_history = [phase.copy()]                    # List to store phase at each time step
temp_init = temperature.copy()                 # Initial temperature of the rod
# print(temperature_history,phi_history)
# Array to store temperature at midpoint over time
midpoint_index = num_points // 2                          # Index of the midpoint

midpoint_temperature_history = [temperature[midpoint_index]]            # List to store temperature at midpoint over time
dm = 60.0e-3                                                            # die thickness in m

# r_m =  (k_mo / dm) + (1/htc)

t_surr = 500.0                                        # Surrounding temperature in K
# t_surr = h()

def kramp(temp,v1,v2,T_L,T_s):                                      # Function to calculate thermal conductivity in Mushy Zone
        slope = (v1-v2)/(T_L-T_S)
        if temp > T_L:
            k_m = k_l
        elif temp < T_S:
            k_m = k_s
        else:
            k_m = k_s + slope*(temp-T_S)
        return k_m

def cp_ramp(temp,v1,v2,T_L,T_s):                                    # Function to calculate specific heat capacity in Mushy Zone
    slope = (v1-v2)/(T_L-T_S)
    if temp > T_L:
        cp_m = cp_l
    elif temp < T_S:
        cp_m = cp_s
    else:
        cp_m = cp_s + slope*(temp-T_S)
    return cp_m

def rho_ramp(temp,v1,v2,T_L,T_s):                                       # Function to calculate density in Mushy Zone
    slope = (v1-v2)/(T_L-T_S)
    if temp > T_L:
        rho_m = rho_l
    elif temp < T_S:
        rho_m = rho_s
    else:
        rho_m = rho_s + slope*(temp-T_S)
    return rho_m

# %% [markdown]
# ### Solving the HT equation and phase change numerically

# %%
for m in range(1, num_steps+1):                                                                            # time loop
    htc = 10.0                   # htc of Still air in W/m^2-K
    q1 = htc*(temp_init[0]-t_surr)   # Heat flux at the left boundary
    
    # print(f"q1 is {q1}")
    temperature[0] = temp_init[0] + alpha_l * step_coeff * ((2.0*temp_init[1]) - (2.0 * temp_init[0])-(2.0*dx*(q1)))  # Update boundary condition temperature
    
    q2 = htc*(temp_init[-1]-t_surr)                   # Heat flux at the right boundary
    temperature[-1] = temp_init[-1] + alpha_l * step_coeff * ((2.0*temp_init[-2]) - (2.0 * temp_init[-1])-(2.0*dx*(q2)))  # Update boundary condition temperature
    
    for n in range(1,num_points+1):              # space loop, adjusted range
       
        if temperature[n] >= T_L:
            temperature[n] += ((alpha_l * step_coeff) * (temp_init[n+1] - (2.0 * temp_init[n]) + temp_init[n-1]))
            phase[n] = 0
            
            # print(f" Time-Step{m},Spatial point{n},Temperature{temperature[n]}")
        elif T_S < temperature[n] < T_L:
            
            k_m = kramp(temperature[n],k_l,k_s,T_L,T_S)
            cp_m = cp_ramp(temperature[n],cp_l,cp_s,T_L,T_S)
            rho_m = rho_ramp(temperature[n],rho_l,rho_s,T_L,T_S)
            m_eff =(k_m/(rho_m*(cp_m + (L_fusion/(T_L-T_S)))))
            
            temperature[n] += ((m_eff * step_coeff)* (temp_init[n+1] - (2.0 * temp_init[n]) + temp_init[n-1]))
            
            phase[n] = (T_L - temperature[n]) / (T_L - T_S)
            # print(m,n,temperature[n],phase[n])
         
        elif temperature[n]<T_S:
            temperature[n] += ((alpha_s * step_coeff) * (temp_init[n+1] - (2.0 * temp_init[n])+ temp_init[n-1]))
            phase[n] = 1
                     
        else:
            print("ERROR: should not be here")

     
          
    temperature = temperature.copy()                                                                # Update temperature
    phase = phase.copy()                                                                            # Update phase
    temp_init = temperature.copy()                                                                  # Update last time step temperature
    temperature_history.append(temperature.copy())                                                  # Append the temperature history to add ghost points
    phi_history.append(phase.copy())                                                                # Append the phase history to add ghost points
    midpoint_temperature_history.append(temperature[midpoint_index])                                # Store midpoint temperature
    
    
    # print(f"Step {m}, Temperature: {temperature}")
    


# print(midpoint_temperature_history)
#print(phi_history)

# %% [markdown]
# ### Plot the Results

# %%
# # Plot temperature history for debugging
# temperature_history_1 = np.array(temperature_history)
# print(temperature_history_1.shape)
# time_ss= np.linspace(0, time_end, num_steps+1)
# # print(time_ss.shape)
# plt.figure(figsize=(10, 6))
# plt.plot(time_ss, midpoint_temperature_history, label='Midpoint Temperature')
# plt.axhline(y=T_L, color='r', linestyle='--', label='Liquidus Temperature')
# plt.axhline(y=T_S, color='g', linestyle='--', label='Solidus Temperature')
# plt.xlabel('Time(s)')
# plt.ylabel('Temperature (K)')
# plt.title('Temperature Distribution Over Time at x = 7.5mm') 
# plt.legend()
# plt.show()

# %% [markdown]
# ### Data into Array

# %%
temperature_history = np.array(temperature_history)

phi_history = np.array(phi_history)

t_hist = np.array(temperature_history[:,1:-1])
p_hist = np.array(phi_history[:,1:-1])

t_hist_init = t_hist[0,:]
t_hist_bc_l = t_hist[:,0]
t_hist_bc_r = t_hist[:,-1]

# %%
# Assuming you have temperature_history and phi_history as lists of arrays


# # Check the new shape after transposing
# print("Transposed Temperature History Shape:", temperature_history.shape)
# print("Transposed Phi History Shape:", phi_history.shape)

# # Create a meshgrid for space and time coordinates
# space_coord, time_coord = np.meshgrid(np.arange(temperature_history.shape[1]), np.arange(temperature_history.shape[0]))

# time_coord = time_coord * dt 
# # Create a figure with two subplots
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# # Plot the temperature history on the left subplot
# im1 = ax1.pcolormesh(space_coord, time_coord, temperature_history, cmap='viridis')
# ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
# ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
# ax1.set_title('Temperature Variation Over Time',fontname='Times New Roman', fontsize=20)
# fig.colorbar(im1, ax=ax1, label='Temperature')

# # Plot the phase history on the right subplot
# im2 = ax2.pcolormesh(space_coord, time_coord, phi_history, cmap='viridis')
# ax2.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=18)
# ax2.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
# ax2.set_title('Phase Variation Over Time',fontname='Times New Roman', fontsize=20)
# fig.colorbar(im2, ax=ax2, label='Phase')
# plt.tight_layout()
# plt.show()

# #plot the main
# fig, ax = plt.subplots(figsize=(14, 6))
# im = ax.pcolormesh(space_coord, time_coord, Dim_ny, cmap='viridis')
# ax.set_xlabel('Space Coordinate')
# ax.set_ylabel('Time')
# ax.set_title('Niyama Variation Over Time')
# fig.colorbar(im, ax=ax, label='Main')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## ML training

# %% [markdown]
# ### GPU/CPU check

# %%
# check for gpu
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Data preparation

# %%
space = np.linspace(0, length, num_points) # Spatial points
time = np.linspace(0, time_end, num_steps+1) # Time points
print(space.shape,time.shape)

sp_i = np.linspace(0, length, num_points) # Spatial points
time_i = np.zeros(num_points) # Time points

sp_b_l = np.zeros(num_steps+1) # Spatial points
time_b_l = np.linspace(0, time_end, num_steps+1) # Time points

sp_b_r = np.ones(num_steps+1)*length # Spatial points
time_b_r = np.linspace(0, time_end, num_steps+1) # Time points
# Out:
# (50,) (31470,)

# %%
inputs = input_gen(space,time,'mgrid')
inputs_i = input_gen(sp_i,time_i,'scr')
inputs_b_l = input_gen(sp_b_l,time_b_l,'scr')
inputs_b_r = input_gen(sp_b_r,time_b_r,'scr')

# %%
print(inputs.shape,inputs_i.shape,inputs_b_l.shape,inputs_b_r.shape)
# Out:
# (1573500, 2) (50, 2) (31470, 2) (31470, 2)

# %%
inputs = torch.tensor(inputs).float().to(device) # Convert the inputs to a tensor


inputs_init = torch.tensor(inputs_i).float().to(device) # Convert the inputs to a tensor
inputs_b_l = torch.tensor(inputs_b_l).float().to(device)# Convert the inputs to a tensor
inputs_b_r = torch.tensor(inputs_b_r).float().to(device)# Convert the inputs to a tensor

print(inputs_init.shape)
# label/temp data
temp_tr = torch.tensor(t_hist).float().to(device) # Convert the temperature history to a tensor
temp_inp = temp_tr.reshape(-1,1).float().to(device) # Reshape the temperature tensor to a column vector
temp_inp_init = torch.tensor(t_hist_init).float().to(device) # Convert the temperature history to a tensor
temp_inp_bc_l = torch.tensor(t_hist_bc_l).float().to(device)# Convert the temperature history to a tensor
temp_inp_bc_r = torch.tensor(t_hist_bc_r).float().to(device)# Convert the temperature history to a tensor
print(temp_inp.shape)



#Data Splitting

# train_inputs, val_test_inputs, train_temp_inp, val_test_temp_inp = train_test_split(inputs, temp_inp, test_size=0.2, random_state=42)
# val_inputs, test_inputs, val_temp_inp, test_temp_inp = train_test_split(val_test_inputs, val_test_temp_inp, test_size=0.8, random_state=42)

train_inputs, test_inputs, train_temp_inp, test_temp_inp = train_test_split(inputs, temp_inp,\
                                                                             test_size=0.2, random_state=42)
train_inputs_init, test_inputs_init, train_temp_inp_init, test_temp_inp_init = train_test_split(inputs_init, temp_inp_init, \
                                                                                                test_size=0.2, random_state=42)
train_inputs_bc_l, test_inputs_bc_l, train_temp_inp_bc_l, test_temp_inp_bc_l = train_test_split(inputs_b_l, temp_inp_bc_l, \
                                                                                                 test_size=0.2, random_state=42)
train_inputs_bc_r, test_inputs_bc_r, train_temp_inp_bc_r, test_temp_inp_bc_r = train_test_split(inputs_b_r, temp_inp_bc_r, \
                                                                                                test_size=0.2, random_state=42)
# Out:
# torch.Size([50, 2])
# torch.Size([1573500, 1])

# %% [markdown]
# ### Create Data loader

# %%
class TensorDataset(torch.utils.data.Dataset):
    def __init__(self, inputs, temp_inp,transform=None, target_transform =None):
        self.inputs = inputs
        self.temp_inp = temp_inp

    def __getitem__(self, index):
        return self.inputs[index], self.temp_inp[index]
    
    def __len__(self):
        return len(self.inputs)

  
train_dataset = TensorDataset(train_inputs, train_temp_inp) # Create the training dataset
# val_dataset = TensorDataset(val_inputs, val_temp_inp) # Create the validation dataset
test_dataset = TensorDataset(test_inputs, test_temp_inp) # Create the test dataset

train_dataset_init = TensorDataset(train_inputs_init, train_temp_inp_init) # Create the training dataset
test_dataset_init = TensorDataset(test_inputs_init, test_temp_inp_init) # Create the test dataset
train_dataset_bc_l = TensorDataset(train_inputs_bc_l, train_temp_inp_bc_l) # Create the training dataset
test_dataset_bc_l = TensorDataset(test_inputs_bc_l, test_temp_inp_bc_l) # Create the test dataset
train_dataset_bc_r = TensorDataset(train_inputs_bc_r, train_temp_inp_bc_r) # Create the training dataset
test_dataset_bc_r = TensorDataset(test_inputs_bc_r, test_temp_inp_bc_r) # Create the test dataset


batch_size = 128

random_sampler_train = RandomSampler(train_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the training dataset
# random_sampler_val = RandomSampler(val_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the validation dataset
random_sampler_test = RandomSampler(test_dataset, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset

random_sampler_train_init = RandomSampler(train_dataset_init, replacement=True, num_samples=batch_size) # Create a random sampler for the training dataset
random_sampler_test_init = RandomSampler(test_dataset_init, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset
random_sampler_train_bc_l = RandomSampler(train_dataset_bc_l, replacement=True, num_samples=batch_size) # Create a random sampler for the training dataset
random_sampler_test_bc_l = RandomSampler(test_dataset_bc_l, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset
random_sampler_train_bc_r = RandomSampler(train_dataset_bc_r, replacement=True, num_samples=batch_size) # Create a random sampler for the training dataset
random_sampler_test_bc_r = RandomSampler(test_dataset_bc_r, replacement=True, num_samples=batch_size) # Create a random sampler for the test dataset





train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=random_sampler_train) # Create the training dataloader
# val_loader = DataLoader(val_dataset, batch_size=batch_size, sampler=random_sampler_val) # Create the validation dataloader
test_loader = DataLoader(test_dataset, batch_size=batch_size, sampler=random_sampler_test) # Create the test dataloader

train_loader_init = DataLoader(train_dataset_init, batch_size=batch_size, sampler=random_sampler_train_init) # Create the training dataloader
test_loader_init = DataLoader(test_dataset_init, batch_size=batch_size, sampler=random_sampler_test_init) # Create the test dataloader
train_loader_bc_l = DataLoader(train_dataset_bc_l, batch_size=batch_size, sampler=random_sampler_train_bc_l) # Create the training dataloader
test_loader_bc_l = DataLoader(test_dataset_bc_l, batch_size=batch_size, sampler=random_sampler_test_bc_l) # Create the test dataloader
train_loader_bc_r = DataLoader(train_dataset_bc_r, batch_size=batch_size, sampler=random_sampler_train_bc_r) # Create the training dataloader
test_loader_bc_r = DataLoader(test_dataset_bc_r, batch_size=batch_size, sampler=random_sampler_test_bc_r) # Create the test dataloader

# %% [markdown]
# ### NN Architecture Definition

# %%
# Define the neural network architecture
class Mushydata(nn.Module):
    def __init__(self, input_size, hidden_size, output_size): # This is the constructor
        super(Mushydata, self).__init__()
        self.base = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            # nn.BatchNorm1d(hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            # nn.BatchNorm1d(hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            # nn.BatchNorm1d(hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, output_size)
        )
        
    def forward(self, x, t):                               # This is the forward pass
        input_features = torch.cat([x, t], dim=1)          # Concatenate the input features
        m = self.base(input_features)                                 # Pass through the third layer
        return m                    # Return the output of the network


# features = torch.rand(1, 2)
# model = HeatPINN(2, 20, 1)
# output = model(features[:, 0:1], features[:, 1:2])
# print(output)


# Loss function for data

# %% [markdown]
# ### Hyperparamters Init

# %%
# Hyperparameters
hidden_size = 40
learning_rate = 0.003
epochs = 30000
# alpha = 0.01  # Adjust this value based on your problem
# boundary_value = 313.0
# initial_value = init_temp
# Initialize the model
model = Mushydata(input_size=2, hidden_size=hidden_size,output_size=1).to(device)
lambd = 0.1

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Loss List Init

# %%
train_losses = []
val_losses = []
test_losses = []

print(f"Datatype of train_loader is {type(train_loader)}")
# Out:
# Datatype of train_loader is <class 'torch.utils.data.dataloader.DataLoader'>

# %% [markdown]
# ### Loss functions

# %%
# def loss_fn_data(u_pred, u_true):
#     return nn.MSELoss()(u_pred, u_true)

# def l1_regularization(model, lambd):
#     l1_reg = sum(param.abs().sum() for param in model.parameters())
#     return l1_reg * lambd

# def pde_loss(u_pred,x,t):
#     # u_pred.requires_grad = True
#     x.requires_grad = True
#     t.requires_grad = True
    
#     u_pred = model(x,t).requires_grad_()
#     u_t = torch.autograd.grad(u_pred, t, 
#                                 torch.ones_like(u_pred).to(device),
#                                 create_graph=True,
#                                 allow_unused=True,
#                                 )[0] # Calculate the first time derivative
#     if u_t is None:
#         raise RuntimeError("u_t is None")

#     u_x = torch.autograd.grad(u_pred, 
#                                 x, 
#                                 torch.ones_like(u_pred).to(device), 
#                                 create_graph=True,
#                                 allow_unused =True)[0] # Calculate the first space derivative
            
#     u_xx = torch.autograd.grad(u_x, 
#                                 x, 
#                                 torch.ones_like(u_x).to(device), 
#                                 create_graph=True,
#                                 allow_unused=True)[0] 
    
#     T_S_tensor = torch.tensor(T_S, device=device)
#     T_L_tensor = torch.tensor(T_L, device=device)
    
#     k_m = torch.where((u_pred >= T_S_tensor) * (u_pred <= T_L_tensor),\
#                        kramp(u_pred, k_l,k_s,T_L,T_S),torch.tensor(0.0,device=device))
#     cp_m = torch.where(u_pred >= T_S_tensor * u_pred <= T_L_tensor, cp_ramp((u_pred), cp_l,cp_s,T_L,T_S))
#     rho_m = torch.where(u_pred >= T_S_tensor * u_pred <= T_L_tensor, rho_ramp((u_pred), rho_l,rho_s,T_L,T_S))
#     m_eff = (k_m / (rho_m * (cp_m + (L_fusion / (T_L - T_S)))))

#     alpha_T = torch.where(u_pred >= T_L_tensor, alpha_l, torch.where(u_pred<=T_S_tensor,alpha_s ,m_eff))
#     alpha_T = 1
#     residual = u_t - alpha_T * u_xx

#     return nn.MSELoss()(residual,torch.zeros_like(residual))

# def boundary_loss(u_pred,x,t,t_surr):
    
#     u_x = torch.autograd.grad(u_pred,x, 
#                                 torch.ones_like(u_pred).to(device), 
#                                 create_graph=True,
#                                 allow_unused =True)[0] # Calculate the first space derivative
#     t_surr_t = torch.tensor(t_surr, device=device)
#     res_l = u_x -(htc* (u_pred-t_surr_t))
   

#     return nn.MSELoss()(res_l,torch.zeros_like(res_l))

# def ic_loss(u_pred):
#     temp_init_tsr = torch.tensor(temp_init[1:-1],device=device)
#     ic = u_pred -temp_init_tsr
#     return nn.MSELoss()(ic,torch.zeros_like(ic))

def accuracy(u_pred, u_true):
    return torch.mean(torch.abs(u_pred - u_true) / u_true)

# %% [markdown]
# ### Training, Validation and Testing Module

# %%
def training_loop(epochs, model, loss_fn_data, optimizer, train_dataloader,test_dataloader,train_loader_init,\
                  train_loader_bc_l,train_loader_bc_r):
    train_losses = []  # Initialize the list to store the training losses
    # val_losses = []    # Initialize the list to store the validation losses
    test_losses = []   # Initialize the list to store the test losses
    data_losses = []   # Initialize the list to store the data losses
    pde_losses = []   # Initialize the list to store the PDE losses
    ic_losses = []   # Initialize the list to store the initial condition losses
    bc_losses = []   # Initialize the list to store the boundary condition losses

    for epoch in range(epochs):
        model.train()                                                                           # Set the model to training mode
        train_loss = 0                                                                              # Initialize the training loss
        train_accuracy = 0
        for (batch,batch_init,batch_left,batch_right) in \
             zip (train_dataloader,train_loader_init,train_loader_bc_l,train_loader_bc_r):                                                          # Loop through the training dataloader
            inputs, temp_inp= batch                                                             # Get the inputs and the true values
            inputs_init, temp_inp_init= batch_init                                                             # Get the inputs and the true values 
            inputs_left, temp_inp_left= batch_left                                                             # Get the inputs and the true values
            inputs_right, temp_inp_right= batch_right                                                             # Get the inputs and the true values

            inputs, temp_inp= inputs.to(device), temp_inp.to(device)                             # Move the inputs and true values to the GPU
            inputs_init, temp_inp_init= inputs_init.to(device), temp_inp_init.to(device)                             # Move the initial condition inputs and temperature to the GPU
            inputs_left, temp_inp_left= inputs_left.to(device), temp_inp_left.to(device)                             # Move the left boundary condition inputs and temperature values to the GPU
            inputs_right, temp_inp_right= inputs_right.to(device), temp_inp_right.to(device)                             # Move the right boundary condition inputs and temperature values to the GPU
           
            
            optimizer.zero_grad()                                                                    # Zero the gradients
            
            # Forward pass
            u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).to(device)                       # Get the predictions
            u_initl = model(inputs_init[:,0].unsqueeze(1), inputs_init[:,1].unsqueeze(1)).to(device)                       # Get the predictions
            
            u_left = model(inputs_b_l[:,0].unsqueeze(1), inputs_b_l[:,1].unsqueeze(1)).to(device)               # Left boundary of the temperature
            u_right = model(inputs_b_r[:,0].unsqueeze(1), inputs_b_r[:,1].unsqueeze(1)).to(device)             # Right boundary of the temperature

            # Loss calculation
            data_loss = loss_fn_data(u_pred, temp_inp)                                              # Calculate the data loss
            
            pd_loss = pde_loss(model,inputs[:,0].unsqueeze(1),inputs[:,1].unsqueeze(1))             # Calculate the PDE loss
            # pd_loss = 0
            
            initc_loss = ic_loss(u_initl) 
            # initc_loss =0                                                      # Calculate initial condition loss
            
            bc_loss_left = boundary_loss(model,inputs_b_l[:,0].unsqueeze(1),inputs_b_l[:,1].unsqueeze(1),t_surr) # Calculate the left boundary condition loss
            bc_loss_right = boundary_loss(model,inputs_b_r[:,0].unsqueeze(1),inputs_b_r[:,1].unsqueeze(1),t_surr) # Calculate the right boundary condition loss
            bc_loss = bc_loss_left + bc_loss_right
            # l1_regularization_loss = l1_regularization(model, lambda_l1)                      # Calculate the L1 regularization loss
            # loss = data_loss  + pd_loss + initc_loss + bc_loss                                              # Calculate the total loss
            w1 = 0.0001
            w2 = 0.0001
            w3 = 0.0001
            loss = data_loss + w1* pd_loss + w2 *initc_loss + w3* bc_loss
            train_accuracy += accuracy(u_pred, temp_inp)                                                              # Calculate the total loss
            # Backpropagation
            loss.backward(retain_graph=True)                                                        # Backpropagate the gradients
            
            optimizer.step()                                                                           # Update the weights
            
            train_loss += loss.item()                                                           # Add the loss to the training set loss  
            data_losses.append(data_loss.item())               
            pde_losses.append(pd_loss.item())
            ic_losses.append(initc_loss.item())
            bc_losses.append(bc_loss.item())
        

        # model.eval()
        # test_loss = 0
        # test_accuracy = 0
        # with torch.no_grad():   
        #     for batch in test_dataloader:
        #         inputs, temp_inp= batch
        #         inputs, temp_inp= inputs.to(device), temp_inp.to(device)
        #         u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1))
        #         data_loss = loss_fn_data(u_pred, temp_inp)
        #         # l1_regularization_loss = l1_regularization(model, lambd)
        #         # loss = data_loss  + l1_regularization_loss
        #         loss = data_loss
        #         test_accuracy = accuracy(u_pred, temp_inp)
        #         test_loss += loss.item()
        #     test_losses.append(test_loss)

        train_losses.append(train_loss)                                                   # Append the training loss to the list of training losses
        
        # if epoch % 10 == 0:
        #     print(f"Epoch {epoch}, Training-Loss {train_loss:.4e}")
        
        model.eval()
        test_loss = 0
        test_accuracy = 0
        with torch.no_grad():   
            for batch in test_dataloader:
                inputs, temp_inp= batch
                inputs, temp_inp= inputs.to(device), temp_inp.to(device)
                u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1))
                data_loss = loss_fn_data(u_pred, temp_inp)
                # l1_regularization_loss = l1_regularization(model, lambd)
                # loss = data_loss  + l1_regularization_loss
                loss = data_loss
                test_accuracy = accuracy(u_pred, temp_inp)
                test_loss += loss.item()
        test_losses.append(test_loss)


        if epoch % 10 == 0:
            print(f"Epoch {epoch}, Training-Loss {train_loss:.4e}, Data-loss {data_loss:.4e}\
                  , pde-loss {pd_loss:.4e}, initc-loss {initc_loss:.4e}\
                    bc_loss {bc_loss:.4e}, Test-Loss {test_loss:.4e}") 

    return train_losses, test_losses , pde_losses , bc_losses , ic_losses, data_losses                                                      # Return the training and validation losses

# %%
def test_loop(epochs, model, loss_fn_data, optimizer, train_dataloader, test_dataloader):
      
    model.eval()
    test_loss = 0
    test_accuracy = 0
    with torch.no_grad():   
        for batch in test_dataloader:
            inputs, temp_inp= batch
            inputs, temp_inp= inputs.to(device), temp_inp.to(device)
            u_pred = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1))
            data_loss = loss_fn_data(u_pred, temp_inp)
            # l1_regularization_loss = l1_regularization(model, lambd)
            # loss = data_loss  + l1_regularization_loss
            loss = data_loss
            test_accuracy = accuracy(u_pred, temp_inp)
            test_loss += loss.item()
        test_losses.append(test_loss)
    if epochs % 10 == 0:
        print(f"Epoch {epochs}, Test-Loss {test_loss:.4e}, Test-Accuracy {test_accuracy:.4e}")      
    return test_losses

# %% [markdown]
# ### Training Button

# %%
train_losses, test_losses, pde_losses, bc_losses,ic_losses, data_losses = training_loop(epochs, model, loss_fn_data, optimizer,train_loader,test_loader,train_loader_init,\
                  train_loader_bc_l,train_loader_bc_r)  # Train the model
 
# test_losses = test_loop(epochs, model, loss_fn_data, optimizer, train_loader, test_loader)  # Test the model
# Out:
# Epoch 0, Training-Loss 6.6525e+05, Data-loss 6.6618e+05                  , pde-loss 3.7979e-04, initc-loss 8.4440e+05                    bc_loss 4.9979e+07, Test-Loss 6.6618e+05
# Epoch 10, Training-Loss 6.5559e+05, Data-loss 6.6304e+05                  , pde-loss 5.7920e-02, initc-loss 8.4311e+05                    bc_loss 4.9837e+07, Test-Loss 6.6304e+05
# Epoch 20, Training-Loss 6.6078e+05, Data-loss 6.4445e+05                  , pde-loss 1.6022e+00, initc-loss 8.3923e+05                    bc_loss 4.9406e+07, Test-Loss 6.4445e+05
# Epoch 30, Training-Loss 6.4957e+05, Data-loss 6.3184e+05                  , pde-loss 2.1616e+01, initc-loss 8.2787e+05                    bc_loss 4.8134e+07, Test-Loss 6.3184e+05
# Epoch 40, Training-Loss 6.0620e+05, Data-loss 6.0696e+05                  , pde-loss 1.4501e+02, initc-loss 7.9974e+05                    bc_loss 4.5042e+07, Test-Loss 6.0696e+05
# Epoch 50, Training-Loss 5.4744e+05, Data-loss 5.3710e+05                  , pde-loss 1.0031e+03, initc-loss 7.3967e+05                    bc_loss 3.8691e+07, Test-Loss 5.3710e+05
# Epoch 60, Training-Loss 4.4022e+05, Data-loss 4.2113e+05                  , pde-loss 4.4418e+03, initc-loss 6.3141e+05                    bc_loss 2.7896e+07, Test-Loss 4.2113e+05
# Epoch 70, Training-Loss 2.7141e+05, Data-loss 2.5639e+05                  , pde-loss 1.4328e+04, initc-loss 4.6376e+05                    bc_loss 1.4281e+07, Test-Loss 2.5639e+05
# Epoch 80, Training-Loss 1.0783e+05, Data-loss 9.0908e+04                  , pde-loss 4.5530e+04, initc-loss 2.2984e+05                    bc_loss 6.7142e+06, Test-Loss 9.0908e+04
# Epoch 90, Training-Loss 3.8644e+04, Data-loss 4.3207e+04                  , pde-loss 7.2253e+04, initc-loss 9.5729e+04                    bc_loss 1.5679e+07, Test-Loss 4.3207e+04
# Epoch 100, Training-Loss 4.2427e+04, Data-loss 3.3373e+04                  , pde-loss 8.6132e+04, initc-loss 5.3636e+04                    bc_loss 2.1354e+07, Test-Loss 3.3373e+04
# Epoch 110, Training-Loss 2.4903e+04, Data-loss 2.3601e+04                  , pde-loss 5.2173e+04, initc-loss 6.8284e+04                    bc_loss 1.2273e+07, Test-Loss 2.3601e+04
# Epoch 120, Training-Loss 2.0467e+04, Data-loss 2.2913e+04                  , pde-loss 4.4707e+04, initc-loss 8.5751e+04                    bc_loss 8.2573e+06, Test-Loss 2.2913e+04
# Epoch 130, Training-Loss 1.7799e+04, Data-loss 1.5493e+04                  , pde-loss 4.5771e+04, initc-loss 8.4943e+04                    bc_loss 9.2243e+06, Test-Loss 1.5493e+04
# Epoch 140, Training-Loss 1.7491e+04, Data-loss 1.5712e+04                  , pde-loss 4.1779e+04, initc-loss 6.3033e+04                    bc_loss 1.1250e+07, Test-Loss 1.5712e+04
# Epoch 150, Training-Loss 1.7936e+04, Data-loss 1.3886e+04                  , pde-loss 4.2798e+04, initc-loss 6.7053e+04                    bc_loss 1.1273e+07, Test-Loss 1.3886e+04
# Epoch 160, Training-Loss 1.5322e+04, Data-loss 1.1998e+04                  , pde-loss 4.1732e+04, initc-loss 6.4220e+04                    bc_loss 1.0576e+07, Test-Loss 1.1998e+04
# Epoch 170, Training-Loss 1.5250e+04, Data-loss 9.9770e+03                  , pde-loss 3.2357e+04, initc-loss 6.2808e+04                    bc_loss 1.0714e+07, Test-Loss 9.9770e+03
# Epoch 180, Training-Loss 1.3564e+04, Data-loss 1.0237e+04                  , pde-loss 3.1620e+04, initc-loss 4.9177e+04                    bc_loss 1.1765e+07, Test-Loss 1.0237e+04
# Epoch 190, Training-Loss 1.3347e+04, Data-loss 9.4705e+03                  , pde-loss 3.2558e+04, initc-loss 4.2785e+04                    bc_loss 1.1836e+07, Test-Loss 9.4705e+03
# Epoch 200, Training-Loss 1.1399e+04, Data-loss 1.1411e+04                  , pde-loss 2.7550e+04, initc-loss 4.9132e+04                    bc_loss 1.1506e+07, Test-Loss 1.1411e+04
# Epoch 210, Training-Loss 1.1288e+04, Data-loss 9.4446e+03                  , pde-loss 2.6402e+04, initc-loss 4.6616e+04                    bc_loss 1.2008e+07, Test-Loss 9.4446e+03
# Epoch 220, Training-Loss 9.4593e+03, Data-loss 9.0785e+03                  , pde-loss 2.4623e+04, initc-loss 4.8124e+04                    bc_loss 1.2160e+07, Test-Loss 9.0785e+03
# Epoch 230, Training-Loss 8.7583e+03, Data-loss 8.3277e+03                  , pde-loss 2.5555e+04, initc-loss 3.9299e+04                    bc_loss 1.2279e+07, Test-Loss 8.3277e+03
# Epoch 240, Training-Loss 7.7829e+03, Data-loss 7.7018e+03                  , pde-loss 2.4789e+04, initc-loss 4.3096e+04                    bc_loss 1.2106e+07, Test-Loss 7.7018e+03
# Epoch 250, Training-Loss 8.1585e+03, Data-loss 7.7642e+03                  , pde-loss 1.8521e+04, initc-loss 3.9603e+04                    bc_loss 1.2140e+07, Test-Loss 7.7642e+03
# Epoch 260, Training-Loss 7.5071e+03, Data-loss 7.0148e+03                  , pde-loss 1.6976e+04, initc-loss 3.8064e+04                    bc_loss 1.2788e+07, Test-Loss 7.0148e+03
# Epoch 270, Training-Loss 7.3220e+03, Data-loss 5.5828e+03                  , pde-loss 1.8761e+04, initc-loss 3.2372e+04                    bc_loss 1.2994e+07, Test-Loss 5.5828e+03
# Epoch 280, Training-Loss 6.1055e+03, Data-loss 4.7743e+03                  , pde-loss 1.4516e+04, initc-loss 3.6223e+04                    bc_loss 1.2929e+07, Test-Loss 4.7743e+03
# Epoch 290, Training-Loss 6.4308e+03, Data-loss 5.0486e+03                  , pde-loss 1.3566e+04, initc-loss 3.5139e+04                    bc_loss 1.3085e+07, Test-Loss 5.0486e+03
# Epoch 300, Training-Loss 6.0571e+03, Data-loss 5.0837e+03                  , pde-loss 1.1987e+04, initc-loss 3.2216e+04                    bc_loss 1.3547e+07, Test-Loss 5.0837e+03
# Epoch 310, Training-Loss 5.1219e+03, Data-loss 3.7027e+03                  , pde-loss 1.3453e+04, initc-loss 2.9839e+04                    bc_loss 1.3728e+07, Test-Loss 3.7027e+03
# Epoch 320, Training-Loss 5.1062e+03, Data-loss 3.2323e+03                  , pde-loss 1.3378e+04, initc-loss 3.2190e+04                    bc_loss 1.3835e+07, Test-Loss 3.2323e+03
# Epoch 330, Training-Loss 5.0283e+03, Data-loss 3.8355e+03                  , pde-loss 1.1106e+04, initc-loss 2.8509e+04                    bc_loss 1.4036e+07, Test-Loss 3.8355e+03
# Epoch 340, Training-Loss 4.9991e+03, Data-loss 2.7753e+03                  , pde-loss 1.0119e+04, initc-loss 2.6392e+04                    bc_loss 1.4234e+07, Test-Loss 2.7753e+03
# Epoch 350, Training-Loss 3.8661e+03, Data-loss 3.0310e+03                  , pde-loss 1.1368e+04, initc-loss 2.6681e+04                    bc_loss 1.4148e+07, Test-Loss 3.0310e+03
# Epoch 360, Training-Loss 4.3633e+03, Data-loss 2.6233e+03                  , pde-loss 6.8738e+03, initc-loss 2.5869e+04                    bc_loss 1.4225e+07, Test-Loss 2.6233e+03
# Epoch 370, Training-Loss 4.0196e+03, Data-loss 2.7552e+03                  , pde-loss 8.4475e+03, initc-loss 2.4573e+04                    bc_loss 1.5043e+07, Test-Loss 2.7552e+03
# Epoch 380, Training-Loss 3.5527e+03, Data-loss 1.6864e+03                  , pde-loss 7.8386e+03, initc-loss 2.3333e+04                    bc_loss 1.5101e+07, Test-Loss 1.6864e+03
# Epoch 390, Training-Loss 3.4935e+03, Data-loss 1.9135e+03                  , pde-loss 6.8257e+03, initc-loss 2.5125e+04                    bc_loss 1.4782e+07, Test-Loss 1.9135e+03
# Epoch 400, Training-Loss 3.1239e+03, Data-loss 1.8008e+03                  , pde-loss 8.2302e+03, initc-loss 2.2546e+04                    bc_loss 1.5093e+07, Test-Loss 1.8008e+03
# Epoch 410, Training-Loss 2.9888e+03, Data-loss 1.4909e+03                  , pde-loss 7.4432e+03, initc-loss 2.2713e+04                    bc_loss 1.5622e+07, Test-Loss 1.4909e+03
# Epoch 420, Training-Loss 2.9450e+03, Data-loss 1.4200e+03                  , pde-loss 7.4872e+03, initc-loss 2.0777e+04                    bc_loss 1.5346e+07, Test-Loss 1.4200e+03
# Epoch 430, Training-Loss 2.7152e+03, Data-loss 1.5927e+03                  , pde-loss 5.9591e+03, initc-loss 2.2252e+04                    bc_loss 1.5300e+07, Test-Loss 1.5927e+03
# Epoch 440, Training-Loss 2.9904e+03, Data-loss 1.4442e+03                  , pde-loss 5.8766e+03, initc-loss 2.1187e+04                    bc_loss 1.5964e+07, Test-Loss 1.4442e+03
# Epoch 450, Training-Loss 2.8287e+03, Data-loss 1.8020e+03                  , pde-loss 5.4482e+03, initc-loss 2.0711e+04                    bc_loss 1.5748e+07, Test-Loss 1.8020e+03
# Epoch 460, Training-Loss 2.7165e+03, Data-loss 1.1045e+03                  , pde-loss 4.9300e+03, initc-loss 2.0345e+04                    bc_loss 1.5657e+07, Test-Loss 1.1045e+03
# Epoch 470, Training-Loss 2.5183e+03, Data-loss 1.1594e+03                  , pde-loss 3.6531e+03, initc-loss 2.0093e+04                    bc_loss 1.5927e+07, Test-Loss 1.1594e+03
# Epoch 480, Training-Loss 2.6275e+03, Data-loss 1.0036e+03                  , pde-loss 4.9699e+03, initc-loss 1.8964e+04                    bc_loss 1.6108e+07, Test-Loss 1.0036e+03
# Epoch 490, Training-Loss 2.7175e+03, Data-loss 1.0002e+03                  , pde-loss 3.8229e+03, initc-loss 1.9736e+04                    bc_loss 1.6073e+07, Test-Loss 1.0002e+03
# Epoch 500, Training-Loss 2.5708e+03, Data-loss 8.9887e+02                  , pde-loss 3.9813e+03, initc-loss 1.9655e+04                    bc_loss 1.5908e+07, Test-Loss 8.9887e+02
# Epoch 510, Training-Loss 2.3270e+03, Data-loss 8.0595e+02                  , pde-loss 3.6905e+03, initc-loss 1.8756e+04                    bc_loss 1.6217e+07, Test-Loss 8.0595e+02
# Epoch 520, Training-Loss 2.4207e+03, Data-loss 8.2272e+02                  , pde-loss 3.0457e+03, initc-loss 1.8329e+04                    bc_loss 1.6487e+07, Test-Loss 8.2272e+02
# Epoch 530, Training-Loss 2.2986e+03, Data-loss 7.9002e+02                  , pde-loss 3.3774e+03, initc-loss 1.8232e+04                    bc_loss 1.6562e+07, Test-Loss 7.9002e+02
# Epoch 540, Training-Loss 2.3854e+03, Data-loss 6.7800e+02                  , pde-loss 3.2046e+03, initc-loss 1.8309e+04                    bc_loss 1.6437e+07, Test-Loss 6.7800e+02
# Epoch 550, Training-Loss 2.1912e+03, Data-loss 6.3555e+02                  , pde-loss 4.4988e+03, initc-loss 1.7837e+04                    bc_loss 1.6487e+07, Test-Loss 6.3555e+02
# Epoch 560, Training-Loss 2.1450e+03, Data-loss 6.8855e+02                  , pde-loss 3.7779e+03, initc-loss 1.7735e+04                    bc_loss 1.6544e+07, Test-Loss 6.8855e+02
# Epoch 570, Training-Loss 2.2243e+03, Data-loss 5.9993e+02                  , pde-loss 2.3839e+03, initc-loss 1.7438e+04                    bc_loss 1.6795e+07, Test-Loss 5.9993e+02
# Epoch 580, Training-Loss 2.1501e+03, Data-loss 5.4127e+02                  , pde-loss 2.4694e+03, initc-loss 1.7200e+04                    bc_loss 1.6753e+07, Test-Loss 5.4127e+02
# Epoch 590, Training-Loss 2.1945e+03, Data-loss 4.4081e+02                  , pde-loss 3.8134e+03, initc-loss 1.7304e+04                    bc_loss 1.6739e+07, Test-Loss 4.4081e+02
# Epoch 600, Training-Loss 2.1470e+03, Data-loss 5.5160e+02                  , pde-loss 3.4320e+03, initc-loss 1.6650e+04                    bc_loss 1.6902e+07, Test-Loss 5.5160e+02
# Epoch 610, Training-Loss 2.0983e+03, Data-loss 4.0722e+02                  , pde-loss 3.0785e+03, initc-loss 1.7157e+04                    bc_loss 1.6795e+07, Test-Loss 4.0722e+02
# Epoch 620, Training-Loss 2.1468e+03, Data-loss 4.3697e+02                  , pde-loss 2.2459e+03, initc-loss 1.6531e+04                    bc_loss 1.7114e+07, Test-Loss 4.3697e+02
# Epoch 630, Training-Loss 2.1410e+03, Data-loss 3.8733e+02                  , pde-loss 3.6544e+03, initc-loss 1.6355e+04                    bc_loss 1.6958e+07, Test-Loss 3.8733e+02
# Epoch 640, Training-Loss 2.0957e+03, Data-loss 4.5777e+02                  , pde-loss 3.3818e+03, initc-loss 1.6804e+04                    bc_loss 1.6990e+07, Test-Loss 4.5777e+02
# Epoch 650, Training-Loss 2.0889e+03, Data-loss 3.6317e+02                  , pde-loss 2.3224e+03, initc-loss 1.5896e+04                    bc_loss 1.7166e+07, Test-Loss 3.6317e+02
# Epoch 660, Training-Loss 2.0818e+03, Data-loss 3.8641e+02                  , pde-loss 2.5111e+03, initc-loss 1.6439e+04                    bc_loss 1.7025e+07, Test-Loss 3.8641e+02
# Epoch 670, Training-Loss 2.0701e+03, Data-loss 4.6255e+02                  , pde-loss 2.0093e+03, initc-loss 1.5865e+04                    bc_loss 1.7146e+07, Test-Loss 4.6255e+02
# Epoch 680, Training-Loss 2.1127e+03, Data-loss 3.5929e+02                  , pde-loss 2.5058e+03, initc-loss 1.5307e+04                    bc_loss 1.7305e+07, Test-Loss 3.5929e+02
# Epoch 690, Training-Loss 2.0174e+03, Data-loss 2.9276e+02                  , pde-loss 3.1837e+03, initc-loss 1.5640e+04                    bc_loss 1.7297e+07, Test-Loss 2.9276e+02
# Epoch 700, Training-Loss 2.0041e+03, Data-loss 3.2010e+02                  , pde-loss 2.2802e+03, initc-loss 1.6017e+04                    bc_loss 1.7101e+07, Test-Loss 3.2010e+02
# Epoch 710, Training-Loss 2.0352e+03, Data-loss 3.7510e+02                  , pde-loss 2.4075e+03, initc-loss 1.5674e+04                    bc_loss 1.7255e+07, Test-Loss 3.7510e+02
# Epoch 720, Training-Loss 2.0305e+03, Data-loss 2.9904e+02                  , pde-loss 2.4375e+03, initc-loss 1.5128e+04                    bc_loss 1.7362e+07, Test-Loss 2.9904e+02
# Epoch 730, Training-Loss 2.1069e+03, Data-loss 3.1536e+02                  , pde-loss 2.3048e+03, initc-loss 1.5210e+04                    bc_loss 1.7489e+07, Test-Loss 3.1536e+02
# Epoch 740, Training-Loss 2.0460e+03, Data-loss 3.1677e+02                  , pde-loss 2.0321e+03, initc-loss 1.5444e+04                    bc_loss 1.7354e+07, Test-Loss 3.1677e+02
# Epoch 750, Training-Loss 2.0221e+03, Data-loss 3.0014e+02                  , pde-loss 2.8192e+03, initc-loss 1.4899e+04                    bc_loss 1.7450e+07, Test-Loss 3.0014e+02
# Epoch 760, Training-Loss 2.0284e+03, Data-loss 3.0853e+02                  , pde-loss 2.1129e+03, initc-loss 1.5394e+04                    bc_loss 1.7384e+07, Test-Loss 3.0853e+02
# Epoch 770, Training-Loss 1.9941e+03, Data-loss 2.4488e+02                  , pde-loss 2.5682e+03, initc-loss 1.5360e+04                    bc_loss 1.7501e+07, Test-Loss 2.4488e+02
# Epoch 780, Training-Loss 2.0476e+03, Data-loss 3.0561e+02                  , pde-loss 2.1178e+03, initc-loss 1.4762e+04                    bc_loss 1.7551e+07, Test-Loss 3.0561e+02
# Epoch 790, Training-Loss 2.0268e+03, Data-loss 2.2657e+02                  , pde-loss 2.3566e+03, initc-loss 1.5455e+04                    bc_loss 1.7410e+07, Test-Loss 2.2657e+02
# Epoch 800, Training-Loss 2.0532e+03, Data-loss 2.4149e+02                  , pde-loss 2.1341e+03, initc-loss 1.4795e+04                    bc_loss 1.7604e+07, Test-Loss 2.4149e+02
# Epoch 810, Training-Loss 1.9821e+03, Data-loss 2.7066e+02                  , pde-loss 2.1421e+03, initc-loss 1.5326e+04                    bc_loss 1.7485e+07, Test-Loss 2.7066e+02
# Epoch 820, Training-Loss 1.9995e+03, Data-loss 2.1989e+02                  , pde-loss 2.2437e+03, initc-loss 1.4631e+04                    bc_loss 1.7643e+07, Test-Loss 2.1989e+02
# Epoch 830, Training-Loss 1.9446e+03, Data-loss 2.0553e+02                  , pde-loss 1.8167e+03, initc-loss 1.4911e+04                    bc_loss 1.7577e+07, Test-Loss 2.0553e+02
# Epoch 840, Training-Loss 1.9799e+03, Data-loss 2.1391e+02                  , pde-loss 2.1446e+03, initc-loss 1.5045e+04                    bc_loss 1.7550e+07, Test-Loss 2.1391e+02
# Epoch 850, Training-Loss 2.0091e+03, Data-loss 2.3800e+02                  , pde-loss 1.7894e+03, initc-loss 1.4598e+04                    bc_loss 1.7676e+07, Test-Loss 2.3800e+02
# Epoch 860, Training-Loss 2.0068e+03, Data-loss 1.9783e+02                  , pde-loss 2.2377e+03, initc-loss 1.4831e+04                    bc_loss 1.7741e+07, Test-Loss 1.9783e+02
# Epoch 870, Training-Loss 1.9990e+03, Data-loss 2.2527e+02                  , pde-loss 1.8768e+03, initc-loss 1.4931e+04                    bc_loss 1.7590e+07, Test-Loss 2.2527e+02
# Epoch 880, Training-Loss 1.9763e+03, Data-loss 2.1977e+02                  , pde-loss 2.2339e+03, initc-loss 1.4922e+04                    bc_loss 1.7684e+07, Test-Loss 2.1977e+02
# Epoch 890, Training-Loss 1.9371e+03, Data-loss 2.0061e+02                  , pde-loss 2.0506e+03, initc-loss 1.4349e+04                    bc_loss 1.7874e+07, Test-Loss 2.0061e+02
# Epoch 900, Training-Loss 2.0049e+03, Data-loss 1.6233e+02                  , pde-loss 2.3854e+03, initc-loss 1.4697e+04                    bc_loss 1.7634e+07, Test-Loss 1.6233e+02
# Epoch 910, Training-Loss 1.9872e+03, Data-loss 1.7450e+02                  , pde-loss 1.6815e+03, initc-loss 1.4415e+04                    bc_loss 1.7769e+07, Test-Loss 1.7450e+02
# Epoch 920, Training-Loss 1.9928e+03, Data-loss 1.7848e+02                  , pde-loss 1.6758e+03, initc-loss 1.4447e+04                    bc_loss 1.7802e+07, Test-Loss 1.7848e+02
# Epoch 930, Training-Loss 1.9771e+03, Data-loss 1.8983e+02                  , pde-loss 2.6070e+03, initc-loss 1.4462e+04                    bc_loss 1.7767e+07, Test-Loss 1.8983e+02
# Epoch 940, Training-Loss 1.9859e+03, Data-loss 2.2024e+02                  , pde-loss 1.9890e+03, initc-loss 1.4735e+04                    bc_loss 1.7719e+07, Test-Loss 2.2024e+02
# Epoch 950, Training-Loss 1.9395e+03, Data-loss 2.2128e+02                  , pde-loss 1.7584e+03, initc-loss 1.4336e+04                    bc_loss 1.7891e+07, Test-Loss 2.2128e+02
# Epoch 960, Training-Loss 2.0474e+03, Data-loss 1.4514e+02                  , pde-loss 2.0490e+03, initc-loss 1.4733e+04                    bc_loss 1.7707e+07, Test-Loss 1.4514e+02
# Epoch 970, Training-Loss 1.9853e+03, Data-loss 1.5534e+02                  , pde-loss 1.9883e+03, initc-loss 1.4415e+04                    bc_loss 1.7848e+07, Test-Loss 1.5534e+02
# Epoch 980, Training-Loss 1.9473e+03, Data-loss 1.8899e+02                  , pde-loss 2.4878e+03, initc-loss 1.4457e+04                    bc_loss 1.7833e+07, Test-Loss 1.8899e+02
# Epoch 1910, Training-Loss 1.9524e+03, Data-loss 8.0345e+01                  , pde-loss 3.1382e+03, initc-loss 1.3823e+04                    bc_loss 1.8137e+07, Test-Loss 8.0345e+01
# Epoch 1920, Training-Loss 1.9493e+03, Data-loss 1.3681e+02                  , pde-loss 2.6484e+03, initc-loss 1.4095e+04                    bc_loss 1.7965e+07, Test-Loss 1.3681e+02
# Epoch 1930, Training-Loss 1.9154e+03, Data-loss 1.0813e+02                  , pde-loss 2.2623e+03, initc-loss 1.3591e+04                    bc_loss 1.8200e+07, Test-Loss 1.0813e+02
# Epoch 1940, Training-Loss 1.9298e+03, Data-loss 1.3631e+02                  , pde-loss 2.4995e+03, initc-loss 1.4133e+04                    bc_loss 1.7979e+07, Test-Loss 1.3631e+02
# Epoch 1950, Training-Loss 1.9143e+03, Data-loss 1.6878e+02                  , pde-loss 2.7559e+03, initc-loss 1.4149e+04                    bc_loss 1.7881e+07, Test-Loss 1.6878e+02
# Epoch 1960, Training-Loss 1.9398e+03, Data-loss 1.4354e+02                  , pde-loss 2.7071e+03, initc-loss 1.3586e+04                    bc_loss 1.8191e+07, Test-Loss 1.4354e+02
# Epoch 1970, Training-Loss 1.9196e+03, Data-loss 1.4093e+02                  , pde-loss 2.0274e+03, initc-loss 1.4068e+04                    bc_loss 1.7964e+07, Test-Loss 1.4093e+02
# Epoch 1980, Training-Loss 1.9362e+03, Data-loss 1.2752e+02                  , pde-loss 1.9454e+03, initc-loss 1.3829e+04                    bc_loss 1.8123e+07, Test-Loss 1.2752e+02
# Epoch 1990, Training-Loss 1.9820e+03, Data-loss 1.1828e+02                  , pde-loss 2.9007e+03, initc-loss 1.3986e+04                    bc_loss 1.7988e+07, Test-Loss 1.1828e+02
# Epoch 2000, Training-Loss 1.9534e+03, Data-loss 1.1217e+02                  , pde-loss 2.7785e+03, initc-loss 1.3962e+04                    bc_loss 1.8043e+07, Test-Loss 1.1217e+02
# Epoch 2010, Training-Loss 1.9466e+03, Data-loss 1.4079e+02                  , pde-loss 3.0145e+03, initc-loss 1.3682e+04                    bc_loss 1.8206e+07, Test-Loss 1.4079e+02
# Epoch 2020, Training-Loss 1.9482e+03, Data-loss 2.0201e+02                  , pde-loss 2.5322e+03, initc-loss 1.4191e+04                    bc_loss 1.7878e+07, Test-Loss 2.0201e+02
# Epoch 2030, Training-Loss 1.9464e+03, Data-loss 1.5092e+02                  , pde-loss 2.7945e+03, initc-loss 1.3561e+04                    bc_loss 1.8207e+07, Test-Loss 1.5092e+02
# Epoch 2040, Training-Loss 1.9469e+03, Data-loss 1.2748e+02                  , pde-loss 2.9315e+03, initc-loss 1.4090e+04                    bc_loss 1.7993e+07, Test-Loss 1.2748e+02
# Epoch 2050, Training-Loss 1.9346e+03, Data-loss 1.6503e+02                  , pde-loss 2.4993e+03, initc-loss 1.4220e+04                    bc_loss 1.7830e+07, Test-Loss 1.6503e+02
# Epoch 2060, Training-Loss 1.9276e+03, Data-loss 1.2895e+02                  , pde-loss 2.7351e+03, initc-loss 1.3523e+04                    bc_loss 1.8269e+07, Test-Loss 1.2895e+02
# Epoch 2070, Training-Loss 1.9388e+03, Data-loss 1.3850e+02                  , pde-loss 2.3654e+03, initc-loss 1.4022e+04                    bc_loss 1.7966e+07, Test-Loss 1.3850e+02
# Epoch 2080, Training-Loss 1.9117e+03, Data-loss 1.4649e+02                  , pde-loss 2.5183e+03, initc-loss 1.3955e+04                    bc_loss 1.8054e+07, Test-Loss 1.4649e+02
# Epoch 2090, Training-Loss 1.9319e+03, Data-loss 1.0286e+02                  , pde-loss 2.9494e+03, initc-loss 1.3753e+04                    bc_loss 1.8118e+07, Test-Loss 1.0286e+02
# Epoch 2100, Training-Loss 1.9370e+03, Data-loss 1.4444e+02                  , pde-loss 2.7796e+03, initc-loss 1.3985e+04                    bc_loss 1.8000e+07, Test-Loss 1.4444e+02
# Epoch 2110, Training-Loss 1.9312e+03, Data-loss 1.1830e+02                  , pde-loss 3.0579e+03, initc-loss 1.3754e+04                    bc_loss 1.8075e+07, Test-Loss 1.1830e+02
# Epoch 2120, Training-Loss 1.9484e+03, Data-loss 1.3298e+02                  , pde-loss 2.9882e+03, initc-loss 1.3875e+04                    bc_loss 1.8078e+07, Test-Loss 1.3298e+02
# Epoch 2130, Training-Loss 1.9487e+03, Data-loss 1.4799e+02                  , pde-loss 2.6921e+03, initc-loss 1.4028e+04                    bc_loss 1.7976e+07, Test-Loss 1.4799e+02
# Epoch 2140, Training-Loss 1.9636e+03, Data-loss 1.2589e+02                  , pde-loss 2.9976e+03, initc-loss 1.3598e+04                    bc_loss 1.8181e+07, Test-Loss 1.2589e+02
# Epoch 2150, Training-Loss 1.9401e+03, Data-loss 1.2668e+02                  , pde-loss 3.3748e+03, initc-loss 1.4104e+04                    bc_loss 1.7953e+07, Test-Loss 1.2668e+02
# Epoch 2160, Training-Loss 1.9366e+03, Data-loss 1.1640e+02                  , pde-loss 2.6059e+03, initc-loss 1.3706e+04                    bc_loss 1.8155e+07, Test-Loss 1.1640e+02
# Epoch 2170, Training-Loss 1.9155e+03, Data-loss 1.5574e+02                  , pde-loss 2.7253e+03, initc-loss 1.3805e+04                    bc_loss 1.8011e+07, Test-Loss 1.5574e+02
# Epoch 2180, Training-Loss 1.9427e+03, Data-loss 1.4384e+02                  , pde-loss 2.5065e+03, initc-loss 1.3783e+04                    bc_loss 1.8036e+07, Test-Loss 1.4384e+02
# Epoch 2190, Training-Loss 1.9298e+03, Data-loss 1.0002e+02                  , pde-loss 3.2582e+03, initc-loss 1.3675e+04                    bc_loss 1.8157e+07, Test-Loss 1.0002e+02
# Epoch 2200, Training-Loss 1.9340e+03, Data-loss 1.4298e+02                  , pde-loss 2.8514e+03, initc-loss 1.3836e+04                    bc_loss 1.8041e+07, Test-Loss 1.4298e+02
# Epoch 2210, Training-Loss 1.9234e+03, Data-loss 1.1555e+02                  , pde-loss 2.7877e+03, initc-loss 1.3572e+04                    bc_loss 1.8143e+07, Test-Loss 1.1555e+02
# Epoch 2380, Training-Loss 1.9374e+03, Data-loss 1.4353e+02                  , pde-loss 3.6453e+03, initc-loss 1.4160e+04                    bc_loss 1.7831e+07, Test-Loss 1.4353e+02
# Epoch 2390, Training-Loss 1.9396e+03, Data-loss 9.2510e+01                  , pde-loss 3.3783e+03, initc-loss 1.3013e+04                    bc_loss 1.8429e+07, Test-Loss 9.2510e+01
# Epoch 2400, Training-Loss 1.9511e+03, Data-loss 1.2721e+02                  , pde-loss 2.7016e+03, initc-loss 1.3773e+04                    bc_loss 1.8014e+07, Test-Loss 1.2721e+02
# Epoch 2410, Training-Loss 1.9192e+03, Data-loss 1.3757e+02                  , pde-loss 2.1453e+03, initc-loss 1.4004e+04                    bc_loss 1.7874e+07, Test-Loss 1.3757e+02
# Epoch 2420, Training-Loss 1.9527e+03, Data-loss 1.1755e+02                  , pde-loss 3.4500e+03, initc-loss 1.3569e+04                    bc_loss 1.8114e+07, Test-Loss 1.1755e+02
# Epoch 2430, Training-Loss 1.9375e+03, Data-loss 8.0855e+01                  , pde-loss 2.8458e+03, initc-loss 1.3204e+04                    bc_loss 1.8287e+07, Test-Loss 8.0855e+01
# Epoch 2440, Training-Loss 1.9177e+03, Data-loss 1.3742e+02                  , pde-loss 3.0556e+03, initc-loss 1.3900e+04                    bc_loss 1.7899e+07, Test-Loss 1.3742e+02
# Epoch 2450, Training-Loss 1.9276e+03, Data-loss 1.1261e+02                  , pde-loss 3.8880e+03, initc-loss 1.3778e+04                    bc_loss 1.8019e+07, Test-Loss 1.1261e+02
# Epoch 2460, Training-Loss 1.9249e+03, Data-loss 1.1343e+02                  , pde-loss 3.4362e+03, initc-loss 1.3358e+04                    bc_loss 1.8205e+07, Test-Loss 1.1343e+02
# Epoch 2470, Training-Loss 1.9685e+03, Data-loss 1.3032e+02                  , pde-loss 2.6738e+03, initc-loss 1.4007e+04                    bc_loss 1.7886e+07, Test-Loss 1.3032e+02
# Epoch 2480, Training-Loss 1.9354e+03, Data-loss 1.1164e+02                  , pde-loss 2.7475e+03, initc-loss 1.3449e+04                    bc_loss 1.8175e+07, Test-Loss 1.1164e+02
# Epoch 2490, Training-Loss 1.9308e+03, Data-loss 1.3405e+02                  , pde-loss 3.7421e+03, initc-loss 1.3777e+04                    bc_loss 1.8004e+07, Test-Loss 1.3405e+02
# Epoch 2500, Training-Loss 1.9194e+03, Data-loss 1.0677e+02                  , pde-loss 2.8336e+03, initc-loss 1.3587e+04                    bc_loss 1.8070e+07, Test-Loss 1.0677e+02
# Epoch 2510, Training-Loss 1.9194e+03, Data-loss 1.3528e+02                  , pde-loss 3.6587e+03, initc-loss 1.3789e+04                    bc_loss 1.7956e+07, Test-Loss 1.3528e+02
# Epoch 2520, Training-Loss 1.9380e+03, Data-loss 1.1408e+02                  , pde-loss 3.6676e+03, initc-loss 1.3529e+04                    bc_loss 1.8152e+07, Test-Loss 1.1408e+02
# Epoch 2530, Training-Loss 1.9456e+03, Data-loss 1.1791e+02                  , pde-loss 3.6850e+03, initc-loss 1.3505e+04                    bc_loss 1.8149e+07, Test-Loss 1.1791e+02
# Epoch 2540, Training-Loss 1.9319e+03, Data-loss 1.1086e+02                  , pde-loss 3.7239e+03, initc-loss 1.3728e+04                    bc_loss 1.8006e+07, Test-Loss 1.1086e+02
# Epoch 2550, Training-Loss 1.9334e+03, Data-loss 1.0484e+02                  , pde-loss 3.4003e+03, initc-loss 1.3595e+04                    bc_loss 1.8073e+07, Test-Loss 1.0484e+02
# Epoch 2560, Training-Loss 1.9283e+03, Data-loss 1.1907e+02                  , pde-loss 2.6629e+03, initc-loss 1.3382e+04                    bc_loss 1.8186e+07, Test-Loss 1.1907e+02
# Epoch 2570, Training-Loss 1.9232e+03, Data-loss 1.4564e+02                  , pde-loss 4.2817e+03, initc-loss 1.4036e+04                    bc_loss 1.7815e+07, Test-Loss 1.4564e+02
# Epoch 2580, Training-Loss 1.9391e+03, Data-loss 1.2560e+02                  , pde-loss 2.8193e+03, initc-loss 1.3527e+04                    bc_loss 1.8106e+07, Test-Loss 1.2560e+02
# Epoch 2590, Training-Loss 1.9305e+03, Data-loss 9.4953e+01                  , pde-loss 3.6179e+03, initc-loss 1.3323e+04                    bc_loss 1.8245e+07, Test-Loss 9.4953e+01
# Epoch 2600, Training-Loss 1.9260e+03, Data-loss 1.3724e+02                  , pde-loss 3.4544e+03, initc-loss 1.3725e+04                    bc_loss 1.8014e+07, Test-Loss 1.3724e+02
# Epoch 2610, Training-Loss 1.9273e+03, Data-loss 8.7442e+01                  , pde-loss 3.4451e+03, initc-loss 1.3346e+04                    bc_loss 1.8150e+07, Test-Loss 8.7442e+01
# Epoch 2620, Training-Loss 1.9302e+03, Data-loss 1.0805e+02                  , pde-loss 2.5670e+03, initc-loss 1.3612e+04                    bc_loss 1.8050e+07, Test-Loss 1.0805e+02
# Epoch 2630, Training-Loss 1.9321e+03, Data-loss 1.3408e+02                  , pde-loss 4.3259e+03, initc-loss 1.3721e+04                    bc_loss 1.7999e+07, Test-Loss 1.3408e+02
# Epoch 2640, Training-Loss 1.9329e+03, Data-loss 1.3022e+02                  , pde-loss 2.4028e+03, initc-loss 1.3523e+04                    bc_loss 1.8130e+07, Test-Loss 1.3022e+02
# ...
# Epoch 29130, Training-Loss 1.3261e+02, Data-loss 2.4108e+02                  , pde-loss 4.2337e+03, initc-loss 1.3450e+04                    bc_loss 7.6363e+05, Test-Loss 2.4108e+02
# Epoch 29140, Training-Loss 5.4093e+02, Data-loss 9.4118e+01                  , pde-loss 4.3212e+03, initc-loss 1.3277e+04                    bc_loss 3.3935e+06, Test-Loss 9.4118e+01
# Epoch 29150, Training-Loss 6.3836e+02, Data-loss 2.2127e+02                  , pde-loss 5.5415e+03, initc-loss 1.3538e+04                    bc_loss 4.3526e+06, Test-Loss 2.2127e+02
# Epoch 29160, Training-Loss 1.4096e+02, Data-loss 1.0256e+02                  , pde-loss 4.8078e+03, initc-loss 1.2989e+04                    bc_loss 2.9857e+05, Test-Loss 1.0256e+02
# Epoch 29170, Training-Loss 4.0308e+02, Data-loss 9.6447e+01                  , pde-loss 4.5827e+03, initc-loss 1.3429e+04                    bc_loss 2.4099e+06, Test-Loss 9.6447e+01
# Epoch 29180, Training-Loss 1.2516e+03, Data-loss 2.2681e+02                  , pde-loss 4.7073e+03, initc-loss 1.3814e+04                    bc_loss 1.0963e+07, Test-Loss 2.2681e+02
# Epoch 29190, Training-Loss 1.5939e+02, Data-loss 1.0820e+02                  , pde-loss 5.2702e+03, initc-loss 1.2753e+04                    bc_loss 1.9625e+05, Test-Loss 1.0820e+02
# Epoch 29200, Training-Loss 1.8858e+03, Data-loss 1.8114e+02                  , pde-loss 4.2207e+03, initc-loss 1.4610e+04                    bc_loss 1.8135e+07, Test-Loss 1.8114e+02
# Epoch 29210, Training-Loss 4.0724e+02, Data-loss 3.3558e+02                  , pde-loss 5.9293e+03, initc-loss 1.3636e+04                    bc_loss 2.1605e+06, Test-Loss 3.3558e+02
# Epoch 29220, Training-Loss 6.2366e+02, Data-loss 6.8091e+01                  , pde-loss 5.2176e+03, initc-loss 1.4632e+04                    bc_loss 4.5862e+06, Test-Loss 6.8091e+01
# Epoch 29230, Training-Loss 6.4284e+02, Data-loss 1.4352e+02                  , pde-loss 3.4914e+03, initc-loss 1.3766e+04                    bc_loss 5.2684e+06, Test-Loss 1.4352e+02
# Epoch 29240, Training-Loss 2.5597e+02, Data-loss 9.7285e+01                  , pde-loss 4.4260e+03, initc-loss 1.1353e+04                    bc_loss 1.7043e+05, Test-Loss 9.7285e+01
# Epoch 29250, Training-Loss 5.9547e+02, Data-loss 1.5922e+02                  , pde-loss 5.2725e+03, initc-loss 1.2682e+04                    bc_loss 4.7675e+06, Test-Loss 1.5922e+02
# Epoch 29260, Training-Loss 6.0624e+02, Data-loss 2.2049e+02                  , pde-loss 5.5305e+03, initc-loss 1.3118e+04                    bc_loss 3.7978e+06, Test-Loss 2.2049e+02
# Epoch 29270, Training-Loss 1.4787e+03, Data-loss 1.3272e+02                  , pde-loss 3.6431e+03, initc-loss 1.3939e+04                    bc_loss 1.0707e+07, Test-Loss 1.3272e+02
# Epoch 29280, Training-Loss 1.4271e+02, Data-loss 1.1809e+02                  , pde-loss 4.5625e+03, initc-loss 1.3673e+04                    bc_loss 6.6399e+04, Test-Loss 1.1809e+02
# Epoch 29290, Training-Loss 2.4569e+02, Data-loss 2.3264e+02                  , pde-loss 4.7181e+03, initc-loss 1.2545e+04                    bc_loss 1.8393e+06, Test-Loss 2.3264e+02
# Epoch 29300, Training-Loss 1.9264e+02, Data-loss 1.5092e+02                  , pde-loss 4.0917e+03, initc-loss 1.2448e+04                    bc_loss 1.2605e+06, Test-Loss 1.5092e+02
# Epoch 29310, Training-Loss 1.4918e+02, Data-loss 2.3066e+02                  , pde-loss 4.7745e+03, initc-loss 1.2878e+04                    bc_loss 1.8127e+05, Test-Loss 2.3066e+02
# Epoch 29320, Training-Loss 1.1613e+02, Data-loss 4.4642e+01                  , pde-loss 5.4314e+03, initc-loss 1.2998e+04                    bc_loss 3.7184e+05, Test-Loss 4.4642e+01
# Epoch 29330, Training-Loss 6.7380e+01, Data-loss 8.9257e+01                  , pde-loss 4.9638e+03, initc-loss 1.2220e+04                    bc_loss 7.5623e+04, Test-Loss 8.9257e+01
# Epoch 29340, Training-Loss 9.7561e+01, Data-loss 2.9420e+01                  , pde-loss 4.6458e+03, initc-loss 1.2348e+04                    bc_loss 4.5270e+05, Test-Loss 2.9420e+01
# Epoch 29350, Training-Loss 6.2288e+01, Data-loss 2.5913e+01                  , pde-loss 4.5434e+03, initc-loss 1.2297e+04                    bc_loss 1.0409e+05, Test-Loss 2.5913e+01
# Epoch 29360, Training-Loss 8.7928e+02, Data-loss 3.0690e+01                  , pde-loss 3.4845e+03, initc-loss 1.2850e+04                    bc_loss 8.0263e+06, Test-Loss 3.0690e+01
# Epoch 29370, Training-Loss 1.1270e+02, Data-loss 3.8333e+01                  , pde-loss 3.6363e+03, initc-loss 1.3107e+04                    bc_loss 7.1650e+04, Test-Loss 3.8333e+01
# Epoch 29380, Training-Loss 1.3757e+03, Data-loss 7.2294e+01                  , pde-loss 6.1746e+03, initc-loss 1.4055e+04                    bc_loss 1.2361e+07, Test-Loss 7.2294e+01
# Epoch 29390, Training-Loss 3.7700e+02, Data-loss 4.0666e+01                  , pde-loss 4.9916e+03, initc-loss 1.2692e+04                    bc_loss 2.9944e+06, Test-Loss 4.0666e+01
# Epoch 29400, Training-Loss 8.0149e+01, Data-loss 1.3669e+02                  , pde-loss 4.2020e+03, initc-loss 1.2169e+04                    bc_loss 2.5028e+05, Test-Loss 1.3669e+02
# Epoch 29410, Training-Loss 1.6687e+03, Data-loss 8.2051e+01                  , pde-loss 4.0244e+03, initc-loss 1.3625e+04                    bc_loss 1.5429e+07, Test-Loss 8.2051e+01
# Epoch 29420, Training-Loss 1.3671e+03, Data-loss 3.8559e+02                  , pde-loss 4.7567e+03, initc-loss 1.3212e+04                    bc_loss 1.1506e+07, Test-Loss 3.8559e+02
# Epoch 29430, Training-Loss 2.5976e+02, Data-loss 2.5690e+02                  , pde-loss 4.4890e+03, initc-loss 1.1839e+04                    bc_loss 3.0610e+04, Test-Loss 2.5690e+02
# Epoch 29440, Training-Loss 1.7049e+03, Data-loss 1.9905e+02                  , pde-loss 4.4282e+03, initc-loss 1.4197e+04                    bc_loss 1.6143e+07, Test-Loss 1.9905e+02
# Epoch 29450, Training-Loss 3.0577e+02, Data-loss 1.8939e+02                  , pde-loss 4.0863e+03, initc-loss 1.2390e+04                    bc_loss 2.1676e+06, Test-Loss 1.8939e+02
# Epoch 29460, Training-Loss 1.2550e+02, Data-loss 9.3100e+01                  , pde-loss 5.2141e+03, initc-loss 1.2987e+04                    bc_loss 1.8837e+05, Test-Loss 9.3100e+01
# Epoch 29470, Training-Loss 9.6540e+01, Data-loss 5.3875e+01                  , pde-loss 5.3957e+03, initc-loss 1.3268e+04                    bc_loss 1.1119e+05, Test-Loss 5.3875e+01
# Epoch 29480, Training-Loss 1.3566e+02, Data-loss 6.7333e+01                  , pde-loss 4.7069e+03, initc-loss 1.3260e+04                    bc_loss 3.1010e+04, Test-Loss 6.7333e+01
# Epoch 29490, Training-Loss 1.5118e+02, Data-loss 1.4451e+02                  , pde-loss 5.7802e+03, initc-loss 1.3079e+04                    bc_loss 4.1512e+04, Test-Loss 1.4451e+02
# Epoch 29500, Training-Loss 2.7834e+01, Data-loss 1.4532e+02                  , pde-loss 5.8849e+03, initc-loss 1.3008e+04                    bc_loss 1.6499e+05, Test-Loss 1.4532e+02
# Epoch 29510, Training-Loss 1.1164e+03, Data-loss 6.1233e+01                  , pde-loss 5.0859e+03, initc-loss 1.2945e+04                    bc_loss 8.8044e+06, Test-Loss 6.1233e+01
# Epoch 29520, Training-Loss 3.2622e+02, Data-loss 2.4173e+01                  , pde-loss 4.5025e+03, initc-loss 1.3243e+04                    bc_loss 1.9606e+06, Test-Loss 2.4173e+01
# Epoch 29530, Training-Loss 7.1514e+02, Data-loss 3.8638e+01                  , pde-loss 5.2518e+03, initc-loss 1.3713e+04                    bc_loss 6.4978e+06, Test-Loss 3.8638e+01
# Epoch 29540, Training-Loss 4.9513e+02, Data-loss 7.5361e+01                  , pde-loss 5.3545e+03, initc-loss 1.3205e+04                    bc_loss 4.2074e+06, Test-Loss 7.5361e+01
# Epoch 29550, Training-Loss 2.5799e+02, Data-loss 8.9103e+01                  , pde-loss 5.5680e+03, initc-loss 1.2558e+04                    bc_loss 1.9277e+06, Test-Loss 8.9103e+01
# Epoch 29560, Training-Loss 8.8243e+02, Data-loss 1.0360e+02                  , pde-loss 5.4152e+03, initc-loss 1.2960e+04                    bc_loss 8.0207e+06, Test-Loss 1.0360e+02
# Epoch 29570, Training-Loss 1.4315e+02, Data-loss 7.8105e+01                  , pde-loss 4.9403e+03, initc-loss 1.2718e+04                    bc_loss 3.8369e+04, Test-Loss 7.8105e+01
# Epoch 29580, Training-Loss 1.2518e+03, Data-loss 6.9510e+01                  , pde-loss 4.3404e+03, initc-loss 1.3122e+04                    bc_loss 1.1506e+07, Test-Loss 6.9510e+01
# Epoch 29590, Training-Loss 4.5738e+02, Data-loss 1.6274e+02                  , pde-loss 6.4083e+03, initc-loss 1.2147e+04                    bc_loss 3.4537e+06, Test-Loss 1.6274e+02
# Epoch 29600, Training-Loss 3.6319e+02, Data-loss 6.3658e+01                  , pde-loss 6.2719e+03, initc-loss 1.1463e+04                    bc_loss 2.5799e+06, Test-Loss 6.3658e+01
# Epoch 29610, Training-Loss 1.0884e+03, Data-loss 1.2068e+02                  , pde-loss 5.3371e+03, initc-loss 1.2393e+04                    bc_loss 9.1769e+06, Test-Loss 1.2068e+02
# Epoch 29620, Training-Loss 7.4059e+01, Data-loss 2.0452e+02                  , pde-loss 4.6673e+03, initc-loss 1.3294e+04                    bc_loss 2.2809e+05, Test-Loss 2.0452e+02
# Epoch 29630, Training-Loss 1.8814e+03, Data-loss 2.1476e+02                  , pde-loss 4.8075e+03, initc-loss 1.5141e+04                    bc_loss 1.6516e+07, Test-Loss 2.1476e+02
# Epoch 29640, Training-Loss 5.9018e+02, Data-loss 1.0774e+02                  , pde-loss 3.6569e+03, initc-loss 1.3463e+04                    bc_loss 3.3757e+06, Test-Loss 1.0774e+02
# Epoch 29650, Training-Loss 7.0216e+02, Data-loss 2.7987e+02                  , pde-loss 3.2648e+03, initc-loss 1.3886e+04                    bc_loss 4.1429e+06, Test-Loss 2.7987e+02
# Epoch 29660, Training-Loss 8.1848e+02, Data-loss 1.4709e+02                  , pde-loss 3.7197e+03, initc-loss 1.2221e+04                    bc_loss 5.6867e+06, Test-Loss 1.4709e+02
# Epoch 29670, Training-Loss 7.6864e+02, Data-loss 1.7027e+02                  , pde-loss 5.7098e+03, initc-loss 1.3009e+04                    bc_loss 6.5820e+06, Test-Loss 1.7027e+02
# Epoch 29680, Training-Loss 4.4642e+02, Data-loss 7.3784e+01                  , pde-loss 4.5057e+03, initc-loss 1.2626e+04                    bc_loss 3.5281e+06, Test-Loss 7.3784e+01
# Epoch 29690, Training-Loss 1.0382e+02, Data-loss 4.4545e+01                  , pde-loss 5.8479e+03, initc-loss 1.4230e+04                    bc_loss 3.9837e+04, Test-Loss 4.4545e+01
# Epoch 29700, Training-Loss 1.2614e+03, Data-loss 2.5765e+02                  , pde-loss 6.4851e+03, initc-loss 1.4905e+04                    bc_loss 1.0268e+07, Test-Loss 2.5765e+02
# Epoch 29710, Training-Loss 1.3376e+02, Data-loss 1.4117e+02                  , pde-loss 4.9974e+03, initc-loss 1.2871e+04                    bc_loss 5.8463e+04, Test-Loss 1.4117e+02
# Epoch 29720, Training-Loss 2.1993e+02, Data-loss 3.5283e+01                  , pde-loss 5.2388e+03, initc-loss 1.2322e+04                    bc_loss 5.1035e+05, Test-Loss 3.5283e+01
# Epoch 29730, Training-Loss 2.3137e+02, Data-loss 1.2790e+02                  , pde-loss 4.8840e+03, initc-loss 1.2248e+04                    bc_loss 1.9826e+06, Test-Loss 1.2790e+02
# Epoch 29740, Training-Loss 1.7854e+02, Data-loss 1.2809e+02                  , pde-loss 5.0369e+03, initc-loss 1.3329e+04                    bc_loss 1.1396e+06, Test-Loss 1.2809e+02
# Epoch 29750, Training-Loss 4.8687e+02, Data-loss 1.2433e+02                  , pde-loss 4.0621e+03, initc-loss 1.3117e+04                    bc_loss 3.2735e+06, Test-Loss 1.2433e+02
# Epoch 29760, Training-Loss 4.6578e+02, Data-loss 1.7854e+02                  , pde-loss 4.9040e+03, initc-loss 1.2893e+04                    bc_loss 2.9230e+06, Test-Loss 1.7854e+02
# Epoch 29770, Training-Loss 5.6781e+02, Data-loss 9.4165e+01                  , pde-loss 5.5005e+03, initc-loss 1.2608e+04                    bc_loss 4.6193e+06, Test-Loss 9.4165e+01
# Epoch 29780, Training-Loss 4.9061e+02, Data-loss 5.2401e+01                  , pde-loss 4.7580e+03, initc-loss 1.2845e+04                    bc_loss 4.1697e+06, Test-Loss 5.2401e+01
# Epoch 29790, Training-Loss 1.2792e+03, Data-loss 1.4880e+02                  , pde-loss 5.5791e+03, initc-loss 1.3708e+04                    bc_loss 1.1370e+07, Test-Loss 1.4880e+02
# Epoch 29800, Training-Loss 4.3369e+02, Data-loss 3.1166e+01                  , pde-loss 5.8083e+03, initc-loss 1.3087e+04                    bc_loss 4.0689e+06, Test-Loss 3.1166e+01
# Epoch 29810, Training-Loss 1.2202e+03, Data-loss 1.2761e+02                  , pde-loss 5.5666e+03, initc-loss 1.4519e+04                    bc_loss 9.9346e+06, Test-Loss 1.2761e+02
# Epoch 29820, Training-Loss 6.2015e+02, Data-loss 1.5218e+02                  , pde-loss 6.0004e+03, initc-loss 1.3680e+04                    bc_loss 4.2345e+06, Test-Loss 1.5218e+02
# Epoch 29830, Training-Loss 5.0369e+02, Data-loss 1.2702e+02                  , pde-loss 4.5228e+03, initc-loss 1.3772e+04                    bc_loss 4.1138e+06, Test-Loss 1.2702e+02
# Epoch 29840, Training-Loss 1.6460e+03, Data-loss 2.0366e+02                  , pde-loss 4.1243e+03, initc-loss 1.4090e+04                    bc_loss 1.3249e+07, Test-Loss 2.0366e+02
# Epoch 29850, Training-Loss 4.4915e+02, Data-loss 1.7531e+02                  , pde-loss 4.2625e+03, initc-loss 1.3081e+04                    bc_loss 4.0019e+06, Test-Loss 1.7531e+02
# Epoch 29860, Training-Loss 1.3117e+03, Data-loss 1.9472e+02                  , pde-loss 6.1695e+03, initc-loss 1.3379e+04                    bc_loss 1.1092e+07, Test-Loss 1.9472e+02
# Epoch 29870, Training-Loss 7.7188e+02, Data-loss 2.5560e+02                  , pde-loss 3.9165e+03, initc-loss 1.2997e+04                    bc_loss 5.7854e+06, Test-Loss 2.5560e+02
# Epoch 29880, Training-Loss 5.1497e+02, Data-loss 2.1696e+02                  , pde-loss 5.1288e+03, initc-loss 1.3724e+04                    bc_loss 4.1769e+06, Test-Loss 2.1696e+02
# Epoch 29890, Training-Loss 1.4834e+03, Data-loss 3.1528e+02                  , pde-loss 4.1726e+03, initc-loss 1.2656e+04                    bc_loss 1.1485e+07, Test-Loss 3.1528e+02
# Epoch 29900, Training-Loss 4.9203e+02, Data-loss 2.6443e+02                  , pde-loss 4.9058e+03, initc-loss 1.3521e+04                    bc_loss 4.2103e+06, Test-Loss 2.6443e+02
# Epoch 29910, Training-Loss 7.6303e+02, Data-loss 9.1861e+01                  , pde-loss 4.5320e+03, initc-loss 1.2853e+04                    bc_loss 5.0378e+06, Test-Loss 9.1861e+01
# Epoch 29920, Training-Loss 1.0747e+03, Data-loss 1.6140e+02                  , pde-loss 4.7281e+03, initc-loss 1.3900e+04                    bc_loss 9.2772e+06, Test-Loss 1.6140e+02
# Epoch 29930, Training-Loss 6.8817e+02, Data-loss 1.5744e+02                  , pde-loss 4.7036e+03, initc-loss 1.3093e+04                    bc_loss 4.6643e+06, Test-Loss 1.5744e+02
# Epoch 29940, Training-Loss 7.1858e+02, Data-loss 1.7538e+02                  , pde-loss 4.4644e+03, initc-loss 1.3457e+04                    bc_loss 5.1846e+06, Test-Loss 1.7538e+02
# Epoch 29950, Training-Loss 7.0361e+02, Data-loss 1.2625e+02                  , pde-loss 5.3952e+03, initc-loss 1.2738e+04                    bc_loss 5.0224e+06, Test-Loss 1.2625e+02
# Epoch 29960, Training-Loss 5.5263e+02, Data-loss 1.1437e+02                  , pde-loss 5.6047e+03, initc-loss 1.2640e+04                    bc_loss 3.9722e+06, Test-Loss 1.1437e+02
# Epoch 29970, Training-Loss 6.4197e+02, Data-loss 2.5135e+02                  , pde-loss 5.5395e+03, initc-loss 1.2281e+04                    bc_loss 5.7440e+06, Test-Loss 2.5135e+02
# Epoch 29980, Training-Loss 6.6451e+02, Data-loss 1.4651e+02                  , pde-loss 4.8664e+03, initc-loss 1.2798e+04                    bc_loss 3.8961e+06, Test-Loss 1.4651e+02
# Epoch 29990, Training-Loss 1.0006e+03, Data-loss 1.0971e+02                  , pde-loss 4.6316e+03, initc-loss 1.3259e+04                    bc_loss 7.6697e+06, Test-Loss 1.0971e+02

# %% [markdown]
# ## Plots

# %%
temp_nn = model(inputs[:,0].unsqueeze(1), inputs[:,1].unsqueeze(1)).cpu().detach().numpy() # Get the predictions from the model

temp_nn = temp_nn.reshape(num_steps+1, num_points) # Reshape the predictions to a 2D array
time_ss= np.linspace(0, time_end, num_steps+1 )
plt.figure
plt.plot(time_ss, temp_nn[:, num_points//2], label='Predicted Temperature')
plt.plot(time_ss, temperature_history[:,num_points//2], label='Actual Temperature')
plt.xlabel('Time(s)')
plt.ylabel('Temperature (K)')
plt.yscale('log')
plt.title('Predicted vs Actual Temperature at x = 7.5mm')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(test_losses, label='test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data_losses, label='Data Loss')
plt.plot(pde_losses, label='Pde Loss')
plt.plot(ic_losses, label='IC Loss')
plt.plot(bc_losses, label='BC Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
space_coord, time_coord = np.meshgrid(np.arange(t_hist.shape[1]), np.arange(t_hist.shape[0]))

time_coord = time_coord * dt 
# Create a figure with two subplots

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))


# Plot the temperature history on the left subplot
im1 = ax1.pcolormesh(space_coord, time_coord, t_hist, cmap='viridis', shading='auto')
ax1.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax1.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax1.set_title('Temperature Variation Over Time(Analytical Model)',fontname='Times New Roman', fontsize=20)
ax1.contour(space_coord, time_coord, t_hist, colors='red', linewidths=1.0, alpha=0.9)

ax1.grid(True)
cbar = fig.colorbar(im1, ax=ax1)
cbar.ax.invert_yaxis()
cbar.set_label('Temperature (K)', rotation=270, labelpad=20, fontname='Times New Roman', fontsize=16)

im2 = ax2.pcolormesh(space_coord, time_coord, temp_nn, cmap='viridis', shading='auto')
ax2.set_xlabel('Space Coordinate', fontname='Times New Roman', fontsize=16)
ax2.set_ylabel('Time',fontname='Times New Roman', fontsize=16)
ax2.set_title('Temperature Variation Over Time(PINN model)',fontname='Times New Roman', fontsize=20)
ax2.contour(space_coord, time_coord, t_hist, colors='red', linewidths=1.0, alpha=0.9)

ax2.grid(True)
cbar = fig.colorbar(im2, ax=ax2)
cbar.ax.invert_yaxis()
cbar.set_label('Temperature (K)', rotation=270, labelpad=20, fontname='Times New Roman', fontsize=16)


plt.tight_layout()
plt.show()
