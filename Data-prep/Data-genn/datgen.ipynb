# %%
import numpy as np
import matplotlib.pyplot as plt
from Datagen import sim1d

# %%
dtaL0w = sim1d(rho_l=2460.0,rho_s=2710, k_l=104,k_s=96.2,cp_l=1245.3,cp_s=963,L_fusion=389e3,t_surr=298,temp_init=913,htc_l=10, \
               htc_r=10,length=15e-3)
# Out:
# (311, 50)
