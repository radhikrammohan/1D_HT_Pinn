# %%
import numpy as np
import matplotlib.pyplot as plt
from Datagen import sim1d

# %%
# dtaL0w = sim1d(rho_l=2460.0,rho_s=2710, k_l=104,k_s=96.2,cp_l=1245.3,cp_s=963.0,t_surr=298.0,L_fusion=389000.0,temp_init=913.0,htc_l=10.0, \
#                htc_r=15.0,length=15.0e-3,gen_graph=True,gen_data=False)

# dtahgh = sim1d(rho_l=2460.0,rho_s=2710, k_l=104,k_s=96.2,cp_l=1245.3,cp_s=963.0,t_surr=298.0,L_fusion=389000.0,temp_init=913.0,htc_l=20.0, \
#                htc_r=10.0,length=15.0e-3,gen_graph=True,gen_data=False)

# %%
L1 = sim1d(rho_l=2460.0, rho_s=2710.0, k_l=104.0, k_s= 96.2, cp_l=1245.3, cp_s=963.0, \
            t_surr=298.0, L_fusion=389000, temp_init=913.0, htc_l=12.0,htc_r= 12.0, length =15.0e-3,\
                gen_graph=True,gen_data=True)

L2 = sim1d(rho_l=2460.0, rho_s=2710.0, k_l=104.0, k_s= 96.2, cp_l=1245.3, cp_s=963.0, \
            t_surr=298.0, L_fusion=389000, temp_init=913.0, htc_l=10.0,htc_r= 15.0, length =15.0e-3,\
                gen_graph=True,gen_data=False)

L3 = sim1d(rho_l=2460.0, rho_s=2710.0, k_l=104.0, k_s= 96.2, cp_l=1245.3, cp_s=963.0, \
            t_surr=298.0, L_fusion=389000, temp_init=913.0, htc_l=15.0,htc_r= 10.0, length =15.0e-3,\
                gen_graph=True,gen_data=False)
# Out:
# (14025, 50)
# (13603, 50)
# (13603, 50)
