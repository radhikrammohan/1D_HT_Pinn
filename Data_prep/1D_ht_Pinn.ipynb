# %%
import deepxde as dde
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-7d8e3d28522d> in <module>
# ----> 1 import deepxde as dde
#
# ~\anaconda3\lib\site-packages\deepxde\__init__.py in <module>
#      18
#      19 # Should import backend before importing anything else
# ---> 20 from . import backend
#      21
#      22 from . import callbacks
#
# ~\anaconda3\lib\site-packages\deepxde\backend\__init__.py in <module>
#     128
#     129
# --> 130 load_backend(get_preferred_backend())
#
# ~\anaconda3\lib\site-packages\deepxde\backend\__init__.py in get_preferred_backend()
#     108             backend_name = config_dict.get("backend", "").lower()
#     109     if backend_name is not None:
# --> 110         verify_backend(backend_name)
#     111         return backend_name
#     112     # No backend selected
#
# ...
